# %%
from monai.utils import set_determinism, first
from monai.transforms import (
    EnsureChannelFirstD,
    Compose,
    LoadImageD,
    RandRotateD,
    RandZoomD,
    ScaleIntensityRanged,
)
import monai
from monai.data import DataLoader, Dataset, CacheDataset
from monai.config import print_config, USE_COMPILED
from monai.networks.nets import GlobalNet, LocalNet
from monai.networks.blocks import Warp
from monai.apps import MedNISTDataset
import torch.nn.functional as F

from glob import glob
import cv2
import torchmetrics

from torch.autograd import Variable

from scipy.spatial.distance import directed_hausdorff
import pandas as pd

import torch.nn as nn

import numpy as np
import torch
from torch.nn import MSELoss
import matplotlib.pyplot as plt
import os
import tempfile
from monai.losses import *
from monai.metrics import *
from piqa import SSIM


print_config()
set_determinism(42)
# Out:
# MONAI version: 1.1.0
# Numpy version: 1.23.5
# Pytorch version: 1.13.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: a2ec3752f54bfc3b40e7952234fbeb5452ed63e3
# MONAI __file__: /home/yaplab2/anaconda3/envs/phd/lib/python3.9/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.10
# Nibabel version: 5.0.0
# scikit-image version: 0.19.3
# Pillow version: 9.3.0
# Tensorboard version: 2.11.0
# gdown version: 4.6.0
# TorchVision version: 0.14.1
# tqdm version: 4.64.1
# lmdb version: 1.4.0
# psutil version: 5.9.4
# pandas version: 1.5.2
# einops version: 0.6.0
# transformers version: 4.21.3
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
dataDir = 'CAMUS_EStoED_A2C'

root_dir = 'data/'+dataDir+'/'
print(root_dir)

fileNames = "Vanilla_DLIR_" + dataDir

trainBatch = 8
testBatch = 8

img_size = 512

EP = 100

num_workers = 0
# Out:
# data/CAMUS_EStoED_A2C/

# %%
print('How many GPUs = ' + str(torch.cuda.device_count()))

#checking for device

device=torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
print(device)


if not torch.cuda.is_available():
  raise Exception("GPU not availalbe. CPU training will be too slow.")

print("device name", torch.cuda.get_device_name(0))
# Out:
# How many GPUs = 4
# cuda:2
# device name NVIDIA GeForce RTX 3090 Ti

# %%
class EchoDataset(Dataset):
    def __init__(self, images_path):

        self.images_path = images_path
        self.n_samples = len(images_path)

    def __getitem__(self, index):
        """ Reading image """
        image = cv2.imread(self.images_path[index], cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image,(img_size, img_size))
        image = image/(image.max()) ## (512, 512, 3)
#         print(image.max())
        image = np.expand_dims(image, axis=0)
        image = image.astype(np.float32)
        self.images_path[index]
        return image

    def __len__(self):
        return self.n_samples
    
class EchoDatasetMask(Dataset):
    def __init__(self, images_path):

        self.images_path = images_path
        self.n_samples = len(images_path)

    def __getitem__(self, index):
        """ Reading image """
        image = cv2.imread(self.images_path[index], cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image,(img_size, img_size), interpolation=cv2.INTER_NEAREST)
#         print(image.max())
#         image = image/(image.max()) ## (512, 512, 3)
        image = np.expand_dims(image, axis=0)
        image = image.astype(np.float32)
        self.images_path[index]
        return image

    def __len__(self):
        return self.n_samples

# %%
def get_batches(train_dir,
                batch_size,
                num_workers,
                pin_memory):
    
    train_data = EchoDataset(images_path=train_dir)

    train_loader = DataLoader(train_data,
                              batch_size=batch_size,
                              num_workers=num_workers,
                              pin_memory=pin_memory,
                              shuffle=False)

    return train_loader

def get_batches_mask(train_dir,
                batch_size,
                num_workers,
                pin_memory):
    
    train_data = EchoDatasetMask(images_path=train_dir)

    train_loader = DataLoader(train_data,
                              batch_size=batch_size,
                              num_workers=num_workers,
                              pin_memory=pin_memory,
                              shuffle=False)

    return train_loader


print(f'Train Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"/train/fixed_img/*.png")))}')
print(f'Train Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"/train/fixed_msk/*.png")))}')
print(f'Train Sample numbers (moving_img) = {len(sorted(glob(root_dir+"/train/moving_img/*.png")))}')
print(f'Train Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"/train/moving_msk/*.png")))}')
print()
print(f'Val Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"/val/fixed_img/*.png")))}')
print(f'Val Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"/val/fixed_msk/*.png")))}')
print(f'Val Sample numbers (moving_img) = {len(sorted(glob(root_dir+"/val/moving_img/*.png")))}')
print(f'Val Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"/val/moving_msk/*.png")))}')
print()


fixed_train_img = get_batches(train_dir = sorted(glob(root_dir+"/train/fixed_img/*")),
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_train_msk = get_batches_mask(train_dir = sorted(glob(root_dir+"/train/fixed_msk/*")),
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


moving_train_img = get_batches(train_dir = sorted(glob(root_dir+"/train/moving_img/*")),
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_train_msk = get_batches_mask(train_dir = sorted(glob(root_dir+"/train/moving_msk/*")),
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


print("Train IMG FIXED:", fixed_train_img)
print("Train MSK FIXED:", fixed_train_msk)
print("Train IMG Moving:", moving_train_img)
print("Train MSK Moving:", moving_train_msk)


fixed_val_img = get_batches(train_dir = sorted(glob(root_dir+"/val/fixed_img/*")),
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_val_msk = get_batches_mask(train_dir = sorted(glob(root_dir+"/val/fixed_msk/*")),
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


moving_val_img = get_batches(train_dir = sorted(glob(root_dir+"/val/moving_img/*")),
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_val_msk = get_batches_mask(train_dir = sorted(glob(root_dir+"/val/moving_msk/*")),
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


print("Val IMG FIXED:", fixed_val_img)
print("Val MSK FIXED:", fixed_val_msk)
print("Val IMG Moving:", moving_val_img)
print("Val MSK Moving:", moving_val_msk)
# Out:
# Train Sample numbers (fixed_img) = 450
# Train Sample numbers (fixed_msk) = 450
# Train Sample numbers (moving_img) = 450
# Train Sample numbers (moving_msk) = 450
#
# Val Sample numbers (fixed_img) = 50
# Val Sample numbers (fixed_msk) = 50
# Val Sample numbers (moving_img) = 50
# Val Sample numbers (moving_msk) = 50
#
# Train IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7f46545269d0>
# Train MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7f465579e7f0>
# Train IMG Moving: <monai.data.dataloader.DataLoader object at 0x7f465c21e190>
# Train MSK Moving: <monai.data.dataloader.DataLoader object at 0x7f46557ab0d0>
# Val IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7f4654496d90>
# Val MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7f46544967c0>
# Val IMG Moving: <monai.data.dataloader.DataLoader object at 0x7f4654496a30>
# Val MSK Moving: <monai.data.dataloader.DataLoader object at 0x7f46557428b0>

# %%
dataloaders = {
      'fixed_train_img': fixed_train_img,
      'fixed_train_msk': fixed_train_msk,
    'moving_train_img': moving_train_img,
    'moving_train_msk': moving_train_msk,
    'fixed_val_img': fixed_val_img,
    'fixed_val_msk': fixed_val_msk,
    'moving_val_img': moving_val_img,
    'moving_val_msk': moving_val_msk
    }

# %%
fixed_train_img_ = first(dataloaders["fixed_train_img"])[0][0]
fixed_train_msk_ = first(dataloaders["fixed_train_msk"])[0][0]
moving_train_img_ = first(dataloaders["moving_train_img"])[0][0]
moving_train_msk_ = first(dataloaders["moving_train_msk"])[0][0]

fixed_val_img_ = first(dataloaders["fixed_val_img"])[0][0]
fixed_val_msk_ = first(dataloaders["fixed_val_msk"])[0][0]
moving_val_img_ = first(dataloaders["moving_val_img"])[0][0]
moving_val_msk_ = first(dataloaders["moving_val_msk"])[0][0]


print(f"fixed_train_img_ shape: {fixed_train_img_.shape}")
print(f"fixed_train_msk_ shape: {fixed_train_msk_.shape}")
print(f"moving_train_img_ shape: {moving_train_img_.shape}")
print(f"moving_train_msk_ shape: {moving_train_msk_.shape}")

print(f"fixed_val_img_ shape: {fixed_val_img_.shape}")
print(f"fixed_val_msk_ shape: {fixed_val_msk_.shape}")
print(f"moving_val_img_ shape: {moving_val_img_.shape}")
print(f"moving_val_msk_ shape: {moving_val_msk_.shape}")


print(f"fixed_train_img_ Range: {fixed_train_img_.max()} {fixed_train_img_.min()}")
print(f"fixed_train_msk_ range: {fixed_train_msk_.max()} {fixed_train_msk_.min()} {np.unique(fixed_train_msk_)}")
print(f"moving_train_img_ Range: {moving_train_img_.max()} {moving_train_img_.min()}")
print(f"moving_train_msk_ range: {moving_train_msk_.max()} {moving_train_msk_.min()} {np.unique(moving_train_msk_)}")

print(f"fixed_val_img_ Range: {fixed_val_img_.max()} {fixed_val_img_.min()}")
print(f"fixed_val_msk_ range: {fixed_val_msk_.max()} {fixed_val_msk_.min()} {np.unique(fixed_val_msk_)}")
print(f"moving_val_img_ Range: {moving_val_img_.max()} {moving_val_img_.min()}")
print(f"moving_val_msk_ range: {moving_val_msk_.max()} {moving_val_msk_.min()} {np.unique(moving_val_msk_)}")


plt.figure("check", (10, 5))

plt.subplot(2, 4, 1)
plt.title("fixed_train_img_")
plt.imshow(fixed_train_img_, cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 2)
plt.title("fixed_train_msk_")
plt.imshow(fixed_train_msk_, cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 3)
plt.title("moving_train_img_")
plt.imshow(moving_train_img_, cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 4)
plt.title("moving_train_msk_")
plt.imshow(moving_train_msk_, cmap="gray")
plt.axis('off')


plt.subplot(2, 4, 5)
plt.title("fixed_val_img_")
plt.imshow(fixed_val_img_, cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 6)
plt.title("fixed_val_msk_")
plt.imshow(fixed_val_msk_, cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 7)
plt.title("moving_val_img_")
plt.imshow(moving_val_img_, cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 8)
plt.title("moving_val_msk_")
plt.imshow(moving_val_msk_, cmap="gray")
plt.axis('off')

plt.show()
# Out:
# fixed_train_img_ shape: torch.Size([512, 512])
# fixed_train_msk_ shape: torch.Size([512, 512])
# moving_train_img_ shape: torch.Size([512, 512])
# moving_train_msk_ shape: torch.Size([512, 512])
# fixed_val_img_ shape: torch.Size([512, 512])
# fixed_val_msk_ shape: torch.Size([512, 512])
# moving_val_img_ shape: torch.Size([512, 512])
# moving_val_msk_ shape: torch.Size([512, 512])
# fixed_train_img_ Range: 1.0 0.0
# fixed_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_train_img_ Range: 1.0 0.0
# moving_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# fixed_val_img_ Range: 1.0 0.0
# fixed_val_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_val_img_ Range: 1.0 0.0
# moving_val_msk_ range: 2.0 0.0 [0. 1. 2.]

# %%
mod = LocalNet(
    spatial_dims=2,
    in_channels=2,
    num_channel_initial=32,
    extract_levels=[5],
    out_activation=None,
    out_channels=2,
    out_kernel_initializer="zeros",
    concat_skip=False)

        

inputs = torch.randn((2, 2, img_size, img_size))

y = mod(inputs)
print(y.shape)

import torch, torchinfo
# from torchviz import make_dot, make_dot_from_trace
    
# make_dot(y, params=dict(mod.named_parameters()),
#          show_attrs=False,
#          show_saved=False).render(fileNames, format="png")

torchinfo.summary(mod, input_size=(2, 2, img_size, img_size), depth=100)
# Out:
# torch.Size([2, 2, 512, 512])
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# LocalNet                                                [2, 2, 512, 512]          --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-1                                  [2, 32, 512, 512]         --
# │    │    └─Convolution: 3-1                            [2, 32, 512, 512]         --
# │    │    │    └─Conv2d: 4-1                            [2, 32, 512, 512]         3,136
# │    │    │    └─ADN: 4-2                               [2, 32, 512, 512]         --
# │    │    │    │    └─BatchNorm2d: 5-1                  [2, 32, 512, 512]         64
# │    │    │    │    └─ReLU: 5-2                         [2, 32, 512, 512]         --
# │    │    └─RegistrationResidualConvBlock: 3-2          [2, 32, 512, 512]         --
# │    │    │    └─ModuleList: 4-6                        --                        (recursive)
# │    │    │    │    └─Convolution: 5-3                  [2, 32, 512, 512]         --
# │    │    │    │    │    └─Conv2d: 6-1                  [2, 32, 512, 512]         50,176
# │    │    │    └─ModuleList: 4-7                        --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-4                  [2, 32, 512, 512]         64
# │    │    │    └─ModuleList: 4-8                        --                        --
# │    │    │    │    └─ReLU: 5-5                         [2, 32, 512, 512]         --
# │    │    │    └─ModuleList: 4-6                        --                        (recursive)
# │    │    │    │    └─Convolution: 5-6                  [2, 32, 512, 512]         --
# │    │    │    │    │    └─Conv2d: 6-2                  [2, 32, 512, 512]         50,176
# │    │    │    └─ModuleList: 4-7                        --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-7                  [2, 32, 512, 512]         64
# │    │    │    └─ModuleList: 4-8                        --                        --
# │    │    │    │    └─ReLU: 5-8                         [2, 32, 512, 512]         --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-2                 [2, 32, 256, 256]         --
# │    │    └─MaxPool2d: 3-3                              [2, 32, 256, 256]         --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-3                                  [2, 64, 256, 256]         --
# │    │    └─Convolution: 3-4                            [2, 64, 256, 256]         --
# │    │    │    └─Conv2d: 4-9                            [2, 64, 256, 256]         18,432
# │    │    │    └─ADN: 4-10                              [2, 64, 256, 256]         --
# │    │    │    │    └─BatchNorm2d: 5-9                  [2, 64, 256, 256]         128
# │    │    │    │    └─ReLU: 5-10                        [2, 64, 256, 256]         --
# │    │    └─RegistrationResidualConvBlock: 3-5          [2, 64, 256, 256]         --
# │    │    │    └─ModuleList: 4-14                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-11                 [2, 64, 256, 256]         --
# │    │    │    │    │    └─Conv2d: 6-3                  [2, 64, 256, 256]         36,864
# │    │    │    └─ModuleList: 4-15                       --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-12                 [2, 64, 256, 256]         128
# │    │    │    └─ModuleList: 4-16                       --                        --
# │    │    │    │    └─ReLU: 5-13                        [2, 64, 256, 256]         --
# │    │    │    └─ModuleList: 4-14                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-14                 [2, 64, 256, 256]         --
# │    │    │    │    │    └─Conv2d: 6-4                  [2, 64, 256, 256]         36,864
# │    │    │    └─ModuleList: 4-15                       --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-15                 [2, 64, 256, 256]         128
# │    │    │    └─ModuleList: 4-16                       --                        --
# │    │    │    │    └─ReLU: 5-16                        [2, 64, 256, 256]         --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-4                 [2, 64, 128, 128]         --
# │    │    └─MaxPool2d: 3-6                              [2, 64, 128, 128]         --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-5                                  [2, 128, 128, 128]        --
# │    │    └─Convolution: 3-7                            [2, 128, 128, 128]        --
# │    │    │    └─Conv2d: 4-17                           [2, 128, 128, 128]        73,728
# │    │    │    └─ADN: 4-18                              [2, 128, 128, 128]        --
# │    │    │    │    └─BatchNorm2d: 5-17                 [2, 128, 128, 128]        256
# │    │    │    │    └─ReLU: 5-18                        [2, 128, 128, 128]        --
# │    │    └─RegistrationResidualConvBlock: 3-8          [2, 128, 128, 128]        --
# │    │    │    └─ModuleList: 4-22                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-19                 [2, 128, 128, 128]        --
# │    │    │    │    │    └─Conv2d: 6-5                  [2, 128, 128, 128]        147,456
# │    │    │    └─ModuleList: 4-23                       --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-20                 [2, 128, 128, 128]        256
# │    │    │    └─ModuleList: 4-24                       --                        --
# │    │    │    │    └─ReLU: 5-21                        [2, 128, 128, 128]        --
# │    │    │    └─ModuleList: 4-22                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-22                 [2, 128, 128, 128]        --
# │    │    │    │    │    └─Conv2d: 6-6                  [2, 128, 128, 128]        147,456
# │    │    │    └─ModuleList: 4-23                       --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-23                 [2, 128, 128, 128]        256
# │    │    │    └─ModuleList: 4-24                       --                        --
# │    │    │    │    └─ReLU: 5-24                        [2, 128, 128, 128]        --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-6                 [2, 128, 64, 64]          --
# │    │    └─MaxPool2d: 3-9                              [2, 128, 64, 64]          --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-7                                  [2, 256, 64, 64]          --
# │    │    └─Convolution: 3-10                           [2, 256, 64, 64]          --
# │    │    │    └─Conv2d: 4-25                           [2, 256, 64, 64]          294,912
# │    │    │    └─ADN: 4-26                              [2, 256, 64, 64]          --
# │    │    │    │    └─BatchNorm2d: 5-25                 [2, 256, 64, 64]          512
# │    │    │    │    └─ReLU: 5-26                        [2, 256, 64, 64]          --
# │    │    └─RegistrationResidualConvBlock: 3-11         [2, 256, 64, 64]          --
# │    │    │    └─ModuleList: 4-30                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-27                 [2, 256, 64, 64]          --
# │    │    │    │    │    └─Conv2d: 6-7                  [2, 256, 64, 64]          589,824
# │    │    │    └─ModuleList: 4-31                       --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-28                 [2, 256, 64, 64]          512
# │    │    │    └─ModuleList: 4-32                       --                        --
# │    │    │    │    └─ReLU: 5-29                        [2, 256, 64, 64]          --
# │    │    │    └─ModuleList: 4-30                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-30                 [2, 256, 64, 64]          --
# │    │    │    │    │    └─Conv2d: 6-8                  [2, 256, 64, 64]          589,824
# │    │    │    └─ModuleList: 4-31                       --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-31                 [2, 256, 64, 64]          512
# │    │    │    └─ModuleList: 4-32                       --                        --
# │    │    │    │    └─ReLU: 5-32                        [2, 256, 64, 64]          --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-8                 [2, 256, 32, 32]          --
# │    │    └─MaxPool2d: 3-12                             [2, 256, 32, 32]          --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-9                                  [2, 512, 32, 32]          --
# │    │    └─Convolution: 3-13                           [2, 512, 32, 32]          --
# │    │    │    └─Conv2d: 4-33                           [2, 512, 32, 32]          1,179,648
# │    │    │    └─ADN: 4-34                              [2, 512, 32, 32]          --
# │    │    │    │    └─BatchNorm2d: 5-33                 [2, 512, 32, 32]          1,024
# │    │    │    │    └─ReLU: 5-34                        [2, 512, 32, 32]          --
# │    │    └─RegistrationResidualConvBlock: 3-14         [2, 512, 32, 32]          --
# │    │    │    └─ModuleList: 4-38                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-35                 [2, 512, 32, 32]          --
# │    │    │    │    │    └─Conv2d: 6-9                  [2, 512, 32, 32]          2,359,296
# │    │    │    └─ModuleList: 4-39                       --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-36                 [2, 512, 32, 32]          1,024
# │    │    │    └─ModuleList: 4-40                       --                        --
# │    │    │    │    └─ReLU: 5-37                        [2, 512, 32, 32]          --
# │    │    │    └─ModuleList: 4-38                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-38                 [2, 512, 32, 32]          --
# │    │    │    │    │    └─Conv2d: 6-10                 [2, 512, 32, 32]          2,359,296
# │    │    │    └─ModuleList: 4-39                       --                        (recursive)
# │    │    │    │    └─BatchNorm2d: 5-39                 [2, 512, 32, 32]          1,024
# │    │    │    └─ModuleList: 4-40                       --                        --
# │    │    │    │    └─ReLU: 5-40                        [2, 512, 32, 32]          --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-10                [2, 512, 16, 16]          --
# │    │    └─MaxPool2d: 3-15                             [2, 512, 16, 16]          --
# ├─Convolution: 1-11                                     [2, 1024, 16, 16]         --
# │    └─Conv2d: 2-11                                     [2, 1024, 16, 16]         4,718,592
# │    └─ADN: 2-12                                        [2, 1024, 16, 16]         --
# │    │    └─BatchNorm2d: 3-16                           [2, 1024, 16, 16]         2,048
# │    │    └─ReLU: 3-17                                  [2, 1024, 16, 16]         --
# ├─RegistrationExtractionBlock: 1-12                     [2, 2, 512, 512]          --
# │    └─ModuleList: 2-13                                 --                        --
# │    │    └─Convolution: 3-18                           [2, 2, 16, 16]            --
# │    │    │    └─Conv2d: 4-41                           [2, 2, 16, 16]            18,432
# =========================================================================================================
# Total params: 12,682,112
# Trainable params: 12,682,112
# Non-trainable params: 0
# Total mult-adds (G): 105.00
# =========================================================================================================
# Input size (MB): 4.19
# Forward/backward pass size (MB): 1568.68
# Params size (MB): 50.73
# Estimated Total Size (MB): 1623.60
# =========================================================================================================

# %%
model = mod.to(device)


warp_layer = Warp().to(device)

# image_loss = MSELoss()

image_loss = GlobalMutualInformationLoss()

class SSIMLoss(SSIM):
    def forward(self, x, y):
        return 1. - super().forward(x, y)
    

label_SSIM = SSIMLoss(n_channels=1).to(device) # .cuda() if you need GPU support

label_loss = DiceLoss()

# label_loss = MultiScaleLoss(label_loss, scales=[0, 1, 2, 4, 8, 16])

regularization = BendingEnergyLoss()

optimizer = torch.optim.Adam(model.parameters(), 1e-5)

dice_metric = DiceMetric(include_background=True, reduction="mean", get_not_nans=False)


# dice_metric = compute_meandice(y_pred, y, include_background=True)

# %%
def make_one_hot(labels, C=2):
    '''
    Converts an integer label torch.autograd.Variable to a one-hot Variable.
    
    Parameters
    ----------
    labels : torch.autograd.Variable of torch.cuda.LongTensor
        N x 1 x H x W, where N is batch size. 
        Each value is an integer representing correct classification.
    C : integer. 
        number of classes in labels.
    
    Returns
    -------
    target : torch.autograd.Variable of torch.cuda.FloatTensor
        N x C x H x W, where C is class number. One-hot encoded.
    '''
    labels = labels.long()
    one_hot = torch.FloatTensor(labels.size(0), C, labels.size(2), labels.size(3)).zero_().to(device)
    target = one_hot.scatter_(1, labels.data, 1)
    
    target = Variable(target)
        
    return target

# %%
max_epochs = EP
epoch_loss_values = []
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
epoch_val_loss_values = []
metric_values = []
best_loss = 1e10
best_dsc = 0

for epoch in range(max_epochs):
    print("-" * 100)
    print(f"Epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss, step = 0, 0
    
    for fixed_train_img_, fixed_train_msk_, moving_train_img_, moving_train_msk_ in zip(fixed_train_img,
                                                                                    fixed_train_msk, moving_train_img,
                                                                                    moving_train_msk):    
        step += 1
        
        optimizer.zero_grad()

        fixed_train_img_ = fixed_train_img_.to(device)
        fixed_train_msk_ = fixed_train_msk_.to(device)
        moving_train_img_ = moving_train_img_.to(device)
        moving_train_msk_ = moving_train_msk_.to(device)
        
        ddf_train = model(torch.cat((moving_train_img_, fixed_train_img_), dim=1))
        
        pred_image_train = warp_layer(moving_train_img_, ddf_train)
        pred_mask_train = warp_layer(moving_train_msk_, ddf_train)

        imageLOSS = image_loss(pred_image_train, fixed_train_img_)
        
        loss = imageLOSS
    
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        
        dice_metric(y_pred = make_one_hot(pred_mask_train, C=3), y=make_one_hot(fixed_train_msk_, C=3))

    metric = dice_metric.aggregate().item()
    dice_metric.reset()
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"For epoch: {epoch + 1}, Average train loss: {epoch_loss:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train DSC: {metric:.5f} !\n")
    
    print("-" * 60)
    if (epoch + 1) % val_interval == 0 or epoch == 0:
        model.eval()
        val_loss = 0
        val_met = 0
        step = 0
        with torch.no_grad():
            for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk):  

                fixed_val_img_ = fixed_val_img_.to(device)
                fixed_val_msk_ = fixed_val_msk_.to(device)
                
                moving_val_img_ = moving_val_img_.to(device)
                moving_val_msk_ = moving_val_msk_.to(device)
                
                
                ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))
                
                pred_image_val = warp_layer(moving_val_img_, ddf_val)
                pred_mask_val = warp_layer(moving_val_msk_, ddf_val)


                imageLOSS = image_loss(pred_image_val, fixed_val_img_)

                loss = imageLOSS
                
                
    
                val_loss += loss.item()
                step += 1

                
                dice_metric(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))
                

            val_loss /= step
            epoch_val_loss_values.append(val_loss)
            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            dice_metric.reset()
            
            if metric > best_dsc:
                best_loss_epoch = epoch + 1
                torch.save(model.state_dict(),
                           os.path.join(root_dir, fileNames+'.pth'))
                print(f"Valid DSC improved from {best_dsc:2.4f} to {metric:2.4f}! Best model is saving as---> {fileNames+'.pth'}")
                best_dsc = metric
                
            print(
                f"\nCurrent mean dice: {metric:.4f} "
                f"\t and \t Current val loss: {val_loss:.4f}\n\n"
                f"Best val DSC: {best_dsc:.4f} "
                f"at epoch number of {best_loss_epoch}")
# Out:
# ----------------------------------------------------------------------------------------------------
# Epoch 1/100
# For epoch: 1, Average train loss: -0.84246 !
# For epoch: 1, Average train DSC: 0.78296 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.0000 to 0.7889! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.7889 	 and 	 Current val loss: -0.8515
#
# Best val DSC: 0.7889 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 2/100
# For epoch: 2, Average train loss: -0.84734 !
# For epoch: 2, Average train DSC: 0.78929 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.7889 to 0.8030! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8030 	 and 	 Current val loss: -0.8626
#
# Best val DSC: 0.8030 at epoch number of 2
# ----------------------------------------------------------------------------------------------------
# Epoch 3/100
# For epoch: 3, Average train loss: -0.85921 !
# For epoch: 3, Average train DSC: 0.80859 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8030 to 0.8278! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8278 	 and 	 Current val loss: -0.8742
#
# Best val DSC: 0.8278 at epoch number of 3
# ----------------------------------------------------------------------------------------------------
# Epoch 4/100
# For epoch: 4, Average train loss: -0.87184 !
# For epoch: 4, Average train DSC: 0.82961 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8278 to 0.8417! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8417 	 and 	 Current val loss: -0.8860
#
# Best val DSC: 0.8417 at epoch number of 4
# ----------------------------------------------------------------------------------------------------
# Epoch 5/100
# For epoch: 5, Average train loss: -0.88322 !
# For epoch: 5, Average train DSC: 0.84468 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8417 to 0.8533! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8533 	 and 	 Current val loss: -0.8959
#
# Best val DSC: 0.8533 at epoch number of 5
# ----------------------------------------------------------------------------------------------------
# Epoch 6/100
# For epoch: 6, Average train loss: -0.89226 !
# For epoch: 6, Average train DSC: 0.85476 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8533 to 0.8625! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8625 	 and 	 Current val loss: -0.9024
#
# Best val DSC: 0.8625 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 7/100
# For epoch: 7, Average train loss: -0.89906 !
# For epoch: 7, Average train DSC: 0.86191 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8617 	 and 	 Current val loss: -0.9077
#
# Best val DSC: 0.8625 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 8/100
# For epoch: 8, Average train loss: -0.90411 !
# For epoch: 8, Average train DSC: 0.86531 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8625 to 0.8679! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8679 	 and 	 Current val loss: -0.9122
#
# Best val DSC: 0.8679 at epoch number of 8
# ----------------------------------------------------------------------------------------------------
# Epoch 9/100
# For epoch: 9, Average train loss: -0.90852 !
# For epoch: 9, Average train DSC: 0.86768 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8679 to 0.8723! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8723 	 and 	 Current val loss: -0.9166
#
# Best val DSC: 0.8723 at epoch number of 9
# ----------------------------------------------------------------------------------------------------
# Epoch 10/100
# For epoch: 10, Average train loss: -0.91209 !
# For epoch: 10, Average train DSC: 0.86917 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8723 to 0.8748! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8748 	 and 	 Current val loss: -0.9203
#
# Best val DSC: 0.8748 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 11/100
# For epoch: 11, Average train loss: -0.91530 !
# For epoch: 11, Average train DSC: 0.87087 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8748 to 0.8775! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8775 	 and 	 Current val loss: -0.9216
#
# Best val DSC: 0.8775 at epoch number of 11
# ----------------------------------------------------------------------------------------------------
# Epoch 12/100
# For epoch: 12, Average train loss: -0.91805 !
# For epoch: 12, Average train DSC: 0.87167 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8765 	 and 	 Current val loss: -0.9234
#
# Best val DSC: 0.8775 at epoch number of 11
# ----------------------------------------------------------------------------------------------------
# Epoch 13/100
# For epoch: 13, Average train loss: -0.92074 !
# For epoch: 13, Average train DSC: 0.87170 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8734 	 and 	 Current val loss: -0.9242
#
# Best val DSC: 0.8775 at epoch number of 11
# ----------------------------------------------------------------------------------------------------
# Epoch 14/100
# For epoch: 14, Average train loss: -0.92305 !
# For epoch: 14, Average train DSC: 0.87202 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8755 	 and 	 Current val loss: -0.9257
#
# Best val DSC: 0.8775 at epoch number of 11
# ----------------------------------------------------------------------------------------------------
# Epoch 15/100
# For epoch: 15, Average train loss: -0.92487 !
# For epoch: 15, Average train DSC: 0.87296 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8761 	 and 	 Current val loss: -0.9251
#
# Best val DSC: 0.8775 at epoch number of 11
# ----------------------------------------------------------------------------------------------------
# Epoch 16/100
# For epoch: 16, Average train loss: -0.92630 !
# For epoch: 16, Average train DSC: 0.87334 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8771 	 and 	 Current val loss: -0.9280
#
# Best val DSC: 0.8775 at epoch number of 11
# ----------------------------------------------------------------------------------------------------
# Epoch 17/100
# For epoch: 17, Average train loss: -0.92851 !
# For epoch: 17, Average train DSC: 0.87366 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8753 	 and 	 Current val loss: -0.9273
#
# Best val DSC: 0.8775 at epoch number of 11
# ----------------------------------------------------------------------------------------------------
# Epoch 18/100
# For epoch: 18, Average train loss: -0.92998 !
# For epoch: 18, Average train DSC: 0.87390 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8775 to 0.8800! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8800 	 and 	 Current val loss: -0.9303
#
# Best val DSC: 0.8800 at epoch number of 18
# ----------------------------------------------------------------------------------------------------
# Epoch 19/100
# For epoch: 19, Average train loss: -0.93140 !
# For epoch: 19, Average train DSC: 0.87382 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8800 to 0.8809! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8809 	 and 	 Current val loss: -0.9320
#
# Best val DSC: 0.8809 at epoch number of 19
# ----------------------------------------------------------------------------------------------------
# Epoch 20/100
# For epoch: 20, Average train loss: -0.93234 !
# For epoch: 20, Average train DSC: 0.87402 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8761 	 and 	 Current val loss: -0.9270
#
# Best val DSC: 0.8809 at epoch number of 19
# ----------------------------------------------------------------------------------------------------
# Epoch 21/100
# For epoch: 21, Average train loss: -0.93409 !
# For epoch: 21, Average train DSC: 0.87399 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8724 	 and 	 Current val loss: -0.9284
#
# Best val DSC: 0.8809 at epoch number of 19
# ----------------------------------------------------------------------------------------------------
# Epoch 22/100
# For epoch: 22, Average train loss: -0.93564 !
# For epoch: 22, Average train DSC: 0.87445 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8765 	 and 	 Current val loss: -0.9314
#
# Best val DSC: 0.8809 at epoch number of 19
# ----------------------------------------------------------------------------------------------------
# Epoch 23/100
# For epoch: 23, Average train loss: -0.93539 !
# For epoch: 23, Average train DSC: 0.87479 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8800 	 and 	 Current val loss: -0.9333
#
# Best val DSC: 0.8809 at epoch number of 19
# ----------------------------------------------------------------------------------------------------
# Epoch 24/100
# For epoch: 24, Average train loss: -0.93780 !
# For epoch: 24, Average train DSC: 0.87468 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8779 	 and 	 Current val loss: -0.9329
#
# Best val DSC: 0.8809 at epoch number of 19
# ----------------------------------------------------------------------------------------------------
# Epoch 25/100
# For epoch: 25, Average train loss: -0.93923 !
# For epoch: 25, Average train DSC: 0.87402 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8770 	 and 	 Current val loss: -0.9329
#
# Best val DSC: 0.8809 at epoch number of 19
# ----------------------------------------------------------------------------------------------------
# Epoch 26/100
# For epoch: 26, Average train loss: -0.94063 !
# For epoch: 26, Average train DSC: 0.87455 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8797 	 and 	 Current val loss: -0.9347
#
# Best val DSC: 0.8809 at epoch number of 19
# ----------------------------------------------------------------------------------------------------
# Epoch 27/100
# For epoch: 27, Average train loss: -0.94146 !
# For epoch: 27, Average train DSC: 0.87399 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8769 	 and 	 Current val loss: -0.9326
#
# Best val DSC: 0.8809 at epoch number of 19
# ----------------------------------------------------------------------------------------------------
# Epoch 28/100
# For epoch: 28, Average train loss: -0.94282 !
# For epoch: 28, Average train DSC: 0.87474 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8809 to 0.8813! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8813 	 and 	 Current val loss: -0.9330
#
# Best val DSC: 0.8813 at epoch number of 28
# ----------------------------------------------------------------------------------------------------
# Epoch 29/100
# For epoch: 29, Average train loss: -0.94380 !
# For epoch: 29, Average train DSC: 0.87489 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8795 	 and 	 Current val loss: -0.9331
#
# Best val DSC: 0.8813 at epoch number of 28
# ----------------------------------------------------------------------------------------------------
# Epoch 30/100
# For epoch: 30, Average train loss: -0.94424 !
# For epoch: 30, Average train DSC: 0.87460 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8760 	 and 	 Current val loss: -0.9370
#
# Best val DSC: 0.8813 at epoch number of 28
# ----------------------------------------------------------------------------------------------------
# Epoch 31/100
# For epoch: 31, Average train loss: -0.94583 !
# For epoch: 31, Average train DSC: 0.87489 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8813 to 0.8817! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8817 	 and 	 Current val loss: -0.9383
#
# Best val DSC: 0.8817 at epoch number of 31
# ----------------------------------------------------------------------------------------------------
# Epoch 32/100
# For epoch: 32, Average train loss: -0.94742 !
# For epoch: 32, Average train DSC: 0.87505 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8792 	 and 	 Current val loss: -0.9385
#
# Best val DSC: 0.8817 at epoch number of 31
# ----------------------------------------------------------------------------------------------------
# Epoch 33/100
# For epoch: 33, Average train loss: -0.94785 !
# For epoch: 33, Average train DSC: 0.87498 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8791 	 and 	 Current val loss: -0.9391
#
# Best val DSC: 0.8817 at epoch number of 31
# ----------------------------------------------------------------------------------------------------
# Epoch 34/100
# For epoch: 34, Average train loss: -0.94825 !
# For epoch: 34, Average train DSC: 0.87478 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8798 	 and 	 Current val loss: -0.9387
#
# Best val DSC: 0.8817 at epoch number of 31
# ----------------------------------------------------------------------------------------------------
# Epoch 35/100
# For epoch: 35, Average train loss: -0.94901 !
# For epoch: 35, Average train DSC: 0.87450 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8815 	 and 	 Current val loss: -0.9384
#
# Best val DSC: 0.8817 at epoch number of 31
# ----------------------------------------------------------------------------------------------------
# Epoch 36/100
# For epoch: 36, Average train loss: -0.95008 !
# For epoch: 36, Average train DSC: 0.87430 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8817 to 0.8821! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8821 	 and 	 Current val loss: -0.9381
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 37/100
# For epoch: 37, Average train loss: -0.95083 !
# For epoch: 37, Average train DSC: 0.87414 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8794 	 and 	 Current val loss: -0.9372
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 38/100
# For epoch: 38, Average train loss: -0.95131 !
# For epoch: 38, Average train DSC: 0.87367 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8788 	 and 	 Current val loss: -0.9356
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 39/100
# For epoch: 39, Average train loss: -0.95228 !
# For epoch: 39, Average train DSC: 0.87297 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8763 	 and 	 Current val loss: -0.9384
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 40/100
# For epoch: 40, Average train loss: -0.95289 !
# For epoch: 40, Average train DSC: 0.87353 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8777 	 and 	 Current val loss: -0.9395
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 41/100
# For epoch: 41, Average train loss: -0.95334 !
# For epoch: 41, Average train DSC: 0.87420 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8798 	 and 	 Current val loss: -0.9420
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 42/100
# For epoch: 42, Average train loss: -0.95307 !
# For epoch: 42, Average train DSC: 0.87237 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8808 	 and 	 Current val loss: -0.9412
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 43/100
# For epoch: 43, Average train loss: -0.95349 !
# For epoch: 43, Average train DSC: 0.87336 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8795 	 and 	 Current val loss: -0.9419
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 44/100
# For epoch: 44, Average train loss: -0.95414 !
# For epoch: 44, Average train DSC: 0.87253 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8791 	 and 	 Current val loss: -0.9396
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 45/100
# For epoch: 45, Average train loss: -0.95407 !
# For epoch: 45, Average train DSC: 0.87300 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8716 	 and 	 Current val loss: -0.9381
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 46/100
# For epoch: 46, Average train loss: -0.95503 !
# For epoch: 46, Average train DSC: 0.87333 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8805 	 and 	 Current val loss: -0.9421
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 47/100
# For epoch: 47, Average train loss: -0.95658 !
# For epoch: 47, Average train DSC: 0.87303 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8795 	 and 	 Current val loss: -0.9406
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 48/100
# For epoch: 48, Average train loss: -0.95761 !
# For epoch: 48, Average train DSC: 0.87422 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8808 	 and 	 Current val loss: -0.9401
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 49/100
# For epoch: 49, Average train loss: -0.95852 !
# For epoch: 49, Average train DSC: 0.87314 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8807 	 and 	 Current val loss: -0.9392
#
# Best val DSC: 0.8821 at epoch number of 36
# ----------------------------------------------------------------------------------------------------
# Epoch 50/100
# For epoch: 50, Average train loss: -0.95916 !
# For epoch: 50, Average train DSC: 0.87296 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8821 to 0.8823! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8823 	 and 	 Current val loss: -0.9411
#
# Best val DSC: 0.8823 at epoch number of 50
# ----------------------------------------------------------------------------------------------------
# Epoch 51/100
# For epoch: 51, Average train loss: -0.96018 !
# For epoch: 51, Average train DSC: 0.87299 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8817 	 and 	 Current val loss: -0.9423
#
# Best val DSC: 0.8823 at epoch number of 50
# ----------------------------------------------------------------------------------------------------
# Epoch 52/100
# For epoch: 52, Average train loss: -0.96059 !
# For epoch: 52, Average train DSC: 0.87350 !
#
# ------------------------------------------------------------
# Valid DSC improved from 0.8823 to 0.8840! Best model is saving as---> Vanilla_DLIR_CAMUS_EStoED_A2C.pth
#
# Current mean dice: 0.8840 	 and 	 Current val loss: -0.9438
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 53/100
# For epoch: 53, Average train loss: -0.96128 !
# For epoch: 53, Average train DSC: 0.87378 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8828 	 and 	 Current val loss: -0.9438
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 54/100
# For epoch: 54, Average train loss: -0.96194 !
# For epoch: 54, Average train DSC: 0.87343 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8808 	 and 	 Current val loss: -0.9438
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 55/100
# For epoch: 55, Average train loss: -0.96207 !
# For epoch: 55, Average train DSC: 0.87456 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8790 	 and 	 Current val loss: -0.9455
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 56/100
# For epoch: 56, Average train loss: -0.96249 !
# For epoch: 56, Average train DSC: 0.87393 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8785 	 and 	 Current val loss: -0.9416
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 57/100
# For epoch: 57, Average train loss: -0.96309 !
# For epoch: 57, Average train DSC: 0.87370 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8796 	 and 	 Current val loss: -0.9411
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 58/100
# For epoch: 58, Average train loss: -0.96339 !
# For epoch: 58, Average train DSC: 0.87355 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8814 	 and 	 Current val loss: -0.9419
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 59/100
# For epoch: 59, Average train loss: -0.96404 !
# For epoch: 59, Average train DSC: 0.87376 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8779 	 and 	 Current val loss: -0.9420
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 60/100
# For epoch: 60, Average train loss: -0.96326 !
# For epoch: 60, Average train DSC: 0.87334 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8786 	 and 	 Current val loss: -0.9443
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 61/100
# For epoch: 61, Average train loss: -0.96375 !
# For epoch: 61, Average train DSC: 0.87348 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8758 	 and 	 Current val loss: -0.9417
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 62/100
# For epoch: 62, Average train loss: -0.96538 !
# For epoch: 62, Average train DSC: 0.87365 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8760 	 and 	 Current val loss: -0.9424
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 63/100
# For epoch: 63, Average train loss: -0.96630 !
# For epoch: 63, Average train DSC: 0.87367 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8809 	 and 	 Current val loss: -0.9440
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 64/100
# For epoch: 64, Average train loss: -0.96767 !
# For epoch: 64, Average train DSC: 0.87333 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8780 	 and 	 Current val loss: -0.9433
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 65/100
# For epoch: 65, Average train loss: -0.96788 !
# For epoch: 65, Average train DSC: 0.87366 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8809 	 and 	 Current val loss: -0.9432
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 66/100
# For epoch: 66, Average train loss: -0.96851 !
# For epoch: 66, Average train DSC: 0.87348 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8784 	 and 	 Current val loss: -0.9445
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 67/100
# For epoch: 67, Average train loss: -0.96827 !
# For epoch: 67, Average train DSC: 0.87252 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8789 	 and 	 Current val loss: -0.9431
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 68/100
# For epoch: 68, Average train loss: -0.96734 !
# For epoch: 68, Average train DSC: 0.87201 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8769 	 and 	 Current val loss: -0.9430
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 69/100
# For epoch: 69, Average train loss: -0.96592 !
# For epoch: 69, Average train DSC: 0.87302 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8790 	 and 	 Current val loss: -0.9452
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 70/100
# For epoch: 70, Average train loss: -0.96792 !
# For epoch: 70, Average train DSC: 0.87309 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8768 	 and 	 Current val loss: -0.9448
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 71/100
# For epoch: 71, Average train loss: -0.96921 !
# For epoch: 71, Average train DSC: 0.87294 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8783 	 and 	 Current val loss: -0.9447
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 72/100
# For epoch: 72, Average train loss: -0.96962 !
# For epoch: 72, Average train DSC: 0.87248 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8784 	 and 	 Current val loss: -0.9453
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 73/100
# For epoch: 73, Average train loss: -0.97125 !
# For epoch: 73, Average train DSC: 0.87355 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8769 	 and 	 Current val loss: -0.9444
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 74/100
# For epoch: 74, Average train loss: -0.97227 !
# For epoch: 74, Average train DSC: 0.87302 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8767 	 and 	 Current val loss: -0.9437
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 75/100
# For epoch: 75, Average train loss: -0.97282 !
# For epoch: 75, Average train DSC: 0.87289 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8722 	 and 	 Current val loss: -0.9403
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 76/100
# For epoch: 76, Average train loss: -0.97311 !
# For epoch: 76, Average train DSC: 0.87246 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8670 	 and 	 Current val loss: -0.9386
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 77/100
# For epoch: 77, Average train loss: -0.97293 !
# For epoch: 77, Average train DSC: 0.87219 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8659 	 and 	 Current val loss: -0.9393
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 78/100
# For epoch: 78, Average train loss: -0.97220 !
# For epoch: 78, Average train DSC: 0.87205 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8675 	 and 	 Current val loss: -0.9422
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 79/100
# For epoch: 79, Average train loss: -0.97144 !
# For epoch: 79, Average train DSC: 0.87120 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8715 	 and 	 Current val loss: -0.9436
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 80/100
# For epoch: 80, Average train loss: -0.97131 !
# For epoch: 80, Average train DSC: 0.87169 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8756 	 and 	 Current val loss: -0.9455
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 81/100
# For epoch: 81, Average train loss: -0.97117 !
# For epoch: 81, Average train DSC: 0.87159 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8756 	 and 	 Current val loss: -0.9459
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 82/100
# For epoch: 82, Average train loss: -0.97215 !
# For epoch: 82, Average train DSC: 0.87218 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8752 	 and 	 Current val loss: -0.9450
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 83/100
# For epoch: 83, Average train loss: -0.97398 !
# For epoch: 83, Average train DSC: 0.87219 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8732 	 and 	 Current val loss: -0.9451
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 84/100
# For epoch: 84, Average train loss: -0.97428 !
# For epoch: 84, Average train DSC: 0.87273 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8745 	 and 	 Current val loss: -0.9436
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 85/100
# For epoch: 85, Average train loss: -0.97482 !
# For epoch: 85, Average train DSC: 0.87212 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8766 	 and 	 Current val loss: -0.9441
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 86/100
# For epoch: 86, Average train loss: -0.97494 !
# For epoch: 86, Average train DSC: 0.87199 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8772 	 and 	 Current val loss: -0.9456
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 87/100
# For epoch: 87, Average train loss: -0.97546 !
# For epoch: 87, Average train DSC: 0.87217 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8779 	 and 	 Current val loss: -0.9462
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 88/100
# For epoch: 88, Average train loss: -0.97621 !
# For epoch: 88, Average train DSC: 0.87274 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8760 	 and 	 Current val loss: -0.9456
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 89/100
# For epoch: 89, Average train loss: -0.97713 !
# For epoch: 89, Average train DSC: 0.87202 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8756 	 and 	 Current val loss: -0.9465
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 90/100
# For epoch: 90, Average train loss: -0.97680 !
# For epoch: 90, Average train DSC: 0.87229 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8735 	 and 	 Current val loss: -0.9470
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 91/100
# For epoch: 91, Average train loss: -0.97734 !
# For epoch: 91, Average train DSC: 0.87247 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8721 	 and 	 Current val loss: -0.9473
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 92/100
# For epoch: 92, Average train loss: -0.97681 !
# For epoch: 92, Average train DSC: 0.87180 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8706 	 and 	 Current val loss: -0.9483
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 93/100
# For epoch: 93, Average train loss: -0.97835 !
# For epoch: 93, Average train DSC: 0.87276 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8720 	 and 	 Current val loss: -0.9473
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 94/100
# For epoch: 94, Average train loss: -0.97849 !
# For epoch: 94, Average train DSC: 0.87149 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8726 	 and 	 Current val loss: -0.9454
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 95/100
# For epoch: 95, Average train loss: -0.97913 !
# For epoch: 95, Average train DSC: 0.87196 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8749 	 and 	 Current val loss: -0.9447
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 96/100
# For epoch: 96, Average train loss: -0.97980 !
# For epoch: 96, Average train DSC: 0.87251 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8747 	 and 	 Current val loss: -0.9455
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 97/100
# For epoch: 97, Average train loss: -0.97979 !
# For epoch: 97, Average train DSC: 0.87251 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8765 	 and 	 Current val loss: -0.9474
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 98/100
# For epoch: 98, Average train loss: -0.98044 !
# For epoch: 98, Average train DSC: 0.87188 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8762 	 and 	 Current val loss: -0.9489
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 99/100
# For epoch: 99, Average train loss: -0.98153 !
# For epoch: 99, Average train DSC: 0.87259 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8757 	 and 	 Current val loss: -0.9496
#
# Best val DSC: 0.8840 at epoch number of 52
# ----------------------------------------------------------------------------------------------------
# Epoch 100/100
# For epoch: 100, Average train loss: -0.98175 !
# For epoch: 100, Average train DSC: 0.87198 !
#
# ------------------------------------------------------------
#
# Current mean dice: 0.8763 	 and 	 Current val loss: -0.9500
#
# Best val DSC: 0.8840 at epoch number of 52

# %%
# %matplotlib inline
plt.figure("train", (20, 4))
plt.subplot(1, 2, 1)
plt.plot(epoch_loss_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.plot(epoch_val_loss_values, label = 'val', color='b', lw=2, linestyle='-', marker = 'x')
plt.legend(fontsize=20, loc='upper right', ncol=1)
plt.xticks(range(0, max_epochs , 1))
plt.ylabel('Losses', fontsize=20)
plt.xlabel('Epochs', fontsize=20)

plt.subplot(1, 2, 2)
plt.plot(metric_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.ylabel('DSC', fontsize=20)
plt.xlabel('Epochs', fontsize=20)
# Out:
# Text(0.5, 0, 'Epochs')

# %%
def hausdorff (mask1, mask2):
    mask1_class_LV = mask1.copy()
    mask1_class_Myo = mask1.copy()
    
    mask1_class_LV[mask1_class_LV==1] = 0
    mask1_class_Myo[mask1_class_Myo==2] = 0
    
    mask2_class_LV = mask2.copy()
    mask2_class_Myo = mask2.copy()
    
    mask2_class_LV[mask2_class_LV==1] = 0
    mask2_class_Myo[mask2_class_Myo==2] = 0
    
    hausdorff_Myo = (directed_hausdorff(mask1_class_Myo, mask2_class_Myo)[0]+directed_hausdorff(mask2_class_Myo, mask1_class_Myo)[0])/2

    hausdorff_LV = (directed_hausdorff(mask1_class_LV, mask2_class_LV)[0]+directed_hausdorff(mask2_class_LV, mask1_class_LV)[0])/2
    
    return [hausdorff_Myo, hausdorff_LV]

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()

metric = monai.metrics.MSEMetric()

before_MSEMetric = []
after_MSEMetric = []

before_compute_meandice = []
after_compute_meandice = []

before_compute_hausdorff_distance = []
after_compute_hausdorff_distance = []
                                                                         

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    before_MSEMetric.extend(metric(moving_val_img_,fixed_val_img_).detach().cpu().numpy())
    
    after_MSEMetric.extend(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())
    
#     print(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())

    before_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy())
    after_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy()) 
    
    
    before_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy())
    after_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy()) 
    
    
#     break

print(np.array(before_MSEMetric).shape)
print(np.array(after_MSEMetric).shape)

print(np.array(before_compute_meandice).shape)
print(np.array(after_compute_meandice).shape)

print()

print(f'MSEMetric W/O registration {np.mean(np.array(before_MSEMetric))}')
print(f'MSEMetric W/ registration = {np.mean(np.array(after_MSEMetric))}')

print(f'Mean dice W/O registration = {np.mean(np.array(before_compute_meandice), axis=0)}')
print(f'Mean dice W/ registration = {np.mean(np.array(after_compute_meandice), axis=0)}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.array(before_compute_hausdorff_distance), axis=0)}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.array(after_compute_hausdorff_distance), axis=0)}')

print()

print('----------------For Report Metric +/- Std-----------------------')
print(f'Mean dice W/O registration = {np.mean(np.mean(np.array(before_compute_meandice), axis=0))} + {np.mean(np.std(np.array(before_compute_meandice), axis=0))}')
print(f'Mean dice W/ registration = {np.mean(np.mean(np.array(after_compute_meandice), axis=0))} + {np.mean(np.std(np.array(after_compute_meandice), axis=0))}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.mean(np.array(before_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(before_compute_hausdorff_distance), axis=0))}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.mean(np.array(after_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(after_compute_hausdorff_distance), axis=0))}')

df = ({
     'before_compute_hausdorff_distance':np.mean(np.array(before_compute_hausdorff_distance), axis=1),
     'after_compute_hausdorff_distance'   : np.mean(np.array(after_compute_hausdorff_distance), axis=1),
     'before_compute_meandice':np.mean(np.array(before_compute_meandice), axis=1),
     'after_compute_meandice':np.mean(np.array(after_compute_meandice), axis=1),
     'before_MSEMetric': np.mean(np.array(before_MSEMetric), axis=1),
     'after_MSEMetric':np.mean(np.array(after_MSEMetric), axis=1)
})

pd.DataFrame(df).to_csv(fileNames+'.csv')
# Out:
# (50, 1)
# (50, 1)
# (50, 3)
# (50, 3)
#
# MSEMetric W/O registration 0.010285538621246815
# MSEMetric W/ registration = 0.005717859137803316
# Mean dice W/O registration = [0.9703092  0.67663497 0.7601223 ]
# Mean dice W/ registration = [0.9791628 0.7773114 0.8954782]
# Hausdorff_distance W/O registration = [30.1291024  32.37624519]
# Hausdorff_distance W/ registration = [51.1465205  41.81666991]
#
# ----------------For Report Metric +/- Std-----------------------
# Mean dice W/O registration = 0.8023554682731628 + 0.054866645485162735
# Mean dice W/ registration = 0.8839841485023499 + 0.03214448317885399
# Hausdorff_distance W/O registration = 31.252673790909952 + 8.652237773863073
# Hausdorff_distance W/ registration = 46.48159520462136 + 16.466816337578884

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()
                                          

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    break

fixed_val_img_ = fixed_val_img_.detach().cpu().numpy()[:, 0]
fixed_val_msk_ = fixed_val_msk_.detach().cpu().numpy()[:, 0]

moving_val_img_ = moving_val_img_.detach().cpu().numpy()[:, 0]
moving_val_msk_ = moving_val_msk_.detach().cpu().numpy()[:, 0]

pred_image_val = pred_image_val.detach().cpu().numpy()[:, 0]
pred_mask_val = pred_mask_val.detach().cpu().numpy()[:, 0]

# %%
def colored (pred_img, true_img): 
    bitwise_and = cv2.bitwise_and(pred_img, true_img)
    
    TP = np.stack((np.zeros_like(bitwise_and), bitwise_and, np.zeros_like(bitwise_and)), axis=-1)
    
    FN = np.stack((true_img-bitwise_and,
                   true_img-bitwise_and,
                   np.zeros_like(true_img-bitwise_and)), axis=-1)
    
    FP = np.stack((pred_img-bitwise_and,
                   pred_img-bitwise_and,
                  np.zeros_like(pred_img-bitwise_and)), axis=-1)
    
    return (255*(TP+FN+FP)).astype('uint8')

# %%
# %matplotlib inline
batch_size = testBatch
plt.subplots(batch_size, 7, figsize=(12, 15))

for b in range(batch_size):
    # moving image
    plt.subplot(batch_size, 7, b * 7 + 1)
    plt.axis('off')
    plt.title("moving img")
    plt.imshow(moving_val_img_[b], cmap="gray")
    
    # moving label
    plt.subplot(batch_size, 7, b * 7 + 2)
    plt.axis('off')
    plt.title("moving lab")
    plt.imshow(moving_val_msk_[b], cmap="gray")
    
    
    # fixed image
    plt.subplot(batch_size, 7, b * 7 + 3)
    plt.axis('off')
    plt.title("fixed img")
    plt.imshow(fixed_val_img_[b], cmap="gray")
    
    # fixed label
    plt.subplot(batch_size, 7, b * 7 + 4)
    plt.axis('off')
    plt.title("fixed lab")
    plt.imshow(fixed_val_msk_[b], cmap="gray")
    
    
    # warped moving
    plt.subplot(batch_size, 7, b * 7 + 5)
    plt.axis('off')
    plt.title("Pred Img")
    plt.imshow(pred_image_val[b], cmap="gray")


    # warped moving
    plt.subplot(batch_size, 7, b * 7 + 6)
    plt.axis('off')
    plt.title("Before Reg")
    plt.imshow(colored(moving_val_msk_[b], fixed_val_msk_[b]))
    
    
    # warped moving
    plt.subplot(batch_size, 7, b * 7 + 7)
    plt.axis('off')
    plt.title("After Reg")
    plt.imshow(colored(pred_mask_val[b], fixed_val_msk_[b]))
    
plt.axis('off')
plt.show()
