# %%
# Import and Install Libraries

from monai.utils import set_determinism, first
from monai.transforms import (
    EnsureChannelFirstD,
    Compose,
    LoadImageD,
    RandRotateD,
    RandZoomD,
    ScaleIntensityRanged,
)
import monai
from monai.data import DataLoader, Dataset, CacheDataset
from monai.config import print_config, USE_COMPILED
from monai.networks.nets import GlobalNet, LocalNet, RegUNet
from monai.networks.blocks import Warp
from monai.apps import MedNISTDataset
import torch.nn.functional as F

from glob import glob
import cv2
import torchmetrics

from torch.autograd import Variable

from scipy.spatial.distance import directed_hausdorff
from scipy.ndimage import zoom
import pandas as pd

import torch.nn as nn

import numpy as np
import torch
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
from matplotlib.animation import FuncAnimation
import os
import tempfile
from monai.losses import *
from monai.metrics import *
from piqa import SSIM

import nibabel as nib

import csv

print_config()
set_determinism(40)
# Out:
# MONAI version: 1.0.1
# Numpy version: 1.22.3
# Pytorch version: 1.13.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 8271a193229fe4437026185e218d5b06f7c8ce69
# MONAI __file__: /home/mkh/anaconda3/envs/phd/lib/python3.9/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.10
# Nibabel version: 5.0.1
# scikit-image version: 0.19.3
# Pillow version: 9.0.1
# Tensorboard version: 2.12.0
# gdown version: 4.6.4
# TorchVision version: 0.14.1
# tqdm version: 4.64.1
# lmdb version: 1.4.0
# psutil version: 5.9.4
# pandas version: 1.5.3
# einops version: 0.6.0
# transformers version: 4.21.3
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
# Directories and some Parameters

dataDir = '3D_Updated'

root_dir = '/home/mkh/MKH/KSA/Dataset/'+dataDir+'/'
print(root_dir)

trainBatch = 1
testBatch = 1

img_size = 256
slice_size = 32

previousWeight = 128

preTrained = 0

EP = 100

num_workers = 0

ExpName = "AC_DLIR_ESED"

fileNames = ExpName + '_' + dataDir + '_' +str(img_size) + '_'+str(slice_size) + '_'

# print(fileNames)
# Out:
# /home/mkh/MKH/KSA/Dataset/3D_Updated/

# %%
# GPU information
print('How many GPUs = ' + str(torch.cuda.device_count()))

#checking for device

device=torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
print(device)

if not torch.cuda.is_available():
  raise Exception("GPU not availalbe. CPU training will be too slow.")

print("device name", torch.cuda.get_device_name(0))
# Out:
# How many GPUs = 4
# cuda:3
# device name NVIDIA GeForce RTX 3090 Ti

# %%
# # Make fixed-moving pairs in csv
# # root_dir = '/home/mkh/MKH/KSA/Dataset/'+dataDir+'/'
# splits = ['train', 'val']
# for split in splits:
#     fixed_names = []
#     moving_names = []
#     split_path = os.path.join(root_dir, split)
#     for folders in sorted(os.listdir(split_path)):
#         split_path_folders = os.path.join(split_path, folders)
#         if 'fixed_img' in folders:
#             for fixed_imgs in sorted(os.listdir(split_path_folders)):
#                 split_path_folders_fixed_imgs = os.path.join(split_path_folders, fixed_imgs)
#                 fixed_pt = fixed_imgs.split('_')[0]
#                 for mov_folders in sorted(os.listdir(split_path)):
#                     if 'moving_img' in mov_folders:
#                         mov_split_path_folders = os.path.join(split_path, mov_folders)
#                         for moving_imgs in sorted(os.listdir(mov_split_path_folders)):
#                             moving_pt = moving_imgs.split('_')[0]
#                             if(fixed_pt==moving_pt):
#                                 fixed_names.append(fixed_imgs)
#                                 moving_names.append(moving_imgs)
#     data = {'Fixed':fixed_names, 'Moving':moving_names}
#     dataframe = pd.DataFrame(data=data, index=None)
#     csv_path = root_dir + split + '.csv'
#     dataframe.to_csv(csv_path,index=False)

# %%
class EchoDataset3D(Dataset):
    def __init__(self, images_path, flagMask):

        self.images_path = images_path
        self.n_samples = len(images_path)
        self.flagMask = flagMask

    def __getitem__(self, index):
        """ Reading Nifti Files """
        
        # image = cv2.imread(self.images_path[index], cv2.IMREAD_GRAYSCALE)
        img_3d = nib.load(self.images_path[index])
        image = img_3d.get_fdata()

        if self.flagMask==0:
            image = zoom(image, (img_size / image.shape[0], img_size / image.shape[1], slice_size / image.shape[2]))
            # image = cv2.resize(image,(img_size, img_size))
            image = (image-image.min())/(image.max()-image.min())
        else:
            image[image==127]=1
            image[image==255]=2
            image = zoom(image, (img_size / image.shape[0], img_size / image.shape[1], slice_size / image.shape[2]), order=0)
            # image = cv2.resize(image,(img_size, img_size), interpolation=cv2.INTER_NEAREST)
            # image = image/(image.max()) ## (512, 512, 3)
            # print(image.max())
        image = np.expand_dims(image, axis=0)
        image = image.astype(np.float32)
        self.images_path[index]
        return image

    def __len__(self):
        return self.n_samples

# %%
def get_batches(split_dir,
                split,
                fixOrMov,
                flagMask,
                batch_size,
                num_workers,
                pin_memory):
    
    csv_path = pd.read_csv(root_dir + split + "_esed_v2.csv")
    all_path  = split_dir + csv_path[fixOrMov]
    
    split_data = EchoDataset3D(images_path=all_path, flagMask=flagMask)

    split_loader = DataLoader(split_data,
                              batch_size=batch_size,
                              num_workers=num_workers,
                              pin_memory=pin_memory,
                              shuffle=False)

    return split_loader

# %%
fixed_train_img = get_batches(split_dir = sorted(glob(root_dir+"train/img/")),
                                        split = 'train',
                                        fixOrMov = 'Fixed',
                                        flagMask = 0,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_train_msk = get_batches(split_dir = sorted(glob(root_dir+"train/msk/")),
                                        split = 'train',
                                        fixOrMov = 'Fixed',
                                        flagMask = 1,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_train_img = get_batches(split_dir = sorted(glob(root_dir+"train/img/")),
                                        split = 'train',
                                        fixOrMov = 'Moving',
                                        flagMask = 0,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_train_msk = get_batches(split_dir = sorted(glob(root_dir+"train/msk/")),
                                        split = 'train',
                                        fixOrMov = 'Moving',
                                        flagMask = 1,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

print("Train IMG FIXED:", fixed_train_img)
print("Train MSK FIXED:", fixed_train_msk)
print("Train IMG Moving:", moving_train_img)
print("Train MSK Moving:", moving_train_msk)

fixed_val_img = get_batches(split_dir = sorted(glob(root_dir+"val/img/")),
                                        split = 'val',
                                        fixOrMov = 'Fixed',
                                        flagMask = 0,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_val_msk = get_batches(split_dir = sorted(glob(root_dir+"val/msk/")),
                                        split = 'val',
                                        fixOrMov = 'Fixed',
                                        flagMask = 1,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


moving_val_img = get_batches(split_dir = sorted(glob(root_dir+"val/img/")),
                                        split = 'val',
                                        fixOrMov = 'Moving',
                                        flagMask = 0,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_val_msk = get_batches(split_dir = sorted(glob(root_dir+"val/msk/")),
                                        split = 'val',
                                        fixOrMov = 'Moving',
                                        flagMask = 1,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


print("Val IMG FIXED:", fixed_val_img)
print("Val MSK FIXED:", fixed_val_msk)
print("Val IMG Moving:", moving_val_img)
print("Val MSK Moving:", moving_val_msk)
# Out:
# Train IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7f99e051d670>
# Train MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7f99e051fc40>
# Train IMG Moving: <monai.data.dataloader.DataLoader object at 0x7f99e051faf0>
# Train MSK Moving: <monai.data.dataloader.DataLoader object at 0x7f99df8ee880>
# Val IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7f99e053f7f0>
# Val MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7f99e053f7c0>
# Val IMG Moving: <monai.data.dataloader.DataLoader object at 0x7f99e053f880>
# Val MSK Moving: <monai.data.dataloader.DataLoader object at 0x7f99e045dc70>

# %%
# Change here
train_csv = pd.read_csv(root_dir + 'train_esed_v2.csv')
val_csv =  pd.read_csv(root_dir + 'val_esed_v2.csv')

print(f'Train Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"train/img/")) + train_csv["Fixed"] )}')
print(f'Train Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"train/msk/")) + train_csv["Fixed"] )}')
print(f'Train Sample numbers (moving_img) = {len(sorted(glob(root_dir+"train/img/")) + train_csv["Moving"] )}')
print(f'Train Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"/train/msk/")) + train_csv["Fixed"] )}')
print()
print(f'Val Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"val/img/")) + val_csv["Fixed"] )}')
print(f'Val Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"val/msk/")) + val_csv["Fixed"] )}')
print(f'Val Sample numbers (moving_img) = {len(sorted(glob(root_dir+"val/img/")) + val_csv["Moving"] )}')
print(f'Val Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"val/msk/")) + val_csv["Moving"] )}')
print()
# Out:
# Train Sample numbers (fixed_img) = 50
# Train Sample numbers (fixed_msk) = 50
# Train Sample numbers (moving_img) = 50
# Train Sample numbers (moving_msk) = 50
#
# Val Sample numbers (fixed_img) = 20
# Val Sample numbers (fixed_msk) = 20
# Val Sample numbers (moving_img) = 20
# Val Sample numbers (moving_msk) = 20

# %%
dataloaders = {
    'fixed_train_img': fixed_train_img,
    'fixed_train_msk': fixed_train_msk,
    'moving_train_img': moving_train_img,
    'moving_train_msk': moving_train_msk,
    'fixed_val_img': fixed_val_img,
    'fixed_val_msk': fixed_val_msk,
    'moving_val_img': moving_val_img,
    'moving_val_msk': moving_val_msk
    }

# %%
fixed_train_img_ = first(dataloaders["fixed_train_img"])[0][0]
fixed_train_msk_ = first(dataloaders["fixed_train_msk"])[0][0]
moving_train_img_ = first(dataloaders["moving_train_img"])[0][0]
moving_train_msk_ = first(dataloaders["moving_train_msk"])[0][0]

fixed_val_img_ = first(dataloaders["fixed_val_img"])[0][0]
fixed_val_msk_ = first(dataloaders["fixed_val_msk"])[0][0]
moving_val_img_ = first(dataloaders["moving_val_img"])[0][0]
moving_val_msk_ = first(dataloaders["moving_val_msk"])[0][0]


print(f"fixed_train_img_ shape: {fixed_train_img_.shape}")
print(f"fixed_train_msk_ shape: {fixed_train_msk_.shape}")
print(f"moving_train_img_ shape: {moving_train_img_.shape}")
print(f"moving_train_msk_ shape: {moving_train_msk_.shape}")

print(f"fixed_val_img_ shape: {fixed_val_img_.shape}")
print(f"fixed_val_msk_ shape: {fixed_val_msk_.shape}")
print(f"moving_val_img_ shape: {moving_val_img_.shape}")
print(f"moving_val_msk_ shape: {moving_val_msk_.shape}")


print(f"fixed_train_img_ Range: {fixed_train_img_.max()} {fixed_train_img_.min()}")
print(f"fixed_train_msk_ range: {fixed_train_msk_.max()} {fixed_train_msk_.min()} {np.unique(fixed_train_msk_)}")
print(f"moving_train_img_ Range: {moving_train_img_.max()} {moving_train_img_.min()}")
print(f"moving_train_msk_ range: {moving_train_msk_.max()} {moving_train_msk_.min()} {np.unique(moving_train_msk_)}")

print(f"fixed_val_img_ Range: {fixed_val_img_.max()} {fixed_val_img_.min()}")
print(f"fixed_val_msk_ range: {fixed_val_msk_.max()} {fixed_val_msk_.min()} {np.unique(fixed_val_msk_)}")
print(f"moving_val_img_ Range: {moving_val_img_.max()} {moving_val_img_.min()}")
print(f"moving_val_msk_ range: {moving_val_msk_.max()} {moving_val_msk_.min()} {np.unique(moving_val_msk_)}")
# Out:
# fixed_train_img_ shape: torch.Size([256, 256, 32])
# fixed_train_msk_ shape: torch.Size([256, 256, 32])
# moving_train_img_ shape: torch.Size([256, 256, 32])
# moving_train_msk_ shape: torch.Size([256, 256, 32])
# fixed_val_img_ shape: torch.Size([256, 256, 32])
# fixed_val_msk_ shape: torch.Size([256, 256, 32])
# moving_val_img_ shape: torch.Size([256, 256, 32])
# moving_val_msk_ shape: torch.Size([256, 256, 32])
# fixed_train_img_ Range: 1.0 0.0
# fixed_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_train_img_ Range: 1.0 0.0
# moving_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# fixed_val_img_ Range: 1.0 0.0
# fixed_val_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_val_img_ Range: 1.0 0.0
# moving_val_msk_ range: 2.0 0.0 [0. 1. 2.]

# %%
# %matplotlib widget

# volumes = [fixed_train_img_, fixed_train_msk_, moving_train_img_, moving_train_msk_, fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_]  # Replace with your actual 3D volume data

# # Create a figure and subplots
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))

# # Create initial slices for each volume
# initial_slices = [0] * 8
# current_slices = []

# # Plot the initial slices
# for i, ax in enumerate(axs.flat):
#     ax.axis('off')  # Hide the axis numbers
#     current_slice = ax.imshow(volumes[i][:, :, initial_slices[i]], cmap='gray')
#     current_slices.append(current_slice)

# # Create sliders and axes for each volume
# sliders = []
# slider_axes = []
# for i, ax in enumerate(axs.flat):
#     ax_slider = plt.axes([ax.get_position().x0, ax.get_position().y0 - 0.05, ax.get_position().width, 0.02])
#     slider = Slider(ax=ax_slider, label=f'Slice {i+1}', valmin=0, valmax=volumes[i].shape[2] - 1, valinit=initial_slices[i], valstep=1)
#     sliders.append(slider)
#     slider_axes.append(ax_slider)

# # Update the plots when the slider values change
# def update_slices():
#     for i, slider in enumerate(sliders):
#         current_slices[i].set_data(volumes[i][:, :, int(slider.val)])

#     fig.canvas.draw_idle()

# for slider in sliders:
#     slider.on_changed(lambda event: update_slices())

# # Animation function
# def animate(i):
#     # Increment the slice values for each volume
#     slice_vals = [(initial_slices[j] + i) % volumes[j].shape[2] for j in range(8)]

#     # Update the slider values
#     for j, slider in enumerate(sliders):
#         slider.set_val(slice_vals[j])

#     # Update the plots
#     update_slices()

# # Create the animation
# animation = FuncAnimation(fig, animate, frames=volumes[0].shape[2]*2, interval=200)

# # Set up plot settings
# plt.subplots_adjust(hspace=0.4, wspace=0.2, bottom=0.15)

# # Display the plot
# plt.show()

# %%
# %matplotlib widget

# volume = fixed_train_img_  # Replace this with your actual 3D volume data

# # Create a figure and axes for the plot
# fig, ax = plt.subplots()

# # Plot the initial slice
# initial_slice = 0
# current_slice = ax.imshow(volume[:, :, initial_slice], cmap='gray')

# # Create a slider for selecting the slice
# ax_slider = plt.axes([0.2, 0.03, 0.6, 0.05])
# slider = Slider(ax=ax_slider, label='Slice', valmin=0, valmax=volume.shape[2] - 1, valinit=initial_slice, valstep=1)

# # Update the plot when the slider value changes
# def update_slice(val):
#     current_slice.set_data(volume[:, :, int(val)])
#     fig.canvas.draw_idle()

# slider.on_changed(update_slice)

# # Set up plot settings
# plt.subplots_adjust(hspace=0.4, wspace=0.2, bottom=0.15)

# # Display the plot
# plt.show()

# %%
plt.figure("check", (10, 5))
train_slice_no = 18
val_slice_no = 18

plt.subplot(2, 4, 1)
plt.title("fixed_train_img_\n Slice: "+str(train_slice_no))
plt.imshow(fixed_train_img_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 2)
plt.title("fixed_train_msk_\n Slice: "+str(train_slice_no))
plt.imshow(fixed_train_msk_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 3)
plt.title("moving_train_img_\n Slice: "+str(train_slice_no))
plt.imshow(moving_train_img_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 4)
plt.title("moving_train_msk_\n Slice: "+str(train_slice_no))
plt.imshow(moving_train_msk_[:,:,train_slice_no], cmap="gray")
plt.axis('off')


plt.subplot(2, 4, 5)
plt.title("fixed_val_img_\n Slice: "+str(val_slice_no))
plt.imshow(fixed_val_img_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 6)
plt.title("fixed_val_msk_\n Slice: "+str(val_slice_no))
plt.imshow(fixed_val_msk_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 7)
plt.title("moving_val_img_\n Slice: "+str(val_slice_no))
plt.imshow(moving_val_img_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 8)
plt.title("moving_val_msk_\n Slice: "+str(val_slice_no))
plt.imshow(moving_val_msk_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.show()

# %%
mod = RegUNet(
    spatial_dims=3,
    in_channels=2,
    num_channel_initial=32,
    depth = 3,
    extract_levels=[3],
    out_activation=None,
    out_channels=3,
    out_kernel_initializer="zeros",
    concat_skip=False)

        

inputs = torch.randn((1, 2, img_size, img_size, slice_size))

y = mod(inputs)
print(y.shape)

import torch, torchinfo
# from torchviz import make_dot, make_dot_from_trace
    
# make_dot(y, params=dict(mod.named_parameters()),
#          show_attrs=False,
#          show_saved=False).render(fileNames, format="png")

torchinfo.summary(mod, input_size=(1, 2, img_size, img_size, slice_size), depth=10)
# Out:
# torch.Size([1, 3, 256, 256, 32])
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# RegUNet                                            [1, 3, 256, 256, 32]      --
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─Sequential: 2-1                             [1, 32, 256, 256, 32]     --
# │    │    └─Convolution: 3-1                       [1, 32, 256, 256, 32]     --
# │    │    │    └─Conv3d: 4-1                       [1, 32, 256, 256, 32]     1,728
# │    │    │    └─ADN: 4-2                          [1, 32, 256, 256, 32]     --
# │    │    │    │    └─BatchNorm3d: 5-1             [1, 32, 256, 256, 32]     64
# │    │    │    │    └─ReLU: 5-2                    [1, 32, 256, 256, 32]     --
# │    │    └─RegistrationResidualConvBlock: 3-2     [1, 32, 256, 256, 32]     --
# │    │    │    └─ModuleList: 4-6                   --                        (recursive)
# │    │    │    │    └─Convolution: 5-3             [1, 32, 256, 256, 32]     --
# │    │    │    │    │    └─Conv3d: 6-1             [1, 32, 256, 256, 32]     27,648
# │    │    │    └─ModuleList: 4-7                   --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-4             [1, 32, 256, 256, 32]     64
# │    │    │    └─ModuleList: 4-8                   --                        --
# │    │    │    │    └─ReLU: 5-5                    [1, 32, 256, 256, 32]     --
# │    │    │    └─ModuleList: 4-6                   --                        (recursive)
# │    │    │    │    └─Convolution: 5-6             [1, 32, 256, 256, 32]     --
# │    │    │    │    │    └─Conv3d: 6-2             [1, 32, 256, 256, 32]     27,648
# │    │    │    └─ModuleList: 4-7                   --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-7             [1, 32, 256, 256, 32]     64
# │    │    │    └─ModuleList: 4-8                   --                        --
# │    │    │    │    └─ReLU: 5-8                    [1, 32, 256, 256, 32]     --
# ├─ModuleList: 1-6                                  --                        --
# │    └─RegistrationDownSampleBlock: 2-2            [1, 32, 128, 128, 16]     --
# │    │    └─MaxPool3d: 3-3                         [1, 32, 128, 128, 16]     --
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─Sequential: 2-3                             [1, 64, 128, 128, 16]     --
# │    │    └─Convolution: 3-4                       [1, 64, 128, 128, 16]     --
# │    │    │    └─Conv3d: 4-9                       [1, 64, 128, 128, 16]     55,296
# │    │    │    └─ADN: 4-10                         [1, 64, 128, 128, 16]     --
# │    │    │    │    └─BatchNorm3d: 5-9             [1, 64, 128, 128, 16]     128
# │    │    │    │    └─ReLU: 5-10                   [1, 64, 128, 128, 16]     --
# │    │    └─RegistrationResidualConvBlock: 3-5     [1, 64, 128, 128, 16]     --
# │    │    │    └─ModuleList: 4-14                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-11            [1, 64, 128, 128, 16]     --
# │    │    │    │    │    └─Conv3d: 6-3             [1, 64, 128, 128, 16]     110,592
# │    │    │    └─ModuleList: 4-15                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-12            [1, 64, 128, 128, 16]     128
# │    │    │    └─ModuleList: 4-16                  --                        --
# │    │    │    │    └─ReLU: 5-13                   [1, 64, 128, 128, 16]     --
# │    │    │    └─ModuleList: 4-14                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-14            [1, 64, 128, 128, 16]     --
# │    │    │    │    │    └─Conv3d: 6-4             [1, 64, 128, 128, 16]     110,592
# │    │    │    └─ModuleList: 4-15                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-15            [1, 64, 128, 128, 16]     128
# │    │    │    └─ModuleList: 4-16                  --                        --
# │    │    │    │    └─ReLU: 5-16                   [1, 64, 128, 128, 16]     --
# ├─ModuleList: 1-6                                  --                        --
# │    └─RegistrationDownSampleBlock: 2-4            [1, 64, 64, 64, 8]        --
# │    │    └─MaxPool3d: 3-6                         [1, 64, 64, 64, 8]        --
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─Sequential: 2-5                             [1, 128, 64, 64, 8]       --
# │    │    └─Convolution: 3-7                       [1, 128, 64, 64, 8]       --
# │    │    │    └─Conv3d: 4-17                      [1, 128, 64, 64, 8]       221,184
# │    │    │    └─ADN: 4-18                         [1, 128, 64, 64, 8]       --
# │    │    │    │    └─BatchNorm3d: 5-17            [1, 128, 64, 64, 8]       256
# │    │    │    │    └─ReLU: 5-18                   [1, 128, 64, 64, 8]       --
# │    │    └─RegistrationResidualConvBlock: 3-8     [1, 128, 64, 64, 8]       --
# │    │    │    └─ModuleList: 4-22                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-19            [1, 128, 64, 64, 8]       --
# │    │    │    │    │    └─Conv3d: 6-5             [1, 128, 64, 64, 8]       442,368
# │    │    │    └─ModuleList: 4-23                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-20            [1, 128, 64, 64, 8]       256
# │    │    │    └─ModuleList: 4-24                  --                        --
# │    │    │    │    └─ReLU: 5-21                   [1, 128, 64, 64, 8]       --
# │    │    │    └─ModuleList: 4-22                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-22            [1, 128, 64, 64, 8]       --
# │    │    │    │    │    └─Conv3d: 6-6             [1, 128, 64, 64, 8]       442,368
# │    │    │    └─ModuleList: 4-23                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-23            [1, 128, 64, 64, 8]       256
# │    │    │    └─ModuleList: 4-24                  --                        --
# │    │    │    │    └─ReLU: 5-24                   [1, 128, 64, 64, 8]       --
# ├─ModuleList: 1-6                                  --                        --
# │    └─RegistrationDownSampleBlock: 2-6            [1, 128, 32, 32, 4]       --
# │    │    └─MaxPool3d: 3-9                         [1, 128, 32, 32, 4]       --
# ├─Sequential: 1-7                                  [1, 256, 32, 32, 4]       --
# │    └─Convolution: 2-7                            [1, 256, 32, 32, 4]       --
# │    │    └─Conv3d: 3-10                           [1, 256, 32, 32, 4]       884,736
# │    │    └─ADN: 3-11                              [1, 256, 32, 32, 4]       --
# │    │    │    └─BatchNorm3d: 4-25                 [1, 256, 32, 32, 4]       512
# │    │    │    └─ReLU: 4-26                        [1, 256, 32, 32, 4]       --
# │    └─RegistrationResidualConvBlock: 2-8          [1, 256, 32, 32, 4]       --
# │    │    └─ModuleList: 3-15                       --                        (recursive)
# │    │    │    └─Convolution: 4-27                 [1, 256, 32, 32, 4]       --
# │    │    │    │    └─Conv3d: 5-25                 [1, 256, 32, 32, 4]       1,769,472
# │    │    └─ModuleList: 3-16                       --                        (recursive)
# │    │    │    └─BatchNorm3d: 4-28                 [1, 256, 32, 32, 4]       512
# │    │    └─ModuleList: 3-17                       --                        --
# │    │    │    └─ReLU: 4-29                        [1, 256, 32, 32, 4]       --
# │    │    └─ModuleList: 3-15                       --                        (recursive)
# │    │    │    └─Convolution: 4-30                 [1, 256, 32, 32, 4]       --
# │    │    │    │    └─Conv3d: 5-26                 [1, 256, 32, 32, 4]       1,769,472
# │    │    └─ModuleList: 3-16                       --                        (recursive)
# │    │    │    └─BatchNorm3d: 4-31                 [1, 256, 32, 32, 4]       512
# │    │    └─ModuleList: 3-17                       --                        --
# │    │    │    └─ReLU: 4-32                        [1, 256, 32, 32, 4]       --
# ├─RegistrationExtractionBlock: 1-8                 [1, 3, 256, 256, 32]      --
# │    └─ModuleList: 2-9                             --                        --
# │    │    └─Convolution: 3-18                      [1, 3, 32, 32, 4]         --
# │    │    │    └─Conv3d: 4-33                      [1, 3, 32, 32, 4]         20,736
# ====================================================================================================
# Total params: 5,886,720
# Trainable params: 5,886,720
# Non-trainable params: 0
# Total mult-adds (G): 246.51
# ====================================================================================================
# Input size (MB): 16.78
# Forward/backward pass size (MB): 4278.29
# Params size (MB): 23.55
# Estimated Total Size (MB): 4318.61
# ====================================================================================================

# %%
model = mod.to(device)

if preTrained:
    model.load_state_dict(torch.load(os.path.join(root_dir, ExpName + '_' + dataDir + '_' +str(previousWeight) + '_'+'.pth')))


warp_layer = Warp().to(device)

# image_loss = MSELoss()

image_loss = GlobalMutualInformationLoss()

class SSIMLoss(SSIM):
    def forward(self, x, y):
        return 1. - super().forward(x, y)
    

label_SSIM = SSIMLoss(n_channels=1).to(device) # .cuda() if you need GPU support

label_loss = DiceLoss()

# label_loss = MultiScaleLoss(label_loss, scales=[0, 1, 2, 4, 8, 16])

regularization = BendingEnergyLoss()

optimizer = torch.optim.Adam(model.parameters(), 1e-5)

# exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.5, verbose=True)

dice_metric = DiceMetric(include_background=True, reduction="mean", get_not_nans=False)

# dice_metric = compute_meandice(y_pred, y, include_background=True)
# Out:
# monai.networks.blocks.Warp: Using PyTorch native grid_sample.

# %%
def make_one_hot(labels, C=2):
    '''
    Converts an integer label torch.Tensor to a one-hot Tensor.
    
    Parameters
    ----------
    labels : torch.Tensor
        N x 1 x D x H x W, where N is batch size. 
        Each value is an integer representing correct classification.
    C : integer
        Number of classes in labels.
    
    Returns
    -------
    target : torch.Tensor
        N x C x D x H x W, where C is class number. One-hot encoded.
    '''
    labels = labels.long()
    one_hot = torch.zeros(labels.size(0), C, labels.size(2), labels.size(3), labels.size(4)).to(device)
    labels = labels.squeeze(1)
    target = one_hot.scatter_(1, labels.unsqueeze(1), 1)
        
    return target

# %%
class VariationalEncoder3D(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalEncoder3D, self).__init__()
        self.conv1 = nn.Conv3d(1, 8, 3, stride=2, padding=1)
        self.conv2 = nn.Conv3d(8, 16, 3, stride=2, padding=1)
        self.batch2 = nn.BatchNorm3d(16)
        self.conv3 = nn.Conv3d(16, 32, 3, stride=2, padding=1)
        self.linear1 = nn.Linear((img_size // 8) * (img_size // 8) * (slice_size // 8) * 32, 128)
        self.linear2 = nn.Linear(128, latent_dims)
        self.linear3 = nn.Linear(128, latent_dims)

        self.N = torch.distributions.Normal(0, 1)
        self.N.loc = self.N.loc.to(device)
        self.N.scale = self.N.scale.to(device)
        self.kl = 0

    def forward(self, x):
        x = x.to(device)
        x = F.relu(self.conv1(x))
        x = F.relu(self.batch2(self.conv2(x)))
        x = F.relu(self.conv3(x))
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.linear1(x))
        mu = self.linear2(x)
        sigma = torch.exp(self.linear3(x))
        z = mu + sigma * self.N.sample(mu.shape)
        self.kl = (sigma ** 2 + mu ** 2 - torch.log(sigma) - 1/2).sum()
        return z


class Decoder3D(nn.Module):
    def __init__(self, latent_dims):
        super(Decoder3D, self).__init__()
        self.decoder_lin = nn.Sequential(
            nn.Linear(latent_dims, 128),
            nn.ReLU(True),
            nn.Linear(128, (img_size // 8) * (img_size // 8) * (slice_size // 8) * 32),
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, img_size // 8, img_size // 8, slice_size // 8))

        # self.m = nn.Softmax(dim=1)

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose3d(32, 16, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm3d(16),
            nn.ReLU(True),
            nn.ConvTranspose3d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm3d(8),
            nn.ReLU(True),
            nn.ConvTranspose3d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )

    def forward(self, x):
        x = self.decoder_lin(x)
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        x = torch.sigmoid(x)
        # x = self.m(x)
        return x

class VariationalAutoencoder3D(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalAutoencoder3D, self).__init__()
        self.encoder = VariationalEncoder3D(latent_dims)
        self.decoder = Decoder3D(latent_dims)

    def forward(self, x):
        x = x.to(device)
        z = self.encoder(x)
        return self.decoder(z)

torch.manual_seed(0)

d = 8

Myo_VAE_3D = VariationalAutoencoder3D(latent_dims=d)
Myo_VAE_3D.to(device)
Myo_VAE_3D.load_state_dict(torch.load('/home/mkh/MKH/KSA/Dataset/Myo_VAE_3D_256_32_.pth', map_location=device))
Myo_VAE_3D.eval()

LV_VAE_3D = VariationalAutoencoder3D(latent_dims=d)
LV_VAE_3D.to(device)
LV_VAE_3D.load_state_dict(torch.load('/home/mkh/MKH/KSA/Dataset/LV_VAE_3D_256_32_.pth', map_location=device))
LV_VAE_3D.eval()
# Out:
# VariationalAutoencoder3D(
#   (encoder): VariationalEncoder3D(
#     (conv1): Conv3d(1, 8, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     (conv2): Conv3d(8, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     (batch2): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     (linear1): Linear(in_features=131072, out_features=128, bias=True)
#     (linear2): Linear(in_features=128, out_features=8, bias=True)
#     (linear3): Linear(in_features=128, out_features=8, bias=True)
#   )
#   (decoder): Decoder3D(
#     (decoder_lin): Sequential(
#       (0): Linear(in_features=8, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=128, out_features=131072, bias=True)
#       (3): ReLU(inplace=True)
#     )
#     (unflatten): Unflatten(dim=1, unflattened_size=(32, 32, 32, 4))
#     (decoder_conv): Sequential(
#       (0): ConvTranspose3d(32, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#       (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): ConvTranspose3d(16, 8, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#       (4): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): ConvTranspose3d(8, 1, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     )
#   )
# )

# %%
L2_loss = nn.MSELoss(reduction='mean')

def globalLoss(trueMask, predMask):
    myo_trueMask = trueMask.clone()
    LV_trueMask = trueMask.clone()

    #Thresholding the prediction
    thresholded_predMask = predMask.clone()

    background_class = torch.zeros_like(predMask)
    lv_class = torch.ones_like(predMask)
    myo_class = 2*torch.ones_like(predMask)

    thresholded_predMask_ = torch.where(thresholded_predMask<0.98, background_class, thresholded_predMask)
    thresholded_predMask_ = torch.where(thresholded_predMask_>1.0, myo_class, thresholded_predMask_)
    thresholded_predMask_ = torch.where((thresholded_predMask_<=1.0) & (thresholded_predMask_>=0.98), lv_class, thresholded_predMask_)

    myo_predMask = thresholded_predMask_.clone()
    LV_predMask = thresholded_predMask_.clone()

    LV_predMask[LV_predMask==2] =0 
    LV_trueMask[LV_trueMask==2] =0 

    myo_predMask[myo_predMask==1] =0 
    myo_predMask = myo_predMask/2

    myo_trueMask[myo_trueMask==1] =0 
    myo_trueMask = myo_trueMask/2

    # plt.subplot(241), plt.imshow(myo_predMask[0,:,:,:].reshape(512,512).detach().cpu().squeeze().numpy(), cmap='gist_gray')
    # plt.subplot(242), plt.imshow(myo_trueMask[0,:,:,:].reshape(512,512).detach().cpu().squeeze().numpy(), cmap='gist_gray')
    # plt.subplot(243), plt.imshow(LV_predMask[0,:,:,:].reshape(512,512).detach().cpu().squeeze().numpy(), cmap='gist_gray')
    # plt.subplot(244), plt.imshow(LV_trueMask[0,:,:,:].reshape(512,512).detach().cpu().squeeze().numpy(), cmap='gist_gray')

    attribute_myo_true = Myo_VAE_3D(myo_trueMask)
    attribute_myo_pred = Myo_VAE_3D(myo_predMask)

    myo_L2 = L2_loss(attribute_myo_true, attribute_myo_pred)

    attribute_lv_true = LV_VAE_3D(LV_trueMask)
    attribute_lv_pred = LV_VAE_3D(LV_predMask)

    # print(LV_trueMask.shape)
    # print(attribute_lv_true.shape)

    lv_L2 = L2_loss(attribute_lv_true, attribute_lv_pred)

    # print(myo_L2)
    # print(lv_L2)

    loss_ = myo_L2 + lv_L2

    return loss_

# globalLoss (TTg, TTp)
# globalLoss (TTg, TTm)

# %%
max_epochs = EP
epoch_loss_values = []
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
epoch_val_loss_values = []
epoch_loss_d_values = []
epoch_loss_g_values = []
metric_values = []
best_loss = 1e10
best_dsc = 0
k=1


for epoch in range(max_epochs):
    print("-" * 100)
    print(f"Epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss, step = 0, 0

    epoch_DSC, epoch_L2, epoch_MI, epoch_ddf = 0, 0, 0, 0

    epoch_loss_d, epoch_loss_g=0,0
    
    for fixed_train_img_, fixed_train_msk_, moving_train_img_, moving_train_msk_ in zip(fixed_train_img,
                                                                                    fixed_train_msk, moving_train_img,
                                                                                    moving_train_msk):    
        step += 1
        
        optimizer.zero_grad()
        # optim_d.zero_grad()

        fixed_train_img_ = fixed_train_img_.to(device)
        fixed_train_msk_ = fixed_train_msk_.to(device)
        moving_train_img_ = moving_train_img_.to(device)
        moving_train_msk_ = moving_train_msk_.to(device)
        
        ddf_train = model(torch.cat((moving_train_img_, fixed_train_img_), dim=1))
        
        pred_image_train = warp_layer(moving_train_img_, ddf_train)
        pred_mask_train = warp_layer(moving_train_msk_, ddf_train)

        # real_label = label_real(fixed_train_img_.size(0))
        # fake_label = label_fake(fixed_train_img_.size(0))


        # output_real = discriminator(fixed_train_img_)
        # loss_real = criterion(output_real, real_label)
        # loss_real.backward()

        # output_fake = discriminator(pred_image_train.detach())
        # loss_fake = criterion(output_fake, fake_label)
        # loss_fake.backward()

        # optim_d.step()

        # loss_d = (loss_real + loss_fake)/2

        # epoch_loss_d += loss_d.item()

        # output = discriminator(pred_image_train)
        
        # loss_g = criterion(output, real_label)

        imageLOSS = image_loss(pred_image_train, fixed_train_img_)
        
        labelDSC = label_loss(fixed_train_msk_, pred_mask_train)

        # labelDSC = label_loss(make_one_hot(pred_mask_train, C=3), make_one_hot(fixed_train_msk_, C=3))

        labelGlobal =  globalLoss(fixed_train_msk_, pred_mask_train)-1
        
        regLOSS  = regularization(ddf_train)

        loss = imageLOSS + regLOSS + 2*labelGlobal + 2*labelDSC
    
        # loss_g.backward(retain_graph=True)
        
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()

        # epoch_loss_g += loss_g.item()
        epoch_DSC += labelDSC.item()
        epoch_L2 += labelGlobal.item()
        epoch_MI += imageLOSS.item()
        epoch_ddf += regLOSS.item()


        
        dice_metric(y_pred = make_one_hot(pred_mask_train, C=3), y=make_one_hot(fixed_train_msk_, C=3))

    # exp_lr_scheduler.step()
    for param_group in optimizer.param_groups:
        print("LR is == ", param_group['lr'])


    metric = dice_metric.aggregate().item()
    dice_metric.reset()
    epoch_loss /= step

    # epoch_loss_g /=step
    # epoch_loss_d /= step

    epoch_DSC /= step
    epoch_L2 /= step
    epoch_MI /= step
    epoch_ddf /= step

    epoch_loss_values.append(epoch_loss)
    # epoch_loss_d_values.append(epoch_loss_d)
    # epoch_loss_g_values.append(epoch_loss_g)

    print(f"For epoch: {epoch + 1}, Average train loss: {epoch_loss:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train DSC: {metric:.5f} !\n")

    print(f"For epoch: {epoch + 1}, Average train DSC: {epoch_DSC:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train L2: {epoch_L2:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train MI: {epoch_MI:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train DDF: {epoch_ddf:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train D Loss: {epoch_loss_d:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train G Loss: {epoch_loss_g:.5f} !")
    
    print("-" * 60)
    if (epoch + 1) % val_interval == 0 or epoch == 0:
        model.eval()
        val_loss = 0
        val_met = 0
        step = 0
        with torch.no_grad():
            for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk):  

                fixed_val_img_ = fixed_val_img_.to(device)
                fixed_val_msk_ = fixed_val_msk_.to(device)
                
                moving_val_img_ = moving_val_img_.to(device)
                moving_val_msk_ = moving_val_msk_.to(device)
                
                
                ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))
                
                pred_image_val = warp_layer(moving_val_img_, ddf_val)
                pred_mask_val = warp_layer(moving_val_msk_, ddf_val)

                # real_label = label_real(pred_image_val.size(0))
        
                # output = discriminator(pred_image_val)
        
                # loss_g = criterion(output, real_label)

                imageLOSS = image_loss(pred_image_val, fixed_val_img_)

                labelDSC = label_loss(fixed_val_msk_, pred_mask_val)

                # labelDSC = label_loss(make_one_hot(pred_mask_val, C=3), make_one_hot(fixed_val_msk_, C=3))

                labelGlobal =  globalLoss(fixed_val_msk_, pred_mask_val)-1

                regLOSS  = regularization(ddf_val)


                loss = imageLOSS + regLOSS + 2*labelGlobal + 2*labelDSC
                
                
    
                val_loss += loss.item()
                step += 1

                
                dice_metric(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))
                

            val_loss /= step
            epoch_val_loss_values.append(val_loss)
            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            dice_metric.reset()
            
            if metric > best_dsc:
                best_loss_epoch = epoch + 1
                torch.save(model.state_dict(),
                           os.path.join(root_dir, fileNames+'.pth'))
                print(f"Valid DSC improved from {best_dsc:2.4f} to {metric:2.4f}! Best model is saving as---> {fileNames+'.pth'}")
                best_dsc = metric
                
            print(
                f"\nCurrent mean dice: {metric:.4f} "
                f"\t and \t Current val loss: {val_loss:.4f}\n\n"
                f"Best val DSC: {best_dsc:.4f} "
                f"at epoch number of {best_loss_epoch}")
# Out:
# ----------------------------------------------------------------------------------------------------
# Epoch 1/100
# LR is ==  1e-05
# For epoch: 1, Average train loss: -3.54932 !
# For epoch: 1, Average train DSC: 0.77474 !
#
# For epoch: 1, Average train DSC: -0.46422 !
# For epoch: 1, Average train L2: -0.96291 !
# For epoch: 1, Average train MI: -0.69548 !
# For epoch: 1, Average train DDF: 0.00043 !
# ------------------------------------------------------------
# Valid DSC improved from 0.0000 to 0.7498! Best model is saving as---> AC_DLIR_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7498 	 and 	 Current val loss: -3.6094
#
# Best val DSC: 0.7498 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 2/100
# LR is ==  1e-05
# For epoch: 2, Average train loss: -3.56286 !
# For epoch: 2, Average train DSC: 0.77404 !
#
# For epoch: 2, Average train DSC: -0.46890 !
# For epoch: 2, Average train L2: -0.96383 !
# For epoch: 2, Average train MI: -0.69834 !
# For epoch: 2, Average train DDF: 0.00095 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7401 	 and 	 Current val loss: -3.6182
#
# Best val DSC: 0.7498 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 3/100
# LR is ==  1e-05
# For epoch: 3, Average train loss: -3.60806 !
# For epoch: 3, Average train DSC: 0.78132 !
#
# For epoch: 3, Average train DSC: -0.49084 !
# For epoch: 3, Average train L2: -0.96471 !
# For epoch: 3, Average train MI: -0.70031 !
# For epoch: 3, Average train DDF: 0.00335 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7431 	 and 	 Current val loss: -3.6192
#
# Best val DSC: 0.7498 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 4/100
# LR is ==  1e-05
# For epoch: 4, Average train loss: -3.66552 !
# For epoch: 4, Average train DSC: 0.79389 !
#
# For epoch: 4, Average train DSC: -0.51750 !
# For epoch: 4, Average train L2: -0.96566 !
# For epoch: 4, Average train MI: -0.70556 !
# For epoch: 4, Average train DDF: 0.00636 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7452 	 and 	 Current val loss: -3.6224
#
# Best val DSC: 0.7498 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 5/100
# LR is ==  1e-05
# For epoch: 5, Average train loss: -3.70904 !
# For epoch: 5, Average train DSC: 0.80100 !
#
# For epoch: 5, Average train DSC: -0.53782 !
# For epoch: 5, Average train L2: -0.96510 !
# For epoch: 5, Average train MI: -0.71290 !
# For epoch: 5, Average train DDF: 0.00970 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7486 	 and 	 Current val loss: -3.6130
#
# Best val DSC: 0.7498 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 6/100
# LR is ==  1e-05
# For epoch: 6, Average train loss: -3.74464 !
# For epoch: 6, Average train DSC: 0.80387 !
#
# For epoch: 6, Average train DSC: -0.55270 !
# For epoch: 6, Average train L2: -0.96701 !
# For epoch: 6, Average train MI: -0.71631 !
# For epoch: 6, Average train DDF: 0.01107 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7498 to 0.7502! Best model is saving as---> AC_DLIR_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7502 	 and 	 Current val loss: -3.6117
#
# Best val DSC: 0.7502 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 7/100
# LR is ==  1e-05
# For epoch: 7, Average train loss: -3.77244 !
# For epoch: 7, Average train DSC: 0.80936 !
#
# For epoch: 7, Average train DSC: -0.56292 !
# For epoch: 7, Average train L2: -0.96942 !
# For epoch: 7, Average train MI: -0.71996 !
# For epoch: 7, Average train DDF: 0.01221 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7477 	 and 	 Current val loss: -3.6128
#
# Best val DSC: 0.7502 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 8/100
# LR is ==  1e-05
# For epoch: 8, Average train loss: -3.79219 !
# For epoch: 8, Average train DSC: 0.81106 !
#
# For epoch: 8, Average train DSC: -0.57059 !
# For epoch: 8, Average train L2: -0.97030 !
# For epoch: 8, Average train MI: -0.72389 !
# For epoch: 8, Average train DDF: 0.01346 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7479 	 and 	 Current val loss: -3.5814
#
# Best val DSC: 0.7502 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 9/100
# LR is ==  1e-05
# For epoch: 9, Average train loss: -3.80718 !
# For epoch: 9, Average train DSC: 0.81290 !
#
# For epoch: 9, Average train DSC: -0.57661 !
# For epoch: 9, Average train L2: -0.97045 !
# For epoch: 9, Average train MI: -0.72751 !
# For epoch: 9, Average train DDF: 0.01444 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7447 	 and 	 Current val loss: -3.6002
#
# Best val DSC: 0.7502 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 10/100
# LR is ==  1e-05
# For epoch: 10, Average train loss: -3.81724 !
# For epoch: 10, Average train DSC: 0.81393 !
#
# For epoch: 10, Average train DSC: -0.57901 !
# For epoch: 10, Average train L2: -0.97207 !
# For epoch: 10, Average train MI: -0.73124 !
# For epoch: 10, Average train DDF: 0.01616 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7502 to 0.7586! Best model is saving as---> AC_DLIR_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7586 	 and 	 Current val loss: -3.6136
#
# Best val DSC: 0.7586 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 11/100
# LR is ==  1e-05
# For epoch: 11, Average train loss: -3.80935 !
# For epoch: 11, Average train DSC: 0.81193 !
#
# For epoch: 11, Average train DSC: -0.57694 !
# For epoch: 11, Average train L2: -0.97113 !
# For epoch: 11, Average train MI: -0.73074 !
# For epoch: 11, Average train DDF: 0.01752 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7469 	 and 	 Current val loss: -3.6014
#
# Best val DSC: 0.7586 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 12/100
# LR is ==  1e-05
# For epoch: 12, Average train loss: -3.82373 !
# For epoch: 12, Average train DSC: 0.81525 !
#
# For epoch: 12, Average train DSC: -0.58264 !
# For epoch: 12, Average train L2: -0.96999 !
# For epoch: 12, Average train MI: -0.73691 !
# For epoch: 12, Average train DDF: 0.01844 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7586 to 0.7628! Best model is saving as---> AC_DLIR_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7628 	 and 	 Current val loss: -3.6186
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 13/100
# LR is ==  1e-05
# For epoch: 13, Average train loss: -3.84143 !
# For epoch: 13, Average train DSC: 0.81346 !
#
# For epoch: 13, Average train DSC: -0.58748 !
# For epoch: 13, Average train L2: -0.97332 !
# For epoch: 13, Average train MI: -0.73837 !
# For epoch: 13, Average train DDF: 0.01855 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7343 	 and 	 Current val loss: -3.5958
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 14/100
# LR is ==  1e-05
# For epoch: 14, Average train loss: -3.85010 !
# For epoch: 14, Average train DSC: 0.81963 !
#
# For epoch: 14, Average train DSC: -0.58986 !
# For epoch: 14, Average train L2: -0.97389 !
# For epoch: 14, Average train MI: -0.74335 !
# For epoch: 14, Average train DDF: 0.02075 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7429 	 and 	 Current val loss: -3.6155
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 15/100
# LR is ==  1e-05
# For epoch: 15, Average train loss: -3.85070 !
# For epoch: 15, Average train DSC: 0.81510 !
#
# For epoch: 15, Average train DSC: -0.59228 !
# For epoch: 15, Average train L2: -0.97217 !
# For epoch: 15, Average train MI: -0.74316 !
# For epoch: 15, Average train DDF: 0.02138 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7449 	 and 	 Current val loss: -3.5980
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 16/100
# LR is ==  1e-05
# For epoch: 16, Average train loss: -3.86438 !
# For epoch: 16, Average train DSC: 0.81879 !
#
# For epoch: 16, Average train DSC: -0.59825 !
# For epoch: 16, Average train L2: -0.97091 !
# For epoch: 16, Average train MI: -0.74846 !
# For epoch: 16, Average train DDF: 0.02241 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7465 	 and 	 Current val loss: -3.5879
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 17/100
# LR is ==  1e-05
# For epoch: 17, Average train loss: -3.87474 !
# For epoch: 17, Average train DSC: 0.81941 !
#
# For epoch: 17, Average train DSC: -0.60198 !
# For epoch: 17, Average train L2: -0.97212 !
# For epoch: 17, Average train MI: -0.74947 !
# For epoch: 17, Average train DDF: 0.02293 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7462 	 and 	 Current val loss: -3.6036
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 18/100
# LR is ==  1e-05
# For epoch: 18, Average train loss: -3.87601 !
# For epoch: 18, Average train DSC: 0.82019 !
#
# For epoch: 18, Average train DSC: -0.60002 !
# For epoch: 18, Average train L2: -0.97584 !
# For epoch: 18, Average train MI: -0.74774 !
# For epoch: 18, Average train DDF: 0.02344 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7563 	 and 	 Current val loss: -3.5819
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 19/100
# LR is ==  1e-05
# For epoch: 19, Average train loss: -3.86819 !
# For epoch: 19, Average train DSC: 0.82028 !
#
# For epoch: 19, Average train DSC: -0.60030 !
# For epoch: 19, Average train L2: -0.97190 !
# For epoch: 19, Average train MI: -0.74758 !
# For epoch: 19, Average train DDF: 0.02379 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7568 	 and 	 Current val loss: -3.6072
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 20/100
# LR is ==  1e-05
# For epoch: 20, Average train loss: -3.87892 !
# For epoch: 20, Average train DSC: 0.82052 !
#
# For epoch: 20, Average train DSC: -0.60322 !
# For epoch: 20, Average train L2: -0.97292 !
# For epoch: 20, Average train MI: -0.75141 !
# For epoch: 20, Average train DDF: 0.02477 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7549 	 and 	 Current val loss: -3.6142
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 21/100
# LR is ==  1e-05
# For epoch: 21, Average train loss: -3.89340 !
# For epoch: 21, Average train DSC: 0.82389 !
#
# For epoch: 21, Average train DSC: -0.60678 !
# For epoch: 21, Average train L2: -0.97534 !
# For epoch: 21, Average train MI: -0.75453 !
# For epoch: 21, Average train DDF: 0.02536 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7501 	 and 	 Current val loss: -3.6078
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 22/100
# LR is ==  1e-05
# For epoch: 22, Average train loss: -3.89399 !
# For epoch: 22, Average train DSC: 0.82481 !
#
# For epoch: 22, Average train DSC: -0.60538 !
# For epoch: 22, Average train L2: -0.97571 !
# For epoch: 22, Average train MI: -0.75642 !
# For epoch: 22, Average train DDF: 0.02461 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7547 	 and 	 Current val loss: -3.6193
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 23/100
# LR is ==  1e-05
# For epoch: 23, Average train loss: -3.89597 !
# For epoch: 23, Average train DSC: 0.82218 !
#
# For epoch: 23, Average train DSC: -0.60845 !
# For epoch: 23, Average train L2: -0.97395 !
# For epoch: 23, Average train MI: -0.75719 !
# For epoch: 23, Average train DDF: 0.02603 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7490 	 and 	 Current val loss: -3.6169
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 24/100
# LR is ==  1e-05
# For epoch: 24, Average train loss: -3.89890 !
# For epoch: 24, Average train DSC: 0.82458 !
#
# For epoch: 24, Average train DSC: -0.60792 !
# For epoch: 24, Average train L2: -0.97476 !
# For epoch: 24, Average train MI: -0.75898 !
# For epoch: 24, Average train DDF: 0.02544 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7527 	 and 	 Current val loss: -3.6260
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 25/100
# LR is ==  1e-05
# For epoch: 25, Average train loss: -3.91345 !
# For epoch: 25, Average train DSC: 0.82248 !
#
# For epoch: 25, Average train DSC: -0.61342 !
# For epoch: 25, Average train L2: -0.97724 !
# For epoch: 25, Average train MI: -0.75815 !
# For epoch: 25, Average train DDF: 0.02604 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7455 	 and 	 Current val loss: -3.6130
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 26/100
# LR is ==  1e-05
# For epoch: 26, Average train loss: -3.89564 !
# For epoch: 26, Average train DSC: 0.82500 !
#
# For epoch: 26, Average train DSC: -0.61329 !
# For epoch: 26, Average train L2: -0.96799 !
# For epoch: 26, Average train MI: -0.76012 !
# For epoch: 26, Average train DDF: 0.02703 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7514 	 and 	 Current val loss: -3.6200
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 27/100
# LR is ==  1e-05
# For epoch: 27, Average train loss: -3.91691 !
# For epoch: 27, Average train DSC: 0.82168 !
#
# For epoch: 27, Average train DSC: -0.61526 !
# For epoch: 27, Average train L2: -0.97676 !
# For epoch: 27, Average train MI: -0.76036 !
# For epoch: 27, Average train DDF: 0.02750 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7364 	 and 	 Current val loss: -3.6031
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 28/100
# LR is ==  1e-05
# For epoch: 28, Average train loss: -3.90451 !
# For epoch: 28, Average train DSC: 0.82590 !
#
# For epoch: 28, Average train DSC: -0.61216 !
# For epoch: 28, Average train L2: -0.97292 !
# For epoch: 28, Average train MI: -0.76078 !
# For epoch: 28, Average train DDF: 0.02644 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7556 	 and 	 Current val loss: -3.6335
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 29/100
# LR is ==  1e-05
# For epoch: 29, Average train loss: -3.91689 !
# For epoch: 29, Average train DSC: 0.82420 !
#
# For epoch: 29, Average train DSC: -0.61593 !
# For epoch: 29, Average train L2: -0.97495 !
# For epoch: 29, Average train MI: -0.76221 !
# For epoch: 29, Average train DDF: 0.02707 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7468 	 and 	 Current val loss: -3.6223
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 30/100
# LR is ==  1e-05
# For epoch: 30, Average train loss: -3.91821 !
# For epoch: 30, Average train DSC: 0.82458 !
#
# For epoch: 30, Average train DSC: -0.61746 !
# For epoch: 30, Average train L2: -0.97301 !
# For epoch: 30, Average train MI: -0.76517 !
# For epoch: 30, Average train DDF: 0.02790 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7532 	 and 	 Current val loss: -3.6378
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 31/100
# LR is ==  1e-05
# For epoch: 31, Average train loss: -3.92434 !
# For epoch: 31, Average train DSC: 0.82402 !
#
# For epoch: 31, Average train DSC: -0.61896 !
# For epoch: 31, Average train L2: -0.97440 !
# For epoch: 31, Average train MI: -0.76564 !
# For epoch: 31, Average train DDF: 0.02801 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7493 	 and 	 Current val loss: -3.6255
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 32/100
# LR is ==  1e-05
# For epoch: 32, Average train loss: -3.91636 !
# For epoch: 32, Average train DSC: 0.82246 !
#
# For epoch: 32, Average train DSC: -0.61815 !
# For epoch: 32, Average train L2: -0.97163 !
# For epoch: 32, Average train MI: -0.76438 !
# For epoch: 32, Average train DDF: 0.02757 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7553 	 and 	 Current val loss: -3.6326
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 33/100
# LR is ==  1e-05
# For epoch: 33, Average train loss: -3.92507 !
# For epoch: 33, Average train DSC: 0.82437 !
#
# For epoch: 33, Average train DSC: -0.61930 !
# For epoch: 33, Average train L2: -0.97424 !
# For epoch: 33, Average train MI: -0.76719 !
# For epoch: 33, Average train DDF: 0.02920 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7500 	 and 	 Current val loss: -3.6096
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 34/100
# LR is ==  1e-05
# For epoch: 34, Average train loss: -3.92764 !
# For epoch: 34, Average train DSC: 0.82391 !
#
# For epoch: 34, Average train DSC: -0.61868 !
# For epoch: 34, Average train L2: -0.97490 !
# For epoch: 34, Average train MI: -0.76873 !
# For epoch: 34, Average train DDF: 0.02826 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7575 	 and 	 Current val loss: -3.6334
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 35/100
# LR is ==  1e-05
# For epoch: 35, Average train loss: -3.92146 !
# For epoch: 35, Average train DSC: 0.82356 !
#
# For epoch: 35, Average train DSC: -0.61899 !
# For epoch: 35, Average train L2: -0.97374 !
# For epoch: 35, Average train MI: -0.76564 !
# For epoch: 35, Average train DDF: 0.02965 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7499 	 and 	 Current val loss: -3.5956
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 36/100
# LR is ==  1e-05
# For epoch: 36, Average train loss: -3.91734 !
# For epoch: 36, Average train DSC: 0.82545 !
#
# For epoch: 36, Average train DSC: -0.61978 !
# For epoch: 36, Average train L2: -0.96924 !
# For epoch: 36, Average train MI: -0.76837 !
# For epoch: 36, Average train DDF: 0.02906 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7539 	 and 	 Current val loss: -3.6189
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 37/100
# LR is ==  1e-05
# For epoch: 37, Average train loss: -3.91590 !
# For epoch: 37, Average train DSC: 0.82362 !
#
# For epoch: 37, Average train DSC: -0.61881 !
# For epoch: 37, Average train L2: -0.96929 !
# For epoch: 37, Average train MI: -0.76907 !
# For epoch: 37, Average train DDF: 0.02936 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7551 	 and 	 Current val loss: -3.6326
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 38/100
# LR is ==  1e-05
# For epoch: 38, Average train loss: -3.92459 !
# For epoch: 38, Average train DSC: 0.82441 !
#
# For epoch: 38, Average train DSC: -0.61768 !
# For epoch: 38, Average train L2: -0.97573 !
# For epoch: 38, Average train MI: -0.76605 !
# For epoch: 38, Average train DDF: 0.02829 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7539 	 and 	 Current val loss: -3.6272
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 39/100
# LR is ==  1e-05
# For epoch: 39, Average train loss: -3.92078 !
# For epoch: 39, Average train DSC: 0.82404 !
#
# For epoch: 39, Average train DSC: -0.61994 !
# For epoch: 39, Average train L2: -0.97090 !
# For epoch: 39, Average train MI: -0.76962 !
# For epoch: 39, Average train DDF: 0.03052 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7538 	 and 	 Current val loss: -3.6223
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 40/100
# LR is ==  1e-05
# For epoch: 40, Average train loss: -3.92818 !
# For epoch: 40, Average train DSC: 0.82525 !
#
# For epoch: 40, Average train DSC: -0.61835 !
# For epoch: 40, Average train L2: -0.97500 !
# For epoch: 40, Average train MI: -0.77024 !
# For epoch: 40, Average train DDF: 0.02874 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7562 	 and 	 Current val loss: -3.6424
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 41/100
# LR is ==  1e-05
# For epoch: 41, Average train loss: -3.92980 !
# For epoch: 41, Average train DSC: 0.82462 !
#
# For epoch: 41, Average train DSC: -0.62091 !
# For epoch: 41, Average train L2: -0.97433 !
# For epoch: 41, Average train MI: -0.76991 !
# For epoch: 41, Average train DDF: 0.03060 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7498 	 and 	 Current val loss: -3.6164
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 42/100
# LR is ==  1e-05
# For epoch: 42, Average train loss: -3.92748 !
# For epoch: 42, Average train DSC: 0.82484 !
#
# For epoch: 42, Average train DSC: -0.61999 !
# For epoch: 42, Average train L2: -0.97211 !
# For epoch: 42, Average train MI: -0.77266 !
# For epoch: 42, Average train DDF: 0.02937 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7522 	 and 	 Current val loss: -3.6233
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 43/100
# LR is ==  1e-05
# For epoch: 43, Average train loss: -3.92673 !
# For epoch: 43, Average train DSC: 0.82515 !
#
# For epoch: 43, Average train DSC: -0.62124 !
# For epoch: 43, Average train L2: -0.97085 !
# For epoch: 43, Average train MI: -0.77311 !
# For epoch: 43, Average train DDF: 0.03057 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7515 	 and 	 Current val loss: -3.6460
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 44/100
# LR is ==  1e-05
# For epoch: 44, Average train loss: -3.93018 !
# For epoch: 44, Average train DSC: 0.82208 !
#
# For epoch: 44, Average train DSC: -0.62083 !
# For epoch: 44, Average train L2: -0.97446 !
# For epoch: 44, Average train MI: -0.76929 !
# For epoch: 44, Average train DDF: 0.02969 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7535 	 and 	 Current val loss: -3.6191
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 45/100
# LR is ==  1e-05
# For epoch: 45, Average train loss: -3.92832 !
# For epoch: 45, Average train DSC: 0.82541 !
#
# For epoch: 45, Average train DSC: -0.62272 !
# For epoch: 45, Average train L2: -0.97048 !
# For epoch: 45, Average train MI: -0.77372 !
# For epoch: 45, Average train DDF: 0.03181 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7536 	 and 	 Current val loss: -3.6384
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 46/100
# LR is ==  1e-05
# For epoch: 46, Average train loss: -3.93536 !
# For epoch: 46, Average train DSC: 0.82423 !
#
# For epoch: 46, Average train DSC: -0.62459 !
# For epoch: 46, Average train L2: -0.97100 !
# For epoch: 46, Average train MI: -0.77492 !
# For epoch: 46, Average train DDF: 0.03073 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7529 	 and 	 Current val loss: -3.6250
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 47/100
# LR is ==  1e-05
# For epoch: 47, Average train loss: -3.94190 !
# For epoch: 47, Average train DSC: 0.82516 !
#
# For epoch: 47, Average train DSC: -0.62558 !
# For epoch: 47, Average train L2: -0.97334 !
# For epoch: 47, Average train MI: -0.77540 !
# For epoch: 47, Average train DDF: 0.03134 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7551 	 and 	 Current val loss: -3.6420
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 48/100
# LR is ==  1e-05
# For epoch: 48, Average train loss: -3.93618 !
# For epoch: 48, Average train DSC: 0.82367 !
#
# For epoch: 48, Average train DSC: -0.62441 !
# For epoch: 48, Average train L2: -0.97123 !
# For epoch: 48, Average train MI: -0.77687 !
# For epoch: 48, Average train DDF: 0.03196 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7552 	 and 	 Current val loss: -3.6311
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 49/100
# LR is ==  1e-05
# For epoch: 49, Average train loss: -3.93796 !
# For epoch: 49, Average train DSC: 0.82518 !
#
# For epoch: 49, Average train DSC: -0.62548 !
# For epoch: 49, Average train L2: -0.97042 !
# For epoch: 49, Average train MI: -0.77740 !
# For epoch: 49, Average train DDF: 0.03125 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7494 	 and 	 Current val loss: -3.6360
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 50/100
# LR is ==  1e-05
# For epoch: 50, Average train loss: -3.94935 !
# For epoch: 50, Average train DSC: 0.82535 !
#
# For epoch: 50, Average train DSC: -0.62630 !
# For epoch: 50, Average train L2: -0.97508 !
# For epoch: 50, Average train MI: -0.77857 !
# For epoch: 50, Average train DDF: 0.03198 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7492 	 and 	 Current val loss: -3.6126
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 51/100
# LR is ==  1e-05
# For epoch: 51, Average train loss: -3.93456 !
# For epoch: 51, Average train DSC: 0.82363 !
#
# For epoch: 51, Average train DSC: -0.62562 !
# For epoch: 51, Average train L2: -0.96849 !
# For epoch: 51, Average train MI: -0.77838 !
# For epoch: 51, Average train DDF: 0.03204 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7561 	 and 	 Current val loss: -3.6457
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 52/100
# LR is ==  1e-05
# For epoch: 52, Average train loss: -3.94065 !
# For epoch: 52, Average train DSC: 0.82355 !
#
# For epoch: 52, Average train DSC: -0.62523 !
# For epoch: 52, Average train L2: -0.97226 !
# For epoch: 52, Average train MI: -0.77723 !
# For epoch: 52, Average train DDF: 0.03157 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7526 	 and 	 Current val loss: -3.6094
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 53/100
# LR is ==  1e-05
# For epoch: 53, Average train loss: -3.93274 !
# For epoch: 53, Average train DSC: 0.82424 !
#
# For epoch: 53, Average train DSC: -0.62259 !
# For epoch: 53, Average train L2: -0.97082 !
# For epoch: 53, Average train MI: -0.77882 !
# For epoch: 53, Average train DDF: 0.03289 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7561 	 and 	 Current val loss: -3.6444
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 54/100
# LR is ==  1e-05
# For epoch: 54, Average train loss: -3.93183 !
# For epoch: 54, Average train DSC: 0.82450 !
#
# For epoch: 54, Average train DSC: -0.62357 !
# For epoch: 54, Average train L2: -0.96994 !
# For epoch: 54, Average train MI: -0.77609 !
# For epoch: 54, Average train DDF: 0.03126 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7574 	 and 	 Current val loss: -3.6324
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 55/100
# LR is ==  1e-05
# For epoch: 55, Average train loss: -3.94550 !
# For epoch: 55, Average train DSC: 0.82400 !
#
# For epoch: 55, Average train DSC: -0.62915 !
# For epoch: 55, Average train L2: -0.96960 !
# For epoch: 55, Average train MI: -0.78090 !
# For epoch: 55, Average train DDF: 0.03290 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7532 	 and 	 Current val loss: -3.6189
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 56/100
# LR is ==  1e-05
# For epoch: 56, Average train loss: -3.95288 !
# For epoch: 56, Average train DSC: 0.82496 !
#
# For epoch: 56, Average train DSC: -0.62863 !
# For epoch: 56, Average train L2: -0.97348 !
# For epoch: 56, Average train MI: -0.78089 !
# For epoch: 56, Average train DDF: 0.03224 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7564 	 and 	 Current val loss: -3.6522
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 57/100
# LR is ==  1e-05
# For epoch: 57, Average train loss: -3.93802 !
# For epoch: 57, Average train DSC: 0.82592 !
#
# For epoch: 57, Average train DSC: -0.62679 !
# For epoch: 57, Average train L2: -0.96913 !
# For epoch: 57, Average train MI: -0.77908 !
# For epoch: 57, Average train DDF: 0.03289 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7472 	 and 	 Current val loss: -3.6149
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 58/100
# LR is ==  1e-05
# For epoch: 58, Average train loss: -3.94435 !
# For epoch: 58, Average train DSC: 0.82064 !
#
# For epoch: 58, Average train DSC: -0.62630 !
# For epoch: 58, Average train L2: -0.97122 !
# For epoch: 58, Average train MI: -0.78216 !
# For epoch: 58, Average train DDF: 0.03284 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7561 	 and 	 Current val loss: -3.6256
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 59/100
# LR is ==  1e-05
# For epoch: 59, Average train loss: -3.94386 !
# For epoch: 59, Average train DSC: 0.82578 !
#
# For epoch: 59, Average train DSC: -0.62809 !
# For epoch: 59, Average train L2: -0.96960 !
# For epoch: 59, Average train MI: -0.78190 !
# For epoch: 59, Average train DDF: 0.03341 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7527 	 and 	 Current val loss: -3.6424
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 60/100
# LR is ==  1e-05
# For epoch: 60, Average train loss: -3.94407 !
# For epoch: 60, Average train DSC: 0.82155 !
#
# For epoch: 60, Average train DSC: -0.62669 !
# For epoch: 60, Average train L2: -0.97182 !
# For epoch: 60, Average train MI: -0.77970 !
# For epoch: 60, Average train DDF: 0.03265 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7549 	 and 	 Current val loss: -3.6215
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 61/100
# LR is ==  1e-05
# For epoch: 61, Average train loss: -3.94436 !
# For epoch: 61, Average train DSC: 0.82627 !
#
# For epoch: 61, Average train DSC: -0.62857 !
# For epoch: 61, Average train L2: -0.96995 !
# For epoch: 61, Average train MI: -0.78243 !
# For epoch: 61, Average train DDF: 0.03510 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7545 	 and 	 Current val loss: -3.6345
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 62/100
# LR is ==  1e-05
# For epoch: 62, Average train loss: -3.94585 !
# For epoch: 62, Average train DSC: 0.82209 !
#
# For epoch: 62, Average train DSC: -0.62986 !
# For epoch: 62, Average train L2: -0.96845 !
# For epoch: 62, Average train MI: -0.78224 !
# For epoch: 62, Average train DDF: 0.03302 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7526 	 and 	 Current val loss: -3.6445
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 63/100
# LR is ==  1e-05
# For epoch: 63, Average train loss: -3.95951 !
# For epoch: 63, Average train DSC: 0.82530 !
#
# For epoch: 63, Average train DSC: -0.63063 !
# For epoch: 63, Average train L2: -0.97398 !
# For epoch: 63, Average train MI: -0.78453 !
# For epoch: 63, Average train DDF: 0.03424 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7567 	 and 	 Current val loss: -3.6371
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 64/100
# LR is ==  1e-05
# For epoch: 64, Average train loss: -3.94997 !
# For epoch: 64, Average train DSC: 0.82333 !
#
# For epoch: 64, Average train DSC: -0.63138 !
# For epoch: 64, Average train L2: -0.96820 !
# For epoch: 64, Average train MI: -0.78502 !
# For epoch: 64, Average train DDF: 0.03421 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7560 	 and 	 Current val loss: -3.6267
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 65/100
# LR is ==  1e-05
# For epoch: 65, Average train loss: -3.95566 !
# For epoch: 65, Average train DSC: 0.82429 !
#
# For epoch: 65, Average train DSC: -0.62991 !
# For epoch: 65, Average train L2: -0.97171 !
# For epoch: 65, Average train MI: -0.78697 !
# For epoch: 65, Average train DDF: 0.03454 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7582 	 and 	 Current val loss: -3.6280
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 66/100
# LR is ==  1e-05
# For epoch: 66, Average train loss: -3.95360 !
# For epoch: 66, Average train DSC: 0.82752 !
#
# For epoch: 66, Average train DSC: -0.63244 !
# For epoch: 66, Average train L2: -0.96928 !
# For epoch: 66, Average train MI: -0.78437 !
# For epoch: 66, Average train DDF: 0.03423 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7537 	 and 	 Current val loss: -3.6338
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 67/100
# LR is ==  1e-05
# For epoch: 67, Average train loss: -3.94898 !
# For epoch: 67, Average train DSC: 0.82378 !
#
# For epoch: 67, Average train DSC: -0.63144 !
# For epoch: 67, Average train L2: -0.96730 !
# For epoch: 67, Average train MI: -0.78674 !
# For epoch: 67, Average train DDF: 0.03524 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7497 	 and 	 Current val loss: -3.6334
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 68/100
# LR is ==  1e-05
# For epoch: 68, Average train loss: -3.96202 !
# For epoch: 68, Average train DSC: 0.82476 !
#
# For epoch: 68, Average train DSC: -0.63289 !
# For epoch: 68, Average train L2: -0.97185 !
# For epoch: 68, Average train MI: -0.78790 !
# For epoch: 68, Average train DDF: 0.03535 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7509 	 and 	 Current val loss: -3.6492
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 69/100
# LR is ==  1e-05
# For epoch: 69, Average train loss: -3.95688 !
# For epoch: 69, Average train DSC: 0.82272 !
#
# For epoch: 69, Average train DSC: -0.63168 !
# For epoch: 69, Average train L2: -0.97055 !
# For epoch: 69, Average train MI: -0.78696 !
# For epoch: 69, Average train DDF: 0.03454 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7538 	 and 	 Current val loss: -3.6161
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 70/100
# LR is ==  1e-05
# For epoch: 70, Average train loss: -3.95027 !
# For epoch: 70, Average train DSC: 0.82333 !
#
# For epoch: 70, Average train DSC: -0.63082 !
# For epoch: 70, Average train L2: -0.96796 !
# For epoch: 70, Average train MI: -0.78908 !
# For epoch: 70, Average train DDF: 0.03636 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7545 	 and 	 Current val loss: -3.6289
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 71/100
# LR is ==  1e-05
# For epoch: 71, Average train loss: -3.95058 !
# For epoch: 71, Average train DSC: 0.82460 !
#
# For epoch: 71, Average train DSC: -0.62756 !
# For epoch: 71, Average train L2: -0.97140 !
# For epoch: 71, Average train MI: -0.78710 !
# For epoch: 71, Average train DDF: 0.03446 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7539 	 and 	 Current val loss: -3.6333
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 72/100
# LR is ==  1e-05
# For epoch: 72, Average train loss: -3.95013 !
# For epoch: 72, Average train DSC: 0.82201 !
#
# For epoch: 72, Average train DSC: -0.62958 !
# For epoch: 72, Average train L2: -0.96923 !
# For epoch: 72, Average train MI: -0.78876 !
# For epoch: 72, Average train DDF: 0.03626 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7533 	 and 	 Current val loss: -3.6248
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 73/100
# LR is ==  1e-05
# For epoch: 73, Average train loss: -3.95112 !
# For epoch: 73, Average train DSC: 0.82406 !
#
# For epoch: 73, Average train DSC: -0.62909 !
# For epoch: 73, Average train L2: -0.97029 !
# For epoch: 73, Average train MI: -0.78696 !
# For epoch: 73, Average train DDF: 0.03459 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7538 	 and 	 Current val loss: -3.6279
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 74/100
# LR is ==  1e-05
# For epoch: 74, Average train loss: -3.93878 !
# For epoch: 74, Average train DSC: 0.82460 !
#
# For epoch: 74, Average train DSC: -0.62732 !
# For epoch: 74, Average train L2: -0.96674 !
# For epoch: 74, Average train MI: -0.78650 !
# For epoch: 74, Average train DDF: 0.03582 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7569 	 and 	 Current val loss: -3.6305
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 75/100
# LR is ==  1e-05
# For epoch: 75, Average train loss: -3.95075 !
# For epoch: 75, Average train DSC: 0.82314 !
#
# For epoch: 75, Average train DSC: -0.62807 !
# For epoch: 75, Average train L2: -0.97098 !
# For epoch: 75, Average train MI: -0.78692 !
# For epoch: 75, Average train DDF: 0.03427 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7563 	 and 	 Current val loss: -3.6400
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 76/100
# LR is ==  1e-05
# For epoch: 76, Average train loss: -3.95394 !
# For epoch: 76, Average train DSC: 0.82233 !
#
# For epoch: 76, Average train DSC: -0.63171 !
# For epoch: 76, Average train L2: -0.96951 !
# For epoch: 76, Average train MI: -0.78754 !
# For epoch: 76, Average train DDF: 0.03604 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7570 	 and 	 Current val loss: -3.6344
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 77/100
# LR is ==  1e-05
# For epoch: 77, Average train loss: -3.95521 !
# For epoch: 77, Average train DSC: 0.82405 !
#
# For epoch: 77, Average train DSC: -0.63230 !
# For epoch: 77, Average train L2: -0.96782 !
# For epoch: 77, Average train MI: -0.79093 !
# For epoch: 77, Average train DDF: 0.03594 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7609 	 and 	 Current val loss: -3.6352
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 78/100
# LR is ==  1e-05
# For epoch: 78, Average train loss: -3.95654 !
# For epoch: 78, Average train DSC: 0.82448 !
#
# For epoch: 78, Average train DSC: -0.63200 !
# For epoch: 78, Average train L2: -0.97024 !
# For epoch: 78, Average train MI: -0.78833 !
# For epoch: 78, Average train DDF: 0.03626 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7525 	 and 	 Current val loss: -3.6120
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 79/100
# LR is ==  1e-05
# For epoch: 79, Average train loss: -3.94682 !
# For epoch: 79, Average train DSC: 0.82495 !
#
# For epoch: 79, Average train DSC: -0.62942 !
# For epoch: 79, Average train L2: -0.96713 !
# For epoch: 79, Average train MI: -0.79007 !
# For epoch: 79, Average train DDF: 0.03634 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7567 	 and 	 Current val loss: -3.6190
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 80/100
# LR is ==  1e-05
# For epoch: 80, Average train loss: -3.96034 !
# For epoch: 80, Average train DSC: 0.82544 !
#
# For epoch: 80, Average train DSC: -0.63324 !
# For epoch: 80, Average train L2: -0.96970 !
# For epoch: 80, Average train MI: -0.79045 !
# For epoch: 80, Average train DDF: 0.03600 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7551 	 and 	 Current val loss: -3.6359
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 81/100
# LR is ==  1e-05
# For epoch: 81, Average train loss: -3.96043 !
# For epoch: 81, Average train DSC: 0.82442 !
#
# For epoch: 81, Average train DSC: -0.63323 !
# For epoch: 81, Average train L2: -0.96975 !
# For epoch: 81, Average train MI: -0.79132 !
# For epoch: 81, Average train DDF: 0.03685 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7533 	 and 	 Current val loss: -3.6194
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 82/100
# LR is ==  1e-05
# For epoch: 82, Average train loss: -3.96796 !
# For epoch: 82, Average train DSC: 0.82705 !
#
# For epoch: 82, Average train DSC: -0.63314 !
# For epoch: 82, Average train L2: -0.97317 !
# For epoch: 82, Average train MI: -0.79258 !
# For epoch: 82, Average train DDF: 0.03724 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7530 	 and 	 Current val loss: -3.6299
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 83/100
# LR is ==  1e-05
# For epoch: 83, Average train loss: -3.95541 !
# For epoch: 83, Average train DSC: 0.82288 !
#
# For epoch: 83, Average train DSC: -0.63320 !
# For epoch: 83, Average train L2: -0.96706 !
# For epoch: 83, Average train MI: -0.79171 !
# For epoch: 83, Average train DDF: 0.03682 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7588 	 and 	 Current val loss: -3.6240
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 84/100
# LR is ==  1e-05
# For epoch: 84, Average train loss: -3.96657 !
# For epoch: 84, Average train DSC: 0.82679 !
#
# For epoch: 84, Average train DSC: -0.63507 !
# For epoch: 84, Average train L2: -0.97022 !
# For epoch: 84, Average train MI: -0.79271 !
# For epoch: 84, Average train DDF: 0.03673 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7579 	 and 	 Current val loss: -3.6269
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 85/100
# LR is ==  1e-05
# For epoch: 85, Average train loss: -3.96561 !
# For epoch: 85, Average train DSC: 0.82412 !
#
# For epoch: 85, Average train DSC: -0.63591 !
# For epoch: 85, Average train L2: -0.96933 !
# For epoch: 85, Average train MI: -0.79297 !
# For epoch: 85, Average train DDF: 0.03784 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7565 	 and 	 Current val loss: -3.6377
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 86/100
# LR is ==  1e-05
# For epoch: 86, Average train loss: -3.96631 !
# For epoch: 86, Average train DSC: 0.82602 !
#
# For epoch: 86, Average train DSC: -0.63452 !
# For epoch: 86, Average train L2: -0.96990 !
# For epoch: 86, Average train MI: -0.79444 !
# For epoch: 86, Average train DDF: 0.03697 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7571 	 and 	 Current val loss: -3.6429
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 87/100
# LR is ==  1e-05
# For epoch: 87, Average train loss: -3.96585 !
# For epoch: 87, Average train DSC: 0.82431 !
#
# For epoch: 87, Average train DSC: -0.63514 !
# For epoch: 87, Average train L2: -0.96943 !
# For epoch: 87, Average train MI: -0.79468 !
# For epoch: 87, Average train DDF: 0.03797 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7522 	 and 	 Current val loss: -3.6445
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 88/100
# LR is ==  1e-05
# For epoch: 88, Average train loss: -3.96406 !
# For epoch: 88, Average train DSC: 0.82263 !
#
# For epoch: 88, Average train DSC: -0.63387 !
# For epoch: 88, Average train L2: -0.97001 !
# For epoch: 88, Average train MI: -0.79365 !
# For epoch: 88, Average train DDF: 0.03737 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7572 	 and 	 Current val loss: -3.6286
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 89/100
# LR is ==  1e-05
# For epoch: 89, Average train loss: -3.95950 !
# For epoch: 89, Average train DSC: 0.82558 !
#
# For epoch: 89, Average train DSC: -0.63212 !
# For epoch: 89, Average train L2: -0.97010 !
# For epoch: 89, Average train MI: -0.79257 !
# For epoch: 89, Average train DDF: 0.03750 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7544 	 and 	 Current val loss: -3.6327
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 90/100
# LR is ==  1e-05
# For epoch: 90, Average train loss: -3.96216 !
# For epoch: 90, Average train DSC: 0.82302 !
#
# For epoch: 90, Average train DSC: -0.63269 !
# For epoch: 90, Average train L2: -0.97114 !
# For epoch: 90, Average train MI: -0.79251 !
# For epoch: 90, Average train DDF: 0.03800 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7580 	 and 	 Current val loss: -3.6400
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 91/100
# LR is ==  1e-05
# For epoch: 91, Average train loss: -3.95492 !
# For epoch: 91, Average train DSC: 0.82613 !
#
# For epoch: 91, Average train DSC: -0.63234 !
# For epoch: 91, Average train L2: -0.96851 !
# For epoch: 91, Average train MI: -0.79091 !
# For epoch: 91, Average train DDF: 0.03768 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7502 	 and 	 Current val loss: -3.6141
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 92/100
# LR is ==  1e-05
# For epoch: 92, Average train loss: -3.94560 !
# For epoch: 92, Average train DSC: 0.82145 !
#
# For epoch: 92, Average train DSC: -0.62838 !
# For epoch: 92, Average train L2: -0.96763 !
# For epoch: 92, Average train MI: -0.79151 !
# For epoch: 92, Average train DDF: 0.03792 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7522 	 and 	 Current val loss: -3.6321
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 93/100
# LR is ==  1e-05
# For epoch: 93, Average train loss: -3.96183 !
# For epoch: 93, Average train DSC: 0.82641 !
#
# For epoch: 93, Average train DSC: -0.63096 !
# For epoch: 93, Average train L2: -0.97265 !
# For epoch: 93, Average train MI: -0.79117 !
# For epoch: 93, Average train DDF: 0.03655 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7510 	 and 	 Current val loss: -3.6209
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 94/100
# LR is ==  1e-05
# For epoch: 94, Average train loss: -3.95867 !
# For epoch: 94, Average train DSC: 0.82296 !
#
# For epoch: 94, Average train DSC: -0.63266 !
# For epoch: 94, Average train L2: -0.96884 !
# For epoch: 94, Average train MI: -0.79361 !
# For epoch: 94, Average train DDF: 0.03795 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7540 	 and 	 Current val loss: -3.6119
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 95/100
# LR is ==  1e-05
# For epoch: 95, Average train loss: -3.95753 !
# For epoch: 95, Average train DSC: 0.82505 !
#
# For epoch: 95, Average train DSC: -0.63330 !
# For epoch: 95, Average train L2: -0.96722 !
# For epoch: 95, Average train MI: -0.79380 !
# For epoch: 95, Average train DDF: 0.03731 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7548 	 and 	 Current val loss: -3.6501
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 96/100
# LR is ==  1e-05
# For epoch: 96, Average train loss: -3.96340 !
# For epoch: 96, Average train DSC: 0.82307 !
#
# For epoch: 96, Average train DSC: -0.63359 !
# For epoch: 96, Average train L2: -0.96996 !
# For epoch: 96, Average train MI: -0.79457 !
# For epoch: 96, Average train DDF: 0.03828 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7518 	 and 	 Current val loss: -3.6383
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 97/100
# LR is ==  1e-05
# For epoch: 97, Average train loss: -3.96617 !
# For epoch: 97, Average train DSC: 0.82356 !
#
# For epoch: 97, Average train DSC: -0.63236 !
# For epoch: 97, Average train L2: -0.97227 !
# For epoch: 97, Average train MI: -0.79442 !
# For epoch: 97, Average train DDF: 0.03750 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7603 	 and 	 Current val loss: -3.6411
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 98/100
# LR is ==  1e-05
# For epoch: 98, Average train loss: -3.96097 !
# For epoch: 98, Average train DSC: 0.82426 !
#
# For epoch: 98, Average train DSC: -0.63308 !
# For epoch: 98, Average train L2: -0.96890 !
# For epoch: 98, Average train MI: -0.79531 !
# For epoch: 98, Average train DDF: 0.03830 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7551 	 and 	 Current val loss: -3.6291
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 99/100
# LR is ==  1e-05
# For epoch: 99, Average train loss: -3.95977 !
# For epoch: 99, Average train DSC: 0.82408 !
#
# For epoch: 99, Average train DSC: -0.63404 !
# For epoch: 99, Average train L2: -0.96667 !
# For epoch: 99, Average train MI: -0.79578 !
# For epoch: 99, Average train DDF: 0.03742 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7584 	 and 	 Current val loss: -3.6472
#
# Best val DSC: 0.7628 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 100/100
# LR is ==  1e-05
# For epoch: 100, Average train loss: -3.96830 !
# For epoch: 100, Average train DSC: 0.82501 !
#
# For epoch: 100, Average train DSC: -0.63621 !
# For epoch: 100, Average train L2: -0.96921 !
# For epoch: 100, Average train MI: -0.79726 !
# For epoch: 100, Average train DDF: 0.03979 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7529 	 and 	 Current val loss: -3.6368
#
# Best val DSC: 0.7628 at epoch number of 12

# %%
# %matplotlib inline
plt.figure("train", (20, 4))
plt.subplot(1, 2, 1)
plt.plot(epoch_loss_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.plot(epoch_val_loss_values, label = 'val', color='b', lw=2, linestyle='-', marker = 'x')
plt.legend(fontsize=20, loc='upper right', ncol=1)
plt.xticks(range(0, max_epochs , 5))
plt.ylabel('Losses', fontsize=20)
plt.xlabel('Epochs', fontsize=20)

plt.subplot(1, 2, 2)
plt.plot(metric_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.ylabel('DSC', fontsize=20)
plt.xlabel('Epochs', fontsize=20)
# Out:
# Text(0.5, 0, 'Epochs')

# %%
def hausdorff (mask1, mask2):
    mask1_class_LV = mask1.copy()
    mask1_class_Myo = mask1.copy()
    
    mask1_class_LV[mask1_class_LV==1] = 0
    mask1_class_Myo[mask1_class_Myo==2] = 0
    
    mask2_class_LV = mask2.copy()
    mask2_class_Myo = mask2.copy()
    
    mask2_class_LV[mask2_class_LV==1] = 0
    mask2_class_Myo[mask2_class_Myo==2] = 0
    
    hausdorff_Myo = (directed_hausdorff(mask1_class_Myo, mask2_class_Myo)[0]+directed_hausdorff(mask2_class_Myo, mask1_class_Myo)[0])/2

    hausdorff_LV = (directed_hausdorff(mask1_class_LV, mask2_class_LV)[0]+directed_hausdorff(mask2_class_LV, mask1_class_LV)[0])/2
    
    return [hausdorff_Myo, hausdorff_LV]

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()

metric = monai.metrics.MSEMetric()

before_MSEMetric = []
after_MSEMetric = []

before_compute_meandice = []
after_compute_meandice = []

before_compute_hausdorff_distance = []
after_compute_hausdorff_distance = []
                                                                         

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    before_MSEMetric.extend(metric(moving_val_img_,fixed_val_img_).detach().cpu().numpy())
    
    after_MSEMetric.extend(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())
    
#     print(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())

    before_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy())
    after_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy()) 
    
    
    before_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy())
    after_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy()) 
    
    
#     break

print(np.array(before_MSEMetric).shape)
print(np.array(after_MSEMetric).shape)

print(np.array(before_compute_meandice).shape)
print(np.array(after_compute_meandice).shape)

print()

print(f'MSEMetric W/O registration {np.mean(np.array(before_MSEMetric))}')
print(f'MSEMetric W/ registration = {np.mean(np.array(after_MSEMetric))}')

print(f'Mean dice W/O registration = {np.mean(np.array(before_compute_meandice), axis=0)}')
print(f'Mean dice W/ registration = {np.mean(np.array(after_compute_meandice), axis=0)}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.array(before_compute_hausdorff_distance), axis=0)}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.array(after_compute_hausdorff_distance), axis=0)}')

print()

print('----------------For Report Metric +/- Std-----------------------')
print(f'Mean dice W/O registration = {np.mean(np.mean(np.array(before_compute_meandice), axis=0))} + {np.mean(np.std(np.array(before_compute_meandice), axis=0))}')
print(f'Mean dice W/ registration = {np.mean(np.mean(np.array(after_compute_meandice), axis=0))} + {np.mean(np.std(np.array(after_compute_meandice), axis=0))}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.mean(np.array(before_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(before_compute_hausdorff_distance), axis=0))}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.mean(np.array(after_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(after_compute_hausdorff_distance), axis=0))}')

df = ({
     'before_compute_hausdorff_distance':np.mean(np.array(before_compute_hausdorff_distance), axis=1),
     'after_compute_hausdorff_distance'   : np.mean(np.array(after_compute_hausdorff_distance), axis=1),
     'before_compute_meandice':np.mean(np.array(before_compute_meandice), axis=1),
     'after_compute_meandice':np.mean(np.array(after_compute_meandice), axis=1),
     'before_MSEMetric': np.mean(np.array(before_MSEMetric), axis=1),
     'after_MSEMetric':np.mean(np.array(after_MSEMetric), axis=1)
})

pd.DataFrame(df).to_csv(fileNames+'.csv')
# Out:
# <function compute_meandice at 0x7f99ebcf4280>: Function `compute_meandice` has been deprecated since version 1.0.0. use `compute_dice` instead.
# (20, 1)
# (20, 1)
# (20, 3)
# (20, 3)
#
# MSEMetric W/O registration 0.0037914433050900698
# MSEMetric W/ registration = 0.0036689802072942257
# Mean dice W/O registration = [0.99137247 0.8077254  0.7419963 ]
# Mean dice W/ registration = [0.98797786 0.6926135  0.6077784 ]
# Hausdorff_distance W/O registration = [5.79930922 6.06233479]
# Hausdorff_distance W/ registration = [20.57065603  6.62290739]
#
# ----------------For Report Metric +/- Std-----------------------
# Mean dice W/O registration = 0.8470314145088196 + 0.12218629568815231
# Mean dice W/ registration = 0.7627899050712585 + 0.086185984313488
# Hausdorff_distance W/O registration = 5.930822006719249 + 2.0668776584082336
# Hausdorff_distance W/ registration = 13.596781708384992 + 3.6516194841190686

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()
                                          

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    break

fixed_val_img_ = fixed_val_img_.detach().cpu().numpy()[:, 0]
fixed_val_msk_ = fixed_val_msk_.detach().cpu().numpy()[:, 0]

moving_val_img_ = moving_val_img_.detach().cpu().numpy()[:, 0]
moving_val_msk_ = moving_val_msk_.detach().cpu().numpy()[:, 0]

pred_image_val = pred_image_val.detach().cpu().numpy()[:, 0]
pred_mask_val = pred_mask_val.detach().cpu().numpy()[:, 0]

# %%
def colored (pred_img, true_img): 
    bitwise_and = cv2.bitwise_and(pred_img, true_img)
    
    TP = np.stack((np.zeros_like(bitwise_and), bitwise_and, np.zeros_like(bitwise_and)), axis=-1)
    
    FN = np.stack((true_img-bitwise_and,
                   true_img-bitwise_and,
                   np.zeros_like(true_img-bitwise_and)), axis=-1)
    
    FP = np.stack((pred_img-bitwise_and,
                   pred_img-bitwise_and,
                  np.zeros_like(pred_img-bitwise_and)), axis=-1)
    
    return (255*(TP+FN+FP)).astype('uint8')

# %%
slice_no = 15
# %matplotlib inline
slice_num = 8
plt.subplots(slice_num, 7, figsize=(12, 15))

for b in range(slice_num):
    # moving image
    plt.subplot(slice_num, 7, b * 7 + 1)
    plt.axis('off')
    plt.title("moving img")
    plt.imshow(moving_val_img_[0, :, :, slice_no], cmap="gray")
    
    # moving label
    plt.subplot(slice_num, 7, b * 7 + 2)
    plt.axis('off')
    plt.title("moving lab")
    plt.imshow(moving_val_msk_[0, :, :, slice_no], cmap="gray")
    
    
    # fixed image
    plt.subplot(slice_num, 7, b * 7 + 3)
    plt.axis('off')
    plt.title("fixed img")
    plt.imshow(fixed_val_img_[0, :, :, slice_no], cmap="gray")
    
    # fixed label
    plt.subplot(slice_num, 7, b * 7 + 4)
    plt.axis('off')
    plt.title("fixed lab")
    plt.imshow(fixed_val_msk_[0, :, :, slice_no], cmap="gray")
    
    
    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 5)
    plt.axis('off')
    plt.title("Pred Img")
    plt.imshow(pred_image_val[0, :, :, slice_no], cmap="gray")


    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 6)
    plt.axis('off')
    plt.title("Before Reg")
    plt.imshow(colored(moving_val_msk_[0, :, :, slice_no], fixed_val_msk_[0, :, :, slice_no]))
    
    
    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 7)
    plt.axis('off')
    plt.title("After Reg")
    plt.imshow(colored(pred_mask_val[0, :, :, slice_no], fixed_val_msk_[0, :, :, slice_no]))

    slice_no = slice_no + 1
    
plt.axis('off')
plt.show()
