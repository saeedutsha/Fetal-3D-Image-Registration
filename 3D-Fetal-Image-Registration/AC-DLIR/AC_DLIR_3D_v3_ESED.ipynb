# %%
# Import and Install Libraries

from monai.utils import set_determinism, first
from monai.transforms import (
    EnsureChannelFirstD,
    Compose,
    LoadImageD,
    RandRotateD,
    RandZoomD,
    ScaleIntensityRanged,
)
import monai
from monai.data import DataLoader, Dataset, CacheDataset
from monai.config import print_config, USE_COMPILED
from monai.networks.nets import GlobalNet, LocalNet, RegUNet
from monai.networks.blocks import Warp
from monai.apps import MedNISTDataset
import torch.nn.functional as F

from glob import glob
import cv2
import torchmetrics

from torch.autograd import Variable

from scipy.spatial.distance import directed_hausdorff
from scipy.ndimage import zoom
import pandas as pd

import torch.nn as nn

import numpy as np
import torch
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
from matplotlib.animation import FuncAnimation
import os
import tempfile
from monai.losses import *
from monai.metrics import *
from piqa import SSIM

import nibabel as nib

import csv

print_config()
set_determinism(40)
# Out:
# MONAI version: 1.0.1
# Numpy version: 1.22.3
# Pytorch version: 1.13.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 8271a193229fe4437026185e218d5b06f7c8ce69
# MONAI __file__: /home/mkh/anaconda3/envs/phd/lib/python3.9/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.10
# Nibabel version: 5.0.1
# scikit-image version: 0.19.3
# Pillow version: 9.0.1
# Tensorboard version: 2.12.0
# gdown version: 4.6.4
# TorchVision version: 0.14.1
# tqdm version: 4.64.1
# lmdb version: 1.4.0
# psutil version: 5.9.4
# pandas version: 1.5.3
# einops version: 0.6.0
# transformers version: 4.21.3
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
# Directories and some Parameters

dataDir = '3D_Updated'

root_dir = '/home/mkh/MKH/KSA/Dataset/'+dataDir+'/'
print(root_dir)

trainBatch = 1
testBatch = 1

img_size = 256
slice_size = 32

previousWeight = 128

preTrained = 0

EP = 100

num_workers = 0

ExpName = "AC_DLIR_ESED"

fileNames = ExpName + '_' + dataDir + '_' +str(img_size) + '_'+str(slice_size) + '_'

# print(fileNames)
# Out:
# /home/mkh/MKH/KSA/Dataset/3D_Updated/

# %%
# GPU information
print('How many GPUs = ' + str(torch.cuda.device_count()))

#checking for device

device=torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
print(device)

if not torch.cuda.is_available():
  raise Exception("GPU not availalbe. CPU training will be too slow.")

print("device name", torch.cuda.get_device_name(0))
# Out:
# How many GPUs = 4
# cuda:2
# device name NVIDIA GeForce RTX 3090 Ti

# %%
# # Make fixed-moving pairs in csv
# # root_dir = '/home/mkh/MKH/KSA/Dataset/'+dataDir+'/'
# splits = ['train', 'val']
# for split in splits:
#     fixed_names = []
#     moving_names = []
#     split_path = os.path.join(root_dir, split)
#     for folders in sorted(os.listdir(split_path)):
#         split_path_folders = os.path.join(split_path, folders)
#         if 'fixed_img' in folders:
#             for fixed_imgs in sorted(os.listdir(split_path_folders)):
#                 split_path_folders_fixed_imgs = os.path.join(split_path_folders, fixed_imgs)
#                 fixed_pt = fixed_imgs.split('_')[0]
#                 for mov_folders in sorted(os.listdir(split_path)):
#                     if 'moving_img' in mov_folders:
#                         mov_split_path_folders = os.path.join(split_path, mov_folders)
#                         for moving_imgs in sorted(os.listdir(mov_split_path_folders)):
#                             moving_pt = moving_imgs.split('_')[0]
#                             if(fixed_pt==moving_pt):
#                                 fixed_names.append(fixed_imgs)
#                                 moving_names.append(moving_imgs)
#     data = {'Fixed':fixed_names, 'Moving':moving_names}
#     dataframe = pd.DataFrame(data=data, index=None)
#     csv_path = root_dir + split + '.csv'
#     dataframe.to_csv(csv_path,index=False)

# %%
class EchoDataset3D(Dataset):
    def __init__(self, images_path, flagMask):

        self.images_path = images_path
        self.n_samples = len(images_path)
        self.flagMask = flagMask

    def __getitem__(self, index):
        """ Reading Nifti Files """
        
        # image = cv2.imread(self.images_path[index], cv2.IMREAD_GRAYSCALE)
        img_3d = nib.load(self.images_path[index])
        image = img_3d.get_fdata()

        if self.flagMask==0:
            image = zoom(image, (img_size / image.shape[0], img_size / image.shape[1], slice_size / image.shape[2]))
            # image = cv2.resize(image,(img_size, img_size))
            image = (image-image.min())/(image.max()-image.min())
        else:
            image[image==127]=1
            image[image==255]=2
            image = zoom(image, (img_size / image.shape[0], img_size / image.shape[1], slice_size / image.shape[2]), order=0)
            # image = cv2.resize(image,(img_size, img_size), interpolation=cv2.INTER_NEAREST)
            # image = image/(image.max()) ## (512, 512, 3)
            # print(image.max())
        image = np.expand_dims(image, axis=0)
        image = image.astype(np.float32)
        self.images_path[index]
        return image

    def __len__(self):
        return self.n_samples

# %%
def get_batches(split_dir,
                split,
                fixOrMov,
                flagMask,
                batch_size,
                num_workers,
                pin_memory):
    
    csv_path = pd.read_csv(root_dir + split + "_esed_v2.csv")
    all_path  = split_dir + csv_path[fixOrMov]
    
    split_data = EchoDataset3D(images_path=all_path, flagMask=flagMask)

    split_loader = DataLoader(split_data,
                              batch_size=batch_size,
                              num_workers=num_workers,
                              pin_memory=pin_memory,
                              shuffle=False)

    return split_loader

# %%
fixed_train_img = get_batches(split_dir = sorted(glob(root_dir+"train/img/")),
                                        split = 'train',
                                        fixOrMov = 'Fixed',
                                        flagMask = 0,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_train_msk = get_batches(split_dir = sorted(glob(root_dir+"train/msk/")),
                                        split = 'train',
                                        fixOrMov = 'Fixed',
                                        flagMask = 1,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_train_img = get_batches(split_dir = sorted(glob(root_dir+"train/img/")),
                                        split = 'train',
                                        fixOrMov = 'Moving',
                                        flagMask = 0,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_train_msk = get_batches(split_dir = sorted(glob(root_dir+"train/msk/")),
                                        split = 'train',
                                        fixOrMov = 'Moving',
                                        flagMask = 1,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

print("Train IMG FIXED:", fixed_train_img)
print("Train MSK FIXED:", fixed_train_msk)
print("Train IMG Moving:", moving_train_img)
print("Train MSK Moving:", moving_train_msk)

fixed_val_img = get_batches(split_dir = sorted(glob(root_dir+"val/img/")),
                                        split = 'val',
                                        fixOrMov = 'Fixed',
                                        flagMask = 0,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_val_msk = get_batches(split_dir = sorted(glob(root_dir+"val/msk/")),
                                        split = 'val',
                                        fixOrMov = 'Fixed',
                                        flagMask = 1,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


moving_val_img = get_batches(split_dir = sorted(glob(root_dir+"val/img/")),
                                        split = 'val',
                                        fixOrMov = 'Moving',
                                        flagMask = 0,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_val_msk = get_batches(split_dir = sorted(glob(root_dir+"val/msk/")),
                                        split = 'val',
                                        fixOrMov = 'Moving',
                                        flagMask = 1,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


print("Val IMG FIXED:", fixed_val_img)
print("Val MSK FIXED:", fixed_val_msk)
print("Val IMG Moving:", moving_val_img)
print("Val MSK Moving:", moving_val_msk)
# Out:
# Train IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7fb3c86026d0>
# Train MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7fb3c86160d0>
# Train IMG Moving: <monai.data.dataloader.DataLoader object at 0x7fb273539a30>
# Train MSK Moving: <monai.data.dataloader.DataLoader object at 0x7fb273539c10>
# Val IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7fb273539a90>
# Val MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7fb273539c70>
# Val IMG Moving: <monai.data.dataloader.DataLoader object at 0x7fb3c8615d30>
# Val MSK Moving: <monai.data.dataloader.DataLoader object at 0x7fb27251b370>

# %%
# Change here
train_csv = pd.read_csv(root_dir + 'train_esed_v2.csv')
val_csv =  pd.read_csv(root_dir + 'val_esed_v2.csv')

print(f'Train Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"train/img/")) + train_csv["Fixed"] )}')
print(f'Train Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"train/msk/")) + train_csv["Fixed"] )}')
print(f'Train Sample numbers (moving_img) = {len(sorted(glob(root_dir+"train/img/")) + train_csv["Moving"] )}')
print(f'Train Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"/train/msk/")) + train_csv["Fixed"] )}')
print()
print(f'Val Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"val/img/")) + val_csv["Fixed"] )}')
print(f'Val Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"val/msk/")) + val_csv["Fixed"] )}')
print(f'Val Sample numbers (moving_img) = {len(sorted(glob(root_dir+"val/img/")) + val_csv["Moving"] )}')
print(f'Val Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"val/msk/")) + val_csv["Moving"] )}')
print()
# Out:
# Train Sample numbers (fixed_img) = 50
# Train Sample numbers (fixed_msk) = 50
# Train Sample numbers (moving_img) = 50
# Train Sample numbers (moving_msk) = 50
#
# Val Sample numbers (fixed_img) = 20
# Val Sample numbers (fixed_msk) = 20
# Val Sample numbers (moving_img) = 20
# Val Sample numbers (moving_msk) = 20

# %%
dataloaders = {
    'fixed_train_img': fixed_train_img,
    'fixed_train_msk': fixed_train_msk,
    'moving_train_img': moving_train_img,
    'moving_train_msk': moving_train_msk,
    'fixed_val_img': fixed_val_img,
    'fixed_val_msk': fixed_val_msk,
    'moving_val_img': moving_val_img,
    'moving_val_msk': moving_val_msk
    }

# %%
fixed_train_img_ = first(dataloaders["fixed_train_img"])[0][0]
fixed_train_msk_ = first(dataloaders["fixed_train_msk"])[0][0]
moving_train_img_ = first(dataloaders["moving_train_img"])[0][0]
moving_train_msk_ = first(dataloaders["moving_train_msk"])[0][0]

fixed_val_img_ = first(dataloaders["fixed_val_img"])[0][0]
fixed_val_msk_ = first(dataloaders["fixed_val_msk"])[0][0]
moving_val_img_ = first(dataloaders["moving_val_img"])[0][0]
moving_val_msk_ = first(dataloaders["moving_val_msk"])[0][0]


print(f"fixed_train_img_ shape: {fixed_train_img_.shape}")
print(f"fixed_train_msk_ shape: {fixed_train_msk_.shape}")
print(f"moving_train_img_ shape: {moving_train_img_.shape}")
print(f"moving_train_msk_ shape: {moving_train_msk_.shape}")

print(f"fixed_val_img_ shape: {fixed_val_img_.shape}")
print(f"fixed_val_msk_ shape: {fixed_val_msk_.shape}")
print(f"moving_val_img_ shape: {moving_val_img_.shape}")
print(f"moving_val_msk_ shape: {moving_val_msk_.shape}")


print(f"fixed_train_img_ Range: {fixed_train_img_.max()} {fixed_train_img_.min()}")
print(f"fixed_train_msk_ range: {fixed_train_msk_.max()} {fixed_train_msk_.min()} {np.unique(fixed_train_msk_)}")
print(f"moving_train_img_ Range: {moving_train_img_.max()} {moving_train_img_.min()}")
print(f"moving_train_msk_ range: {moving_train_msk_.max()} {moving_train_msk_.min()} {np.unique(moving_train_msk_)}")

print(f"fixed_val_img_ Range: {fixed_val_img_.max()} {fixed_val_img_.min()}")
print(f"fixed_val_msk_ range: {fixed_val_msk_.max()} {fixed_val_msk_.min()} {np.unique(fixed_val_msk_)}")
print(f"moving_val_img_ Range: {moving_val_img_.max()} {moving_val_img_.min()}")
print(f"moving_val_msk_ range: {moving_val_msk_.max()} {moving_val_msk_.min()} {np.unique(moving_val_msk_)}")
# Out:
# fixed_train_img_ shape: torch.Size([256, 256, 32])
# fixed_train_msk_ shape: torch.Size([256, 256, 32])
# moving_train_img_ shape: torch.Size([256, 256, 32])
# moving_train_msk_ shape: torch.Size([256, 256, 32])
# fixed_val_img_ shape: torch.Size([256, 256, 32])
# fixed_val_msk_ shape: torch.Size([256, 256, 32])
# moving_val_img_ shape: torch.Size([256, 256, 32])
# moving_val_msk_ shape: torch.Size([256, 256, 32])
# fixed_train_img_ Range: 1.0 0.0
# fixed_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_train_img_ Range: 1.0 0.0
# moving_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# fixed_val_img_ Range: 1.0 0.0
# fixed_val_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_val_img_ Range: 1.0 0.0
# moving_val_msk_ range: 2.0 0.0 [0. 1. 2.]

# %%
# %matplotlib widget

# volumes = [fixed_train_img_, fixed_train_msk_, moving_train_img_, moving_train_msk_, fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_]  # Replace with your actual 3D volume data

# # Create a figure and subplots
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))

# # Create initial slices for each volume
# initial_slices = [0] * 8
# current_slices = []

# # Plot the initial slices
# for i, ax in enumerate(axs.flat):
#     ax.axis('off')  # Hide the axis numbers
#     current_slice = ax.imshow(volumes[i][:, :, initial_slices[i]], cmap='gray')
#     current_slices.append(current_slice)

# # Create sliders and axes for each volume
# sliders = []
# slider_axes = []
# for i, ax in enumerate(axs.flat):
#     ax_slider = plt.axes([ax.get_position().x0, ax.get_position().y0 - 0.05, ax.get_position().width, 0.02])
#     slider = Slider(ax=ax_slider, label=f'Slice {i+1}', valmin=0, valmax=volumes[i].shape[2] - 1, valinit=initial_slices[i], valstep=1)
#     sliders.append(slider)
#     slider_axes.append(ax_slider)

# # Update the plots when the slider values change
# def update_slices():
#     for i, slider in enumerate(sliders):
#         current_slices[i].set_data(volumes[i][:, :, int(slider.val)])

#     fig.canvas.draw_idle()

# for slider in sliders:
#     slider.on_changed(lambda event: update_slices())

# # Animation function
# def animate(i):
#     # Increment the slice values for each volume
#     slice_vals = [(initial_slices[j] + i) % volumes[j].shape[2] for j in range(8)]

#     # Update the slider values
#     for j, slider in enumerate(sliders):
#         slider.set_val(slice_vals[j])

#     # Update the plots
#     update_slices()

# # Create the animation
# animation = FuncAnimation(fig, animate, frames=volumes[0].shape[2]*2, interval=200)

# # Set up plot settings
# plt.subplots_adjust(hspace=0.4, wspace=0.2, bottom=0.15)

# # Display the plot
# plt.show()

# %%
# %matplotlib widget

# volume = fixed_train_img_  # Replace this with your actual 3D volume data

# # Create a figure and axes for the plot
# fig, ax = plt.subplots()

# # Plot the initial slice
# initial_slice = 0
# current_slice = ax.imshow(volume[:, :, initial_slice], cmap='gray')

# # Create a slider for selecting the slice
# ax_slider = plt.axes([0.2, 0.03, 0.6, 0.05])
# slider = Slider(ax=ax_slider, label='Slice', valmin=0, valmax=volume.shape[2] - 1, valinit=initial_slice, valstep=1)

# # Update the plot when the slider value changes
# def update_slice(val):
#     current_slice.set_data(volume[:, :, int(val)])
#     fig.canvas.draw_idle()

# slider.on_changed(update_slice)

# # Set up plot settings
# plt.subplots_adjust(hspace=0.4, wspace=0.2, bottom=0.15)

# # Display the plot
# plt.show()

# %%
plt.figure("check", (10, 5))
train_slice_no = 18
val_slice_no = 18

plt.subplot(2, 4, 1)
plt.title("fixed_train_img_\n Slice: "+str(train_slice_no))
plt.imshow(fixed_train_img_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 2)
plt.title("fixed_train_msk_\n Slice: "+str(train_slice_no))
plt.imshow(fixed_train_msk_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 3)
plt.title("moving_train_img_\n Slice: "+str(train_slice_no))
plt.imshow(moving_train_img_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 4)
plt.title("moving_train_msk_\n Slice: "+str(train_slice_no))
plt.imshow(moving_train_msk_[:,:,train_slice_no], cmap="gray")
plt.axis('off')


plt.subplot(2, 4, 5)
plt.title("fixed_val_img_\n Slice: "+str(val_slice_no))
plt.imshow(fixed_val_img_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 6)
plt.title("fixed_val_msk_\n Slice: "+str(val_slice_no))
plt.imshow(fixed_val_msk_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 7)
plt.title("moving_val_img_\n Slice: "+str(val_slice_no))
plt.imshow(moving_val_img_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 8)
plt.title("moving_val_msk_\n Slice: "+str(val_slice_no))
plt.imshow(moving_val_msk_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.show()

# %%
mod = RegUNet(
    spatial_dims=3,
    in_channels=2,
    num_channel_initial=32,
    depth = 5,
    extract_levels=[5],
    out_activation=None,
    out_channels=3,
    out_kernel_initializer="zeros",
    concat_skip=False)

        

inputs = torch.randn((1, 2, img_size, img_size, slice_size))

y = mod(inputs)
print(y.shape)

import torch, torchinfo
# from torchviz import make_dot, make_dot_from_trace
    
# make_dot(y, params=dict(mod.named_parameters()),
#          show_attrs=False,
#          show_saved=False).render(fileNames, format="png")

torchinfo.summary(mod, input_size=(1, 2, img_size, img_size, slice_size), depth=10)
# Out:
# torch.Size([1, 3, 256, 256, 32])
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# RegUNet                                                 [1, 3, 256, 256, 32]      --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-1                                  [1, 32, 256, 256, 32]     --
# │    │    └─Convolution: 3-1                            [1, 32, 256, 256, 32]     --
# │    │    │    └─Conv3d: 4-1                            [1, 32, 256, 256, 32]     1,728
# │    │    │    └─ADN: 4-2                               [1, 32, 256, 256, 32]     --
# │    │    │    │    └─BatchNorm3d: 5-1                  [1, 32, 256, 256, 32]     64
# │    │    │    │    └─ReLU: 5-2                         [1, 32, 256, 256, 32]     --
# │    │    └─RegistrationResidualConvBlock: 3-2          [1, 32, 256, 256, 32]     --
# │    │    │    └─ModuleList: 4-6                        --                        (recursive)
# │    │    │    │    └─Convolution: 5-3                  [1, 32, 256, 256, 32]     --
# │    │    │    │    │    └─Conv3d: 6-1                  [1, 32, 256, 256, 32]     27,648
# │    │    │    └─ModuleList: 4-7                        --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-4                  [1, 32, 256, 256, 32]     64
# │    │    │    └─ModuleList: 4-8                        --                        --
# │    │    │    │    └─ReLU: 5-5                         [1, 32, 256, 256, 32]     --
# │    │    │    └─ModuleList: 4-6                        --                        (recursive)
# │    │    │    │    └─Convolution: 5-6                  [1, 32, 256, 256, 32]     --
# │    │    │    │    │    └─Conv3d: 6-2                  [1, 32, 256, 256, 32]     27,648
# │    │    │    └─ModuleList: 4-7                        --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-7                  [1, 32, 256, 256, 32]     64
# │    │    │    └─ModuleList: 4-8                        --                        --
# │    │    │    │    └─ReLU: 5-8                         [1, 32, 256, 256, 32]     --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-2                 [1, 32, 128, 128, 16]     --
# │    │    └─MaxPool3d: 3-3                              [1, 32, 128, 128, 16]     --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-3                                  [1, 64, 128, 128, 16]     --
# │    │    └─Convolution: 3-4                            [1, 64, 128, 128, 16]     --
# │    │    │    └─Conv3d: 4-9                            [1, 64, 128, 128, 16]     55,296
# │    │    │    └─ADN: 4-10                              [1, 64, 128, 128, 16]     --
# │    │    │    │    └─BatchNorm3d: 5-9                  [1, 64, 128, 128, 16]     128
# │    │    │    │    └─ReLU: 5-10                        [1, 64, 128, 128, 16]     --
# │    │    └─RegistrationResidualConvBlock: 3-5          [1, 64, 128, 128, 16]     --
# │    │    │    └─ModuleList: 4-14                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-11                 [1, 64, 128, 128, 16]     --
# │    │    │    │    │    └─Conv3d: 6-3                  [1, 64, 128, 128, 16]     110,592
# │    │    │    └─ModuleList: 4-15                       --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-12                 [1, 64, 128, 128, 16]     128
# │    │    │    └─ModuleList: 4-16                       --                        --
# │    │    │    │    └─ReLU: 5-13                        [1, 64, 128, 128, 16]     --
# │    │    │    └─ModuleList: 4-14                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-14                 [1, 64, 128, 128, 16]     --
# │    │    │    │    │    └─Conv3d: 6-4                  [1, 64, 128, 128, 16]     110,592
# │    │    │    └─ModuleList: 4-15                       --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-15                 [1, 64, 128, 128, 16]     128
# │    │    │    └─ModuleList: 4-16                       --                        --
# │    │    │    │    └─ReLU: 5-16                        [1, 64, 128, 128, 16]     --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-4                 [1, 64, 64, 64, 8]        --
# │    │    └─MaxPool3d: 3-6                              [1, 64, 64, 64, 8]        --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-5                                  [1, 128, 64, 64, 8]       --
# │    │    └─Convolution: 3-7                            [1, 128, 64, 64, 8]       --
# │    │    │    └─Conv3d: 4-17                           [1, 128, 64, 64, 8]       221,184
# │    │    │    └─ADN: 4-18                              [1, 128, 64, 64, 8]       --
# │    │    │    │    └─BatchNorm3d: 5-17                 [1, 128, 64, 64, 8]       256
# │    │    │    │    └─ReLU: 5-18                        [1, 128, 64, 64, 8]       --
# │    │    └─RegistrationResidualConvBlock: 3-8          [1, 128, 64, 64, 8]       --
# │    │    │    └─ModuleList: 4-22                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-19                 [1, 128, 64, 64, 8]       --
# │    │    │    │    │    └─Conv3d: 6-5                  [1, 128, 64, 64, 8]       442,368
# │    │    │    └─ModuleList: 4-23                       --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-20                 [1, 128, 64, 64, 8]       256
# │    │    │    └─ModuleList: 4-24                       --                        --
# │    │    │    │    └─ReLU: 5-21                        [1, 128, 64, 64, 8]       --
# │    │    │    └─ModuleList: 4-22                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-22                 [1, 128, 64, 64, 8]       --
# │    │    │    │    │    └─Conv3d: 6-6                  [1, 128, 64, 64, 8]       442,368
# │    │    │    └─ModuleList: 4-23                       --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-23                 [1, 128, 64, 64, 8]       256
# │    │    │    └─ModuleList: 4-24                       --                        --
# │    │    │    │    └─ReLU: 5-24                        [1, 128, 64, 64, 8]       --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-6                 [1, 128, 32, 32, 4]       --
# │    │    └─MaxPool3d: 3-9                              [1, 128, 32, 32, 4]       --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-7                                  [1, 256, 32, 32, 4]       --
# │    │    └─Convolution: 3-10                           [1, 256, 32, 32, 4]       --
# │    │    │    └─Conv3d: 4-25                           [1, 256, 32, 32, 4]       884,736
# │    │    │    └─ADN: 4-26                              [1, 256, 32, 32, 4]       --
# │    │    │    │    └─BatchNorm3d: 5-25                 [1, 256, 32, 32, 4]       512
# │    │    │    │    └─ReLU: 5-26                        [1, 256, 32, 32, 4]       --
# │    │    └─RegistrationResidualConvBlock: 3-11         [1, 256, 32, 32, 4]       --
# │    │    │    └─ModuleList: 4-30                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-27                 [1, 256, 32, 32, 4]       --
# │    │    │    │    │    └─Conv3d: 6-7                  [1, 256, 32, 32, 4]       1,769,472
# │    │    │    └─ModuleList: 4-31                       --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-28                 [1, 256, 32, 32, 4]       512
# │    │    │    └─ModuleList: 4-32                       --                        --
# │    │    │    │    └─ReLU: 5-29                        [1, 256, 32, 32, 4]       --
# │    │    │    └─ModuleList: 4-30                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-30                 [1, 256, 32, 32, 4]       --
# │    │    │    │    │    └─Conv3d: 6-8                  [1, 256, 32, 32, 4]       1,769,472
# │    │    │    └─ModuleList: 4-31                       --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-31                 [1, 256, 32, 32, 4]       512
# │    │    │    └─ModuleList: 4-32                       --                        --
# │    │    │    │    └─ReLU: 5-32                        [1, 256, 32, 32, 4]       --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-8                 [1, 256, 16, 16, 2]       --
# │    │    └─MaxPool3d: 3-12                             [1, 256, 16, 16, 2]       --
# ├─ModuleList: 1-9                                       --                        (recursive)
# │    └─Sequential: 2-9                                  [1, 512, 16, 16, 2]       --
# │    │    └─Convolution: 3-13                           [1, 512, 16, 16, 2]       --
# │    │    │    └─Conv3d: 4-33                           [1, 512, 16, 16, 2]       3,538,944
# │    │    │    └─ADN: 4-34                              [1, 512, 16, 16, 2]       --
# │    │    │    │    └─BatchNorm3d: 5-33                 [1, 512, 16, 16, 2]       1,024
# │    │    │    │    └─ReLU: 5-34                        [1, 512, 16, 16, 2]       --
# │    │    └─RegistrationResidualConvBlock: 3-14         [1, 512, 16, 16, 2]       --
# │    │    │    └─ModuleList: 4-38                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-35                 [1, 512, 16, 16, 2]       --
# │    │    │    │    │    └─Conv3d: 6-9                  [1, 512, 16, 16, 2]       7,077,888
# │    │    │    └─ModuleList: 4-39                       --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-36                 [1, 512, 16, 16, 2]       1,024
# │    │    │    └─ModuleList: 4-40                       --                        --
# │    │    │    │    └─ReLU: 5-37                        [1, 512, 16, 16, 2]       --
# │    │    │    └─ModuleList: 4-38                       --                        (recursive)
# │    │    │    │    └─Convolution: 5-38                 [1, 512, 16, 16, 2]       --
# │    │    │    │    │    └─Conv3d: 6-10                 [1, 512, 16, 16, 2]       7,077,888
# │    │    │    └─ModuleList: 4-39                       --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-39                 [1, 512, 16, 16, 2]       1,024
# │    │    │    └─ModuleList: 4-40                       --                        --
# │    │    │    │    └─ReLU: 5-40                        [1, 512, 16, 16, 2]       --
# ├─ModuleList: 1-10                                      --                        --
# │    └─RegistrationDownSampleBlock: 2-10                [1, 512, 8, 8, 1]         --
# │    │    └─MaxPool3d: 3-15                             [1, 512, 8, 8, 1]         --
# ├─Sequential: 1-11                                      [1, 1024, 8, 8, 1]        --
# │    └─Convolution: 2-11                                [1, 1024, 8, 8, 1]        --
# │    │    └─Conv3d: 3-16                                [1, 1024, 8, 8, 1]        14,155,776
# │    │    └─ADN: 3-17                                   [1, 1024, 8, 8, 1]        --
# │    │    │    └─BatchNorm3d: 4-41                      [1, 1024, 8, 8, 1]        2,048
# │    │    │    └─ReLU: 4-42                             [1, 1024, 8, 8, 1]        --
# │    └─RegistrationResidualConvBlock: 2-12              [1, 1024, 8, 8, 1]        --
# │    │    └─ModuleList: 3-21                            --                        (recursive)
# │    │    │    └─Convolution: 4-43                      [1, 1024, 8, 8, 1]        --
# │    │    │    │    └─Conv3d: 5-41                      [1, 1024, 8, 8, 1]        28,311,552
# │    │    └─ModuleList: 3-22                            --                        (recursive)
# │    │    │    └─BatchNorm3d: 4-44                      [1, 1024, 8, 8, 1]        2,048
# │    │    └─ModuleList: 3-23                            --                        --
# │    │    │    └─ReLU: 4-45                             [1, 1024, 8, 8, 1]        --
# │    │    └─ModuleList: 3-21                            --                        (recursive)
# │    │    │    └─Convolution: 4-46                      [1, 1024, 8, 8, 1]        --
# │    │    │    │    └─Conv3d: 5-42                      [1, 1024, 8, 8, 1]        28,311,552
# │    │    └─ModuleList: 3-22                            --                        (recursive)
# │    │    │    └─BatchNorm3d: 4-47                      [1, 1024, 8, 8, 1]        2,048
# │    │    └─ModuleList: 3-23                            --                        --
# │    │    │    └─ReLU: 4-48                             [1, 1024, 8, 8, 1]        --
# ├─RegistrationExtractionBlock: 1-12                     [1, 3, 256, 256, 32]      --
# │    └─ModuleList: 2-13                                 --                        --
# │    │    └─Convolution: 3-24                           [1, 3, 8, 8, 1]           --
# │    │    │    └─Conv3d: 4-49                           [1, 3, 8, 8, 1]           82,944
# =========================================================================================================
# Total params: 94,431,744
# Trainable params: 94,431,744
# Non-trainable params: 0
# Total mult-adds (G): 260.02
# =========================================================================================================
# Input size (MB): 16.78
# Forward/backward pass size (MB): 4293.92
# Params size (MB): 377.73
# Estimated Total Size (MB): 4688.42
# =========================================================================================================

# %%
model = mod.to(device)

if preTrained:
    model.load_state_dict(torch.load(os.path.join(root_dir, ExpName + '_' + dataDir + '_' +str(previousWeight) + '_'+'.pth')))


warp_layer = Warp().to(device)

# image_loss = MSELoss()

image_loss = GlobalMutualInformationLoss()

class SSIMLoss(SSIM):
    def forward(self, x, y):
        return 1. - super().forward(x, y)
    

label_SSIM = SSIMLoss(n_channels=1).to(device) # .cuda() if you need GPU support

label_loss = DiceLoss()

# label_loss = MultiScaleLoss(label_loss, scales=[0, 1, 2, 4, 8, 16])

regularization = BendingEnergyLoss()

optimizer = torch.optim.Adam(model.parameters(), 1e-5)

# exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.5, verbose=True)

dice_metric = DiceMetric(include_background=True, reduction="mean", get_not_nans=False)

# dice_metric = compute_meandice(y_pred, y, include_background=True)
# Out:
# monai.networks.blocks.Warp: Using PyTorch native grid_sample.

# %%
def make_one_hot(labels, C=2):
    '''
    Converts an integer label torch.Tensor to a one-hot Tensor.
    
    Parameters
    ----------
    labels : torch.Tensor
        N x 1 x D x H x W, where N is batch size. 
        Each value is an integer representing correct classification.
    C : integer
        Number of classes in labels.
    
    Returns
    -------
    target : torch.Tensor
        N x C x D x H x W, where C is class number. One-hot encoded.
    '''
    labels = labels.long()
    one_hot = torch.zeros(labels.size(0), C, labels.size(2), labels.size(3), labels.size(4)).to(device)
    labels = labels.squeeze(1)
    target = one_hot.scatter_(1, labels.unsqueeze(1), 1)
        
    return target

# %%
class VariationalEncoder3D(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalEncoder3D, self).__init__()
        self.conv1 = nn.Conv3d(1, 8, 3, stride=2, padding=1)
        self.conv2 = nn.Conv3d(8, 16, 3, stride=2, padding=1)
        self.batch2 = nn.BatchNorm3d(16)
        self.conv3 = nn.Conv3d(16, 32, 3, stride=2, padding=1)
        self.linear1 = nn.Linear((img_size // 8) * (img_size // 8) * (slice_size // 8) * 32, 128)
        self.linear2 = nn.Linear(128, latent_dims)
        self.linear3 = nn.Linear(128, latent_dims)

        self.N = torch.distributions.Normal(0, 1)
        self.N.loc = self.N.loc.to(device)
        self.N.scale = self.N.scale.to(device)
        self.kl = 0

    def forward(self, x):
        x = x.to(device)
        x = F.relu(self.conv1(x))
        x = F.relu(self.batch2(self.conv2(x)))
        x = F.relu(self.conv3(x))
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.linear1(x))
        mu = self.linear2(x)
        sigma = torch.exp(self.linear3(x))
        z = mu + sigma * self.N.sample(mu.shape)
        self.kl = (sigma ** 2 + mu ** 2 - torch.log(sigma) - 1/2).sum()
        return z


class Decoder3D(nn.Module):
    def __init__(self, latent_dims):
        super(Decoder3D, self).__init__()
        self.decoder_lin = nn.Sequential(
            nn.Linear(latent_dims, 128),
            nn.ReLU(True),
            nn.Linear(128, (img_size // 8) * (img_size // 8) * (slice_size // 8) * 32),
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, img_size // 8, img_size // 8, slice_size // 8))

        # self.m = nn.Softmax(dim=1)

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose3d(32, 16, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm3d(16),
            nn.ReLU(True),
            nn.ConvTranspose3d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm3d(8),
            nn.ReLU(True),
            nn.ConvTranspose3d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )

    def forward(self, x):
        x = self.decoder_lin(x)
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        x = torch.sigmoid(x)
        # x = self.m(x)
        return x

class VariationalAutoencoder3D(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalAutoencoder3D, self).__init__()
        self.encoder = VariationalEncoder3D(latent_dims)
        self.decoder = Decoder3D(latent_dims)

    def forward(self, x):
        x = x.to(device)
        z = self.encoder(x)
        return self.decoder(z)

torch.manual_seed(0)

d = 8

Myo_VAE_3D = VariationalAutoencoder3D(latent_dims=d)
Myo_VAE_3D.to(device)
Myo_VAE_3D.load_state_dict(torch.load('/home/mkh/MKH/KSA/Dataset/Myo_VAE_3D_256_32_.pth', map_location=device))
Myo_VAE_3D.eval()

LV_VAE_3D = VariationalAutoencoder3D(latent_dims=d)
LV_VAE_3D.to(device)
LV_VAE_3D.load_state_dict(torch.load('/home/mkh/MKH/KSA/Dataset/LV_VAE_3D_256_32_.pth', map_location=device))
LV_VAE_3D.eval()
# Out:
# VariationalAutoencoder3D(
#   (encoder): VariationalEncoder3D(
#     (conv1): Conv3d(1, 8, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     (conv2): Conv3d(8, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     (batch2): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#     (linear1): Linear(in_features=131072, out_features=128, bias=True)
#     (linear2): Linear(in_features=128, out_features=8, bias=True)
#     (linear3): Linear(in_features=128, out_features=8, bias=True)
#   )
#   (decoder): Decoder3D(
#     (decoder_lin): Sequential(
#       (0): Linear(in_features=8, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=128, out_features=131072, bias=True)
#       (3): ReLU(inplace=True)
#     )
#     (unflatten): Unflatten(dim=1, unflattened_size=(32, 32, 32, 4))
#     (decoder_conv): Sequential(
#       (0): ConvTranspose3d(32, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#       (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): ConvTranspose3d(16, 8, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#       (4): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): ConvTranspose3d(8, 1, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     )
#   )
# )

# %%
L2_loss = nn.MSELoss(reduction='mean')

def globalLoss(trueMask, predMask):
    myo_trueMask = trueMask.clone()
    LV_trueMask = trueMask.clone()

    #Thresholding the prediction
    thresholded_predMask = predMask.clone()

    background_class = torch.zeros_like(predMask)
    lv_class = torch.ones_like(predMask)
    myo_class = 2*torch.ones_like(predMask)

    thresholded_predMask_ = torch.where(thresholded_predMask<0.98, background_class, thresholded_predMask)
    thresholded_predMask_ = torch.where(thresholded_predMask_>1.0, myo_class, thresholded_predMask_)
    thresholded_predMask_ = torch.where((thresholded_predMask_<=1.0) & (thresholded_predMask_>=0.98), lv_class, thresholded_predMask_)

    myo_predMask = thresholded_predMask_.clone()
    LV_predMask = thresholded_predMask_.clone()

    LV_predMask[LV_predMask==2] =0 
    LV_trueMask[LV_trueMask==2] =0 

    myo_predMask[myo_predMask==1] =0 
    myo_predMask = myo_predMask/2

    myo_trueMask[myo_trueMask==1] =0 
    myo_trueMask = myo_trueMask/2

    # plt.subplot(241), plt.imshow(myo_predMask[0,:,:,:].reshape(512,512).detach().cpu().squeeze().numpy(), cmap='gist_gray')
    # plt.subplot(242), plt.imshow(myo_trueMask[0,:,:,:].reshape(512,512).detach().cpu().squeeze().numpy(), cmap='gist_gray')
    # plt.subplot(243), plt.imshow(LV_predMask[0,:,:,:].reshape(512,512).detach().cpu().squeeze().numpy(), cmap='gist_gray')
    # plt.subplot(244), plt.imshow(LV_trueMask[0,:,:,:].reshape(512,512).detach().cpu().squeeze().numpy(), cmap='gist_gray')

    attribute_myo_true = Myo_VAE_3D(myo_trueMask)
    attribute_myo_pred = Myo_VAE_3D(myo_predMask)

    myo_L2 = L2_loss(attribute_myo_true, attribute_myo_pred)

    attribute_lv_true = LV_VAE_3D(LV_trueMask)
    attribute_lv_pred = LV_VAE_3D(LV_predMask)

    # print(LV_trueMask.shape)
    # print(attribute_lv_true.shape)

    lv_L2 = L2_loss(attribute_lv_true, attribute_lv_pred)

    # print(myo_L2)
    # print(lv_L2)

    loss_ = myo_L2 + lv_L2

    return loss_

# globalLoss (TTg, TTp)
# globalLoss (TTg, TTm)

# %%
max_epochs = EP
epoch_loss_values = []
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
epoch_val_loss_values = []
epoch_loss_d_values = []
epoch_loss_g_values = []
metric_values = []
best_loss = 1e10
best_dsc = 0
k=1


for epoch in range(max_epochs):
    print("-" * 100)
    print(f"Epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss, step = 0, 0

    epoch_DSC, epoch_L2, epoch_MI, epoch_ddf = 0, 0, 0, 0

    epoch_loss_d, epoch_loss_g=0,0
    
    for fixed_train_img_, fixed_train_msk_, moving_train_img_, moving_train_msk_ in zip(fixed_train_img,
                                                                                    fixed_train_msk, moving_train_img,
                                                                                    moving_train_msk):    
        step += 1
        
        optimizer.zero_grad()
        # optim_d.zero_grad()

        fixed_train_img_ = fixed_train_img_.to(device)
        fixed_train_msk_ = fixed_train_msk_.to(device)
        moving_train_img_ = moving_train_img_.to(device)
        moving_train_msk_ = moving_train_msk_.to(device)
        
        ddf_train = model(torch.cat((moving_train_img_, fixed_train_img_), dim=1))
        
        pred_image_train = warp_layer(moving_train_img_, ddf_train)
        pred_mask_train = warp_layer(moving_train_msk_, ddf_train)

        # real_label = label_real(fixed_train_img_.size(0))
        # fake_label = label_fake(fixed_train_img_.size(0))


        # output_real = discriminator(fixed_train_img_)
        # loss_real = criterion(output_real, real_label)
        # loss_real.backward()

        # output_fake = discriminator(pred_image_train.detach())
        # loss_fake = criterion(output_fake, fake_label)
        # loss_fake.backward()

        # optim_d.step()

        # loss_d = (loss_real + loss_fake)/2

        # epoch_loss_d += loss_d.item()

        # output = discriminator(pred_image_train)
        
        # loss_g = criterion(output, real_label)

        imageLOSS = image_loss(pred_image_train, fixed_train_img_)
        
        labelDSC = label_loss(fixed_train_msk_, pred_mask_train)

        # labelDSC = label_loss(make_one_hot(pred_mask_train, C=3), make_one_hot(fixed_train_msk_, C=3))

        labelGlobal =  globalLoss(fixed_train_msk_, pred_mask_train)-1
        
        regLOSS  = regularization(ddf_train)

        loss = imageLOSS + regLOSS + 2*labelGlobal + 2*labelDSC
    
        # loss_g.backward(retain_graph=True)
        
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()

        # epoch_loss_g += loss_g.item()
        epoch_DSC += labelDSC.item()
        epoch_L2 += labelGlobal.item()
        epoch_MI += imageLOSS.item()
        epoch_ddf += regLOSS.item()


        
        dice_metric(y_pred = make_one_hot(pred_mask_train, C=3), y=make_one_hot(fixed_train_msk_, C=3))

    # exp_lr_scheduler.step()
    for param_group in optimizer.param_groups:
        print("LR is == ", param_group['lr'])


    metric = dice_metric.aggregate().item()
    dice_metric.reset()
    epoch_loss /= step

    # epoch_loss_g /=step
    # epoch_loss_d /= step

    epoch_DSC /= step
    epoch_L2 /= step
    epoch_MI /= step
    epoch_ddf /= step

    epoch_loss_values.append(epoch_loss)
    # epoch_loss_d_values.append(epoch_loss_d)
    # epoch_loss_g_values.append(epoch_loss_g)

    print(f"For epoch: {epoch + 1}, Average train loss: {epoch_loss:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train DSC: {metric:.5f} !\n")

    print(f"For epoch: {epoch + 1}, Average train DSC: {epoch_DSC:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train L2: {epoch_L2:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train MI: {epoch_MI:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train DDF: {epoch_ddf:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train D Loss: {epoch_loss_d:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train G Loss: {epoch_loss_g:.5f} !")
    
    print("-" * 60)
    if (epoch + 1) % val_interval == 0 or epoch == 0:
        model.eval()
        val_loss = 0
        val_met = 0
        step = 0
        with torch.no_grad():
            for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk):  

                fixed_val_img_ = fixed_val_img_.to(device)
                fixed_val_msk_ = fixed_val_msk_.to(device)
                
                moving_val_img_ = moving_val_img_.to(device)
                moving_val_msk_ = moving_val_msk_.to(device)
                
                
                ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))
                
                pred_image_val = warp_layer(moving_val_img_, ddf_val)
                pred_mask_val = warp_layer(moving_val_msk_, ddf_val)

                # real_label = label_real(pred_image_val.size(0))
        
                # output = discriminator(pred_image_val)
        
                # loss_g = criterion(output, real_label)

                imageLOSS = image_loss(pred_image_val, fixed_val_img_)

                labelDSC = label_loss(fixed_val_msk_, pred_mask_val)

                # labelDSC = label_loss(make_one_hot(pred_mask_val, C=3), make_one_hot(fixed_val_msk_, C=3))

                labelGlobal =  globalLoss(fixed_val_msk_, pred_mask_val)-1

                regLOSS  = regularization(ddf_val)


                loss = imageLOSS + regLOSS + 2*labelGlobal + 2*labelDSC
                
                
    
                val_loss += loss.item()
                step += 1

                
                dice_metric(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))
                

            val_loss /= step
            epoch_val_loss_values.append(val_loss)
            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            dice_metric.reset()
            
            if metric > best_dsc:
                best_loss_epoch = epoch + 1
                torch.save(model.state_dict(),
                           os.path.join(root_dir, fileNames+'.pth'))
                print(f"Valid DSC improved from {best_dsc:2.4f} to {metric:2.4f}! Best model is saving as---> {fileNames+'.pth'}")
                best_dsc = metric
                
            print(
                f"\nCurrent mean dice: {metric:.4f} "
                f"\t and \t Current val loss: {val_loss:.4f}\n\n"
                f"Best val DSC: {best_dsc:.4f} "
                f"at epoch number of {best_loss_epoch}")
# Out:
# ----------------------------------------------------------------------------------------------------
# Epoch 1/100
# LR is ==  1e-05
# For epoch: 1, Average train loss: -3.55509 !
# For epoch: 1, Average train DSC: 0.77024 !
#
# For epoch: 1, Average train DSC: -0.46804 !
# For epoch: 1, Average train L2: -0.96118 !
# For epoch: 1, Average train MI: -0.69684 !
# For epoch: 1, Average train DDF: 0.00020 !
# ------------------------------------------------------------
# Valid DSC improved from 0.0000 to 0.7317! Best model is saving as---> AC_DLIR_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7317 	 and 	 Current val loss: -3.6124
#
# Best val DSC: 0.7317 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 2/100
# LR is ==  1e-05
# For epoch: 2, Average train loss: -3.59194 !
# For epoch: 2, Average train DSC: 0.78326 !
#
# For epoch: 2, Average train DSC: -0.48739 !
# For epoch: 2, Average train L2: -0.96066 !
# For epoch: 2, Average train MI: -0.69833 !
# For epoch: 2, Average train DDF: 0.00248 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7317 to 0.7403! Best model is saving as---> AC_DLIR_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7403 	 and 	 Current val loss: -3.6060
#
# Best val DSC: 0.7403 at epoch number of 2
# ----------------------------------------------------------------------------------------------------
# Epoch 3/100
# LR is ==  1e-05
# For epoch: 3, Average train loss: -3.64145 !
# For epoch: 3, Average train DSC: 0.78662 !
#
# For epoch: 3, Average train DSC: -0.50908 !
# For epoch: 3, Average train L2: -0.96408 !
# For epoch: 3, Average train MI: -0.70135 !
# For epoch: 3, Average train DDF: 0.00623 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7403 to 0.7530! Best model is saving as---> AC_DLIR_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7530 	 and 	 Current val loss: -3.5963
#
# Best val DSC: 0.7530 at epoch number of 3
# ----------------------------------------------------------------------------------------------------
# Epoch 4/100
# LR is ==  1e-05
# For epoch: 4, Average train loss: -3.66957 !
# For epoch: 4, Average train DSC: 0.79308 !
#
# For epoch: 4, Average train DSC: -0.52214 !
# For epoch: 4, Average train L2: -0.96508 !
# For epoch: 4, Average train MI: -0.70419 !
# For epoch: 4, Average train DDF: 0.00905 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7413 	 and 	 Current val loss: -3.5577
#
# Best val DSC: 0.7530 at epoch number of 3
# ----------------------------------------------------------------------------------------------------
# Epoch 5/100
# LR is ==  1e-05
# For epoch: 5, Average train loss: -3.68204 !
# For epoch: 5, Average train DSC: 0.79614 !
#
# For epoch: 5, Average train DSC: -0.52788 !
# For epoch: 5, Average train L2: -0.96603 !
# For epoch: 5, Average train MI: -0.70425 !
# For epoch: 5, Average train DDF: 0.01004 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7396 	 and 	 Current val loss: -3.5889
#
# Best val DSC: 0.7530 at epoch number of 3
# ----------------------------------------------------------------------------------------------------
# Epoch 6/100
# LR is ==  1e-05
# For epoch: 6, Average train loss: -3.68557 !
# For epoch: 6, Average train DSC: 0.79485 !
#
# For epoch: 6, Average train DSC: -0.52874 !
# For epoch: 6, Average train L2: -0.96723 !
# For epoch: 6, Average train MI: -0.70572 !
# For epoch: 6, Average train DDF: 0.01209 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7524 	 and 	 Current val loss: -3.5574
#
# Best val DSC: 0.7530 at epoch number of 3
# ----------------------------------------------------------------------------------------------------
# Epoch 7/100
# LR is ==  1e-05
# For epoch: 7, Average train loss: -3.69896 !
# For epoch: 7, Average train DSC: 0.80075 !
#
# For epoch: 7, Average train DSC: -0.53084 !
# For epoch: 7, Average train L2: -0.97101 !
# For epoch: 7, Average train MI: -0.70731 !
# For epoch: 7, Average train DDF: 0.01204 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7513 	 and 	 Current val loss: -3.5736
#
# Best val DSC: 0.7530 at epoch number of 3
# ----------------------------------------------------------------------------------------------------
# Epoch 8/100
# LR is ==  1e-05
# For epoch: 8, Average train loss: -3.70483 !
# For epoch: 8, Average train DSC: 0.79785 !
#
# For epoch: 8, Average train DSC: -0.53598 !
# For epoch: 8, Average train L2: -0.96987 !
# For epoch: 8, Average train MI: -0.70640 !
# For epoch: 8, Average train DDF: 0.01326 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7520 	 and 	 Current val loss: -3.5858
#
# Best val DSC: 0.7530 at epoch number of 3
# ----------------------------------------------------------------------------------------------------
# Epoch 9/100
# LR is ==  1e-05
# For epoch: 9, Average train loss: -3.71265 !
# For epoch: 9, Average train DSC: 0.79975 !
#
# For epoch: 9, Average train DSC: -0.54186 !
# For epoch: 9, Average train L2: -0.96733 !
# For epoch: 9, Average train MI: -0.70871 !
# For epoch: 9, Average train DDF: 0.01444 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7530 to 0.7567! Best model is saving as---> AC_DLIR_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7567 	 and 	 Current val loss: -3.5846
#
# Best val DSC: 0.7567 at epoch number of 9
# ----------------------------------------------------------------------------------------------------
# Epoch 10/100
# LR is ==  1e-05
# For epoch: 10, Average train loss: -3.72598 !
# For epoch: 10, Average train DSC: 0.79903 !
#
# For epoch: 10, Average train DSC: -0.54607 !
# For epoch: 10, Average train L2: -0.96976 !
# For epoch: 10, Average train MI: -0.71000 !
# For epoch: 10, Average train DDF: 0.01567 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7567 to 0.7623! Best model is saving as---> AC_DLIR_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7623 	 and 	 Current val loss: -3.5813
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 11/100
# LR is ==  1e-05
# For epoch: 11, Average train loss: -3.73086 !
# For epoch: 11, Average train DSC: 0.80229 !
#
# For epoch: 11, Average train DSC: -0.54693 !
# For epoch: 11, Average train L2: -0.96992 !
# For epoch: 11, Average train MI: -0.71321 !
# For epoch: 11, Average train DDF: 0.01603 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7387 	 and 	 Current val loss: -3.5967
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 12/100
# LR is ==  1e-05
# For epoch: 12, Average train loss: -3.72821 !
# For epoch: 12, Average train DSC: 0.80332 !
#
# For epoch: 12, Average train DSC: -0.54873 !
# For epoch: 12, Average train L2: -0.96804 !
# For epoch: 12, Average train MI: -0.71162 !
# For epoch: 12, Average train DDF: 0.01695 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7485 	 and 	 Current val loss: -3.5754
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 13/100
# LR is ==  1e-05
# For epoch: 13, Average train loss: -3.73905 !
# For epoch: 13, Average train DSC: 0.80289 !
#
# For epoch: 13, Average train DSC: -0.54976 !
# For epoch: 13, Average train L2: -0.97226 !
# For epoch: 13, Average train MI: -0.71281 !
# For epoch: 13, Average train DDF: 0.01780 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7478 	 and 	 Current val loss: -3.5774
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 14/100
# LR is ==  1e-05
# For epoch: 14, Average train loss: -3.74611 !
# For epoch: 14, Average train DSC: 0.79661 !
#
# For epoch: 14, Average train DSC: -0.55097 !
# For epoch: 14, Average train L2: -0.97363 !
# For epoch: 14, Average train MI: -0.71502 !
# For epoch: 14, Average train DDF: 0.01811 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7435 	 and 	 Current val loss: -3.6000
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 15/100
# LR is ==  1e-05
# For epoch: 15, Average train loss: -3.74515 !
# For epoch: 15, Average train DSC: 0.80275 !
#
# For epoch: 15, Average train DSC: -0.55377 !
# For epoch: 15, Average train L2: -0.97162 !
# For epoch: 15, Average train MI: -0.71337 !
# For epoch: 15, Average train DDF: 0.01900 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7360 	 and 	 Current val loss: -3.5933
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 16/100
# LR is ==  1e-05
# For epoch: 16, Average train loss: -3.75474 !
# For epoch: 16, Average train DSC: 0.80953 !
#
# For epoch: 16, Average train DSC: -0.55688 !
# For epoch: 16, Average train L2: -0.97254 !
# For epoch: 16, Average train MI: -0.71588 !
# For epoch: 16, Average train DDF: 0.01997 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7320 	 and 	 Current val loss: -3.5923
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 17/100
# LR is ==  1e-05
# For epoch: 17, Average train loss: -3.76502 !
# For epoch: 17, Average train DSC: 0.80865 !
#
# For epoch: 17, Average train DSC: -0.55802 !
# For epoch: 17, Average train L2: -0.97589 !
# For epoch: 17, Average train MI: -0.71753 !
# For epoch: 17, Average train DDF: 0.02033 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7354 	 and 	 Current val loss: -3.5990
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 18/100
# LR is ==  1e-05
# For epoch: 18, Average train loss: -3.76095 !
# For epoch: 18, Average train DSC: 0.80798 !
#
# For epoch: 18, Average train DSC: -0.55942 !
# For epoch: 18, Average train L2: -0.97311 !
# For epoch: 18, Average train MI: -0.71709 !
# For epoch: 18, Average train DDF: 0.02119 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7287 	 and 	 Current val loss: -3.5930
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 19/100
# LR is ==  1e-05
# For epoch: 19, Average train loss: -3.76532 !
# For epoch: 19, Average train DSC: 0.80501 !
#
# For epoch: 19, Average train DSC: -0.55907 !
# For epoch: 19, Average train L2: -0.97538 !
# For epoch: 19, Average train MI: -0.71739 !
# For epoch: 19, Average train DDF: 0.02098 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7464 	 and 	 Current val loss: -3.5802
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 20/100
# LR is ==  1e-05
# For epoch: 20, Average train loss: -3.77101 !
# For epoch: 20, Average train DSC: 0.80470 !
#
# For epoch: 20, Average train DSC: -0.56252 !
# For epoch: 20, Average train L2: -0.97590 !
# For epoch: 20, Average train MI: -0.71601 !
# For epoch: 20, Average train DDF: 0.02182 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7346 	 and 	 Current val loss: -3.5752
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 21/100
# LR is ==  1e-05
# For epoch: 21, Average train loss: -3.76935 !
# For epoch: 21, Average train DSC: 0.80497 !
#
# For epoch: 21, Average train DSC: -0.56060 !
# For epoch: 21, Average train L2: -0.97550 !
# For epoch: 21, Average train MI: -0.71906 !
# For epoch: 21, Average train DDF: 0.02190 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7331 	 and 	 Current val loss: -3.6000
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 22/100
# LR is ==  1e-05
# For epoch: 22, Average train loss: -3.76501 !
# For epoch: 22, Average train DSC: 0.80596 !
#
# For epoch: 22, Average train DSC: -0.55987 !
# For epoch: 22, Average train L2: -0.97457 !
# For epoch: 22, Average train MI: -0.71756 !
# For epoch: 22, Average train DDF: 0.02143 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7529 	 and 	 Current val loss: -3.5604
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 23/100
# LR is ==  1e-05
# For epoch: 23, Average train loss: -3.76976 !
# For epoch: 23, Average train DSC: 0.81358 !
#
# For epoch: 23, Average train DSC: -0.56026 !
# For epoch: 23, Average train L2: -0.97683 !
# For epoch: 23, Average train MI: -0.71780 !
# For epoch: 23, Average train DDF: 0.02221 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7384 	 and 	 Current val loss: -3.5919
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 24/100
# LR is ==  1e-05
# For epoch: 24, Average train loss: -3.77123 !
# For epoch: 24, Average train DSC: 0.80286 !
#
# For epoch: 24, Average train DSC: -0.56394 !
# For epoch: 24, Average train L2: -0.97382 !
# For epoch: 24, Average train MI: -0.71825 !
# For epoch: 24, Average train DDF: 0.02255 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7384 	 and 	 Current val loss: -3.6026
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 25/100
# LR is ==  1e-05
# For epoch: 25, Average train loss: -3.76046 !
# For epoch: 25, Average train DSC: 0.80174 !
#
# For epoch: 25, Average train DSC: -0.56114 !
# For epoch: 25, Average train L2: -0.97161 !
# For epoch: 25, Average train MI: -0.71764 !
# For epoch: 25, Average train DDF: 0.02269 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7563 	 and 	 Current val loss: -3.5865
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 26/100
# LR is ==  1e-05
# For epoch: 26, Average train loss: -3.77290 !
# For epoch: 26, Average train DSC: 0.81114 !
#
# For epoch: 26, Average train DSC: -0.56193 !
# For epoch: 26, Average train L2: -0.97581 !
# For epoch: 26, Average train MI: -0.71951 !
# For epoch: 26, Average train DDF: 0.02209 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7353 	 and 	 Current val loss: -3.5815
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 27/100
# LR is ==  1e-05
# For epoch: 27, Average train loss: -3.78024 !
# For epoch: 27, Average train DSC: 0.81761 !
#
# For epoch: 27, Average train DSC: -0.56458 !
# For epoch: 27, Average train L2: -0.97682 !
# For epoch: 27, Average train MI: -0.72138 !
# For epoch: 27, Average train DDF: 0.02394 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7391 	 and 	 Current val loss: -3.5982
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 28/100
# LR is ==  1e-05
# For epoch: 28, Average train loss: -3.78047 !
# For epoch: 28, Average train DSC: 0.80794 !
#
# For epoch: 28, Average train DSC: -0.56708 !
# For epoch: 28, Average train L2: -0.97479 !
# For epoch: 28, Average train MI: -0.72072 !
# For epoch: 28, Average train DDF: 0.02398 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7509 	 and 	 Current val loss: -3.5707
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 29/100
# LR is ==  1e-05
# For epoch: 29, Average train loss: -3.77720 !
# For epoch: 29, Average train DSC: 0.80323 !
#
# For epoch: 29, Average train DSC: -0.56688 !
# For epoch: 29, Average train L2: -0.97340 !
# For epoch: 29, Average train MI: -0.72165 !
# For epoch: 29, Average train DDF: 0.02501 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7481 	 and 	 Current val loss: -3.6038
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 30/100
# LR is ==  1e-05
# For epoch: 30, Average train loss: -3.77451 !
# For epoch: 30, Average train DSC: 0.80510 !
#
# For epoch: 30, Average train DSC: -0.56548 !
# For epoch: 30, Average train L2: -0.97304 !
# For epoch: 30, Average train MI: -0.72139 !
# For epoch: 30, Average train DDF: 0.02392 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7466 	 and 	 Current val loss: -3.6022
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 31/100
# LR is ==  1e-05
# For epoch: 31, Average train loss: -3.77550 !
# For epoch: 31, Average train DSC: 0.80413 !
#
# For epoch: 31, Average train DSC: -0.56608 !
# For epoch: 31, Average train L2: -0.97294 !
# For epoch: 31, Average train MI: -0.72222 !
# For epoch: 31, Average train DDF: 0.02476 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7411 	 and 	 Current val loss: -3.5759
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 32/100
# LR is ==  1e-05
# For epoch: 32, Average train loss: -3.78446 !
# For epoch: 32, Average train DSC: 0.80535 !
#
# For epoch: 32, Average train DSC: -0.56702 !
# For epoch: 32, Average train L2: -0.97733 !
# For epoch: 32, Average train MI: -0.72056 !
# For epoch: 32, Average train DDF: 0.02480 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7408 	 and 	 Current val loss: -3.5773
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 33/100
# LR is ==  1e-05
# For epoch: 33, Average train loss: -3.77781 !
# For epoch: 33, Average train DSC: 0.80673 !
#
# For epoch: 33, Average train DSC: -0.56761 !
# For epoch: 33, Average train L2: -0.97193 !
# For epoch: 33, Average train MI: -0.72402 !
# For epoch: 33, Average train DDF: 0.02531 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7512 	 and 	 Current val loss: -3.5918
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 34/100
# LR is ==  1e-05
# For epoch: 34, Average train loss: -3.77880 !
# For epoch: 34, Average train DSC: 0.81174 !
#
# For epoch: 34, Average train DSC: -0.56842 !
# For epoch: 34, Average train L2: -0.97267 !
# For epoch: 34, Average train MI: -0.72064 !
# For epoch: 34, Average train DDF: 0.02402 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7414 	 and 	 Current val loss: -3.5930
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 35/100
# LR is ==  1e-05
# For epoch: 35, Average train loss: -3.79165 !
# For epoch: 35, Average train DSC: 0.80943 !
#
# For epoch: 35, Average train DSC: -0.56854 !
# For epoch: 35, Average train L2: -0.97761 !
# For epoch: 35, Average train MI: -0.72527 !
# For epoch: 35, Average train DDF: 0.02592 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7394 	 and 	 Current val loss: -3.5993
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 36/100
# LR is ==  1e-05
# For epoch: 36, Average train loss: -3.78977 !
# For epoch: 36, Average train DSC: 0.80186 !
#
# For epoch: 36, Average train DSC: -0.56901 !
# For epoch: 36, Average train L2: -0.97774 !
# For epoch: 36, Average train MI: -0.72159 !
# For epoch: 36, Average train DDF: 0.02532 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7365 	 and 	 Current val loss: -3.5936
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 37/100
# LR is ==  1e-05
# For epoch: 37, Average train loss: -3.78651 !
# For epoch: 37, Average train DSC: 0.80905 !
#
# For epoch: 37, Average train DSC: -0.56732 !
# For epoch: 37, Average train L2: -0.97682 !
# For epoch: 37, Average train MI: -0.72329 !
# For epoch: 37, Average train DDF: 0.02506 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7337 	 and 	 Current val loss: -3.5763
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 38/100
# LR is ==  1e-05
# For epoch: 38, Average train loss: -3.76831 !
# For epoch: 38, Average train DSC: 0.81278 !
#
# For epoch: 38, Average train DSC: -0.56443 !
# For epoch: 38, Average train L2: -0.97093 !
# For epoch: 38, Average train MI: -0.72278 !
# For epoch: 38, Average train DDF: 0.02518 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7405 	 and 	 Current val loss: -3.6030
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 39/100
# LR is ==  1e-05
# For epoch: 39, Average train loss: -3.78070 !
# For epoch: 39, Average train DSC: 0.80853 !
#
# For epoch: 39, Average train DSC: -0.56501 !
# For epoch: 39, Average train L2: -0.97649 !
# For epoch: 39, Average train MI: -0.72174 !
# For epoch: 39, Average train DDF: 0.02403 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7404 	 and 	 Current val loss: -3.6096
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 40/100
# LR is ==  1e-05
# For epoch: 40, Average train loss: -3.79013 !
# For epoch: 40, Average train DSC: 0.81112 !
#
# For epoch: 40, Average train DSC: -0.56869 !
# For epoch: 40, Average train L2: -0.97757 !
# For epoch: 40, Average train MI: -0.72441 !
# For epoch: 40, Average train DDF: 0.02680 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7469 	 and 	 Current val loss: -3.5859
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 41/100
# LR is ==  1e-05
# For epoch: 41, Average train loss: -3.78337 !
# For epoch: 41, Average train DSC: 0.81359 !
#
# For epoch: 41, Average train DSC: -0.56810 !
# For epoch: 41, Average train L2: -0.97438 !
# For epoch: 41, Average train MI: -0.72323 !
# For epoch: 41, Average train DDF: 0.02482 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7477 	 and 	 Current val loss: -3.6106
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 42/100
# LR is ==  1e-05
# For epoch: 42, Average train loss: -3.77895 !
# For epoch: 42, Average train DSC: 0.80792 !
#
# For epoch: 42, Average train DSC: -0.56840 !
# For epoch: 42, Average train L2: -0.97185 !
# For epoch: 42, Average train MI: -0.72492 !
# For epoch: 42, Average train DDF: 0.02648 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7436 	 and 	 Current val loss: -3.6119
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 43/100
# LR is ==  1e-05
# For epoch: 43, Average train loss: -3.79071 !
# For epoch: 43, Average train DSC: 0.80733 !
#
# For epoch: 43, Average train DSC: -0.56871 !
# For epoch: 43, Average train L2: -0.97753 !
# For epoch: 43, Average train MI: -0.72440 !
# For epoch: 43, Average train DDF: 0.02619 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7417 	 and 	 Current val loss: -3.5756
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 44/100
# LR is ==  1e-05
# For epoch: 44, Average train loss: -3.79319 !
# For epoch: 44, Average train DSC: 0.80969 !
#
# For epoch: 44, Average train DSC: -0.57064 !
# For epoch: 44, Average train L2: -0.97691 !
# For epoch: 44, Average train MI: -0.72393 !
# For epoch: 44, Average train DDF: 0.02583 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7413 	 and 	 Current val loss: -3.6045
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 45/100
# LR is ==  1e-05
# For epoch: 45, Average train loss: -3.79458 !
# For epoch: 45, Average train DSC: 0.81666 !
#
# For epoch: 45, Average train DSC: -0.57048 !
# For epoch: 45, Average train L2: -0.97629 !
# For epoch: 45, Average train MI: -0.72780 !
# For epoch: 45, Average train DDF: 0.02675 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7326 	 and 	 Current val loss: -3.5950
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 46/100
# LR is ==  1e-05
# For epoch: 46, Average train loss: -3.78484 !
# For epoch: 46, Average train DSC: 0.80516 !
#
# For epoch: 46, Average train DSC: -0.56998 !
# For epoch: 46, Average train L2: -0.97309 !
# For epoch: 46, Average train MI: -0.72589 !
# For epoch: 46, Average train DDF: 0.02719 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7453 	 and 	 Current val loss: -3.5930
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 47/100
# LR is ==  1e-05
# For epoch: 47, Average train loss: -3.79035 !
# For epoch: 47, Average train DSC: 0.80952 !
#
# For epoch: 47, Average train DSC: -0.57127 !
# For epoch: 47, Average train L2: -0.97420 !
# For epoch: 47, Average train MI: -0.72524 !
# For epoch: 47, Average train DDF: 0.02583 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7359 	 and 	 Current val loss: -3.6095
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 48/100
# LR is ==  1e-05
# For epoch: 48, Average train loss: -3.80061 !
# For epoch: 48, Average train DSC: 0.80512 !
#
# For epoch: 48, Average train DSC: -0.57110 !
# For epoch: 48, Average train L2: -0.97835 !
# For epoch: 48, Average train MI: -0.72856 !
# For epoch: 48, Average train DDF: 0.02685 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7448 	 and 	 Current val loss: -3.6030
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 49/100
# LR is ==  1e-05
# For epoch: 49, Average train loss: -3.78951 !
# For epoch: 49, Average train DSC: 0.80937 !
#
# For epoch: 49, Average train DSC: -0.57266 !
# For epoch: 49, Average train L2: -0.97262 !
# For epoch: 49, Average train MI: -0.72566 !
# For epoch: 49, Average train DDF: 0.02672 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7341 	 and 	 Current val loss: -3.6122
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 50/100
# LR is ==  1e-05
# For epoch: 50, Average train loss: -3.78971 !
# For epoch: 50, Average train DSC: 0.81493 !
#
# For epoch: 50, Average train DSC: -0.57067 !
# For epoch: 50, Average train L2: -0.97386 !
# For epoch: 50, Average train MI: -0.72830 !
# For epoch: 50, Average train DDF: 0.02765 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7302 	 and 	 Current val loss: -3.6124
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 51/100
# LR is ==  1e-05
# For epoch: 51, Average train loss: -3.79394 !
# For epoch: 51, Average train DSC: 0.80945 !
#
# For epoch: 51, Average train DSC: -0.57063 !
# For epoch: 51, Average train L2: -0.97655 !
# For epoch: 51, Average train MI: -0.72588 !
# For epoch: 51, Average train DDF: 0.02629 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7340 	 and 	 Current val loss: -3.6103
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 52/100
# LR is ==  1e-05
# For epoch: 52, Average train loss: -3.79851 !
# For epoch: 52, Average train DSC: 0.80940 !
#
# For epoch: 52, Average train DSC: -0.57205 !
# For epoch: 52, Average train L2: -0.97687 !
# For epoch: 52, Average train MI: -0.72785 !
# For epoch: 52, Average train DDF: 0.02718 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7408 	 and 	 Current val loss: -3.6042
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 53/100
# LR is ==  1e-05
# For epoch: 53, Average train loss: -3.79584 !
# For epoch: 53, Average train DSC: 0.82281 !
#
# For epoch: 53, Average train DSC: -0.57167 !
# For epoch: 53, Average train L2: -0.97608 !
# For epoch: 53, Average train MI: -0.72785 !
# For epoch: 53, Average train DDF: 0.02751 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7418 	 and 	 Current val loss: -3.6086
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 54/100
# LR is ==  1e-05
# For epoch: 54, Average train loss: -3.79658 !
# For epoch: 54, Average train DSC: 0.80739 !
#
# For epoch: 54, Average train DSC: -0.57089 !
# For epoch: 54, Average train L2: -0.97685 !
# For epoch: 54, Average train MI: -0.72760 !
# For epoch: 54, Average train DDF: 0.02650 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7471 	 and 	 Current val loss: -3.5998
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 55/100
# LR is ==  1e-05
# For epoch: 55, Average train loss: -3.77164 !
# For epoch: 55, Average train DSC: 0.80668 !
#
# For epoch: 55, Average train DSC: -0.56536 !
# For epoch: 55, Average train L2: -0.97116 !
# For epoch: 55, Average train MI: -0.72548 !
# For epoch: 55, Average train DDF: 0.02687 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7300 	 and 	 Current val loss: -3.6113
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 56/100
# LR is ==  1e-05
# For epoch: 56, Average train loss: -3.78595 !
# For epoch: 56, Average train DSC: 0.80965 !
#
# For epoch: 56, Average train DSC: -0.56658 !
# For epoch: 56, Average train L2: -0.97592 !
# For epoch: 56, Average train MI: -0.72675 !
# For epoch: 56, Average train DDF: 0.02579 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7458 	 and 	 Current val loss: -3.6074
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 57/100
# LR is ==  1e-05
# For epoch: 57, Average train loss: -3.80115 !
# For epoch: 57, Average train DSC: 0.81540 !
#
# For epoch: 57, Average train DSC: -0.57219 !
# For epoch: 57, Average train L2: -0.97837 !
# For epoch: 57, Average train MI: -0.72786 !
# For epoch: 57, Average train DDF: 0.02783 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7481 	 and 	 Current val loss: -3.5978
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 58/100
# LR is ==  1e-05
# For epoch: 58, Average train loss: -3.79275 !
# For epoch: 58, Average train DSC: 0.81063 !
#
# For epoch: 58, Average train DSC: -0.57231 !
# For epoch: 58, Average train L2: -0.97348 !
# For epoch: 58, Average train MI: -0.72822 !
# For epoch: 58, Average train DDF: 0.02704 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7341 	 and 	 Current val loss: -3.6088
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 59/100
# LR is ==  1e-05
# For epoch: 59, Average train loss: -3.78693 !
# For epoch: 59, Average train DSC: 0.81238 !
#
# For epoch: 59, Average train DSC: -0.57148 !
# For epoch: 59, Average train L2: -0.97222 !
# For epoch: 59, Average train MI: -0.72707 !
# For epoch: 59, Average train DDF: 0.02754 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7359 	 and 	 Current val loss: -3.6145
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 60/100
# LR is ==  1e-05
# For epoch: 60, Average train loss: -3.80060 !
# For epoch: 60, Average train DSC: 0.81158 !
#
# For epoch: 60, Average train DSC: -0.57111 !
# For epoch: 60, Average train L2: -0.97794 !
# For epoch: 60, Average train MI: -0.72966 !
# For epoch: 60, Average train DDF: 0.02716 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7346 	 and 	 Current val loss: -3.6073
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 61/100
# LR is ==  1e-05
# For epoch: 61, Average train loss: -3.79469 !
# For epoch: 61, Average train DSC: 0.81482 !
#
# For epoch: 61, Average train DSC: -0.57015 !
# For epoch: 61, Average train L2: -0.97773 !
# For epoch: 61, Average train MI: -0.72608 !
# For epoch: 61, Average train DDF: 0.02715 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7342 	 and 	 Current val loss: -3.6088
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 62/100
# LR is ==  1e-05
# For epoch: 62, Average train loss: -3.79497 !
# For epoch: 62, Average train DSC: 0.81521 !
#
# For epoch: 62, Average train DSC: -0.56984 !
# For epoch: 62, Average train L2: -0.97669 !
# For epoch: 62, Average train MI: -0.72882 !
# For epoch: 62, Average train DDF: 0.02692 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7382 	 and 	 Current val loss: -3.5870
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 63/100
# LR is ==  1e-05
# For epoch: 63, Average train loss: -3.78360 !
# For epoch: 63, Average train DSC: 0.80926 !
#
# For epoch: 63, Average train DSC: -0.56991 !
# For epoch: 63, Average train L2: -0.97195 !
# For epoch: 63, Average train MI: -0.72643 !
# For epoch: 63, Average train DDF: 0.02656 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7464 	 and 	 Current val loss: -3.6044
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 64/100
# LR is ==  1e-05
# For epoch: 64, Average train loss: -3.79678 !
# For epoch: 64, Average train DSC: 0.80741 !
#
# For epoch: 64, Average train DSC: -0.56978 !
# For epoch: 64, Average train L2: -0.97852 !
# For epoch: 64, Average train MI: -0.72800 !
# For epoch: 64, Average train DDF: 0.02783 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7249 	 and 	 Current val loss: -3.6099
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 65/100
# LR is ==  1e-05
# For epoch: 65, Average train loss: -3.79854 !
# For epoch: 65, Average train DSC: 0.81914 !
#
# For epoch: 65, Average train DSC: -0.57012 !
# For epoch: 65, Average train L2: -0.97832 !
# For epoch: 65, Average train MI: -0.72943 !
# For epoch: 65, Average train DDF: 0.02776 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7350 	 and 	 Current val loss: -3.5909
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 66/100
# LR is ==  1e-05
# For epoch: 66, Average train loss: -3.78918 !
# For epoch: 66, Average train DSC: 0.81387 !
#
# For epoch: 66, Average train DSC: -0.57195 !
# For epoch: 66, Average train L2: -0.97202 !
# For epoch: 66, Average train MI: -0.72895 !
# For epoch: 66, Average train DDF: 0.02770 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7371 	 and 	 Current val loss: -3.6130
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 67/100
# LR is ==  1e-05
# For epoch: 67, Average train loss: -3.78376 !
# For epoch: 67, Average train DSC: 0.80398 !
#
# For epoch: 67, Average train DSC: -0.56932 !
# For epoch: 67, Average train L2: -0.97245 !
# For epoch: 67, Average train MI: -0.72712 !
# For epoch: 67, Average train DDF: 0.02689 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7444 	 and 	 Current val loss: -3.5944
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 68/100
# LR is ==  1e-05
# For epoch: 68, Average train loss: -3.79748 !
# For epoch: 68, Average train DSC: 0.80941 !
#
# For epoch: 68, Average train DSC: -0.56970 !
# For epoch: 68, Average train L2: -0.97822 !
# For epoch: 68, Average train MI: -0.72940 !
# For epoch: 68, Average train DDF: 0.02775 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7470 	 and 	 Current val loss: -3.6102
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 69/100
# LR is ==  1e-05
# For epoch: 69, Average train loss: -3.79419 !
# For epoch: 69, Average train DSC: 0.81023 !
#
# For epoch: 69, Average train DSC: -0.56977 !
# For epoch: 69, Average train L2: -0.97692 !
# For epoch: 69, Average train MI: -0.72732 !
# For epoch: 69, Average train DDF: 0.02652 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7430 	 and 	 Current val loss: -3.6018
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 70/100
# LR is ==  1e-05
# For epoch: 70, Average train loss: -3.79053 !
# For epoch: 70, Average train DSC: 0.80759 !
#
# For epoch: 70, Average train DSC: -0.57102 !
# For epoch: 70, Average train L2: -0.97431 !
# For epoch: 70, Average train MI: -0.72834 !
# For epoch: 70, Average train DDF: 0.02848 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7462 	 and 	 Current val loss: -3.6222
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 71/100
# LR is ==  1e-05
# For epoch: 71, Average train loss: -3.78425 !
# For epoch: 71, Average train DSC: 0.80961 !
#
# For epoch: 71, Average train DSC: -0.56928 !
# For epoch: 71, Average train L2: -0.97257 !
# For epoch: 71, Average train MI: -0.72630 !
# For epoch: 71, Average train DDF: 0.02576 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7407 	 and 	 Current val loss: -3.6016
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 72/100
# LR is ==  1e-05
# For epoch: 72, Average train loss: -3.80219 !
# For epoch: 72, Average train DSC: 0.80662 !
#
# For epoch: 72, Average train DSC: -0.57297 !
# For epoch: 72, Average train L2: -0.97867 !
# For epoch: 72, Average train MI: -0.72741 !
# For epoch: 72, Average train DDF: 0.02851 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7360 	 and 	 Current val loss: -3.6130
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 73/100
# LR is ==  1e-05
# For epoch: 73, Average train loss: -3.79738 !
# For epoch: 73, Average train DSC: 0.81317 !
#
# For epoch: 73, Average train DSC: -0.56990 !
# For epoch: 73, Average train L2: -0.97746 !
# For epoch: 73, Average train MI: -0.72947 !
# For epoch: 73, Average train DDF: 0.02681 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7412 	 and 	 Current val loss: -3.5929
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 74/100
# LR is ==  1e-05
# For epoch: 74, Average train loss: -3.77974 !
# For epoch: 74, Average train DSC: 0.80289 !
#
# For epoch: 74, Average train DSC: -0.57010 !
# For epoch: 74, Average train L2: -0.97131 !
# For epoch: 74, Average train MI: -0.72463 !
# For epoch: 74, Average train DDF: 0.02772 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7463 	 and 	 Current val loss: -3.6130
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 75/100
# LR is ==  1e-05
# For epoch: 75, Average train loss: -3.80138 !
# For epoch: 75, Average train DSC: 0.81635 !
#
# For epoch: 75, Average train DSC: -0.57069 !
# For epoch: 75, Average train L2: -0.97868 !
# For epoch: 75, Average train MI: -0.73060 !
# For epoch: 75, Average train DDF: 0.02794 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7404 	 and 	 Current val loss: -3.6066
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 76/100
# LR is ==  1e-05
# For epoch: 76, Average train loss: -3.80013 !
# For epoch: 76, Average train DSC: 0.80704 !
#
# For epoch: 76, Average train DSC: -0.57275 !
# For epoch: 76, Average train L2: -0.97653 !
# For epoch: 76, Average train MI: -0.72855 !
# For epoch: 76, Average train DDF: 0.02698 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7394 	 and 	 Current val loss: -3.5924
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 77/100
# LR is ==  1e-05
# For epoch: 77, Average train loss: -3.78826 !
# For epoch: 77, Average train DSC: 0.80668 !
#
# For epoch: 77, Average train DSC: -0.57146 !
# For epoch: 77, Average train L2: -0.97235 !
# For epoch: 77, Average train MI: -0.72952 !
# For epoch: 77, Average train DDF: 0.02888 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7398 	 and 	 Current val loss: -3.6167
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 78/100
# LR is ==  1e-05
# For epoch: 78, Average train loss: -3.80375 !
# For epoch: 78, Average train DSC: 0.81420 !
#
# For epoch: 78, Average train DSC: -0.57226 !
# For epoch: 78, Average train L2: -0.97820 !
# For epoch: 78, Average train MI: -0.73005 !
# For epoch: 78, Average train DDF: 0.02722 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7471 	 and 	 Current val loss: -3.6075
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 79/100
# LR is ==  1e-05
# For epoch: 79, Average train loss: -3.80482 !
# For epoch: 79, Average train DSC: 0.81440 !
#
# For epoch: 79, Average train DSC: -0.57306 !
# For epoch: 79, Average train L2: -0.97841 !
# For epoch: 79, Average train MI: -0.73066 !
# For epoch: 79, Average train DDF: 0.02878 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7308 	 and 	 Current val loss: -3.6097
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 80/100
# LR is ==  1e-05
# For epoch: 80, Average train loss: -3.79095 !
# For epoch: 80, Average train DSC: 0.80558 !
#
# For epoch: 80, Average train DSC: -0.57206 !
# For epoch: 80, Average train L2: -0.97233 !
# For epoch: 80, Average train MI: -0.73070 !
# For epoch: 80, Average train DDF: 0.02853 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7376 	 and 	 Current val loss: -3.6188
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 81/100
# LR is ==  1e-05
# For epoch: 81, Average train loss: -3.79203 !
# For epoch: 81, Average train DSC: 0.80260 !
#
# For epoch: 81, Average train DSC: -0.57236 !
# For epoch: 81, Average train L2: -0.97213 !
# For epoch: 81, Average train MI: -0.73060 !
# For epoch: 81, Average train DDF: 0.02756 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7459 	 and 	 Current val loss: -3.6053
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 82/100
# LR is ==  1e-05
# For epoch: 82, Average train loss: -3.80901 !
# For epoch: 82, Average train DSC: 0.81537 !
#
# For epoch: 82, Average train DSC: -0.57391 !
# For epoch: 82, Average train L2: -0.97936 !
# For epoch: 82, Average train MI: -0.73172 !
# For epoch: 82, Average train DDF: 0.02925 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7383 	 and 	 Current val loss: -3.6100
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 83/100
# LR is ==  1e-05
# For epoch: 83, Average train loss: -3.80368 !
# For epoch: 83, Average train DSC: 0.80731 !
#
# For epoch: 83, Average train DSC: -0.57260 !
# For epoch: 83, Average train L2: -0.97741 !
# For epoch: 83, Average train MI: -0.73182 !
# For epoch: 83, Average train DDF: 0.02816 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7392 	 and 	 Current val loss: -3.6029
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 84/100
# LR is ==  1e-05
# For epoch: 84, Average train loss: -3.79292 !
# For epoch: 84, Average train DSC: 0.80419 !
#
# For epoch: 84, Average train DSC: -0.57329 !
# For epoch: 84, Average train L2: -0.97241 !
# For epoch: 84, Average train MI: -0.73023 !
# For epoch: 84, Average train DDF: 0.02869 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7463 	 and 	 Current val loss: -3.6158
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 85/100
# LR is ==  1e-05
# For epoch: 85, Average train loss: -3.79848 !
# For epoch: 85, Average train DSC: 0.80896 !
#
# For epoch: 85, Average train DSC: -0.57256 !
# For epoch: 85, Average train L2: -0.97525 !
# For epoch: 85, Average train MI: -0.73136 !
# For epoch: 85, Average train DDF: 0.02850 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7356 	 and 	 Current val loss: -3.6167
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 86/100
# LR is ==  1e-05
# For epoch: 86, Average train loss: -3.80532 !
# For epoch: 86, Average train DSC: 0.81209 !
#
# For epoch: 86, Average train DSC: -0.57424 !
# For epoch: 86, Average train L2: -0.97765 !
# For epoch: 86, Average train MI: -0.72965 !
# For epoch: 86, Average train DDF: 0.02810 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7307 	 and 	 Current val loss: -3.5934
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 87/100
# LR is ==  1e-05
# For epoch: 87, Average train loss: -3.80588 !
# For epoch: 87, Average train DSC: 0.81106 !
#
# For epoch: 87, Average train DSC: -0.57376 !
# For epoch: 87, Average train L2: -0.97788 !
# For epoch: 87, Average train MI: -0.73123 !
# For epoch: 87, Average train DDF: 0.02863 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7380 	 and 	 Current val loss: -3.6067
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 88/100
# LR is ==  1e-05
# For epoch: 88, Average train loss: -3.79707 !
# For epoch: 88, Average train DSC: 0.81238 !
#
# For epoch: 88, Average train DSC: -0.57483 !
# For epoch: 88, Average train L2: -0.97314 !
# For epoch: 88, Average train MI: -0.72982 !
# For epoch: 88, Average train DDF: 0.02870 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7364 	 and 	 Current val loss: -3.6194
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 89/100
# LR is ==  1e-05
# For epoch: 89, Average train loss: -3.80253 !
# For epoch: 89, Average train DSC: 0.80976 !
#
# For epoch: 89, Average train DSC: -0.57390 !
# For epoch: 89, Average train L2: -0.97572 !
# For epoch: 89, Average train MI: -0.73162 !
# For epoch: 89, Average train DDF: 0.02833 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7447 	 and 	 Current val loss: -3.6199
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 90/100
# LR is ==  1e-05
# For epoch: 90, Average train loss: -3.80621 !
# For epoch: 90, Average train DSC: 0.80978 !
#
# For epoch: 90, Average train DSC: -0.57353 !
# For epoch: 90, Average train L2: -0.97779 !
# For epoch: 90, Average train MI: -0.73218 !
# For epoch: 90, Average train DDF: 0.02861 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7367 	 and 	 Current val loss: -3.6075
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 91/100
# LR is ==  1e-05
# For epoch: 91, Average train loss: -3.80275 !
# For epoch: 91, Average train DSC: 0.81047 !
#
# For epoch: 91, Average train DSC: -0.57512 !
# For epoch: 91, Average train L2: -0.97372 !
# For epoch: 91, Average train MI: -0.73371 !
# For epoch: 91, Average train DDF: 0.02863 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7363 	 and 	 Current val loss: -3.6119
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 92/100
# LR is ==  1e-05
# For epoch: 92, Average train loss: -3.80116 !
# For epoch: 92, Average train DSC: 0.81323 !
#
# For epoch: 92, Average train DSC: -0.57505 !
# For epoch: 92, Average train L2: -0.97431 !
# For epoch: 92, Average train MI: -0.73132 !
# For epoch: 92, Average train DDF: 0.02887 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7514 	 and 	 Current val loss: -3.6165
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 93/100
# LR is ==  1e-05
# For epoch: 93, Average train loss: -3.80331 !
# For epoch: 93, Average train DSC: 0.80207 !
#
# For epoch: 93, Average train DSC: -0.57320 !
# For epoch: 93, Average train L2: -0.97684 !
# For epoch: 93, Average train MI: -0.73213 !
# For epoch: 93, Average train DDF: 0.02891 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7364 	 and 	 Current val loss: -3.6115
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 94/100
# LR is ==  1e-05
# For epoch: 94, Average train loss: -3.80749 !
# For epoch: 94, Average train DSC: 0.81914 !
#
# For epoch: 94, Average train DSC: -0.57254 !
# For epoch: 94, Average train L2: -0.97900 !
# For epoch: 94, Average train MI: -0.73315 !
# For epoch: 94, Average train DDF: 0.02873 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7457 	 and 	 Current val loss: -3.6027
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 95/100
# LR is ==  1e-05
# For epoch: 95, Average train loss: -3.80116 !
# For epoch: 95, Average train DSC: 0.80833 !
#
# For epoch: 95, Average train DSC: -0.57389 !
# For epoch: 95, Average train L2: -0.97477 !
# For epoch: 95, Average train MI: -0.73225 !
# For epoch: 95, Average train DDF: 0.02841 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7430 	 and 	 Current val loss: -3.6117
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 96/100
# LR is ==  1e-05
# For epoch: 96, Average train loss: -3.79481 !
# For epoch: 96, Average train DSC: 0.79855 !
#
# For epoch: 96, Average train DSC: -0.57286 !
# For epoch: 96, Average train L2: -0.97323 !
# For epoch: 96, Average train MI: -0.73135 !
# For epoch: 96, Average train DDF: 0.02871 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7358 	 and 	 Current val loss: -3.6145
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 97/100
# LR is ==  1e-05
# For epoch: 97, Average train loss: -3.80615 !
# For epoch: 97, Average train DSC: 0.81095 !
#
# For epoch: 97, Average train DSC: -0.57281 !
# For epoch: 97, Average train L2: -0.97775 !
# For epoch: 97, Average train MI: -0.73360 !
# For epoch: 97, Average train DDF: 0.02857 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7413 	 and 	 Current val loss: -3.6092
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 98/100
# LR is ==  1e-05
# For epoch: 98, Average train loss: -3.80709 !
# For epoch: 98, Average train DSC: 0.80908 !
#
# For epoch: 98, Average train DSC: -0.57492 !
# For epoch: 98, Average train L2: -0.97800 !
# For epoch: 98, Average train MI: -0.72947 !
# For epoch: 98, Average train DDF: 0.02822 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7371 	 and 	 Current val loss: -3.6131
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 99/100
# LR is ==  1e-05
# For epoch: 99, Average train loss: -3.79276 !
# For epoch: 99, Average train DSC: 0.80343 !
#
# For epoch: 99, Average train DSC: -0.57300 !
# For epoch: 99, Average train L2: -0.97208 !
# For epoch: 99, Average train MI: -0.73217 !
# For epoch: 99, Average train DDF: 0.02957 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7426 	 and 	 Current val loss: -3.6184
#
# Best val DSC: 0.7623 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 100/100
# LR is ==  1e-05
# For epoch: 100, Average train loss: -3.80935 !
# For epoch: 100, Average train DSC: 0.80945 !
#
# For epoch: 100, Average train DSC: -0.57346 !
# For epoch: 100, Average train L2: -0.97923 !
# For epoch: 100, Average train MI: -0.73175 !
# For epoch: 100, Average train DDF: 0.02779 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7343 	 and 	 Current val loss: -3.6119
#
# Best val DSC: 0.7623 at epoch number of 10

# %%
# %matplotlib inline
plt.figure("train", (20, 4))
plt.subplot(1, 2, 1)
plt.plot(epoch_loss_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.plot(epoch_val_loss_values, label = 'val', color='b', lw=2, linestyle='-', marker = 'x')
plt.legend(fontsize=20, loc='upper right', ncol=1)
plt.xticks(range(0, max_epochs , 5))
plt.ylabel('Losses', fontsize=20)
plt.xlabel('Epochs', fontsize=20)

plt.subplot(1, 2, 2)
plt.plot(metric_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.ylabel('DSC', fontsize=20)
plt.xlabel('Epochs', fontsize=20)
# Out:
# Text(0.5, 0, 'Epochs')

# %%
def hausdorff (mask1, mask2):
    mask1_class_LV = mask1.copy()
    mask1_class_Myo = mask1.copy()
    
    mask1_class_LV[mask1_class_LV==1] = 0
    mask1_class_Myo[mask1_class_Myo==2] = 0
    
    mask2_class_LV = mask2.copy()
    mask2_class_Myo = mask2.copy()
    
    mask2_class_LV[mask2_class_LV==1] = 0
    mask2_class_Myo[mask2_class_Myo==2] = 0
    
    hausdorff_Myo = (directed_hausdorff(mask1_class_Myo, mask2_class_Myo)[0]+directed_hausdorff(mask2_class_Myo, mask1_class_Myo)[0])/2

    hausdorff_LV = (directed_hausdorff(mask1_class_LV, mask2_class_LV)[0]+directed_hausdorff(mask2_class_LV, mask1_class_LV)[0])/2
    
    return [hausdorff_Myo, hausdorff_LV]

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()

metric = monai.metrics.MSEMetric()

before_MSEMetric = []
after_MSEMetric = []

before_compute_meandice = []
after_compute_meandice = []

before_compute_hausdorff_distance = []
after_compute_hausdorff_distance = []
                                                                         

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    before_MSEMetric.extend(metric(moving_val_img_,fixed_val_img_).detach().cpu().numpy())
    
    after_MSEMetric.extend(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())
    
#     print(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())

    before_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy())
    after_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy()) 
    
    
    before_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy())
    after_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy()) 
    
    
#     break

print(np.array(before_MSEMetric).shape)
print(np.array(after_MSEMetric).shape)

print(np.array(before_compute_meandice).shape)
print(np.array(after_compute_meandice).shape)

print()

print(f'MSEMetric W/O registration {np.mean(np.array(before_MSEMetric))}')
print(f'MSEMetric W/ registration = {np.mean(np.array(after_MSEMetric))}')

print(f'Mean dice W/O registration = {np.mean(np.array(before_compute_meandice), axis=0)}')
print(f'Mean dice W/ registration = {np.mean(np.array(after_compute_meandice), axis=0)}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.array(before_compute_hausdorff_distance), axis=0)}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.array(after_compute_hausdorff_distance), axis=0)}')

print()

print('----------------For Report Metric +/- Std-----------------------')
print(f'Mean dice W/O registration = {np.mean(np.mean(np.array(before_compute_meandice), axis=0))} + {np.mean(np.std(np.array(before_compute_meandice), axis=0))}')
print(f'Mean dice W/ registration = {np.mean(np.mean(np.array(after_compute_meandice), axis=0))} + {np.mean(np.std(np.array(after_compute_meandice), axis=0))}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.mean(np.array(before_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(before_compute_hausdorff_distance), axis=0))}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.mean(np.array(after_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(after_compute_hausdorff_distance), axis=0))}')

df = ({
     'before_compute_hausdorff_distance':np.mean(np.array(before_compute_hausdorff_distance), axis=1),
     'after_compute_hausdorff_distance'   : np.mean(np.array(after_compute_hausdorff_distance), axis=1),
     'before_compute_meandice':np.mean(np.array(before_compute_meandice), axis=1),
     'after_compute_meandice':np.mean(np.array(after_compute_meandice), axis=1),
     'before_MSEMetric': np.mean(np.array(before_MSEMetric), axis=1),
     'after_MSEMetric':np.mean(np.array(after_MSEMetric), axis=1)
})

pd.DataFrame(df).to_csv(fileNames+'.csv')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/mkh/MKH/KSA/AC_DLIR_3D_v3_ESED.ipynb Cell 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bbm-yaplab2.dept.ic.ac.uk/home/mkh/MKH/KSA/AC_DLIR_3D_v3_ESED.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
#       <a href='vscode-notebook-cell://ssh-remote%2Bbm-yaplab2.dept.ic.ac.uk/home/mkh/MKH/KSA/AC_DLIR_3D_v3_ESED.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> model.eval()
#       <a href='vscode-notebook-cell://ssh-remote%2Bbm-yaplab2.dept.ic.ac.uk/home/mkh/MKH/KSA/AC_DLIR_3D_v3_ESED.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> metric = monai.metrics.MSEMetric()
#
# File ~/anaconda3/envs/phd/lib/python3.9/site-packages/torch/nn/modules/module.py:1671, in Module.load_state_dict(self, state_dict, strict)
#    1666         error_msgs.insert(
#    1667             0, 'Missing key(s) in state_dict: {}. '.format(
#    1668                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1670 if len(error_msgs) > 0:
# -> 1671     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1672                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1673 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for RegUNet:
# 	Missing key(s) in state_dict: "encode_convs.3.0.conv.weight", "encode_convs.3.0.adn.N.weight", "encode_convs.3.0.adn.N.bias", "encode_convs.3.0.adn.N.running_mean", "encode_convs.3.0.adn.N.running_var", "encode_convs.3.1.layers.0.conv.weight", "encode_convs.3.1.layers.1.conv.weight", "encode_convs.3.1.norms.0.weight", "encode_convs.3.1.norms.0.bias", "encode_convs.3.1.norms.0.running_mean", "encode_convs.3.1.norms.0.running_var", "encode_convs.3.1.norms.1.weight", "encode_convs.3.1.norms.1.bias", "encode_convs.3.1.norms.1.running_mean", "encode_convs.3.1.norms.1.running_var", "encode_convs.4.0.conv.weight", "encode_convs.4.0.adn.N.weight", "encode_convs.4.0.adn.N.bias", "encode_convs.4.0.adn.N.running_mean", "encode_convs.4.0.adn.N.running_var", "encode_convs.4.1.layers.0.conv.weight", "encode_convs.4.1.layers.1.conv.weight", "encode_convs.4.1.norms.0.weight", "encode_convs.4.1.norms.0.bias", "encode_convs.4.1.norms.0.running_mean", "encode_convs.4.1.norms.0.running_var", "encode_convs.4.1.norms.1.weight", "encode_convs.4.1.norms.1.bias", "encode_convs.4.1.norms.1.running_mean", "encode_convs.4.1.norms.1.running_var".
# 	size mismatch for bottom_block.0.conv.weight: copying a param with shape torch.Size([256, 128, 3, 3, 3]) from checkpoint, the shape in current model is torch.Size([1024, 512, 3, 3, 3]).
# 	size mismatch for bottom_block.0.adn.N.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.0.adn.N.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.0.adn.N.running_mean: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.0.adn.N.running_var: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.1.layers.0.conv.weight: copying a param with shape torch.Size([256, 256, 3, 3, 3]) from checkpoint, the shape in current model is torch.Size([1024, 1024, 3, 3, 3]).
# 	size mismatch for bottom_block.1.layers.1.conv.weight: copying a param with shape torch.Size([256, 256, 3, 3, 3]) from checkpoint, the shape in current model is torch.Size([1024, 1024, 3, 3, 3]).
# 	size mismatch for bottom_block.1.norms.0.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.1.norms.0.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.1.norms.0.running_mean: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.1.norms.0.running_var: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.1.norms.1.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.1.norms.1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.1.norms.1.running_mean: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for bottom_block.1.norms.1.running_var: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for output_block.layers.0.conv.weight: copying a param with shape torch.Size([3, 256, 3, 3, 3]) from checkpoint, the shape in current model is torch.Size([3, 1024, 3, 3, 3]).

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()
                                          

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    break

fixed_val_img_ = fixed_val_img_.detach().cpu().numpy()[:, 0]
fixed_val_msk_ = fixed_val_msk_.detach().cpu().numpy()[:, 0]

moving_val_img_ = moving_val_img_.detach().cpu().numpy()[:, 0]
moving_val_msk_ = moving_val_msk_.detach().cpu().numpy()[:, 0]

pred_image_val = pred_image_val.detach().cpu().numpy()[:, 0]
pred_mask_val = pred_mask_val.detach().cpu().numpy()[:, 0]

# %%
def colored (pred_img, true_img): 
    bitwise_and = cv2.bitwise_and(pred_img, true_img)
    
    TP = np.stack((np.zeros_like(bitwise_and), bitwise_and, np.zeros_like(bitwise_and)), axis=-1)
    
    FN = np.stack((true_img-bitwise_and,
                   true_img-bitwise_and,
                   np.zeros_like(true_img-bitwise_and)), axis=-1)
    
    FP = np.stack((pred_img-bitwise_and,
                   pred_img-bitwise_and,
                  np.zeros_like(pred_img-bitwise_and)), axis=-1)
    
    return (255*(TP+FN+FP)).astype('uint8')

# %%
slice_no = 15
# %matplotlib inline
slice_num = 8
plt.subplots(slice_num, 7, figsize=(12, 15))

for b in range(slice_num):
    # moving image
    plt.subplot(slice_num, 7, b * 7 + 1)
    plt.axis('off')
    plt.title("moving img")
    plt.imshow(moving_val_img_[0, :, :, slice_no], cmap="gray")
    
    # moving label
    plt.subplot(slice_num, 7, b * 7 + 2)
    plt.axis('off')
    plt.title("moving lab")
    plt.imshow(moving_val_msk_[0, :, :, slice_no], cmap="gray")
    
    
    # fixed image
    plt.subplot(slice_num, 7, b * 7 + 3)
    plt.axis('off')
    plt.title("fixed img")
    plt.imshow(fixed_val_img_[0, :, :, slice_no], cmap="gray")
    
    # fixed label
    plt.subplot(slice_num, 7, b * 7 + 4)
    plt.axis('off')
    plt.title("fixed lab")
    plt.imshow(fixed_val_msk_[0, :, :, slice_no], cmap="gray")
    
    
    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 5)
    plt.axis('off')
    plt.title("Pred Img")
    plt.imshow(pred_image_val[0, :, :, slice_no], cmap="gray")


    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 6)
    plt.axis('off')
    plt.title("Before Reg")
    plt.imshow(colored(moving_val_msk_[0, :, :, slice_no], fixed_val_msk_[0, :, :, slice_no]))
    
    
    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 7)
    plt.axis('off')
    plt.title("After Reg")
    plt.imshow(colored(pred_mask_val[0, :, :, slice_no], fixed_val_msk_[0, :, :, slice_no]))

    slice_no = slice_no + 1
    
plt.axis('off')
plt.show()
