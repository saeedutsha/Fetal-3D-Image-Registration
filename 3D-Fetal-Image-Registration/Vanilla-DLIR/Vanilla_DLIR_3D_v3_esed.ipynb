# %%
# Import and Install Libraries

from monai.utils import set_determinism, first
from monai.transforms import (
    EnsureChannelFirstD,
    Compose,
    LoadImageD,
    RandRotateD,
    RandZoomD,
    ScaleIntensityRanged,
)
import monai
from monai.data import DataLoader, Dataset, CacheDataset
from monai.config import print_config, USE_COMPILED
from monai.networks.nets import GlobalNet, LocalNet, RegUNet
from monai.networks.blocks import Warp
from monai.apps import MedNISTDataset
import torch.nn.functional as F

from glob import glob
import cv2
import torchmetrics

from torch.autograd import Variable

from scipy.spatial.distance import directed_hausdorff
from scipy.ndimage import zoom
import pandas as pd

import torch.nn as nn

import numpy as np
import torch
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
from matplotlib.animation import FuncAnimation
import os
import tempfile
from monai.losses import *
from monai.metrics import *
from piqa import SSIM

import nibabel as nib

import csv

print_config()
set_determinism(40)
# Out:
# MONAI version: 1.0.1
# Numpy version: 1.22.3
# Pytorch version: 1.13.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 8271a193229fe4437026185e218d5b06f7c8ce69
# MONAI __file__: /home/mkh/anaconda3/envs/phd/lib/python3.9/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.10
# Nibabel version: 5.0.1
# scikit-image version: 0.19.3
# Pillow version: 9.0.1
# Tensorboard version: 2.12.0
# gdown version: 4.6.4
# TorchVision version: 0.14.1
# tqdm version: 4.64.1
# lmdb version: 1.4.0
# psutil version: 5.9.4
# pandas version: 1.5.3
# einops version: 0.6.0
# transformers version: 4.21.3
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
# Directories and some Parameters

dataDir = '3D_Updated'

root_dir = '/home/mkh/MKH/KSA/Dataset/'+dataDir+'/'
print(root_dir)

trainBatch = 1
testBatch = 1

img_size = 256
slice_size = 32

previousWeight = 128

preTrained = 0

EP = 200

num_workers = 0

ExpName = "Vanilla_DLIR_v3_ESED"

fileNames = ExpName + '_' + dataDir + '_' +str(img_size) + '_'+str(slice_size) + '_'

# print(fileNames)
# Out:
# /home/mkh/MKH/KSA/Dataset/3D_Updated/

# %%
# GPU information
print('How many GPUs = ' + str(torch.cuda.device_count()))

#checking for device

device=torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
print(device)

if not torch.cuda.is_available():
  raise Exception("GPU not availalbe. CPU training will be too slow.")

print("device name", torch.cuda.get_device_name(0))
# Out:
# How many GPUs = 4
# cuda:2
# device name NVIDIA GeForce RTX 3090 Ti

# %%
# # Make fixed-moving pairs in csv
# # root_dir = '/home/mkh/MKH/KSA/Dataset/'+dataDir+'/'
# splits = ['train', 'val']
# for split in splits:
#     fixed_names = []
#     moving_names = []
#     split_path = os.path.join(root_dir, split)
#     for folders in sorted(os.listdir(split_path)):
#         split_path_folders = os.path.join(split_path, folders)
#         if 'fixed_img' in folders:
#             for fixed_imgs in sorted(os.listdir(split_path_folders)):
#                 split_path_folders_fixed_imgs = os.path.join(split_path_folders, fixed_imgs)
#                 fixed_pt = fixed_imgs.split('_')[0]
#                 for mov_folders in sorted(os.listdir(split_path)):
#                     if 'moving_img' in mov_folders:
#                         mov_split_path_folders = os.path.join(split_path, mov_folders)
#                         for moving_imgs in sorted(os.listdir(mov_split_path_folders)):
#                             moving_pt = moving_imgs.split('_')[0]
#                             if(fixed_pt==moving_pt):
#                                 fixed_names.append(fixed_imgs)
#                                 moving_names.append(moving_imgs)
#     data = {'Fixed':fixed_names, 'Moving':moving_names}
#     dataframe = pd.DataFrame(data=data, index=None)
#     csv_path = root_dir + split + '.csv'
#     dataframe.to_csv(csv_path,index=False)

# %%
class EchoDataset3D(Dataset):
    def __init__(self, images_path, flagMask):

        self.images_path = images_path
        self.n_samples = len(images_path)
        self.flagMask = flagMask

    def __getitem__(self, index):
        """ Reading Nifti Files """
        
        # image = cv2.imread(self.images_path[index], cv2.IMREAD_GRAYSCALE)
        img_3d = nib.load(self.images_path[index])
        image = img_3d.get_fdata()

        if self.flagMask==0:
            image = zoom(image, (img_size / image.shape[0], img_size / image.shape[1], slice_size / image.shape[2]))
            # image = cv2.resize(image,(img_size, img_size))
            image = (image-image.min())/(image.max()-image.min())
        else:
            image[image==127]=1
            image[image==255]=2
            image = zoom(image, (img_size / image.shape[0], img_size / image.shape[1], slice_size / image.shape[2]), order=0)
            # image = cv2.resize(image,(img_size, img_size), interpolation=cv2.INTER_NEAREST)
            # image = image/(image.max()) ## (512, 512, 3)
            # print(image.max())
        image = np.expand_dims(image, axis=0)
        image = image.astype(np.float32)
        self.images_path[index]
        return image

    def __len__(self):
        return self.n_samples

# %%
def get_batches(split_dir,
                split,
                fixOrMov,
                flagMask,
                batch_size,
                num_workers,
                pin_memory):
    
    csv_path = pd.read_csv(root_dir + split + "_esed.csv") #Change here
    all_path  = split_dir + csv_path[fixOrMov]
    
    split_data = EchoDataset3D(images_path=all_path, flagMask=flagMask)

    split_loader = DataLoader(split_data,
                              batch_size=batch_size,
                              num_workers=num_workers,
                              pin_memory=pin_memory,
                              shuffle=False)

    return split_loader

# %%
fixed_train_img = get_batches(split_dir = sorted(glob(root_dir+"train/img/")),
                                        split = 'train',
                                        fixOrMov = 'Fixed',
                                        flagMask = 0,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_train_msk = get_batches(split_dir = sorted(glob(root_dir+"train/msk/")),
                                        split = 'train',
                                        fixOrMov = 'Fixed',
                                        flagMask = 1,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_train_img = get_batches(split_dir = sorted(glob(root_dir+"train/img/")),
                                        split = 'train',
                                        fixOrMov = 'Moving',
                                        flagMask = 0,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_train_msk = get_batches(split_dir = sorted(glob(root_dir+"train/msk/")),
                                        split = 'train',
                                        fixOrMov = 'Moving',
                                        flagMask = 1,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

print("Train IMG FIXED:", fixed_train_img)
print("Train MSK FIXED:", fixed_train_msk)
print("Train IMG Moving:", moving_train_img)
print("Train MSK Moving:", moving_train_msk)

fixed_val_img = get_batches(split_dir = sorted(glob(root_dir+"val/img/")),
                                        split = 'val',
                                        fixOrMov = 'Fixed',
                                        flagMask = 0,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_val_msk = get_batches(split_dir = sorted(glob(root_dir+"val/msk/")),
                                        split = 'val',
                                        fixOrMov = 'Fixed',
                                        flagMask = 1,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


moving_val_img = get_batches(split_dir = sorted(glob(root_dir+"val/img/")),
                                        split = 'val',
                                        fixOrMov = 'Moving',
                                        flagMask = 0,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_val_msk = get_batches(split_dir = sorted(glob(root_dir+"val/msk/")),
                                        split = 'val',
                                        fixOrMov = 'Moving',
                                        flagMask = 1,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


print("Val IMG FIXED:", fixed_val_img)
print("Val MSK FIXED:", fixed_val_msk)
print("Val IMG Moving:", moving_val_img)
print("Val MSK Moving:", moving_val_msk)
# Out:
# Train IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7f3d84695400>
# Train MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7f3c2c4571c0>
# Train IMG Moving: <monai.data.dataloader.DataLoader object at 0x7f3c2c4579a0>
# Train MSK Moving: <monai.data.dataloader.DataLoader object at 0x7f3c25076ee0>
# Val IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7f3c2c45ad30>
# Val MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7f3c2c45adc0>
# Val IMG Moving: <monai.data.dataloader.DataLoader object at 0x7f3c2c47dd90>
# Val MSK Moving: <monai.data.dataloader.DataLoader object at 0x7f3c2c47dd00>

# %%
# Change here
train_csv = pd.read_csv(root_dir + 'train_esed.csv')
val_csv =  pd.read_csv(root_dir + 'val_esed.csv')

print(f'Train Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"train/img/")) + train_csv["Fixed"] )}')
print(f'Train Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"train/msk/")) + train_csv["Fixed"] )}')
print(f'Train Sample numbers (moving_img) = {len(sorted(glob(root_dir+"train/img/")) + train_csv["Moving"] )}')
print(f'Train Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"/train/msk/")) + train_csv["Fixed"] )}')
print()
print(f'Val Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"val/img/")) + val_csv["Fixed"] )}')
print(f'Val Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"val/msk/")) + val_csv["Fixed"] )}')
print(f'Val Sample numbers (moving_img) = {len(sorted(glob(root_dir+"val/img/")) + val_csv["Moving"] )}')
print(f'Val Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"val/msk/")) + val_csv["Moving"] )}')
print()
# Out:
# Train Sample numbers (fixed_img) = 10
# Train Sample numbers (fixed_msk) = 10
# Train Sample numbers (moving_img) = 10
# Train Sample numbers (moving_msk) = 10
#
# Val Sample numbers (fixed_img) = 4
# Val Sample numbers (fixed_msk) = 4
# Val Sample numbers (moving_img) = 4
# Val Sample numbers (moving_msk) = 4

# %%
dataloaders = {
    'fixed_train_img': fixed_train_img,
    'fixed_train_msk': fixed_train_msk,
    'moving_train_img': moving_train_img,
    'moving_train_msk': moving_train_msk,
    'fixed_val_img': fixed_val_img,
    'fixed_val_msk': fixed_val_msk,
    'moving_val_img': moving_val_img,
    'moving_val_msk': moving_val_msk
    }

# %%
fixed_train_img_ = first(dataloaders["fixed_train_img"])[0][0]
fixed_train_msk_ = first(dataloaders["fixed_train_msk"])[0][0]
moving_train_img_ = first(dataloaders["moving_train_img"])[0][0]
moving_train_msk_ = first(dataloaders["moving_train_msk"])[0][0]

fixed_val_img_ = first(dataloaders["fixed_val_img"])[0][0]
fixed_val_msk_ = first(dataloaders["fixed_val_msk"])[0][0]
moving_val_img_ = first(dataloaders["moving_val_img"])[0][0]
moving_val_msk_ = first(dataloaders["moving_val_msk"])[0][0]


print(f"fixed_train_img_ shape: {fixed_train_img_.shape}")
print(f"fixed_train_msk_ shape: {fixed_train_msk_.shape}")
print(f"moving_train_img_ shape: {moving_train_img_.shape}")
print(f"moving_train_msk_ shape: {moving_train_msk_.shape}")

print(f"fixed_val_img_ shape: {fixed_val_img_.shape}")
print(f"fixed_val_msk_ shape: {fixed_val_msk_.shape}")
print(f"moving_val_img_ shape: {moving_val_img_.shape}")
print(f"moving_val_msk_ shape: {moving_val_msk_.shape}")


print(f"fixed_train_img_ Range: {fixed_train_img_.max()} {fixed_train_img_.min()}")
print(f"fixed_train_msk_ range: {fixed_train_msk_.max()} {fixed_train_msk_.min()} {np.unique(fixed_train_msk_)}")
print(f"moving_train_img_ Range: {moving_train_img_.max()} {moving_train_img_.min()}")
print(f"moving_train_msk_ range: {moving_train_msk_.max()} {moving_train_msk_.min()} {np.unique(moving_train_msk_)}")

print(f"fixed_val_img_ Range: {fixed_val_img_.max()} {fixed_val_img_.min()}")
print(f"fixed_val_msk_ range: {fixed_val_msk_.max()} {fixed_val_msk_.min()} {np.unique(fixed_val_msk_)}")
print(f"moving_val_img_ Range: {moving_val_img_.max()} {moving_val_img_.min()}")
print(f"moving_val_msk_ range: {moving_val_msk_.max()} {moving_val_msk_.min()} {np.unique(moving_val_msk_)}")
# Out:
# fixed_train_img_ shape: torch.Size([256, 256, 32])
# fixed_train_msk_ shape: torch.Size([256, 256, 32])
# moving_train_img_ shape: torch.Size([256, 256, 32])
# moving_train_msk_ shape: torch.Size([256, 256, 32])
# fixed_val_img_ shape: torch.Size([256, 256, 32])
# fixed_val_msk_ shape: torch.Size([256, 256, 32])
# moving_val_img_ shape: torch.Size([256, 256, 32])
# moving_val_msk_ shape: torch.Size([256, 256, 32])
# fixed_train_img_ Range: 1.0 0.0
# fixed_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_train_img_ Range: 1.0 0.0
# moving_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# fixed_val_img_ Range: 1.0 0.0
# fixed_val_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_val_img_ Range: 1.0 0.0
# moving_val_msk_ range: 2.0 0.0 [0. 1. 2.]

# %%
# %matplotlib widget

# volumes = [fixed_train_img_, fixed_train_msk_, moving_train_img_, moving_train_msk_, fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_]  # Replace with your actual 3D volume data

# # Create a figure and subplots
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))

# # Create initial slices for each volume
# initial_slices = [0] * 8
# current_slices = []

# # Plot the initial slices
# for i, ax in enumerate(axs.flat):
#     ax.axis('off')  # Hide the axis numbers
#     current_slice = ax.imshow(volumes[i][:, :, initial_slices[i]], cmap='gray')
#     current_slices.append(current_slice)

# # Create sliders and axes for each volume
# sliders = []
# slider_axes = []
# for i, ax in enumerate(axs.flat):
#     ax_slider = plt.axes([ax.get_position().x0, ax.get_position().y0 - 0.05, ax.get_position().width, 0.02])
#     slider = Slider(ax=ax_slider, label=f'Slice {i+1}', valmin=0, valmax=volumes[i].shape[2] - 1, valinit=initial_slices[i], valstep=1)
#     sliders.append(slider)
#     slider_axes.append(ax_slider)

# # Update the plots when the slider values change
# def update_slices():
#     for i, slider in enumerate(sliders):
#         current_slices[i].set_data(volumes[i][:, :, int(slider.val)])

#     fig.canvas.draw_idle()

# for slider in sliders:
#     slider.on_changed(lambda event: update_slices())

# # Animation function
# def animate(i):
#     # Increment the slice values for each volume
#     slice_vals = [(initial_slices[j] + i) % volumes[j].shape[2] for j in range(8)]

#     # Update the slider values
#     for j, slider in enumerate(sliders):
#         slider.set_val(slice_vals[j])

#     # Update the plots
#     update_slices()

# # Create the animation
# animation = FuncAnimation(fig, animate, frames=volumes[0].shape[2]*2, interval=200)

# # Set up plot settings
# plt.subplots_adjust(hspace=0.4, wspace=0.2, bottom=0.15)

# # Display the plot
# plt.show()

# %%
# %matplotlib widget

# volume = fixed_train_img_  # Replace this with your actual 3D volume data

# # Create a figure and axes for the plot
# fig, ax = plt.subplots()

# # Plot the initial slice
# initial_slice = 0
# current_slice = ax.imshow(volume[:, :, initial_slice], cmap='gray')

# # Create a slider for selecting the slice
# ax_slider = plt.axes([0.2, 0.03, 0.6, 0.05])
# slider = Slider(ax=ax_slider, label='Slice', valmin=0, valmax=volume.shape[2] - 1, valinit=initial_slice, valstep=1)

# # Update the plot when the slider value changes
# def update_slice(val):
#     current_slice.set_data(volume[:, :, int(val)])
#     fig.canvas.draw_idle()

# slider.on_changed(update_slice)

# # Set up plot settings
# plt.subplots_adjust(hspace=0.4, wspace=0.2, bottom=0.15)

# # Display the plot
# plt.show()

# %%
plt.figure("check", (10, 5))
train_slice_no = 18
val_slice_no = 18

plt.subplot(2, 4, 1)
plt.title("fixed_train_img_\n Slice: "+str(train_slice_no))
plt.imshow(fixed_train_img_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 2)
plt.title("fixed_train_msk_\n Slice: "+str(train_slice_no))
plt.imshow(fixed_train_msk_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 3)
plt.title("moving_train_img_\n Slice: "+str(train_slice_no))
plt.imshow(moving_train_img_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 4)
plt.title("moving_train_msk_\n Slice: "+str(train_slice_no))
plt.imshow(moving_train_msk_[:,:,train_slice_no], cmap="gray")
plt.axis('off')


plt.subplot(2, 4, 5)
plt.title("fixed_val_img_\n Slice: "+str(val_slice_no))
plt.imshow(fixed_val_img_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 6)
plt.title("fixed_val_msk_\n Slice: "+str(val_slice_no))
plt.imshow(fixed_val_msk_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 7)
plt.title("moving_val_img_\n Slice: "+str(val_slice_no))
plt.imshow(moving_val_img_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 8)
plt.title("moving_val_msk_\n Slice: "+str(val_slice_no))
plt.imshow(moving_val_msk_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.show()

# %%
mod = RegUNet(
    spatial_dims=3,
    in_channels=2,
    num_channel_initial=32,
    depth = 3,
    extract_levels=[3],
    out_activation=None,
    out_channels=3,
    out_kernel_initializer="zeros",
    concat_skip=False)

        

inputs = torch.randn((1, 2, img_size, img_size, slice_size))

y = mod(inputs)
print(y.shape)

import torch, torchinfo
# from torchviz import make_dot, make_dot_from_trace
    
# make_dot(y, params=dict(mod.named_parameters()),
#          show_attrs=False,
#          show_saved=False).render(fileNames, format="png")

torchinfo.summary(mod, input_size=(1, 2, img_size, img_size, slice_size), depth=10)
# Out:
# torch.Size([1, 3, 256, 256, 32])
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# RegUNet                                            [1, 3, 256, 256, 32]      --
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─Sequential: 2-1                             [1, 32, 256, 256, 32]     --
# │    │    └─Convolution: 3-1                       [1, 32, 256, 256, 32]     --
# │    │    │    └─Conv3d: 4-1                       [1, 32, 256, 256, 32]     1,728
# │    │    │    └─ADN: 4-2                          [1, 32, 256, 256, 32]     --
# │    │    │    │    └─BatchNorm3d: 5-1             [1, 32, 256, 256, 32]     64
# │    │    │    │    └─ReLU: 5-2                    [1, 32, 256, 256, 32]     --
# │    │    └─RegistrationResidualConvBlock: 3-2     [1, 32, 256, 256, 32]     --
# │    │    │    └─ModuleList: 4-6                   --                        (recursive)
# │    │    │    │    └─Convolution: 5-3             [1, 32, 256, 256, 32]     --
# │    │    │    │    │    └─Conv3d: 6-1             [1, 32, 256, 256, 32]     27,648
# │    │    │    └─ModuleList: 4-7                   --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-4             [1, 32, 256, 256, 32]     64
# │    │    │    └─ModuleList: 4-8                   --                        --
# │    │    │    │    └─ReLU: 5-5                    [1, 32, 256, 256, 32]     --
# │    │    │    └─ModuleList: 4-6                   --                        (recursive)
# │    │    │    │    └─Convolution: 5-6             [1, 32, 256, 256, 32]     --
# │    │    │    │    │    └─Conv3d: 6-2             [1, 32, 256, 256, 32]     27,648
# │    │    │    └─ModuleList: 4-7                   --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-7             [1, 32, 256, 256, 32]     64
# │    │    │    └─ModuleList: 4-8                   --                        --
# │    │    │    │    └─ReLU: 5-8                    [1, 32, 256, 256, 32]     --
# ├─ModuleList: 1-6                                  --                        --
# │    └─RegistrationDownSampleBlock: 2-2            [1, 32, 128, 128, 16]     --
# │    │    └─MaxPool3d: 3-3                         [1, 32, 128, 128, 16]     --
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─Sequential: 2-3                             [1, 64, 128, 128, 16]     --
# │    │    └─Convolution: 3-4                       [1, 64, 128, 128, 16]     --
# │    │    │    └─Conv3d: 4-9                       [1, 64, 128, 128, 16]     55,296
# │    │    │    └─ADN: 4-10                         [1, 64, 128, 128, 16]     --
# │    │    │    │    └─BatchNorm3d: 5-9             [1, 64, 128, 128, 16]     128
# │    │    │    │    └─ReLU: 5-10                   [1, 64, 128, 128, 16]     --
# │    │    └─RegistrationResidualConvBlock: 3-5     [1, 64, 128, 128, 16]     --
# │    │    │    └─ModuleList: 4-14                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-11            [1, 64, 128, 128, 16]     --
# │    │    │    │    │    └─Conv3d: 6-3             [1, 64, 128, 128, 16]     110,592
# │    │    │    └─ModuleList: 4-15                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-12            [1, 64, 128, 128, 16]     128
# │    │    │    └─ModuleList: 4-16                  --                        --
# │    │    │    │    └─ReLU: 5-13                   [1, 64, 128, 128, 16]     --
# │    │    │    └─ModuleList: 4-14                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-14            [1, 64, 128, 128, 16]     --
# │    │    │    │    │    └─Conv3d: 6-4             [1, 64, 128, 128, 16]     110,592
# │    │    │    └─ModuleList: 4-15                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-15            [1, 64, 128, 128, 16]     128
# │    │    │    └─ModuleList: 4-16                  --                        --
# │    │    │    │    └─ReLU: 5-16                   [1, 64, 128, 128, 16]     --
# ├─ModuleList: 1-6                                  --                        --
# │    └─RegistrationDownSampleBlock: 2-4            [1, 64, 64, 64, 8]        --
# │    │    └─MaxPool3d: 3-6                         [1, 64, 64, 64, 8]        --
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─Sequential: 2-5                             [1, 128, 64, 64, 8]       --
# │    │    └─Convolution: 3-7                       [1, 128, 64, 64, 8]       --
# │    │    │    └─Conv3d: 4-17                      [1, 128, 64, 64, 8]       221,184
# │    │    │    └─ADN: 4-18                         [1, 128, 64, 64, 8]       --
# │    │    │    │    └─BatchNorm3d: 5-17            [1, 128, 64, 64, 8]       256
# │    │    │    │    └─ReLU: 5-18                   [1, 128, 64, 64, 8]       --
# │    │    └─RegistrationResidualConvBlock: 3-8     [1, 128, 64, 64, 8]       --
# │    │    │    └─ModuleList: 4-22                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-19            [1, 128, 64, 64, 8]       --
# │    │    │    │    │    └─Conv3d: 6-5             [1, 128, 64, 64, 8]       442,368
# │    │    │    └─ModuleList: 4-23                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-20            [1, 128, 64, 64, 8]       256
# │    │    │    └─ModuleList: 4-24                  --                        --
# │    │    │    │    └─ReLU: 5-21                   [1, 128, 64, 64, 8]       --
# │    │    │    └─ModuleList: 4-22                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-22            [1, 128, 64, 64, 8]       --
# │    │    │    │    │    └─Conv3d: 6-6             [1, 128, 64, 64, 8]       442,368
# │    │    │    └─ModuleList: 4-23                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-23            [1, 128, 64, 64, 8]       256
# │    │    │    └─ModuleList: 4-24                  --                        --
# │    │    │    │    └─ReLU: 5-24                   [1, 128, 64, 64, 8]       --
# ├─ModuleList: 1-6                                  --                        --
# │    └─RegistrationDownSampleBlock: 2-6            [1, 128, 32, 32, 4]       --
# │    │    └─MaxPool3d: 3-9                         [1, 128, 32, 32, 4]       --
# ├─Sequential: 1-7                                  [1, 256, 32, 32, 4]       --
# │    └─Convolution: 2-7                            [1, 256, 32, 32, 4]       --
# │    │    └─Conv3d: 3-10                           [1, 256, 32, 32, 4]       884,736
# │    │    └─ADN: 3-11                              [1, 256, 32, 32, 4]       --
# │    │    │    └─BatchNorm3d: 4-25                 [1, 256, 32, 32, 4]       512
# │    │    │    └─ReLU: 4-26                        [1, 256, 32, 32, 4]       --
# │    └─RegistrationResidualConvBlock: 2-8          [1, 256, 32, 32, 4]       --
# │    │    └─ModuleList: 3-15                       --                        (recursive)
# │    │    │    └─Convolution: 4-27                 [1, 256, 32, 32, 4]       --
# │    │    │    │    └─Conv3d: 5-25                 [1, 256, 32, 32, 4]       1,769,472
# │    │    └─ModuleList: 3-16                       --                        (recursive)
# │    │    │    └─BatchNorm3d: 4-28                 [1, 256, 32, 32, 4]       512
# │    │    └─ModuleList: 3-17                       --                        --
# │    │    │    └─ReLU: 4-29                        [1, 256, 32, 32, 4]       --
# │    │    └─ModuleList: 3-15                       --                        (recursive)
# │    │    │    └─Convolution: 4-30                 [1, 256, 32, 32, 4]       --
# │    │    │    │    └─Conv3d: 5-26                 [1, 256, 32, 32, 4]       1,769,472
# │    │    └─ModuleList: 3-16                       --                        (recursive)
# │    │    │    └─BatchNorm3d: 4-31                 [1, 256, 32, 32, 4]       512
# │    │    └─ModuleList: 3-17                       --                        --
# │    │    │    └─ReLU: 4-32                        [1, 256, 32, 32, 4]       --
# ├─RegistrationExtractionBlock: 1-8                 [1, 3, 256, 256, 32]      --
# │    └─ModuleList: 2-9                             --                        --
# │    │    └─Convolution: 3-18                      [1, 3, 32, 32, 4]         --
# │    │    │    └─Conv3d: 4-33                      [1, 3, 32, 32, 4]         20,736
# ====================================================================================================
# Total params: 5,886,720
# Trainable params: 5,886,720
# Non-trainable params: 0
# Total mult-adds (G): 246.51
# ====================================================================================================
# Input size (MB): 16.78
# Forward/backward pass size (MB): 4278.29
# Params size (MB): 23.55
# Estimated Total Size (MB): 4318.61
# ====================================================================================================

# %%
model = mod.to(device)

if preTrained:
    model.load_state_dict(torch.load(os.path.join(root_dir, ExpName + '_' + dataDir + '_' +str(previousWeight) + '_'+'.pth')))


warp_layer = Warp().to(device)

# image_loss = MSELoss()

image_loss = GlobalMutualInformationLoss()

# class SSIMLoss(SSIM):
#     def forward(self, x, y):
#         return 1. - super().forward(x, y)
    

# label_SSIM = SSIMLoss(n_channels=1).to(device) # .cuda() if you need GPU support

label_loss = DiceLoss()

# label_loss = MultiScaleLoss(label_loss, scales=[0, 1, 2, 4, 8, 16])

regularization = BendingEnergyLoss()

optimizer = torch.optim.Adam(model.parameters(), 0.0002)

# exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.5, verbose=True)

dice_metric = DiceMetric(include_background=True, reduction="mean", get_not_nans=False)

# dice_metric = compute_meandice(y_pred, y, include_background=True)
# Out:
# monai.networks.blocks.Warp: Using PyTorch native grid_sample.

# %%
def make_one_hot(labels, C=2):
    '''
    Converts an integer label torch.Tensor to a one-hot Tensor.
    
    Parameters
    ----------
    labels : torch.Tensor
        N x 1 x D x H x W, where N is batch size. 
        Each value is an integer representing correct classification.
    C : integer
        Number of classes in labels.
    
    Returns
    -------
    target : torch.Tensor
        N x C x D x H x W, where C is class number. One-hot encoded.
    '''
    labels = labels.long()
    one_hot = torch.zeros(labels.size(0), C, labels.size(2), labels.size(3), labels.size(4)).to(device)
    labels = labels.squeeze(1)
    target = one_hot.scatter_(1, labels.unsqueeze(1), 1)
        
    return target

# %%
max_epochs = EP
epoch_loss_values = []
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
epoch_val_loss_values = []
epoch_loss_d_values = []
epoch_loss_g_values = []
metric_values = []
best_loss = 1e10
best_dsc = 0
k=1


for epoch in range(max_epochs):
    print("-" * 100)
    print(f"Epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss, step = 0, 0

    epoch_DSC, epoch_L2, epoch_MI, epoch_ddf = 0, 0, 0, 0

    epoch_loss_d, epoch_loss_g=0,0
    
    for fixed_train_img_, fixed_train_msk_, moving_train_img_, moving_train_msk_ in zip(fixed_train_img,
                                                                                    fixed_train_msk, moving_train_img,
                                                                                    moving_train_msk):    
        step += 1
        
        optimizer.zero_grad()
        # optim_d.zero_grad()

        fixed_train_img_ = fixed_train_img_.to(device)
        fixed_train_msk_ = fixed_train_msk_.to(device)
        moving_train_img_ = moving_train_img_.to(device)
        moving_train_msk_ = moving_train_msk_.to(device)
        
        ddf_train = model(torch.cat((moving_train_img_, fixed_train_img_), dim=1))
        
        pred_image_train = warp_layer(moving_train_img_, ddf_train)
        pred_mask_train = warp_layer(moving_train_msk_, ddf_train)

        # real_label = label_real(fixed_train_img_.size(0))
        # fake_label = label_fake(fixed_train_img_.size(0))


        # output_real = discriminator(fixed_train_img_)
        # loss_real = criterion(output_real, real_label)
        # loss_real.backward()

        # output_fake = discriminator(pred_image_train.detach())
        # loss_fake = criterion(output_fake, fake_label)
        # loss_fake.backward()

        # optim_d.step()

        # loss_d = (loss_real + loss_fake)/2

        # epoch_loss_d += loss_d.item()

        # output = discriminator(pred_image_train)
        
        # loss_g = criterion(output, real_label)

        imageLOSS = image_loss(pred_image_train, fixed_train_img_)
        
        labelDSC = label_loss(fixed_train_msk_, pred_mask_train)

        # labelDSC = label_loss(make_one_hot(pred_mask_train, C=3), make_one_hot(fixed_train_msk_, C=3))

        # labelGlobal =  globalLoss(fixed_train_msk_, pred_mask_train)-1
        
        regLOSS  = regularization(ddf_train)

        loss = imageLOSS 
    
        # loss_g.backward(retain_graph=True)
        loss.backward()

        optimizer.step()
        
        epoch_loss += loss.item()

        # epoch_loss_g += loss_g.item()
        epoch_DSC += labelDSC.item()
        # epoch_L2 += labelGlobal.item()
        epoch_MI += imageLOSS.item()
        epoch_ddf += regLOSS.item()


        
        dice_metric(y_pred = make_one_hot(pred_mask_train, C=3), y=make_one_hot(fixed_train_msk_, C=3))

    # exp_lr_scheduler.step()
    for param_group in optimizer.param_groups:
        print("LR is == ", param_group['lr'])


    metric = dice_metric.aggregate().item()
    dice_metric.reset()
    epoch_loss /= step

    # epoch_loss_g /=step
    # epoch_loss_d /= step

    epoch_DSC /= step
    # epoch_L2 /= step
    epoch_MI /= step
    epoch_ddf /= step

    epoch_loss_values.append(epoch_loss)
    # epoch_loss_d_values.append(epoch_loss_d)
    # epoch_loss_g_values.append(epoch_loss_g)

    print(f"For epoch: {epoch + 1}, Average train loss: {epoch_loss:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train DSC: {metric:.5f} !\n")

    print(f"For epoch: {epoch + 1}, Average train DSC: {epoch_DSC:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train L2: {epoch_L2:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train MI: {epoch_MI:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train DDF: {epoch_ddf:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train D Loss: {epoch_loss_d:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train G Loss: {epoch_loss_g:.5f} !")
    
    print("-" * 60)
    if (epoch + 1) % val_interval == 0 or epoch == 0:
        model.eval()
        val_loss = 0
        val_met = 0
        step = 0
        with torch.no_grad():
            for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk):  

                fixed_val_img_ = fixed_val_img_.to(device)
                fixed_val_msk_ = fixed_val_msk_.to(device)
                
                moving_val_img_ = moving_val_img_.to(device)
                moving_val_msk_ = moving_val_msk_.to(device)
                
                
                ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))
                
                pred_image_val = warp_layer(moving_val_img_, ddf_val)
                pred_mask_val = warp_layer(moving_val_msk_, ddf_val)

                # real_label = label_real(pred_image_val.size(0))
        
                # output = discriminator(pred_image_val)
        
                # loss_g = criterion(output, real_label)

                imageLOSS = image_loss(pred_image_val, fixed_val_img_)

                labelDSC = label_loss(fixed_val_msk_, pred_mask_val)

                # labelDSC = label_loss(make_one_hot(pred_mask_val, C=3), make_one_hot(fixed_val_msk_, C=3))

                # labelGlobal =  globalLoss(fixed_val_msk_, pred_mask_val)-1

                regLOSS  = regularization(ddf_val)


                loss = imageLOSS
                
                
    
                val_loss += loss.item()
                step += 1

                
                dice_metric(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))
                

            val_loss /= step
            epoch_val_loss_values.append(val_loss)
            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            dice_metric.reset()
            
            if metric > best_dsc:
                best_loss_epoch = epoch + 1
                torch.save(model.state_dict(),
                           os.path.join(root_dir, fileNames+'.pth'))
                print(f"Valid DSC improved from {best_dsc:2.4f} to {metric:2.4f}! Best model is saving as---> {fileNames+'.pth'}")
                best_dsc = metric
                
            print(
                f"\nCurrent mean dice: {metric:.4f} "
                f"\t and \t Current val loss: {val_loss:.4f}\n\n"
                f"Best val DSC: {best_dsc:.4f} "
                f"at epoch number of {best_loss_epoch}")
# Out:
# ----------------------------------------------------------------------------------------------------
# Epoch 1/200
# LR is ==  0.0002
# For epoch: 1, Average train loss: -0.65432 !
# For epoch: 1, Average train DSC: 0.75657 !
#
# For epoch: 1, Average train DSC: -0.42394 !
# For epoch: 1, Average train MI: -0.65432 !
# For epoch: 1, Average train DDF: 0.00277 !
# ------------------------------------------------------------
# Valid DSC improved from 0.0000 to 0.6567! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.6567 	 and 	 Current val loss: -0.5090
#
# Best val DSC: 0.6567 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 2/200
# LR is ==  0.0002
# For epoch: 2, Average train loss: -0.68072 !
# For epoch: 2, Average train DSC: 0.76844 !
#
# For epoch: 2, Average train DSC: -0.44924 !
# For epoch: 2, Average train MI: -0.68072 !
# For epoch: 2, Average train DDF: 0.00305 !
# ------------------------------------------------------------
# Valid DSC improved from 0.6567 to 0.6831! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.6831 	 and 	 Current val loss: -0.6296
#
# Best val DSC: 0.6831 at epoch number of 2
# ----------------------------------------------------------------------------------------------------
# Epoch 3/200
# LR is ==  0.0002
# For epoch: 3, Average train loss: -0.69149 !
# For epoch: 3, Average train DSC: 0.75698 !
#
# For epoch: 3, Average train DSC: -0.44875 !
# For epoch: 3, Average train MI: -0.69149 !
# For epoch: 3, Average train DDF: 0.00341 !
# ------------------------------------------------------------
# Valid DSC improved from 0.6831 to 0.7210! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7210 	 and 	 Current val loss: -0.8259
#
# Best val DSC: 0.7210 at epoch number of 3
# ----------------------------------------------------------------------------------------------------
# Epoch 4/200
# LR is ==  0.0002
# For epoch: 4, Average train loss: -0.69312 !
# For epoch: 4, Average train DSC: 0.76410 !
#
# For epoch: 4, Average train DSC: -0.44782 !
# For epoch: 4, Average train MI: -0.69312 !
# For epoch: 4, Average train DDF: 0.00609 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7210 to 0.7279! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7279 	 and 	 Current val loss: -0.8186
#
# Best val DSC: 0.7279 at epoch number of 4
# ----------------------------------------------------------------------------------------------------
# Epoch 5/200
# LR is ==  0.0002
# For epoch: 5, Average train loss: -0.69963 !
# For epoch: 5, Average train DSC: 0.77658 !
#
# For epoch: 5, Average train DSC: -0.45304 !
# For epoch: 5, Average train MI: -0.69963 !
# For epoch: 5, Average train DDF: 0.01182 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7252 	 and 	 Current val loss: -0.8219
#
# Best val DSC: 0.7279 at epoch number of 4
# ----------------------------------------------------------------------------------------------------
# Epoch 6/200
# LR is ==  0.0002
# For epoch: 6, Average train loss: -0.70552 !
# For epoch: 6, Average train DSC: 0.77086 !
#
# For epoch: 6, Average train DSC: -0.43621 !
# For epoch: 6, Average train MI: -0.70552 !
# For epoch: 6, Average train DDF: 0.03879 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7279 to 0.7421! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7421 	 and 	 Current val loss: -0.8316
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 7/200
# LR is ==  0.0002
# For epoch: 7, Average train loss: -0.71343 !
# For epoch: 7, Average train DSC: 0.77491 !
#
# For epoch: 7, Average train DSC: -0.45440 !
# For epoch: 7, Average train MI: -0.71343 !
# For epoch: 7, Average train DDF: 0.04062 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7172 	 and 	 Current val loss: -0.8157
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 8/200
# LR is ==  0.0002
# For epoch: 8, Average train loss: -0.71621 !
# For epoch: 8, Average train DSC: 0.77346 !
#
# For epoch: 8, Average train DSC: -0.44667 !
# For epoch: 8, Average train MI: -0.71621 !
# For epoch: 8, Average train DDF: 0.09068 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7306 	 and 	 Current val loss: -0.8226
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 9/200
# LR is ==  0.0002
# For epoch: 9, Average train loss: -0.71992 !
# For epoch: 9, Average train DSC: 0.77512 !
#
# For epoch: 9, Average train DSC: -0.44752 !
# For epoch: 9, Average train MI: -0.71992 !
# For epoch: 9, Average train DDF: 0.07203 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7210 	 and 	 Current val loss: -0.8424
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 10/200
# LR is ==  0.0002
# For epoch: 10, Average train loss: -0.72895 !
# For epoch: 10, Average train DSC: 0.77316 !
#
# For epoch: 10, Average train DSC: -0.44431 !
# For epoch: 10, Average train MI: -0.72895 !
# For epoch: 10, Average train DDF: 0.07524 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7232 	 and 	 Current val loss: -0.8395
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 11/200
# LR is ==  0.0002
# For epoch: 11, Average train loss: -0.73302 !
# For epoch: 11, Average train DSC: 0.77915 !
#
# For epoch: 11, Average train DSC: -0.44405 !
# For epoch: 11, Average train MI: -0.73302 !
# For epoch: 11, Average train DDF: 0.09353 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7321 	 and 	 Current val loss: -0.8452
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 12/200
# LR is ==  0.0002
# For epoch: 12, Average train loss: -0.73821 !
# For epoch: 12, Average train DSC: 0.77342 !
#
# For epoch: 12, Average train DSC: -0.45347 !
# For epoch: 12, Average train MI: -0.73821 !
# For epoch: 12, Average train DDF: 0.09512 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7260 	 and 	 Current val loss: -0.8372
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 13/200
# LR is ==  0.0002
# For epoch: 13, Average train loss: -0.74392 !
# For epoch: 13, Average train DSC: 0.77896 !
#
# For epoch: 13, Average train DSC: -0.44849 !
# For epoch: 13, Average train MI: -0.74392 !
# For epoch: 13, Average train DDF: 0.12276 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7341 	 and 	 Current val loss: -0.8412
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 14/200
# LR is ==  0.0002
# For epoch: 14, Average train loss: -0.74942 !
# For epoch: 14, Average train DSC: 0.77823 !
#
# For epoch: 14, Average train DSC: -0.45334 !
# For epoch: 14, Average train MI: -0.74942 !
# For epoch: 14, Average train DDF: 0.12511 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7320 	 and 	 Current val loss: -0.8382
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 15/200
# LR is ==  0.0002
# For epoch: 15, Average train loss: -0.75892 !
# For epoch: 15, Average train DSC: 0.78295 !
#
# For epoch: 15, Average train DSC: -0.45724 !
# For epoch: 15, Average train MI: -0.75892 !
# For epoch: 15, Average train DDF: 0.13076 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7291 	 and 	 Current val loss: -0.8189
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 16/200
# LR is ==  0.0002
# For epoch: 16, Average train loss: -0.76173 !
# For epoch: 16, Average train DSC: 0.78001 !
#
# For epoch: 16, Average train DSC: -0.45436 !
# For epoch: 16, Average train MI: -0.76173 !
# For epoch: 16, Average train DDF: 0.13849 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7194 	 and 	 Current val loss: -0.7973
#
# Best val DSC: 0.7421 at epoch number of 6
# ----------------------------------------------------------------------------------------------------
# Epoch 17/200
# LR is ==  0.0002
# For epoch: 17, Average train loss: -0.75943 !
# For epoch: 17, Average train DSC: 0.77869 !
#
# For epoch: 17, Average train DSC: -0.44723 !
# For epoch: 17, Average train MI: -0.75943 !
# For epoch: 17, Average train DDF: 0.17544 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7421 to 0.7434! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7434 	 and 	 Current val loss: -0.8420
#
# Best val DSC: 0.7434 at epoch number of 17
# ----------------------------------------------------------------------------------------------------
# Epoch 18/200
# LR is ==  0.0002
# For epoch: 18, Average train loss: -0.76669 !
# For epoch: 18, Average train DSC: 0.77513 !
#
# For epoch: 18, Average train DSC: -0.44641 !
# For epoch: 18, Average train MI: -0.76669 !
# For epoch: 18, Average train DDF: 0.15591 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7409 	 and 	 Current val loss: -0.8503
#
# Best val DSC: 0.7434 at epoch number of 17
# ----------------------------------------------------------------------------------------------------
# Epoch 19/200
# LR is ==  0.0002
# For epoch: 19, Average train loss: -0.77354 !
# For epoch: 19, Average train DSC: 0.78315 !
#
# For epoch: 19, Average train DSC: -0.45617 !
# For epoch: 19, Average train MI: -0.77354 !
# For epoch: 19, Average train DDF: 0.15118 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7190 	 and 	 Current val loss: -0.7467
#
# Best val DSC: 0.7434 at epoch number of 17
# ----------------------------------------------------------------------------------------------------
# Epoch 20/200
# LR is ==  0.0002
# For epoch: 20, Average train loss: -0.76906 !
# For epoch: 20, Average train DSC: 0.78278 !
#
# For epoch: 20, Average train DSC: -0.46372 !
# For epoch: 20, Average train MI: -0.76906 !
# For epoch: 20, Average train DDF: 0.19269 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7394 	 and 	 Current val loss: -0.8462
#
# Best val DSC: 0.7434 at epoch number of 17
# ----------------------------------------------------------------------------------------------------
# Epoch 21/200
# LR is ==  0.0002
# For epoch: 21, Average train loss: -0.77484 !
# For epoch: 21, Average train DSC: 0.77853 !
#
# For epoch: 21, Average train DSC: -0.45172 !
# For epoch: 21, Average train MI: -0.77484 !
# For epoch: 21, Average train DDF: 0.17510 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7327 	 and 	 Current val loss: -0.8202
#
# Best val DSC: 0.7434 at epoch number of 17
# ----------------------------------------------------------------------------------------------------
# Epoch 22/200
# LR is ==  0.0002
# For epoch: 22, Average train loss: -0.77731 !
# For epoch: 22, Average train DSC: 0.78140 !
#
# For epoch: 22, Average train DSC: -0.45821 !
# For epoch: 22, Average train MI: -0.77731 !
# For epoch: 22, Average train DDF: 0.18336 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7355 	 and 	 Current val loss: -0.8405
#
# Best val DSC: 0.7434 at epoch number of 17
# ----------------------------------------------------------------------------------------------------
# Epoch 23/200
# LR is ==  0.0002
# For epoch: 23, Average train loss: -0.78091 !
# For epoch: 23, Average train DSC: 0.78464 !
#
# For epoch: 23, Average train DSC: -0.45764 !
# For epoch: 23, Average train MI: -0.78091 !
# For epoch: 23, Average train DDF: 0.19002 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7385 	 and 	 Current val loss: -0.8652
#
# Best val DSC: 0.7434 at epoch number of 17
# ----------------------------------------------------------------------------------------------------
# Epoch 24/200
# LR is ==  0.0002
# For epoch: 24, Average train loss: -0.78640 !
# For epoch: 24, Average train DSC: 0.78551 !
#
# For epoch: 24, Average train DSC: -0.45826 !
# For epoch: 24, Average train MI: -0.78640 !
# For epoch: 24, Average train DDF: 0.16567 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7434 to 0.7436! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7436 	 and 	 Current val loss: -0.8489
#
# Best val DSC: 0.7436 at epoch number of 24
# ----------------------------------------------------------------------------------------------------
# Epoch 25/200
# LR is ==  0.0002
# For epoch: 25, Average train loss: -0.78554 !
# For epoch: 25, Average train DSC: 0.77623 !
#
# For epoch: 25, Average train DSC: -0.44714 !
# For epoch: 25, Average train MI: -0.78554 !
# For epoch: 25, Average train DDF: 0.23230 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7436 to 0.7442! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7442 	 and 	 Current val loss: -0.8669
#
# Best val DSC: 0.7442 at epoch number of 25
# ----------------------------------------------------------------------------------------------------
# Epoch 26/200
# LR is ==  0.0002
# For epoch: 26, Average train loss: -0.78812 !
# For epoch: 26, Average train DSC: 0.77863 !
#
# For epoch: 26, Average train DSC: -0.45884 !
# For epoch: 26, Average train MI: -0.78812 !
# For epoch: 26, Average train DDF: 0.19545 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7195 	 and 	 Current val loss: -0.8005
#
# Best val DSC: 0.7442 at epoch number of 25
# ----------------------------------------------------------------------------------------------------
# Epoch 27/200
# LR is ==  0.0002
# For epoch: 27, Average train loss: -0.78808 !
# For epoch: 27, Average train DSC: 0.77877 !
#
# For epoch: 27, Average train DSC: -0.44961 !
# For epoch: 27, Average train MI: -0.78808 !
# For epoch: 27, Average train DDF: 0.21462 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7442 to 0.7468! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7468 	 and 	 Current val loss: -0.8739
#
# Best val DSC: 0.7468 at epoch number of 27
# ----------------------------------------------------------------------------------------------------
# Epoch 28/200
# LR is ==  0.0002
# For epoch: 28, Average train loss: -0.78920 !
# For epoch: 28, Average train DSC: 0.78004 !
#
# For epoch: 28, Average train DSC: -0.45734 !
# For epoch: 28, Average train MI: -0.78920 !
# For epoch: 28, Average train DDF: 0.19578 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7459 	 and 	 Current val loss: -0.8735
#
# Best val DSC: 0.7468 at epoch number of 27
# ----------------------------------------------------------------------------------------------------
# Epoch 29/200
# LR is ==  0.0002
# For epoch: 29, Average train loss: -0.79548 !
# For epoch: 29, Average train DSC: 0.78390 !
#
# For epoch: 29, Average train DSC: -0.46482 !
# For epoch: 29, Average train MI: -0.79548 !
# For epoch: 29, Average train DDF: 0.22341 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7354 	 and 	 Current val loss: -0.7633
#
# Best val DSC: 0.7468 at epoch number of 27
# ----------------------------------------------------------------------------------------------------
# Epoch 30/200
# LR is ==  0.0002
# For epoch: 30, Average train loss: -0.79212 !
# For epoch: 30, Average train DSC: 0.78200 !
#
# For epoch: 30, Average train DSC: -0.46375 !
# For epoch: 30, Average train MI: -0.79212 !
# For epoch: 30, Average train DDF: 0.22313 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7365 	 and 	 Current val loss: -0.8670
#
# Best val DSC: 0.7468 at epoch number of 27
# ----------------------------------------------------------------------------------------------------
# Epoch 31/200
# LR is ==  0.0002
# For epoch: 31, Average train loss: -0.79832 !
# For epoch: 31, Average train DSC: 0.78642 !
#
# For epoch: 31, Average train DSC: -0.46406 !
# For epoch: 31, Average train MI: -0.79832 !
# For epoch: 31, Average train DDF: 0.21390 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7413 	 and 	 Current val loss: -0.8445
#
# Best val DSC: 0.7468 at epoch number of 27
# ----------------------------------------------------------------------------------------------------
# Epoch 32/200
# LR is ==  0.0002
# For epoch: 32, Average train loss: -0.80954 !
# For epoch: 32, Average train DSC: 0.78129 !
#
# For epoch: 32, Average train DSC: -0.46041 !
# For epoch: 32, Average train MI: -0.80954 !
# For epoch: 32, Average train DDF: 0.23546 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7423 	 and 	 Current val loss: -0.8839
#
# Best val DSC: 0.7468 at epoch number of 27
# ----------------------------------------------------------------------------------------------------
# Epoch 33/200
# LR is ==  0.0002
# For epoch: 33, Average train loss: -0.81629 !
# For epoch: 33, Average train DSC: 0.78856 !
#
# For epoch: 33, Average train DSC: -0.47621 !
# For epoch: 33, Average train MI: -0.81629 !
# For epoch: 33, Average train DDF: 0.22831 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7468 to 0.7515! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7515 	 and 	 Current val loss: -0.8949
#
# Best val DSC: 0.7515 at epoch number of 33
# ----------------------------------------------------------------------------------------------------
# Epoch 34/200
# LR is ==  0.0002
# For epoch: 34, Average train loss: -0.81872 !
# For epoch: 34, Average train DSC: 0.79087 !
#
# For epoch: 34, Average train DSC: -0.47896 !
# For epoch: 34, Average train MI: -0.81872 !
# For epoch: 34, Average train DDF: 0.24146 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7404 	 and 	 Current val loss: -0.8691
#
# Best val DSC: 0.7515 at epoch number of 33
# ----------------------------------------------------------------------------------------------------
# Epoch 35/200
# LR is ==  0.0002
# For epoch: 35, Average train loss: -0.81862 !
# For epoch: 35, Average train DSC: 0.78465 !
#
# For epoch: 35, Average train DSC: -0.47694 !
# For epoch: 35, Average train MI: -0.81862 !
# For epoch: 35, Average train DDF: 0.25051 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7428 	 and 	 Current val loss: -0.8722
#
# Best val DSC: 0.7515 at epoch number of 33
# ----------------------------------------------------------------------------------------------------
# Epoch 36/200
# LR is ==  0.0002
# For epoch: 36, Average train loss: -0.81537 !
# For epoch: 36, Average train DSC: 0.78499 !
#
# For epoch: 36, Average train DSC: -0.47638 !
# For epoch: 36, Average train MI: -0.81537 !
# For epoch: 36, Average train DDF: 0.26050 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7438 	 and 	 Current val loss: -0.8344
#
# Best val DSC: 0.7515 at epoch number of 33
# ----------------------------------------------------------------------------------------------------
# Epoch 37/200
# LR is ==  0.0002
# For epoch: 37, Average train loss: -0.81203 !
# For epoch: 37, Average train DSC: 0.78669 !
#
# For epoch: 37, Average train DSC: -0.47497 !
# For epoch: 37, Average train MI: -0.81203 !
# For epoch: 37, Average train DDF: 0.25045 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7472 	 and 	 Current val loss: -0.8777
#
# Best val DSC: 0.7515 at epoch number of 33
# ----------------------------------------------------------------------------------------------------
# Epoch 38/200
# LR is ==  0.0002
# For epoch: 38, Average train loss: -0.81827 !
# For epoch: 38, Average train DSC: 0.78371 !
#
# For epoch: 38, Average train DSC: -0.46491 !
# For epoch: 38, Average train MI: -0.81827 !
# For epoch: 38, Average train DDF: 0.25763 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7310 	 and 	 Current val loss: -0.8618
#
# Best val DSC: 0.7515 at epoch number of 33
# ----------------------------------------------------------------------------------------------------
# Epoch 39/200
# LR is ==  0.0002
# For epoch: 39, Average train loss: -0.82717 !
# For epoch: 39, Average train DSC: 0.78447 !
#
# For epoch: 39, Average train DSC: -0.46737 !
# For epoch: 39, Average train MI: -0.82717 !
# For epoch: 39, Average train DDF: 0.27031 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7515 to 0.7519! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7519 	 and 	 Current val loss: -0.8791
#
# Best val DSC: 0.7519 at epoch number of 39
# ----------------------------------------------------------------------------------------------------
# Epoch 40/200
# LR is ==  0.0002
# For epoch: 40, Average train loss: -0.82795 !
# For epoch: 40, Average train DSC: 0.78876 !
#
# For epoch: 40, Average train DSC: -0.48540 !
# For epoch: 40, Average train MI: -0.82795 !
# For epoch: 40, Average train DDF: 0.28899 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7429 	 and 	 Current val loss: -0.8890
#
# Best val DSC: 0.7519 at epoch number of 39
# ----------------------------------------------------------------------------------------------------
# Epoch 41/200
# LR is ==  0.0002
# For epoch: 41, Average train loss: -0.83158 !
# For epoch: 41, Average train DSC: 0.79033 !
#
# For epoch: 41, Average train DSC: -0.47638 !
# For epoch: 41, Average train MI: -0.83158 !
# For epoch: 41, Average train DDF: 0.28952 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7425 	 and 	 Current val loss: -0.8504
#
# Best val DSC: 0.7519 at epoch number of 39
# ----------------------------------------------------------------------------------------------------
# Epoch 42/200
# LR is ==  0.0002
# For epoch: 42, Average train loss: -0.83209 !
# For epoch: 42, Average train DSC: 0.78441 !
#
# For epoch: 42, Average train DSC: -0.47947 !
# For epoch: 42, Average train MI: -0.83209 !
# For epoch: 42, Average train DDF: 0.29260 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7385 	 and 	 Current val loss: -0.8822
#
# Best val DSC: 0.7519 at epoch number of 39
# ----------------------------------------------------------------------------------------------------
# Epoch 43/200
# LR is ==  0.0002
# For epoch: 43, Average train loss: -0.83112 !
# For epoch: 43, Average train DSC: 0.78582 !
#
# For epoch: 43, Average train DSC: -0.47404 !
# For epoch: 43, Average train MI: -0.83112 !
# For epoch: 43, Average train DDF: 0.30378 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7519 to 0.7521! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7521 	 and 	 Current val loss: -0.8887
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 44/200
# LR is ==  0.0002
# For epoch: 44, Average train loss: -0.83034 !
# For epoch: 44, Average train DSC: 0.78650 !
#
# For epoch: 44, Average train DSC: -0.47415 !
# For epoch: 44, Average train MI: -0.83034 !
# For epoch: 44, Average train DDF: 0.30414 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7344 	 and 	 Current val loss: -0.8786
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 45/200
# LR is ==  0.0002
# For epoch: 45, Average train loss: -0.83518 !
# For epoch: 45, Average train DSC: 0.78530 !
#
# For epoch: 45, Average train DSC: -0.47198 !
# For epoch: 45, Average train MI: -0.83518 !
# For epoch: 45, Average train DDF: 0.31609 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7454 	 and 	 Current val loss: -0.8946
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 46/200
# LR is ==  0.0002
# For epoch: 46, Average train loss: -0.83996 !
# For epoch: 46, Average train DSC: 0.78958 !
#
# For epoch: 46, Average train DSC: -0.47940 !
# For epoch: 46, Average train MI: -0.83996 !
# For epoch: 46, Average train DDF: 0.30271 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7404 	 and 	 Current val loss: -0.8573
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 47/200
# LR is ==  0.0002
# For epoch: 47, Average train loss: -0.83770 !
# For epoch: 47, Average train DSC: 0.79046 !
#
# For epoch: 47, Average train DSC: -0.48404 !
# For epoch: 47, Average train MI: -0.83770 !
# For epoch: 47, Average train DDF: 0.31905 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7443 	 and 	 Current val loss: -0.8978
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 48/200
# LR is ==  0.0002
# For epoch: 48, Average train loss: -0.83852 !
# For epoch: 48, Average train DSC: 0.78697 !
#
# For epoch: 48, Average train DSC: -0.47603 !
# For epoch: 48, Average train MI: -0.83852 !
# For epoch: 48, Average train DDF: 0.33742 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7428 	 and 	 Current val loss: -0.8744
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 49/200
# LR is ==  0.0002
# For epoch: 49, Average train loss: -0.85094 !
# For epoch: 49, Average train DSC: 0.78609 !
#
# For epoch: 49, Average train DSC: -0.47011 !
# For epoch: 49, Average train MI: -0.85094 !
# For epoch: 49, Average train DDF: 0.32992 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7409 	 and 	 Current val loss: -0.8864
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 50/200
# LR is ==  0.0002
# For epoch: 50, Average train loss: -0.85202 !
# For epoch: 50, Average train DSC: 0.79167 !
#
# For epoch: 50, Average train DSC: -0.48425 !
# For epoch: 50, Average train MI: -0.85202 !
# For epoch: 50, Average train DDF: 0.36923 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7422 	 and 	 Current val loss: -0.8983
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 51/200
# LR is ==  0.0002
# For epoch: 51, Average train loss: -0.85204 !
# For epoch: 51, Average train DSC: 0.78870 !
#
# For epoch: 51, Average train DSC: -0.48224 !
# For epoch: 51, Average train MI: -0.85204 !
# For epoch: 51, Average train DDF: 0.33661 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7479 	 and 	 Current val loss: -0.8737
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 52/200
# LR is ==  0.0002
# For epoch: 52, Average train loss: -0.84929 !
# For epoch: 52, Average train DSC: 0.79326 !
#
# For epoch: 52, Average train DSC: -0.48531 !
# For epoch: 52, Average train MI: -0.84929 !
# For epoch: 52, Average train DDF: 0.35044 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7353 	 and 	 Current val loss: -0.8802
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 53/200
# LR is ==  0.0002
# For epoch: 53, Average train loss: -0.84613 !
# For epoch: 53, Average train DSC: 0.78826 !
#
# For epoch: 53, Average train DSC: -0.47654 !
# For epoch: 53, Average train MI: -0.84613 !
# For epoch: 53, Average train DDF: 0.37851 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7493 	 and 	 Current val loss: -0.8889
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 54/200
# LR is ==  0.0002
# For epoch: 54, Average train loss: -0.84494 !
# For epoch: 54, Average train DSC: 0.78651 !
#
# For epoch: 54, Average train DSC: -0.46998 !
# For epoch: 54, Average train MI: -0.84494 !
# For epoch: 54, Average train DDF: 0.33644 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7430 	 and 	 Current val loss: -0.8938
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 55/200
# LR is ==  0.0002
# For epoch: 55, Average train loss: -0.85103 !
# For epoch: 55, Average train DSC: 0.78463 !
#
# For epoch: 55, Average train DSC: -0.47195 !
# For epoch: 55, Average train MI: -0.85103 !
# For epoch: 55, Average train DDF: 0.36865 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7489 	 and 	 Current val loss: -0.9037
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 56/200
# LR is ==  0.0002
# For epoch: 56, Average train loss: -0.85454 !
# For epoch: 56, Average train DSC: 0.78765 !
#
# For epoch: 56, Average train DSC: -0.47708 !
# For epoch: 56, Average train MI: -0.85454 !
# For epoch: 56, Average train DDF: 0.39785 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7420 	 and 	 Current val loss: -0.8886
#
# Best val DSC: 0.7521 at epoch number of 43
# ----------------------------------------------------------------------------------------------------
# Epoch 57/200
# LR is ==  0.0002
# For epoch: 57, Average train loss: -0.85763 !
# For epoch: 57, Average train DSC: 0.78964 !
#
# For epoch: 57, Average train DSC: -0.48476 !
# For epoch: 57, Average train MI: -0.85763 !
# For epoch: 57, Average train DDF: 0.39518 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7521 to 0.7578! Best model is saving as---> Vanilla_DLIR_v3_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7578 	 and 	 Current val loss: -0.8710
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 58/200
# LR is ==  0.0002
# For epoch: 58, Average train loss: -0.85610 !
# For epoch: 58, Average train DSC: 0.79194 !
#
# For epoch: 58, Average train DSC: -0.48732 !
# For epoch: 58, Average train MI: -0.85610 !
# For epoch: 58, Average train DDF: 0.40205 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7425 	 and 	 Current val loss: -0.9038
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 59/200
# LR is ==  0.0002
# For epoch: 59, Average train loss: -0.86062 !
# For epoch: 59, Average train DSC: 0.78703 !
#
# For epoch: 59, Average train DSC: -0.48109 !
# For epoch: 59, Average train MI: -0.86062 !
# For epoch: 59, Average train DDF: 0.41438 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7484 	 and 	 Current val loss: -0.8984
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 60/200
# LR is ==  0.0002
# For epoch: 60, Average train loss: -0.86314 !
# For epoch: 60, Average train DSC: 0.78583 !
#
# For epoch: 60, Average train DSC: -0.47665 !
# For epoch: 60, Average train MI: -0.86314 !
# For epoch: 60, Average train DDF: 0.44541 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7444 	 and 	 Current val loss: -0.8857
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 61/200
# LR is ==  0.0002
# For epoch: 61, Average train loss: -0.85248 !
# For epoch: 61, Average train DSC: 0.78839 !
#
# For epoch: 61, Average train DSC: -0.48022 !
# For epoch: 61, Average train MI: -0.85248 !
# For epoch: 61, Average train DDF: 0.39964 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7490 	 and 	 Current val loss: -0.8931
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 62/200
# LR is ==  0.0002
# For epoch: 62, Average train loss: -0.85450 !
# For epoch: 62, Average train DSC: 0.78763 !
#
# For epoch: 62, Average train DSC: -0.48243 !
# For epoch: 62, Average train MI: -0.85450 !
# For epoch: 62, Average train DDF: 0.38514 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7439 	 and 	 Current val loss: -0.8729
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 63/200
# LR is ==  0.0002
# For epoch: 63, Average train loss: -0.86393 !
# For epoch: 63, Average train DSC: 0.78925 !
#
# For epoch: 63, Average train DSC: -0.48349 !
# For epoch: 63, Average train MI: -0.86393 !
# For epoch: 63, Average train DDF: 0.42887 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7501 	 and 	 Current val loss: -0.8978
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 64/200
# LR is ==  0.0002
# For epoch: 64, Average train loss: -0.86805 !
# For epoch: 64, Average train DSC: 0.79259 !
#
# For epoch: 64, Average train DSC: -0.48992 !
# For epoch: 64, Average train MI: -0.86805 !
# For epoch: 64, Average train DDF: 0.43192 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7332 	 and 	 Current val loss: -0.9034
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 65/200
# LR is ==  0.0002
# For epoch: 65, Average train loss: -0.86964 !
# For epoch: 65, Average train DSC: 0.78843 !
#
# For epoch: 65, Average train DSC: -0.47649 !
# For epoch: 65, Average train MI: -0.86964 !
# For epoch: 65, Average train DDF: 0.42993 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7464 	 and 	 Current val loss: -0.9002
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 66/200
# LR is ==  0.0002
# For epoch: 66, Average train loss: -0.86743 !
# For epoch: 66, Average train DSC: 0.79011 !
#
# For epoch: 66, Average train DSC: -0.48569 !
# For epoch: 66, Average train MI: -0.86743 !
# For epoch: 66, Average train DDF: 0.44314 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7388 	 and 	 Current val loss: -0.8883
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 67/200
# LR is ==  0.0002
# For epoch: 67, Average train loss: -0.86733 !
# For epoch: 67, Average train DSC: 0.78657 !
#
# For epoch: 67, Average train DSC: -0.48003 !
# For epoch: 67, Average train MI: -0.86733 !
# For epoch: 67, Average train DDF: 0.45240 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7485 	 and 	 Current val loss: -0.9011
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 68/200
# LR is ==  0.0002
# For epoch: 68, Average train loss: -0.87330 !
# For epoch: 68, Average train DSC: 0.79112 !
#
# For epoch: 68, Average train DSC: -0.48945 !
# For epoch: 68, Average train MI: -0.87330 !
# For epoch: 68, Average train DDF: 0.42450 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7438 	 and 	 Current val loss: -0.8922
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 69/200
# LR is ==  0.0002
# For epoch: 69, Average train loss: -0.87427 !
# For epoch: 69, Average train DSC: 0.78570 !
#
# For epoch: 69, Average train DSC: -0.48227 !
# For epoch: 69, Average train MI: -0.87427 !
# For epoch: 69, Average train DDF: 0.49031 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7515 	 and 	 Current val loss: -0.8847
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 70/200
# LR is ==  0.0002
# For epoch: 70, Average train loss: -0.86954 !
# For epoch: 70, Average train DSC: 0.79108 !
#
# For epoch: 70, Average train DSC: -0.48487 !
# For epoch: 70, Average train MI: -0.86954 !
# For epoch: 70, Average train DDF: 0.44889 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7467 	 and 	 Current val loss: -0.9040
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 71/200
# LR is ==  0.0002
# For epoch: 71, Average train loss: -0.87206 !
# For epoch: 71, Average train DSC: 0.78781 !
#
# For epoch: 71, Average train DSC: -0.47508 !
# For epoch: 71, Average train MI: -0.87206 !
# For epoch: 71, Average train DDF: 0.46024 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7410 	 and 	 Current val loss: -0.8897
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 72/200
# LR is ==  0.0002
# For epoch: 72, Average train loss: -0.87396 !
# For epoch: 72, Average train DSC: 0.78332 !
#
# For epoch: 72, Average train DSC: -0.46802 !
# For epoch: 72, Average train MI: -0.87396 !
# For epoch: 72, Average train DDF: 0.49477 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7480 	 and 	 Current val loss: -0.9006
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 73/200
# LR is ==  0.0002
# For epoch: 73, Average train loss: -0.86839 !
# For epoch: 73, Average train DSC: 0.79131 !
#
# For epoch: 73, Average train DSC: -0.48657 !
# For epoch: 73, Average train MI: -0.86839 !
# For epoch: 73, Average train DDF: 0.44475 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7471 	 and 	 Current val loss: -0.8668
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 74/200
# LR is ==  0.0002
# For epoch: 74, Average train loss: -0.86948 !
# For epoch: 74, Average train DSC: 0.78796 !
#
# For epoch: 74, Average train DSC: -0.47573 !
# For epoch: 74, Average train MI: -0.86948 !
# For epoch: 74, Average train DDF: 0.50375 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7524 	 and 	 Current val loss: -0.8837
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 75/200
# LR is ==  0.0002
# For epoch: 75, Average train loss: -0.87004 !
# For epoch: 75, Average train DSC: 0.78842 !
#
# For epoch: 75, Average train DSC: -0.47892 !
# For epoch: 75, Average train MI: -0.87004 !
# For epoch: 75, Average train DDF: 0.47098 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7439 	 and 	 Current val loss: -0.9003
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 76/200
# LR is ==  0.0002
# For epoch: 76, Average train loss: -0.87474 !
# For epoch: 76, Average train DSC: 0.78728 !
#
# For epoch: 76, Average train DSC: -0.47311 !
# For epoch: 76, Average train MI: -0.87474 !
# For epoch: 76, Average train DDF: 0.50880 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7370 	 and 	 Current val loss: -0.8731
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 77/200
# LR is ==  0.0002
# For epoch: 77, Average train loss: -0.88141 !
# For epoch: 77, Average train DSC: 0.78586 !
#
# For epoch: 77, Average train DSC: -0.47897 !
# For epoch: 77, Average train MI: -0.88141 !
# For epoch: 77, Average train DDF: 0.49002 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7443 	 and 	 Current val loss: -0.9100
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 78/200
# LR is ==  0.0002
# For epoch: 78, Average train loss: -0.88367 !
# For epoch: 78, Average train DSC: 0.78717 !
#
# For epoch: 78, Average train DSC: -0.47952 !
# For epoch: 78, Average train MI: -0.88367 !
# For epoch: 78, Average train DDF: 0.49324 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7549 	 and 	 Current val loss: -0.9014
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 79/200
# LR is ==  0.0002
# For epoch: 79, Average train loss: -0.87805 !
# For epoch: 79, Average train DSC: 0.78663 !
#
# For epoch: 79, Average train DSC: -0.48240 !
# For epoch: 79, Average train MI: -0.87805 !
# For epoch: 79, Average train DDF: 0.48181 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7461 	 and 	 Current val loss: -0.8950
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 80/200
# LR is ==  0.0002
# For epoch: 80, Average train loss: -0.87838 !
# For epoch: 80, Average train DSC: 0.78849 !
#
# For epoch: 80, Average train DSC: -0.47847 !
# For epoch: 80, Average train MI: -0.87838 !
# For epoch: 80, Average train DDF: 0.52591 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7433 	 and 	 Current val loss: -0.9004
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 81/200
# LR is ==  0.0002
# For epoch: 81, Average train loss: -0.88364 !
# For epoch: 81, Average train DSC: 0.78934 !
#
# For epoch: 81, Average train DSC: -0.47797 !
# For epoch: 81, Average train MI: -0.88364 !
# For epoch: 81, Average train DDF: 0.50928 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7402 	 and 	 Current val loss: -0.8952
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 82/200
# LR is ==  0.0002
# For epoch: 82, Average train loss: -0.88492 !
# For epoch: 82, Average train DSC: 0.78738 !
#
# For epoch: 82, Average train DSC: -0.47495 !
# For epoch: 82, Average train MI: -0.88492 !
# For epoch: 82, Average train DDF: 0.52131 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7428 	 and 	 Current val loss: -0.9137
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 83/200
# LR is ==  0.0002
# For epoch: 83, Average train loss: -0.88222 !
# For epoch: 83, Average train DSC: 0.78885 !
#
# For epoch: 83, Average train DSC: -0.48139 !
# For epoch: 83, Average train MI: -0.88222 !
# For epoch: 83, Average train DDF: 0.52633 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7438 	 and 	 Current val loss: -0.8767
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 84/200
# LR is ==  0.0002
# For epoch: 84, Average train loss: -0.88631 !
# For epoch: 84, Average train DSC: 0.78903 !
#
# For epoch: 84, Average train DSC: -0.48215 !
# For epoch: 84, Average train MI: -0.88631 !
# For epoch: 84, Average train DDF: 0.52286 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7390 	 and 	 Current val loss: -0.9062
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 85/200
# LR is ==  0.0002
# For epoch: 85, Average train loss: -0.88760 !
# For epoch: 85, Average train DSC: 0.78638 !
#
# For epoch: 85, Average train DSC: -0.47340 !
# For epoch: 85, Average train MI: -0.88760 !
# For epoch: 85, Average train DDF: 0.56441 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7430 	 and 	 Current val loss: -0.8911
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 86/200
# LR is ==  0.0002
# For epoch: 86, Average train loss: -0.88641 !
# For epoch: 86, Average train DSC: 0.78995 !
#
# For epoch: 86, Average train DSC: -0.47662 !
# For epoch: 86, Average train MI: -0.88641 !
# For epoch: 86, Average train DDF: 0.54119 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7442 	 and 	 Current val loss: -0.8951
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 87/200
# LR is ==  0.0002
# For epoch: 87, Average train loss: -0.88460 !
# For epoch: 87, Average train DSC: 0.78557 !
#
# For epoch: 87, Average train DSC: -0.47441 !
# For epoch: 87, Average train MI: -0.88460 !
# For epoch: 87, Average train DDF: 0.55089 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7387 	 and 	 Current val loss: -0.9030
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 88/200
# LR is ==  0.0002
# For epoch: 88, Average train loss: -0.88118 !
# For epoch: 88, Average train DSC: 0.79053 !
#
# For epoch: 88, Average train DSC: -0.48905 !
# For epoch: 88, Average train MI: -0.88118 !
# For epoch: 88, Average train DDF: 0.51467 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7420 	 and 	 Current val loss: -0.8658
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 89/200
# LR is ==  0.0002
# For epoch: 89, Average train loss: -0.88015 !
# For epoch: 89, Average train DSC: 0.78304 !
#
# For epoch: 89, Average train DSC: -0.47305 !
# For epoch: 89, Average train MI: -0.88015 !
# For epoch: 89, Average train DDF: 0.61361 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7483 	 and 	 Current val loss: -0.8885
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 90/200
# LR is ==  0.0002
# For epoch: 90, Average train loss: -0.88362 !
# ...
# ------------------------------------------------------------
#
# Current mean dice: 0.7447 	 and 	 Current val loss: -0.9083
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 171/200
# LR is ==  0.0002
# For epoch: 171, Average train loss: -0.93856 !
# For epoch: 171, Average train DSC: 0.78041 !
#
# For epoch: 171, Average train DSC: -0.46010 !
# For epoch: 171, Average train MI: -0.93856 !
# For epoch: 171, Average train DDF: 0.98617 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7470 	 and 	 Current val loss: -0.8841
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 172/200
# LR is ==  0.0002
# For epoch: 172, Average train loss: -0.94381 !
# For epoch: 172, Average train DSC: 0.78289 !
#
# For epoch: 172, Average train DSC: -0.46723 !
# For epoch: 172, Average train MI: -0.94381 !
# For epoch: 172, Average train DDF: 0.98828 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7404 	 and 	 Current val loss: -0.8950
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 173/200
# LR is ==  0.0002
# For epoch: 173, Average train loss: -0.95257 !
# For epoch: 173, Average train DSC: 0.78101 !
#
# For epoch: 173, Average train DSC: -0.47235 !
# For epoch: 173, Average train MI: -0.95257 !
# For epoch: 173, Average train DDF: 0.98324 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7404 	 and 	 Current val loss: -0.9022
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 174/200
# LR is ==  0.0002
# For epoch: 174, Average train loss: -0.94914 !
# For epoch: 174, Average train DSC: 0.78460 !
#
# For epoch: 174, Average train DSC: -0.47085 !
# For epoch: 174, Average train MI: -0.94914 !
# For epoch: 174, Average train DDF: 1.00695 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7467 	 and 	 Current val loss: -0.9073
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 175/200
# LR is ==  0.0002
# For epoch: 175, Average train loss: -0.94706 !
# For epoch: 175, Average train DSC: 0.78365 !
#
# For epoch: 175, Average train DSC: -0.46815 !
# For epoch: 175, Average train MI: -0.94706 !
# For epoch: 175, Average train DDF: 0.99410 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7405 	 and 	 Current val loss: -0.8962
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 176/200
# LR is ==  0.0002
# For epoch: 176, Average train loss: -0.94864 !
# For epoch: 176, Average train DSC: 0.78111 !
#
# For epoch: 176, Average train DSC: -0.46712 !
# For epoch: 176, Average train MI: -0.94864 !
# For epoch: 176, Average train DDF: 1.00635 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7443 	 and 	 Current val loss: -0.8975
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 177/200
# LR is ==  0.0002
# For epoch: 177, Average train loss: -0.94978 !
# For epoch: 177, Average train DSC: 0.77900 !
#
# For epoch: 177, Average train DSC: -0.46659 !
# For epoch: 177, Average train MI: -0.94978 !
# For epoch: 177, Average train DDF: 1.04715 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7492 	 and 	 Current val loss: -0.9023
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 178/200
# LR is ==  0.0002
# For epoch: 178, Average train loss: -0.94822 !
# For epoch: 178, Average train DSC: 0.78411 !
#
# For epoch: 178, Average train DSC: -0.47541 !
# For epoch: 178, Average train MI: -0.94822 !
# For epoch: 178, Average train DDF: 0.99941 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7407 	 and 	 Current val loss: -0.9018
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 179/200
# LR is ==  0.0002
# For epoch: 179, Average train loss: -0.95037 !
# For epoch: 179, Average train DSC: 0.78087 !
#
# For epoch: 179, Average train DSC: -0.46848 !
# For epoch: 179, Average train MI: -0.95037 !
# For epoch: 179, Average train DDF: 0.99576 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7400 	 and 	 Current val loss: -0.8890
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 180/200
# LR is ==  0.0002
# For epoch: 180, Average train loss: -0.94583 !
# For epoch: 180, Average train DSC: 0.77974 !
#
# For epoch: 180, Average train DSC: -0.46152 !
# For epoch: 180, Average train MI: -0.94583 !
# For epoch: 180, Average train DDF: 1.11794 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7468 	 and 	 Current val loss: -0.9113
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 181/200
# LR is ==  0.0002
# For epoch: 181, Average train loss: -0.94217 !
# For epoch: 181, Average train DSC: 0.78478 !
#
# For epoch: 181, Average train DSC: -0.47366 !
# For epoch: 181, Average train MI: -0.94217 !
# For epoch: 181, Average train DDF: 0.96327 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7350 	 and 	 Current val loss: -0.8764
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 182/200
# LR is ==  0.0002
# For epoch: 182, Average train loss: -0.95047 !
# For epoch: 182, Average train DSC: 0.78210 !
#
# For epoch: 182, Average train DSC: -0.47138 !
# For epoch: 182, Average train MI: -0.95047 !
# For epoch: 182, Average train DDF: 1.05329 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7458 	 and 	 Current val loss: -0.9098
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 183/200
# LR is ==  0.0002
# For epoch: 183, Average train loss: -0.95758 !
# For epoch: 183, Average train DSC: 0.78325 !
#
# For epoch: 183, Average train DSC: -0.46687 !
# For epoch: 183, Average train MI: -0.95758 !
# For epoch: 183, Average train DDF: 1.04930 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7448 	 and 	 Current val loss: -0.9009
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 184/200
# LR is ==  0.0002
# For epoch: 184, Average train loss: -0.95702 !
# For epoch: 184, Average train DSC: 0.78370 !
#
# For epoch: 184, Average train DSC: -0.46691 !
# For epoch: 184, Average train MI: -0.95702 !
# For epoch: 184, Average train DDF: 1.08280 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7435 	 and 	 Current val loss: -0.8956
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 185/200
# LR is ==  0.0002
# For epoch: 185, Average train loss: -0.95925 !
# For epoch: 185, Average train DSC: 0.78520 !
#
# For epoch: 185, Average train DSC: -0.47337 !
# For epoch: 185, Average train MI: -0.95925 !
# For epoch: 185, Average train DDF: 1.04623 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7437 	 and 	 Current val loss: -0.8951
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 186/200
# LR is ==  0.0002
# For epoch: 186, Average train loss: -0.95402 !
# For epoch: 186, Average train DSC: 0.78197 !
#
# For epoch: 186, Average train DSC: -0.46880 !
# For epoch: 186, Average train MI: -0.95402 !
# For epoch: 186, Average train DDF: 1.12347 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7462 	 and 	 Current val loss: -0.9120
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 187/200
# LR is ==  0.0002
# For epoch: 187, Average train loss: -0.94975 !
# For epoch: 187, Average train DSC: 0.78235 !
#
# For epoch: 187, Average train DSC: -0.46724 !
# For epoch: 187, Average train MI: -0.94975 !
# For epoch: 187, Average train DDF: 1.02667 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7381 	 and 	 Current val loss: -0.8783
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 188/200
# LR is ==  0.0002
# For epoch: 188, Average train loss: -0.95284 !
# For epoch: 188, Average train DSC: 0.77895 !
#
# For epoch: 188, Average train DSC: -0.46431 !
# For epoch: 188, Average train MI: -0.95284 !
# For epoch: 188, Average train DDF: 1.08732 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7470 	 and 	 Current val loss: -0.8987
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 189/200
# LR is ==  0.0002
# For epoch: 189, Average train loss: -0.95203 !
# For epoch: 189, Average train DSC: 0.78073 !
#
# For epoch: 189, Average train DSC: -0.46828 !
# For epoch: 189, Average train MI: -0.95203 !
# For epoch: 189, Average train DDF: 1.06715 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7439 	 and 	 Current val loss: -0.8950
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 190/200
# LR is ==  0.0002
# For epoch: 190, Average train loss: -0.95645 !
# For epoch: 190, Average train DSC: 0.78064 !
#
# For epoch: 190, Average train DSC: -0.46800 !
# For epoch: 190, Average train MI: -0.95645 !
# For epoch: 190, Average train DDF: 1.11167 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7439 	 and 	 Current val loss: -0.8890
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 191/200
# LR is ==  0.0002
# For epoch: 191, Average train loss: -0.95396 !
# For epoch: 191, Average train DSC: 0.78209 !
#
# For epoch: 191, Average train DSC: -0.46864 !
# For epoch: 191, Average train MI: -0.95396 !
# For epoch: 191, Average train DDF: 1.04563 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7398 	 and 	 Current val loss: -0.8911
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 192/200
# LR is ==  0.0002
# For epoch: 192, Average train loss: -0.95650 !
# For epoch: 192, Average train DSC: 0.78263 !
#
# For epoch: 192, Average train DSC: -0.46462 !
# For epoch: 192, Average train MI: -0.95650 !
# For epoch: 192, Average train DDF: 1.13964 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7425 	 and 	 Current val loss: -0.9056
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 193/200
# LR is ==  0.0002
# For epoch: 193, Average train loss: -0.95616 !
# For epoch: 193, Average train DSC: 0.78417 !
#
# For epoch: 193, Average train DSC: -0.46319 !
# For epoch: 193, Average train MI: -0.95616 !
# For epoch: 193, Average train DDF: 1.08865 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7420 	 and 	 Current val loss: -0.8849
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 194/200
# LR is ==  0.0002
# For epoch: 194, Average train loss: -0.95728 !
# For epoch: 194, Average train DSC: 0.78739 !
#
# For epoch: 194, Average train DSC: -0.47263 !
# For epoch: 194, Average train MI: -0.95728 !
# For epoch: 194, Average train DDF: 1.06410 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7423 	 and 	 Current val loss: -0.8977
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 195/200
# LR is ==  0.0002
# For epoch: 195, Average train loss: -0.95473 !
# For epoch: 195, Average train DSC: 0.78224 !
#
# For epoch: 195, Average train DSC: -0.46337 !
# For epoch: 195, Average train MI: -0.95473 !
# For epoch: 195, Average train DDF: 1.13305 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7463 	 and 	 Current val loss: -0.9029
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 196/200
# LR is ==  0.0002
# For epoch: 196, Average train loss: -0.95729 !
# For epoch: 196, Average train DSC: 0.78072 !
#
# For epoch: 196, Average train DSC: -0.46519 !
# For epoch: 196, Average train MI: -0.95729 !
# For epoch: 196, Average train DDF: 1.10280 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7379 	 and 	 Current val loss: -0.8832
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 197/200
# LR is ==  0.0002
# For epoch: 197, Average train loss: -0.95453 !
# For epoch: 197, Average train DSC: 0.78076 !
#
# For epoch: 197, Average train DSC: -0.46389 !
# For epoch: 197, Average train MI: -0.95453 !
# For epoch: 197, Average train DDF: 1.09610 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7462 	 and 	 Current val loss: -0.8895
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 198/200
# LR is ==  0.0002
# For epoch: 198, Average train loss: -0.95246 !
# For epoch: 198, Average train DSC: 0.78540 !
#
# For epoch: 198, Average train DSC: -0.46851 !
# For epoch: 198, Average train MI: -0.95246 !
# For epoch: 198, Average train DDF: 1.13125 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7468 	 and 	 Current val loss: -0.8928
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 199/200
# LR is ==  0.0002
# For epoch: 199, Average train loss: -0.95326 !
# For epoch: 199, Average train DSC: 0.78095 !
#
# For epoch: 199, Average train DSC: -0.46510 !
# For epoch: 199, Average train MI: -0.95326 !
# For epoch: 199, Average train DDF: 1.05608 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7401 	 and 	 Current val loss: -0.9006
#
# Best val DSC: 0.7578 at epoch number of 57
# ----------------------------------------------------------------------------------------------------
# Epoch 200/200
# LR is ==  0.0002
# For epoch: 200, Average train loss: -0.95709 !
# For epoch: 200, Average train DSC: 0.78020 !
#
# For epoch: 200, Average train DSC: -0.46158 !
# For epoch: 200, Average train MI: -0.95709 !
# For epoch: 200, Average train DDF: 1.14437 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7454 	 and 	 Current val loss: -0.8912
#
# Best val DSC: 0.7578 at epoch number of 57

# %%
# %matplotlib inline
plt.figure("train", (20, 4))
plt.subplot(1, 2, 1)
plt.plot(epoch_loss_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.plot(epoch_val_loss_values, label = 'val', color='b', lw=2, linestyle='-', marker = 'x')
plt.legend(fontsize=20, loc='upper right', ncol=1)
plt.xticks(range(0, max_epochs , 10))
plt.ylabel('Losses', fontsize=20)
plt.xlabel('Epochs', fontsize=20)

plt.subplot(1, 2, 2)
plt.plot(metric_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.ylabel('DSC', fontsize=20)
plt.xlabel('Epochs', fontsize=20)
# Out:
# Text(0.5, 0, 'Epochs')

# %%
def hausdorff (mask1, mask2):
    mask1_class_LV = mask1.copy()
    mask1_class_Myo = mask1.copy()
    
    mask1_class_LV[mask1_class_LV==1] = 0
    mask1_class_Myo[mask1_class_Myo==2] = 0
    
    mask2_class_LV = mask2.copy()
    mask2_class_Myo = mask2.copy()
    
    mask2_class_LV[mask2_class_LV==1] = 0
    mask2_class_Myo[mask2_class_Myo==2] = 0
    
    hausdorff_Myo = (directed_hausdorff(mask1_class_Myo, mask2_class_Myo)[0]+directed_hausdorff(mask2_class_Myo, mask1_class_Myo)[0])/2

    hausdorff_LV = (directed_hausdorff(mask1_class_LV, mask2_class_LV)[0]+directed_hausdorff(mask2_class_LV, mask1_class_LV)[0])/2
    
    return [hausdorff_Myo, hausdorff_LV]

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()

metric = monai.metrics.MSEMetric()

before_MSEMetric = []
after_MSEMetric = []

before_compute_meandice = []
after_compute_meandice = []

before_compute_hausdorff_distance = []
after_compute_hausdorff_distance = []
                                                                         

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    before_MSEMetric.extend(metric(moving_val_img_,fixed_val_img_).detach().cpu().numpy())
    
    after_MSEMetric.extend(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())
    
#     print(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())

    before_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy())
    after_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy()) 
    
    
    before_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy())
    after_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy()) 
    
    
#     break

print(np.array(before_MSEMetric).shape)
print(np.array(after_MSEMetric).shape)

print(np.array(before_compute_meandice).shape)
print(np.array(after_compute_meandice).shape)

print()

print(f'MSEMetric W/O registration {np.mean(np.array(before_MSEMetric))}')
print(f'MSEMetric W/ registration = {np.mean(np.array(after_MSEMetric))}')

print(f'Mean dice W/O registration = {np.mean(np.array(before_compute_meandice), axis=0)}')
print(f'Mean dice W/ registration = {np.mean(np.array(after_compute_meandice), axis=0)}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.array(before_compute_hausdorff_distance), axis=0)}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.array(after_compute_hausdorff_distance), axis=0)}')

print()

print('----------------For Report Metric +/- Std-----------------------')
print(f'Mean dice W/O registration = {np.mean(np.mean(np.array(before_compute_meandice), axis=0))} + {np.mean(np.std(np.array(before_compute_meandice), axis=0))}')
print(f'Mean dice W/ registration = {np.mean(np.mean(np.array(after_compute_meandice), axis=0))} + {np.mean(np.std(np.array(after_compute_meandice), axis=0))}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.mean(np.array(before_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(before_compute_hausdorff_distance), axis=0))}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.mean(np.array(after_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(after_compute_hausdorff_distance), axis=0))}')

df = ({
     'before_compute_hausdorff_distance':np.mean(np.array(before_compute_hausdorff_distance), axis=1),
     'after_compute_hausdorff_distance'   : np.mean(np.array(after_compute_hausdorff_distance), axis=1),
     'before_compute_meandice':np.mean(np.array(before_compute_meandice), axis=1),
     'after_compute_meandice':np.mean(np.array(after_compute_meandice), axis=1),
     'before_MSEMetric': np.mean(np.array(before_MSEMetric), axis=1),
     'after_MSEMetric':np.mean(np.array(after_MSEMetric), axis=1)
})

pd.DataFrame(df).to_csv(fileNames+'.csv')
# Out:
# <function compute_meandice at 0x7f3c36d561f0>: Function `compute_meandice` has been deprecated since version 1.0.0. use `compute_dice` instead.
# (4, 1)
# (4, 1)
# (4, 3)
# (4, 3)
#
# MSEMetric W/O registration 0.0037749039474874735
# MSEMetric W/ registration = 0.002964906394481659
# Mean dice W/O registration = [0.9909303  0.7891744  0.72605586]
# Mean dice W/ registration = [0.9869913  0.70086753 0.5854299 ]
# Hausdorff_distance W/O registration = [5.8599326 6.2704711]
# Hausdorff_distance W/ registration = [20.00842237  6.18340851]
#
# ----------------For Report Metric +/- Std-----------------------
# Mean dice W/O registration = 0.8353868126869202 + 0.1279802769422531
# Mean dice W/ registration = 0.7577629089355469 + 0.080360047519207
# Hausdorff_distance W/O registration = 6.065201854061436 + 2.158310792469111
# Hausdorff_distance W/ registration = 13.095915437567742 + 3.562159743235463

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()
                                          

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    break

fixed_val_img_ = fixed_val_img_.detach().cpu().numpy()[:, 0]
fixed_val_msk_ = fixed_val_msk_.detach().cpu().numpy()[:, 0]

moving_val_img_ = moving_val_img_.detach().cpu().numpy()[:, 0]
moving_val_msk_ = moving_val_msk_.detach().cpu().numpy()[:, 0]

pred_image_val = pred_image_val.detach().cpu().numpy()[:, 0]
pred_mask_val = pred_mask_val.detach().cpu().numpy()[:, 0]

# %%
def colored (pred_img, true_img): 
    bitwise_and = cv2.bitwise_and(pred_img, true_img)
    
    TP = np.stack((np.zeros_like(bitwise_and), bitwise_and, np.zeros_like(bitwise_and)), axis=-1)
    
    FN = np.stack((true_img-bitwise_and,
                   true_img-bitwise_and,
                   np.zeros_like(true_img-bitwise_and)), axis=-1)
    
    FP = np.stack((pred_img-bitwise_and,
                   pred_img-bitwise_and,
                  np.zeros_like(pred_img-bitwise_and)), axis=-1)
    
    return (255*(TP+FN+FP)).astype('uint8')

# %%
slice_no = 15
# %matplotlib inline
slice_num = 8
plt.subplots(slice_num, 7, figsize=(12, 15))

for b in range(slice_num):
    # moving image
    plt.subplot(slice_num, 7, b * 7 + 1)
    plt.axis('off')
    plt.title("moving img")
    plt.imshow(moving_val_img_[0, :, :, slice_no], cmap="gray")
    
    # moving label
    plt.subplot(slice_num, 7, b * 7 + 2)
    plt.axis('off')
    plt.title("moving lab")
    plt.imshow(moving_val_msk_[0, :, :, slice_no], cmap="gray")
    
    
    # fixed image
    plt.subplot(slice_num, 7, b * 7 + 3)
    plt.axis('off')
    plt.title("fixed img")
    plt.imshow(fixed_val_img_[0, :, :, slice_no], cmap="gray")
    
    # fixed label
    plt.subplot(slice_num, 7, b * 7 + 4)
    plt.axis('off')
    plt.title("fixed lab")
    plt.imshow(fixed_val_msk_[0, :, :, slice_no], cmap="gray")
    
    
    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 5)
    plt.axis('off')
    plt.title("Pred Img")
    plt.imshow(pred_image_val[0, :, :, slice_no], cmap="gray")


    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 6)
    plt.axis('off')
    plt.title("Before Reg")
    plt.imshow(colored(moving_val_msk_[0, :, :, slice_no], fixed_val_msk_[0, :, :, slice_no]))
    
    
    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 7)
    plt.axis('off')
    plt.title("After Reg")
    plt.imshow(colored(pred_mask_val[0, :, :, slice_no], fixed_val_msk_[0, :, :, slice_no]))

    slice_no = slice_no + 1
    
plt.axis('off')
plt.show()
