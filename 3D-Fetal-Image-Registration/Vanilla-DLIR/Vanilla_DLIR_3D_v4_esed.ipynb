# %%
# Import and Install Libraries

from monai.utils import set_determinism, first
from monai.transforms import (
    EnsureChannelFirstD,
    Compose,
    LoadImageD,
    RandRotateD,
    RandZoomD,
    ScaleIntensityRanged,
)
import monai
from monai.data import DataLoader, Dataset, CacheDataset
from monai.config import print_config, USE_COMPILED
from monai.networks.nets import GlobalNet, LocalNet, RegUNet
from monai.networks.blocks import Warp
from monai.apps import MedNISTDataset
import torch.nn.functional as F

from glob import glob
import cv2
import torchmetrics

from torch.autograd import Variable

from scipy.spatial.distance import directed_hausdorff
from scipy.ndimage import zoom
import pandas as pd

import torch.nn as nn

import numpy as np
import torch
from torch.nn import MSELoss
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider
from matplotlib.animation import FuncAnimation
import os
import tempfile
from monai.losses import *
from monai.metrics import *
from piqa import SSIM

import nibabel as nib

import csv

print_config()
set_determinism(40)
# Out:
# MONAI version: 1.0.1
# Numpy version: 1.22.3
# Pytorch version: 1.13.1
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 8271a193229fe4437026185e218d5b06f7c8ce69
# MONAI __file__: /home/mkh/anaconda3/envs/phd/lib/python3.9/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.10
# Nibabel version: 5.0.1
# scikit-image version: 0.19.3
# Pillow version: 9.0.1
# Tensorboard version: 2.12.0
# gdown version: 4.6.4
# TorchVision version: 0.14.1
# tqdm version: 4.64.1
# lmdb version: 1.4.0
# psutil version: 5.9.4
# pandas version: 1.5.3
# einops version: 0.6.0
# transformers version: 4.21.3
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
# Directories and some Parameters

dataDir = '3D_Updated'

root_dir = '/home/mkh/MKH/KSA/Dataset/'+dataDir+'/'
print(root_dir)

trainBatch = 1
testBatch = 1

img_size = 256
slice_size = 32

previousWeight = 128

preTrained = 0

EP = 100

num_workers = 0

ExpName = "Vanilla_DLIR_v4_ESED"

fileNames = ExpName + '_' + dataDir + '_' +str(img_size) + '_'+str(slice_size) + '_'

# print(fileNames)
# Out:
# /home/mkh/MKH/KSA/Dataset/3D_Updated/

# %%
# GPU information
print('How many GPUs = ' + str(torch.cuda.device_count()))

#checking for device

device=torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
print(device)

if not torch.cuda.is_available():
  raise Exception("GPU not availalbe. CPU training will be too slow.")

print("device name", torch.cuda.get_device_name(0))
# Out:
# How many GPUs = 4
# cuda:2
# device name NVIDIA GeForce RTX 3090 Ti

# %%
# # Make fixed-moving pairs in csv
# # root_dir = '/home/mkh/MKH/KSA/Dataset/'+dataDir+'/'
# splits = ['train', 'val']
# for split in splits:
#     fixed_names = []
#     moving_names = []
#     split_path = os.path.join(root_dir, split)
#     for folders in sorted(os.listdir(split_path)):
#         split_path_folders = os.path.join(split_path, folders)
#         if 'fixed_img' in folders:
#             for fixed_imgs in sorted(os.listdir(split_path_folders)):
#                 split_path_folders_fixed_imgs = os.path.join(split_path_folders, fixed_imgs)
#                 fixed_pt = fixed_imgs.split('_')[0]
#                 for mov_folders in sorted(os.listdir(split_path)):
#                     if 'moving_img' in mov_folders:
#                         mov_split_path_folders = os.path.join(split_path, mov_folders)
#                         for moving_imgs in sorted(os.listdir(mov_split_path_folders)):
#                             moving_pt = moving_imgs.split('_')[0]
#                             if(fixed_pt==moving_pt):
#                                 fixed_names.append(fixed_imgs)
#                                 moving_names.append(moving_imgs)
#     data = {'Fixed':fixed_names, 'Moving':moving_names}
#     dataframe = pd.DataFrame(data=data, index=None)
#     csv_path = root_dir + split + '.csv'
#     dataframe.to_csv(csv_path,index=False)

# %%
class EchoDataset3D(Dataset):
    def __init__(self, images_path, flagMask):

        self.images_path = images_path
        self.n_samples = len(images_path)
        self.flagMask = flagMask

    def __getitem__(self, index):
        """ Reading Nifti Files """
        
        # image = cv2.imread(self.images_path[index], cv2.IMREAD_GRAYSCALE)
        img_3d = nib.load(self.images_path[index])
        image = img_3d.get_fdata()

        if self.flagMask==0:
            image = zoom(image, (img_size / image.shape[0], img_size / image.shape[1], slice_size / image.shape[2]))
            # image = cv2.resize(image,(img_size, img_size))
            image = (image-image.min())/(image.max()-image.min())
        else:
            image[image==127]=1
            image[image==255]=2
            image = zoom(image, (img_size / image.shape[0], img_size / image.shape[1], slice_size / image.shape[2]), order=0)
            # image = cv2.resize(image,(img_size, img_size), interpolation=cv2.INTER_NEAREST)
            # image = image/(image.max()) ## (512, 512, 3)
            # print(image.max())
        image = np.expand_dims(image, axis=0)
        image = image.astype(np.float32)
        self.images_path[index]
        return image

    def __len__(self):
        return self.n_samples

# %%
def get_batches(split_dir,
                split,
                fixOrMov,
                flagMask,
                batch_size,
                num_workers,
                pin_memory):
    
    csv_path = pd.read_csv(root_dir + split + "_esed_v2.csv") #Change here
    all_path  = split_dir + csv_path[fixOrMov]
    
    split_data = EchoDataset3D(images_path=all_path, flagMask=flagMask)

    split_loader = DataLoader(split_data,
                              batch_size=batch_size,
                              num_workers=num_workers,
                              pin_memory=pin_memory,
                              shuffle=False)

    return split_loader

# %%
fixed_train_img = get_batches(split_dir = sorted(glob(root_dir+"train/img/")),
                                        split = 'train',
                                        fixOrMov = 'Fixed',
                                        flagMask = 0,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_train_msk = get_batches(split_dir = sorted(glob(root_dir+"train/msk/")),
                                        split = 'train',
                                        fixOrMov = 'Fixed',
                                        flagMask = 1,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_train_img = get_batches(split_dir = sorted(glob(root_dir+"train/img/")),
                                        split = 'train',
                                        fixOrMov = 'Moving',
                                        flagMask = 0,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_train_msk = get_batches(split_dir = sorted(glob(root_dir+"train/msk/")),
                                        split = 'train',
                                        fixOrMov = 'Moving',
                                        flagMask = 1,
                                        batch_size = trainBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

print("Train IMG FIXED:", fixed_train_img)
print("Train MSK FIXED:", fixed_train_msk)
print("Train IMG Moving:", moving_train_img)
print("Train MSK Moving:", moving_train_msk)

fixed_val_img = get_batches(split_dir = sorted(glob(root_dir+"val/img/")),
                                        split = 'val',
                                        fixOrMov = 'Fixed',
                                        flagMask = 0,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

fixed_val_msk = get_batches(split_dir = sorted(glob(root_dir+"val/msk/")),
                                        split = 'val',
                                        fixOrMov = 'Fixed',
                                        flagMask = 1,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


moving_val_img = get_batches(split_dir = sorted(glob(root_dir+"val/img/")),
                                        split = 'val',
                                        fixOrMov = 'Moving',
                                        flagMask = 0,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)

moving_val_msk = get_batches(split_dir = sorted(glob(root_dir+"val/msk/")),
                                        split = 'val',
                                        fixOrMov = 'Moving',
                                        flagMask = 1,
                                        batch_size = testBatch,
                                        num_workers = num_workers,
                                        pin_memory = True)


print("Val IMG FIXED:", fixed_val_img)
print("Val MSK FIXED:", fixed_val_msk)
print("Val IMG Moving:", moving_val_img)
print("Val MSK Moving:", moving_val_msk)
# Out:
# Train IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7ff1e0057e80>
# Train MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7ff08b648f40>
# Train IMG Moving: <monai.data.dataloader.DataLoader object at 0x7ff08b6480d0>
# Train MSK Moving: <monai.data.dataloader.DataLoader object at 0x7ff08b64a3d0>
# Val IMG FIXED: <monai.data.dataloader.DataLoader object at 0x7ff08c656910>
# Val MSK FIXED: <monai.data.dataloader.DataLoader object at 0x7ff08c656370>
# Val IMG Moving: <monai.data.dataloader.DataLoader object at 0x7ff1e0071670>
# Val MSK Moving: <monai.data.dataloader.DataLoader object at 0x7ff1e0071430>

# %%
# Change here
train_csv = pd.read_csv(root_dir + 'train_esed_v2.csv')
val_csv =  pd.read_csv(root_dir + 'val_esed_v2.csv')

print(f'Train Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"train/img/")) + train_csv["Fixed"] )}')
print(f'Train Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"train/msk/")) + train_csv["Fixed"] )}')
print(f'Train Sample numbers (moving_img) = {len(sorted(glob(root_dir+"train/img/")) + train_csv["Moving"] )}')
print(f'Train Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"/train/msk/")) + train_csv["Fixed"] )}')
print()
print(f'Val Sample numbers (fixed_img) = {len(sorted(glob(root_dir+"val/img/")) + val_csv["Fixed"] )}')
print(f'Val Sample numbers (fixed_msk) = {len(sorted(glob(root_dir+"val/msk/")) + val_csv["Fixed"] )}')
print(f'Val Sample numbers (moving_img) = {len(sorted(glob(root_dir+"val/img/")) + val_csv["Moving"] )}')
print(f'Val Sample numbers (moving_msk) = {len(sorted(glob(root_dir+"val/msk/")) + val_csv["Moving"] )}')
print()
# Out:
# Train Sample numbers (fixed_img) = 50
# Train Sample numbers (fixed_msk) = 50
# Train Sample numbers (moving_img) = 50
# Train Sample numbers (moving_msk) = 50
#
# Val Sample numbers (fixed_img) = 20
# Val Sample numbers (fixed_msk) = 20
# Val Sample numbers (moving_img) = 20
# Val Sample numbers (moving_msk) = 20

# %%
dataloaders = {
    'fixed_train_img': fixed_train_img,
    'fixed_train_msk': fixed_train_msk,
    'moving_train_img': moving_train_img,
    'moving_train_msk': moving_train_msk,
    'fixed_val_img': fixed_val_img,
    'fixed_val_msk': fixed_val_msk,
    'moving_val_img': moving_val_img,
    'moving_val_msk': moving_val_msk
    }

# %%
fixed_train_img_ = first(dataloaders["fixed_train_img"])[0][0]
fixed_train_msk_ = first(dataloaders["fixed_train_msk"])[0][0]
moving_train_img_ = first(dataloaders["moving_train_img"])[0][0]
moving_train_msk_ = first(dataloaders["moving_train_msk"])[0][0]

fixed_val_img_ = first(dataloaders["fixed_val_img"])[0][0]
fixed_val_msk_ = first(dataloaders["fixed_val_msk"])[0][0]
moving_val_img_ = first(dataloaders["moving_val_img"])[0][0]
moving_val_msk_ = first(dataloaders["moving_val_msk"])[0][0]


print(f"fixed_train_img_ shape: {fixed_train_img_.shape}")
print(f"fixed_train_msk_ shape: {fixed_train_msk_.shape}")
print(f"moving_train_img_ shape: {moving_train_img_.shape}")
print(f"moving_train_msk_ shape: {moving_train_msk_.shape}")

print(f"fixed_val_img_ shape: {fixed_val_img_.shape}")
print(f"fixed_val_msk_ shape: {fixed_val_msk_.shape}")
print(f"moving_val_img_ shape: {moving_val_img_.shape}")
print(f"moving_val_msk_ shape: {moving_val_msk_.shape}")


print(f"fixed_train_img_ Range: {fixed_train_img_.max()} {fixed_train_img_.min()}")
print(f"fixed_train_msk_ range: {fixed_train_msk_.max()} {fixed_train_msk_.min()} {np.unique(fixed_train_msk_)}")
print(f"moving_train_img_ Range: {moving_train_img_.max()} {moving_train_img_.min()}")
print(f"moving_train_msk_ range: {moving_train_msk_.max()} {moving_train_msk_.min()} {np.unique(moving_train_msk_)}")

print(f"fixed_val_img_ Range: {fixed_val_img_.max()} {fixed_val_img_.min()}")
print(f"fixed_val_msk_ range: {fixed_val_msk_.max()} {fixed_val_msk_.min()} {np.unique(fixed_val_msk_)}")
print(f"moving_val_img_ Range: {moving_val_img_.max()} {moving_val_img_.min()}")
print(f"moving_val_msk_ range: {moving_val_msk_.max()} {moving_val_msk_.min()} {np.unique(moving_val_msk_)}")
# Out:
# fixed_train_img_ shape: torch.Size([256, 256, 32])
# fixed_train_msk_ shape: torch.Size([256, 256, 32])
# moving_train_img_ shape: torch.Size([256, 256, 32])
# moving_train_msk_ shape: torch.Size([256, 256, 32])
# fixed_val_img_ shape: torch.Size([256, 256, 32])
# fixed_val_msk_ shape: torch.Size([256, 256, 32])
# moving_val_img_ shape: torch.Size([256, 256, 32])
# moving_val_msk_ shape: torch.Size([256, 256, 32])
# fixed_train_img_ Range: 1.0 0.0
# fixed_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_train_img_ Range: 1.0 0.0
# moving_train_msk_ range: 2.0 0.0 [0. 1. 2.]
# fixed_val_img_ Range: 1.0 0.0
# fixed_val_msk_ range: 2.0 0.0 [0. 1. 2.]
# moving_val_img_ Range: 1.0 0.0
# moving_val_msk_ range: 2.0 0.0 [0. 1. 2.]

# %%
# %matplotlib widget

# volumes = [fixed_train_img_, fixed_train_msk_, moving_train_img_, moving_train_msk_, fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_]  # Replace with your actual 3D volume data

# # Create a figure and subplots
# fig, axs = plt.subplots(2, 4, figsize=(12, 6))

# # Create initial slices for each volume
# initial_slices = [0] * 8
# current_slices = []

# # Plot the initial slices
# for i, ax in enumerate(axs.flat):
#     ax.axis('off')  # Hide the axis numbers
#     current_slice = ax.imshow(volumes[i][:, :, initial_slices[i]], cmap='gray')
#     current_slices.append(current_slice)

# # Create sliders and axes for each volume
# sliders = []
# slider_axes = []
# for i, ax in enumerate(axs.flat):
#     ax_slider = plt.axes([ax.get_position().x0, ax.get_position().y0 - 0.05, ax.get_position().width, 0.02])
#     slider = Slider(ax=ax_slider, label=f'Slice {i+1}', valmin=0, valmax=volumes[i].shape[2] - 1, valinit=initial_slices[i], valstep=1)
#     sliders.append(slider)
#     slider_axes.append(ax_slider)

# # Update the plots when the slider values change
# def update_slices():
#     for i, slider in enumerate(sliders):
#         current_slices[i].set_data(volumes[i][:, :, int(slider.val)])

#     fig.canvas.draw_idle()

# for slider in sliders:
#     slider.on_changed(lambda event: update_slices())

# # Animation function
# def animate(i):
#     # Increment the slice values for each volume
#     slice_vals = [(initial_slices[j] + i) % volumes[j].shape[2] for j in range(8)]

#     # Update the slider values
#     for j, slider in enumerate(sliders):
#         slider.set_val(slice_vals[j])

#     # Update the plots
#     update_slices()

# # Create the animation
# animation = FuncAnimation(fig, animate, frames=volumes[0].shape[2]*2, interval=200)

# # Set up plot settings
# plt.subplots_adjust(hspace=0.4, wspace=0.2, bottom=0.15)

# # Display the plot
# plt.show()

# %%
# %matplotlib widget

# volume = fixed_train_img_  # Replace this with your actual 3D volume data

# # Create a figure and axes for the plot
# fig, ax = plt.subplots()

# # Plot the initial slice
# initial_slice = 0
# current_slice = ax.imshow(volume[:, :, initial_slice], cmap='gray')

# # Create a slider for selecting the slice
# ax_slider = plt.axes([0.2, 0.03, 0.6, 0.05])
# slider = Slider(ax=ax_slider, label='Slice', valmin=0, valmax=volume.shape[2] - 1, valinit=initial_slice, valstep=1)

# # Update the plot when the slider value changes
# def update_slice(val):
#     current_slice.set_data(volume[:, :, int(val)])
#     fig.canvas.draw_idle()

# slider.on_changed(update_slice)

# # Set up plot settings
# plt.subplots_adjust(hspace=0.4, wspace=0.2, bottom=0.15)

# # Display the plot
# plt.show()

# %%
plt.figure("check", (10, 5))
train_slice_no = 18
val_slice_no = 18

plt.subplot(2, 4, 1)
plt.title("fixed_train_img_\n Slice: "+str(train_slice_no))
plt.imshow(fixed_train_img_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 2)
plt.title("fixed_train_msk_\n Slice: "+str(train_slice_no))
plt.imshow(fixed_train_msk_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 3)
plt.title("moving_train_img_\n Slice: "+str(train_slice_no))
plt.imshow(moving_train_img_[:,:,train_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 4)
plt.title("moving_train_msk_\n Slice: "+str(train_slice_no))
plt.imshow(moving_train_msk_[:,:,train_slice_no], cmap="gray")
plt.axis('off')


plt.subplot(2, 4, 5)
plt.title("fixed_val_img_\n Slice: "+str(val_slice_no))
plt.imshow(fixed_val_img_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 6)
plt.title("fixed_val_msk_\n Slice: "+str(val_slice_no))
plt.imshow(fixed_val_msk_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 7)
plt.title("moving_val_img_\n Slice: "+str(val_slice_no))
plt.imshow(moving_val_img_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.subplot(2, 4, 8)
plt.title("moving_val_msk_\n Slice: "+str(val_slice_no))
plt.imshow(moving_val_msk_[:,:,val_slice_no], cmap="gray")
plt.axis('off')

plt.show()

# %%
mod = RegUNet(
    spatial_dims=3,
    in_channels=2,
    num_channel_initial=32,
    depth = 3,
    extract_levels=[3],
    out_activation=None,
    out_channels=3,
    out_kernel_initializer="zeros",
    concat_skip=False)

        

inputs = torch.randn((1, 2, img_size, img_size, slice_size))

y = mod(inputs)
print(y.shape)

import torch, torchinfo
# from torchviz import make_dot, make_dot_from_trace
    
# make_dot(y, params=dict(mod.named_parameters()),
#          show_attrs=False,
#          show_saved=False).render(fileNames, format="png")

torchinfo.summary(mod, input_size=(1, 2, img_size, img_size, slice_size), depth=10)
# Out:
# torch.Size([1, 3, 256, 256, 32])
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# RegUNet                                            [1, 3, 256, 256, 32]      --
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─Sequential: 2-1                             [1, 32, 256, 256, 32]     --
# │    │    └─Convolution: 3-1                       [1, 32, 256, 256, 32]     --
# │    │    │    └─Conv3d: 4-1                       [1, 32, 256, 256, 32]     1,728
# │    │    │    └─ADN: 4-2                          [1, 32, 256, 256, 32]     --
# │    │    │    │    └─BatchNorm3d: 5-1             [1, 32, 256, 256, 32]     64
# │    │    │    │    └─ReLU: 5-2                    [1, 32, 256, 256, 32]     --
# │    │    └─RegistrationResidualConvBlock: 3-2     [1, 32, 256, 256, 32]     --
# │    │    │    └─ModuleList: 4-6                   --                        (recursive)
# │    │    │    │    └─Convolution: 5-3             [1, 32, 256, 256, 32]     --
# │    │    │    │    │    └─Conv3d: 6-1             [1, 32, 256, 256, 32]     27,648
# │    │    │    └─ModuleList: 4-7                   --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-4             [1, 32, 256, 256, 32]     64
# │    │    │    └─ModuleList: 4-8                   --                        --
# │    │    │    │    └─ReLU: 5-5                    [1, 32, 256, 256, 32]     --
# │    │    │    └─ModuleList: 4-6                   --                        (recursive)
# │    │    │    │    └─Convolution: 5-6             [1, 32, 256, 256, 32]     --
# │    │    │    │    │    └─Conv3d: 6-2             [1, 32, 256, 256, 32]     27,648
# │    │    │    └─ModuleList: 4-7                   --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-7             [1, 32, 256, 256, 32]     64
# │    │    │    └─ModuleList: 4-8                   --                        --
# │    │    │    │    └─ReLU: 5-8                    [1, 32, 256, 256, 32]     --
# ├─ModuleList: 1-6                                  --                        --
# │    └─RegistrationDownSampleBlock: 2-2            [1, 32, 128, 128, 16]     --
# │    │    └─MaxPool3d: 3-3                         [1, 32, 128, 128, 16]     --
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─Sequential: 2-3                             [1, 64, 128, 128, 16]     --
# │    │    └─Convolution: 3-4                       [1, 64, 128, 128, 16]     --
# │    │    │    └─Conv3d: 4-9                       [1, 64, 128, 128, 16]     55,296
# │    │    │    └─ADN: 4-10                         [1, 64, 128, 128, 16]     --
# │    │    │    │    └─BatchNorm3d: 5-9             [1, 64, 128, 128, 16]     128
# │    │    │    │    └─ReLU: 5-10                   [1, 64, 128, 128, 16]     --
# │    │    └─RegistrationResidualConvBlock: 3-5     [1, 64, 128, 128, 16]     --
# │    │    │    └─ModuleList: 4-14                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-11            [1, 64, 128, 128, 16]     --
# │    │    │    │    │    └─Conv3d: 6-3             [1, 64, 128, 128, 16]     110,592
# │    │    │    └─ModuleList: 4-15                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-12            [1, 64, 128, 128, 16]     128
# │    │    │    └─ModuleList: 4-16                  --                        --
# │    │    │    │    └─ReLU: 5-13                   [1, 64, 128, 128, 16]     --
# │    │    │    └─ModuleList: 4-14                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-14            [1, 64, 128, 128, 16]     --
# │    │    │    │    │    └─Conv3d: 6-4             [1, 64, 128, 128, 16]     110,592
# │    │    │    └─ModuleList: 4-15                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-15            [1, 64, 128, 128, 16]     128
# │    │    │    └─ModuleList: 4-16                  --                        --
# │    │    │    │    └─ReLU: 5-16                   [1, 64, 128, 128, 16]     --
# ├─ModuleList: 1-6                                  --                        --
# │    └─RegistrationDownSampleBlock: 2-4            [1, 64, 64, 64, 8]        --
# │    │    └─MaxPool3d: 3-6                         [1, 64, 64, 64, 8]        --
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─Sequential: 2-5                             [1, 128, 64, 64, 8]       --
# │    │    └─Convolution: 3-7                       [1, 128, 64, 64, 8]       --
# │    │    │    └─Conv3d: 4-17                      [1, 128, 64, 64, 8]       221,184
# │    │    │    └─ADN: 4-18                         [1, 128, 64, 64, 8]       --
# │    │    │    │    └─BatchNorm3d: 5-17            [1, 128, 64, 64, 8]       256
# │    │    │    │    └─ReLU: 5-18                   [1, 128, 64, 64, 8]       --
# │    │    └─RegistrationResidualConvBlock: 3-8     [1, 128, 64, 64, 8]       --
# │    │    │    └─ModuleList: 4-22                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-19            [1, 128, 64, 64, 8]       --
# │    │    │    │    │    └─Conv3d: 6-5             [1, 128, 64, 64, 8]       442,368
# │    │    │    └─ModuleList: 4-23                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-20            [1, 128, 64, 64, 8]       256
# │    │    │    └─ModuleList: 4-24                  --                        --
# │    │    │    │    └─ReLU: 5-21                   [1, 128, 64, 64, 8]       --
# │    │    │    └─ModuleList: 4-22                  --                        (recursive)
# │    │    │    │    └─Convolution: 5-22            [1, 128, 64, 64, 8]       --
# │    │    │    │    │    └─Conv3d: 6-6             [1, 128, 64, 64, 8]       442,368
# │    │    │    └─ModuleList: 4-23                  --                        (recursive)
# │    │    │    │    └─BatchNorm3d: 5-23            [1, 128, 64, 64, 8]       256
# │    │    │    └─ModuleList: 4-24                  --                        --
# │    │    │    │    └─ReLU: 5-24                   [1, 128, 64, 64, 8]       --
# ├─ModuleList: 1-6                                  --                        --
# │    └─RegistrationDownSampleBlock: 2-6            [1, 128, 32, 32, 4]       --
# │    │    └─MaxPool3d: 3-9                         [1, 128, 32, 32, 4]       --
# ├─Sequential: 1-7                                  [1, 256, 32, 32, 4]       --
# │    └─Convolution: 2-7                            [1, 256, 32, 32, 4]       --
# │    │    └─Conv3d: 3-10                           [1, 256, 32, 32, 4]       884,736
# │    │    └─ADN: 3-11                              [1, 256, 32, 32, 4]       --
# │    │    │    └─BatchNorm3d: 4-25                 [1, 256, 32, 32, 4]       512
# │    │    │    └─ReLU: 4-26                        [1, 256, 32, 32, 4]       --
# │    └─RegistrationResidualConvBlock: 2-8          [1, 256, 32, 32, 4]       --
# │    │    └─ModuleList: 3-15                       --                        (recursive)
# │    │    │    └─Convolution: 4-27                 [1, 256, 32, 32, 4]       --
# │    │    │    │    └─Conv3d: 5-25                 [1, 256, 32, 32, 4]       1,769,472
# │    │    └─ModuleList: 3-16                       --                        (recursive)
# │    │    │    └─BatchNorm3d: 4-28                 [1, 256, 32, 32, 4]       512
# │    │    └─ModuleList: 3-17                       --                        --
# │    │    │    └─ReLU: 4-29                        [1, 256, 32, 32, 4]       --
# │    │    └─ModuleList: 3-15                       --                        (recursive)
# │    │    │    └─Convolution: 4-30                 [1, 256, 32, 32, 4]       --
# │    │    │    │    └─Conv3d: 5-26                 [1, 256, 32, 32, 4]       1,769,472
# │    │    └─ModuleList: 3-16                       --                        (recursive)
# │    │    │    └─BatchNorm3d: 4-31                 [1, 256, 32, 32, 4]       512
# │    │    └─ModuleList: 3-17                       --                        --
# │    │    │    └─ReLU: 4-32                        [1, 256, 32, 32, 4]       --
# ├─RegistrationExtractionBlock: 1-8                 [1, 3, 256, 256, 32]      --
# │    └─ModuleList: 2-9                             --                        --
# │    │    └─Convolution: 3-18                      [1, 3, 32, 32, 4]         --
# │    │    │    └─Conv3d: 4-33                      [1, 3, 32, 32, 4]         20,736
# ====================================================================================================
# Total params: 5,886,720
# Trainable params: 5,886,720
# Non-trainable params: 0
# Total mult-adds (G): 246.51
# ====================================================================================================
# Input size (MB): 16.78
# Forward/backward pass size (MB): 4278.29
# Params size (MB): 23.55
# Estimated Total Size (MB): 4318.61
# ====================================================================================================

# %%
model = mod.to(device)

if preTrained:
    model.load_state_dict(torch.load(os.path.join(root_dir, ExpName + '_' + dataDir + '_' +str(previousWeight) + '_'+'.pth')))


warp_layer = Warp().to(device)

# image_loss = MSELoss()

image_loss = GlobalMutualInformationLoss()

# class SSIMLoss(SSIM):
#     def forward(self, x, y):
#         return 1. - super().forward(x, y)
    

# label_SSIM = SSIMLoss(n_channels=1).to(device) # .cuda() if you need GPU support

label_loss = DiceLoss()

# label_loss = MultiScaleLoss(label_loss, scales=[0, 1, 2, 4, 8, 16])

regularization = BendingEnergyLoss()

optimizer = torch.optim.Adam(model.parameters(), 0.0002)

# exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.5, verbose=True)

dice_metric = DiceMetric(include_background=True, reduction="mean", get_not_nans=False)

# dice_metric = compute_meandice(y_pred, y, include_background=True)
# Out:
# monai.networks.blocks.Warp: Using PyTorch native grid_sample.

# %%
def make_one_hot(labels, C=2):
    '''
    Converts an integer label torch.Tensor to a one-hot Tensor.
    
    Parameters
    ----------
    labels : torch.Tensor
        N x 1 x D x H x W, where N is batch size. 
        Each value is an integer representing correct classification.
    C : integer
        Number of classes in labels.
    
    Returns
    -------
    target : torch.Tensor
        N x C x D x H x W, where C is class number. One-hot encoded.
    '''
    labels = labels.long()
    one_hot = torch.zeros(labels.size(0), C, labels.size(2), labels.size(3), labels.size(4)).to(device)
    labels = labels.squeeze(1)
    target = one_hot.scatter_(1, labels.unsqueeze(1), 1)
        
    return target

# %%
max_epochs = EP
epoch_loss_values = []
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
epoch_val_loss_values = []
epoch_loss_d_values = []
epoch_loss_g_values = []
metric_values = []
best_loss = 1e10
best_dsc = 0
k=1


for epoch in range(max_epochs):
    print("-" * 100)
    print(f"Epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss, step = 0, 0

    epoch_DSC, epoch_L2, epoch_MI, epoch_ddf = 0, 0, 0, 0

    epoch_loss_d, epoch_loss_g=0,0
    
    for fixed_train_img_, fixed_train_msk_, moving_train_img_, moving_train_msk_ in zip(fixed_train_img,
                                                                                    fixed_train_msk, moving_train_img,
                                                                                    moving_train_msk):    
        step += 1
        
        optimizer.zero_grad()
        # optim_d.zero_grad()

        fixed_train_img_ = fixed_train_img_.to(device)
        fixed_train_msk_ = fixed_train_msk_.to(device)
        moving_train_img_ = moving_train_img_.to(device)
        moving_train_msk_ = moving_train_msk_.to(device)
        
        ddf_train = model(torch.cat((moving_train_img_, fixed_train_img_), dim=1))
        
        pred_image_train = warp_layer(moving_train_img_, ddf_train)
        pred_mask_train = warp_layer(moving_train_msk_, ddf_train)

        # real_label = label_real(fixed_train_img_.size(0))
        # fake_label = label_fake(fixed_train_img_.size(0))


        # output_real = discriminator(fixed_train_img_)
        # loss_real = criterion(output_real, real_label)
        # loss_real.backward()

        # output_fake = discriminator(pred_image_train.detach())
        # loss_fake = criterion(output_fake, fake_label)
        # loss_fake.backward()

        # optim_d.step()

        # loss_d = (loss_real + loss_fake)/2

        # epoch_loss_d += loss_d.item()

        # output = discriminator(pred_image_train)
        
        # loss_g = criterion(output, real_label)

        imageLOSS = image_loss(pred_image_train, fixed_train_img_)
        
        labelDSC = label_loss(fixed_train_msk_, pred_mask_train)

        # labelDSC = label_loss(make_one_hot(pred_mask_train, C=3), make_one_hot(fixed_train_msk_, C=3))

        # labelGlobal =  globalLoss(fixed_train_msk_, pred_mask_train)-1
        
        regLOSS  = regularization(ddf_train)

        loss = imageLOSS 
    
        # loss_g.backward(retain_graph=True)
        loss.backward()

        optimizer.step()
        
        epoch_loss += loss.item()

        # epoch_loss_g += loss_g.item()
        epoch_DSC += labelDSC.item()
        # epoch_L2 += labelGlobal.item()
        epoch_MI += imageLOSS.item()
        epoch_ddf += regLOSS.item()


        
        dice_metric(y_pred = make_one_hot(pred_mask_train, C=3), y=make_one_hot(fixed_train_msk_, C=3))

    # exp_lr_scheduler.step()
    for param_group in optimizer.param_groups:
        print("LR is == ", param_group['lr'])


    metric = dice_metric.aggregate().item()
    dice_metric.reset()
    epoch_loss /= step

    # epoch_loss_g /=step
    # epoch_loss_d /= step

    epoch_DSC /= step
    # epoch_L2 /= step
    epoch_MI /= step
    epoch_ddf /= step

    epoch_loss_values.append(epoch_loss)
    # epoch_loss_d_values.append(epoch_loss_d)
    # epoch_loss_g_values.append(epoch_loss_g)

    print(f"For epoch: {epoch + 1}, Average train loss: {epoch_loss:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train DSC: {metric:.5f} !\n")

    print(f"For epoch: {epoch + 1}, Average train DSC: {epoch_DSC:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train L2: {epoch_L2:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train MI: {epoch_MI:.5f} !")
    print(f"For epoch: {epoch + 1}, Average train DDF: {epoch_ddf:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train D Loss: {epoch_loss_d:.5f} !")
    # print(f"For epoch: {epoch + 1}, Average train G Loss: {epoch_loss_g:.5f} !")
    
    print("-" * 60)
    if (epoch + 1) % val_interval == 0 or epoch == 0:
        model.eval()
        val_loss = 0
        val_met = 0
        step = 0
        with torch.no_grad():
            for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk):  

                fixed_val_img_ = fixed_val_img_.to(device)
                fixed_val_msk_ = fixed_val_msk_.to(device)
                
                moving_val_img_ = moving_val_img_.to(device)
                moving_val_msk_ = moving_val_msk_.to(device)
                
                
                ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))
                
                pred_image_val = warp_layer(moving_val_img_, ddf_val)
                pred_mask_val = warp_layer(moving_val_msk_, ddf_val)

                # real_label = label_real(pred_image_val.size(0))
        
                # output = discriminator(pred_image_val)
        
                # loss_g = criterion(output, real_label)

                imageLOSS = image_loss(pred_image_val, fixed_val_img_)

                labelDSC = label_loss(fixed_val_msk_, pred_mask_val)

                # labelDSC = label_loss(make_one_hot(pred_mask_val, C=3), make_one_hot(fixed_val_msk_, C=3))

                # labelGlobal =  globalLoss(fixed_val_msk_, pred_mask_val)-1

                regLOSS  = regularization(ddf_val)


                loss = imageLOSS
                
                
    
                val_loss += loss.item()
                step += 1

                
                dice_metric(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))
                

            val_loss /= step
            epoch_val_loss_values.append(val_loss)
            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            dice_metric.reset()
            
            if metric > best_dsc:
                best_loss_epoch = epoch + 1
                torch.save(model.state_dict(),
                           os.path.join(root_dir, fileNames+'.pth'))
                print(f"Valid DSC improved from {best_dsc:2.4f} to {metric:2.4f}! Best model is saving as---> {fileNames+'.pth'}")
                best_dsc = metric
                
            print(
                f"\nCurrent mean dice: {metric:.4f} "
                f"\t and \t Current val loss: {val_loss:.4f}\n\n"
                f"Best val DSC: {best_dsc:.4f} "
                f"at epoch number of {best_loss_epoch}")
# Out:
# ----------------------------------------------------------------------------------------------------
# Epoch 1/100
# LR is ==  0.0002
# For epoch: 1, Average train loss: -0.70048 !
# For epoch: 1, Average train DSC: 0.77261 !
#
# For epoch: 1, Average train DSC: -0.45758 !
# For epoch: 1, Average train MI: -0.70048 !
# For epoch: 1, Average train DDF: 0.04271 !
# ------------------------------------------------------------
# Valid DSC improved from 0.0000 to 0.7467! Best model is saving as---> Vanilla_DLIR_v4_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7467 	 and 	 Current val loss: -0.8102
#
# Best val DSC: 0.7467 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 2/100
# LR is ==  0.0002
# For epoch: 2, Average train loss: -0.69903 !
# For epoch: 2, Average train DSC: 0.76688 !
#
# For epoch: 2, Average train DSC: -0.44439 !
# For epoch: 2, Average train MI: -0.69903 !
# For epoch: 2, Average train DDF: 0.05722 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7377 	 and 	 Current val loss: -0.8342
#
# Best val DSC: 0.7467 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 3/100
# LR is ==  0.0002
# For epoch: 3, Average train loss: -0.70656 !
# For epoch: 3, Average train DSC: 0.76636 !
#
# For epoch: 3, Average train DSC: -0.43115 !
# For epoch: 3, Average train MI: -0.70656 !
# For epoch: 3, Average train DDF: 0.10960 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7380 	 and 	 Current val loss: -0.8355
#
# Best val DSC: 0.7467 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 4/100
# LR is ==  0.0002
# For epoch: 4, Average train loss: -0.71040 !
# For epoch: 4, Average train DSC: 0.76106 !
#
# For epoch: 4, Average train DSC: -0.43815 !
# For epoch: 4, Average train MI: -0.71040 !
# For epoch: 4, Average train DDF: 0.13945 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7425 	 and 	 Current val loss: -0.8345
#
# Best val DSC: 0.7467 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 5/100
# LR is ==  0.0002
# For epoch: 5, Average train loss: -0.71517 !
# For epoch: 5, Average train DSC: 0.76394 !
#
# For epoch: 5, Average train DSC: -0.43662 !
# For epoch: 5, Average train MI: -0.71517 !
# For epoch: 5, Average train DDF: 0.13256 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7444 	 and 	 Current val loss: -0.8285
#
# Best val DSC: 0.7467 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 6/100
# LR is ==  0.0002
# For epoch: 6, Average train loss: -0.72197 !
# For epoch: 6, Average train DSC: 0.76642 !
#
# For epoch: 6, Average train DSC: -0.44491 !
# For epoch: 6, Average train MI: -0.72197 !
# For epoch: 6, Average train DDF: 0.16208 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7343 	 and 	 Current val loss: -0.8173
#
# Best val DSC: 0.7467 at epoch number of 1
# ----------------------------------------------------------------------------------------------------
# Epoch 7/100
# LR is ==  0.0002
# For epoch: 7, Average train loss: -0.73074 !
# For epoch: 7, Average train DSC: 0.76857 !
#
# For epoch: 7, Average train DSC: -0.45009 !
# For epoch: 7, Average train MI: -0.73074 !
# For epoch: 7, Average train DDF: 0.19722 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7467 to 0.7470! Best model is saving as---> Vanilla_DLIR_v4_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7470 	 and 	 Current val loss: -0.8390
#
# Best val DSC: 0.7470 at epoch number of 7
# ----------------------------------------------------------------------------------------------------
# Epoch 8/100
# LR is ==  0.0002
# For epoch: 8, Average train loss: -0.73777 !
# For epoch: 8, Average train DSC: 0.77313 !
#
# For epoch: 8, Average train DSC: -0.45453 !
# For epoch: 8, Average train MI: -0.73777 !
# For epoch: 8, Average train DDF: 0.18463 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7470 to 0.7479! Best model is saving as---> Vanilla_DLIR_v4_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7479 	 and 	 Current val loss: -0.8512
#
# Best val DSC: 0.7479 at epoch number of 8
# ----------------------------------------------------------------------------------------------------
# Epoch 9/100
# LR is ==  0.0002
# For epoch: 9, Average train loss: -0.74995 !
# For epoch: 9, Average train DSC: 0.77879 !
#
# For epoch: 9, Average train DSC: -0.46070 !
# For epoch: 9, Average train MI: -0.74995 !
# For epoch: 9, Average train DDF: 0.20426 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7479 to 0.7518! Best model is saving as---> Vanilla_DLIR_v4_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7518 	 and 	 Current val loss: -0.8521
#
# Best val DSC: 0.7518 at epoch number of 9
# ----------------------------------------------------------------------------------------------------
# Epoch 10/100
# LR is ==  0.0002
# For epoch: 10, Average train loss: -0.76147 !
# For epoch: 10, Average train DSC: 0.78096 !
#
# For epoch: 10, Average train DSC: -0.46493 !
# For epoch: 10, Average train MI: -0.76147 !
# For epoch: 10, Average train DDF: 0.22956 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7518 to 0.7583! Best model is saving as---> Vanilla_DLIR_v4_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7583 	 and 	 Current val loss: -0.8547
#
# Best val DSC: 0.7583 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 11/100
# LR is ==  0.0002
# For epoch: 11, Average train loss: -0.76901 !
# For epoch: 11, Average train DSC: 0.78238 !
#
# For epoch: 11, Average train DSC: -0.46550 !
# For epoch: 11, Average train MI: -0.76901 !
# For epoch: 11, Average train DDF: 0.25423 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7551 	 and 	 Current val loss: -0.8538
#
# Best val DSC: 0.7583 at epoch number of 10
# ----------------------------------------------------------------------------------------------------
# Epoch 12/100
# LR is ==  0.0002
# For epoch: 12, Average train loss: -0.77480 !
# For epoch: 12, Average train DSC: 0.78512 !
#
# For epoch: 12, Average train DSC: -0.47020 !
# For epoch: 12, Average train MI: -0.77480 !
# For epoch: 12, Average train DDF: 0.27651 !
# ------------------------------------------------------------
# Valid DSC improved from 0.7583 to 0.7585! Best model is saving as---> Vanilla_DLIR_v4_ESED_3D_Updated_256_32_.pth
#
# Current mean dice: 0.7585 	 and 	 Current val loss: -0.8551
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 13/100
# LR is ==  0.0002
# For epoch: 13, Average train loss: -0.78074 !
# For epoch: 13, Average train DSC: 0.78543 !
#
# For epoch: 13, Average train DSC: -0.47275 !
# For epoch: 13, Average train MI: -0.78074 !
# For epoch: 13, Average train DDF: 0.27591 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7539 	 and 	 Current val loss: -0.8629
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 14/100
# LR is ==  0.0002
# For epoch: 14, Average train loss: -0.78544 !
# For epoch: 14, Average train DSC: 0.78292 !
#
# For epoch: 14, Average train DSC: -0.47154 !
# For epoch: 14, Average train MI: -0.78544 !
# For epoch: 14, Average train DDF: 0.27133 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7526 	 and 	 Current val loss: -0.8699
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 15/100
# LR is ==  0.0002
# For epoch: 15, Average train loss: -0.79483 !
# For epoch: 15, Average train DSC: 0.78781 !
#
# For epoch: 15, Average train DSC: -0.47828 !
# For epoch: 15, Average train MI: -0.79483 !
# For epoch: 15, Average train DDF: 0.28361 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7513 	 and 	 Current val loss: -0.8696
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 16/100
# LR is ==  0.0002
# For epoch: 16, Average train loss: -0.79928 !
# For epoch: 16, Average train DSC: 0.78748 !
#
# For epoch: 16, Average train DSC: -0.48062 !
# For epoch: 16, Average train MI: -0.79928 !
# For epoch: 16, Average train DDF: 0.28807 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7509 	 and 	 Current val loss: -0.8725
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 17/100
# LR is ==  0.0002
# For epoch: 17, Average train loss: -0.80505 !
# For epoch: 17, Average train DSC: 0.78900 !
#
# For epoch: 17, Average train DSC: -0.48579 !
# For epoch: 17, Average train MI: -0.80505 !
# For epoch: 17, Average train DDF: 0.30163 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7392 	 and 	 Current val loss: -0.8472
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 18/100
# LR is ==  0.0002
# For epoch: 18, Average train loss: -0.81014 !
# For epoch: 18, Average train DSC: 0.78733 !
#
# For epoch: 18, Average train DSC: -0.48466 !
# For epoch: 18, Average train MI: -0.81014 !
# For epoch: 18, Average train DDF: 0.30805 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7365 	 and 	 Current val loss: -0.8278
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 19/100
# LR is ==  0.0002
# For epoch: 19, Average train loss: -0.81375 !
# For epoch: 19, Average train DSC: 0.78720 !
#
# For epoch: 19, Average train DSC: -0.48148 !
# For epoch: 19, Average train MI: -0.81375 !
# For epoch: 19, Average train DDF: 0.31960 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7373 	 and 	 Current val loss: -0.8168
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 20/100
# LR is ==  0.0002
# For epoch: 20, Average train loss: -0.81681 !
# For epoch: 20, Average train DSC: 0.78357 !
#
# For epoch: 20, Average train DSC: -0.47844 !
# For epoch: 20, Average train MI: -0.81681 !
# For epoch: 20, Average train DDF: 0.33725 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7472 	 and 	 Current val loss: -0.8554
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 21/100
# LR is ==  0.0002
# For epoch: 21, Average train loss: -0.82528 !
# For epoch: 21, Average train DSC: 0.78743 !
#
# For epoch: 21, Average train DSC: -0.48344 !
# For epoch: 21, Average train MI: -0.82528 !
# For epoch: 21, Average train DDF: 0.34438 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7422 	 and 	 Current val loss: -0.8483
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 22/100
# LR is ==  0.0002
# For epoch: 22, Average train loss: -0.83216 !
# For epoch: 22, Average train DSC: 0.78968 !
#
# For epoch: 22, Average train DSC: -0.48501 !
# For epoch: 22, Average train MI: -0.83216 !
# For epoch: 22, Average train DDF: 0.35817 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7415 	 and 	 Current val loss: -0.8563
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 23/100
# LR is ==  0.0002
# For epoch: 23, Average train loss: -0.83662 !
# For epoch: 23, Average train DSC: 0.78694 !
#
# For epoch: 23, Average train DSC: -0.48371 !
# For epoch: 23, Average train MI: -0.83662 !
# For epoch: 23, Average train DDF: 0.37292 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7420 	 and 	 Current val loss: -0.8457
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 24/100
# LR is ==  0.0002
# For epoch: 24, Average train loss: -0.84135 !
# For epoch: 24, Average train DSC: 0.78803 !
#
# For epoch: 24, Average train DSC: -0.48618 !
# For epoch: 24, Average train MI: -0.84135 !
# For epoch: 24, Average train DDF: 0.40009 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7458 	 and 	 Current val loss: -0.8822
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 25/100
# LR is ==  0.0002
# For epoch: 25, Average train loss: -0.84144 !
# For epoch: 25, Average train DSC: 0.78789 !
#
# For epoch: 25, Average train DSC: -0.48574 !
# For epoch: 25, Average train MI: -0.84144 !
# For epoch: 25, Average train DDF: 0.41336 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7504 	 and 	 Current val loss: -0.8591
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 26/100
# LR is ==  0.0002
# For epoch: 26, Average train loss: -0.84368 !
# For epoch: 26, Average train DSC: 0.78942 !
#
# For epoch: 26, Average train DSC: -0.48687 !
# For epoch: 26, Average train MI: -0.84368 !
# For epoch: 26, Average train DDF: 0.40596 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7469 	 and 	 Current val loss: -0.8139
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 27/100
# LR is ==  0.0002
# For epoch: 27, Average train loss: -0.84866 !
# For epoch: 27, Average train DSC: 0.78597 !
#
# For epoch: 27, Average train DSC: -0.48508 !
# For epoch: 27, Average train MI: -0.84866 !
# For epoch: 27, Average train DDF: 0.40144 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7506 	 and 	 Current val loss: -0.8584
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 28/100
# LR is ==  0.0002
# For epoch: 28, Average train loss: -0.85181 !
# For epoch: 28, Average train DSC: 0.78842 !
#
# For epoch: 28, Average train DSC: -0.48822 !
# For epoch: 28, Average train MI: -0.85181 !
# For epoch: 28, Average train DDF: 0.40419 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7456 	 and 	 Current val loss: -0.8912
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 29/100
# LR is ==  0.0002
# For epoch: 29, Average train loss: -0.85331 !
# For epoch: 29, Average train DSC: 0.78921 !
#
# For epoch: 29, Average train DSC: -0.49061 !
# For epoch: 29, Average train MI: -0.85331 !
# For epoch: 29, Average train DDF: 0.42977 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7496 	 and 	 Current val loss: -0.8875
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 30/100
# LR is ==  0.0002
# For epoch: 30, Average train loss: -0.85392 !
# For epoch: 30, Average train DSC: 0.78825 !
#
# For epoch: 30, Average train DSC: -0.48883 !
# For epoch: 30, Average train MI: -0.85392 !
# For epoch: 30, Average train DDF: 0.42648 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7546 	 and 	 Current val loss: -0.8874
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 31/100
# LR is ==  0.0002
# For epoch: 31, Average train loss: -0.85771 !
# For epoch: 31, Average train DSC: 0.78823 !
#
# For epoch: 31, Average train DSC: -0.48578 !
# For epoch: 31, Average train MI: -0.85771 !
# For epoch: 31, Average train DDF: 0.44196 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7548 	 and 	 Current val loss: -0.8985
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 32/100
# LR is ==  0.0002
# For epoch: 32, Average train loss: -0.85889 !
# For epoch: 32, Average train DSC: 0.79070 !
#
# For epoch: 32, Average train DSC: -0.49059 !
# For epoch: 32, Average train MI: -0.85889 !
# For epoch: 32, Average train DDF: 0.45533 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7454 	 and 	 Current val loss: -0.8950
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 33/100
# LR is ==  0.0002
# For epoch: 33, Average train loss: -0.85817 !
# For epoch: 33, Average train DSC: 0.78738 !
#
# For epoch: 33, Average train DSC: -0.48496 !
# For epoch: 33, Average train MI: -0.85817 !
# For epoch: 33, Average train DDF: 0.47750 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7515 	 and 	 Current val loss: -0.8921
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 34/100
# LR is ==  0.0002
# For epoch: 34, Average train loss: -0.86398 !
# For epoch: 34, Average train DSC: 0.78696 !
#
# For epoch: 34, Average train DSC: -0.48523 !
# For epoch: 34, Average train MI: -0.86398 !
# For epoch: 34, Average train DDF: 0.46885 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7545 	 and 	 Current val loss: -0.8964
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 35/100
# LR is ==  0.0002
# For epoch: 35, Average train loss: -0.86321 !
# For epoch: 35, Average train DSC: 0.78766 !
#
# For epoch: 35, Average train DSC: -0.48285 !
# For epoch: 35, Average train MI: -0.86321 !
# For epoch: 35, Average train DDF: 0.46102 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7576 	 and 	 Current val loss: -0.8959
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 36/100
# LR is ==  0.0002
# For epoch: 36, Average train loss: -0.86882 !
# For epoch: 36, Average train DSC: 0.78742 !
#
# For epoch: 36, Average train DSC: -0.48455 !
# For epoch: 36, Average train MI: -0.86882 !
# For epoch: 36, Average train DDF: 0.48966 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7533 	 and 	 Current val loss: -0.8945
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 37/100
# LR is ==  0.0002
# For epoch: 37, Average train loss: -0.86886 !
# For epoch: 37, Average train DSC: 0.78747 !
#
# For epoch: 37, Average train DSC: -0.48624 !
# For epoch: 37, Average train MI: -0.86886 !
# For epoch: 37, Average train DDF: 0.50531 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7508 	 and 	 Current val loss: -0.8907
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 38/100
# LR is ==  0.0002
# For epoch: 38, Average train loss: -0.87669 !
# For epoch: 38, Average train DSC: 0.78748 !
#
# For epoch: 38, Average train DSC: -0.48728 !
# For epoch: 38, Average train MI: -0.87669 !
# For epoch: 38, Average train DDF: 0.53012 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7432 	 and 	 Current val loss: -0.8901
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 39/100
# LR is ==  0.0002
# For epoch: 39, Average train loss: -0.87675 !
# For epoch: 39, Average train DSC: 0.78772 !
#
# For epoch: 39, Average train DSC: -0.48595 !
# For epoch: 39, Average train MI: -0.87675 !
# For epoch: 39, Average train DDF: 0.53144 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7474 	 and 	 Current val loss: -0.9041
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 40/100
# LR is ==  0.0002
# For epoch: 40, Average train loss: -0.87910 !
# For epoch: 40, Average train DSC: 0.78836 !
#
# For epoch: 40, Average train DSC: -0.48764 !
# For epoch: 40, Average train MI: -0.87910 !
# For epoch: 40, Average train DDF: 0.54972 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7480 	 and 	 Current val loss: -0.9018
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 41/100
# LR is ==  0.0002
# For epoch: 41, Average train loss: -0.88157 !
# For epoch: 41, Average train DSC: 0.78437 !
#
# For epoch: 41, Average train DSC: -0.48246 !
# For epoch: 41, Average train MI: -0.88157 !
# For epoch: 41, Average train DDF: 0.55470 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7461 	 and 	 Current val loss: -0.8936
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 42/100
# LR is ==  0.0002
# For epoch: 42, Average train loss: -0.87878 !
# For epoch: 42, Average train DSC: 0.78786 !
#
# For epoch: 42, Average train DSC: -0.48561 !
# For epoch: 42, Average train MI: -0.87878 !
# For epoch: 42, Average train DDF: 0.58461 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7460 	 and 	 Current val loss: -0.8989
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 43/100
# LR is ==  0.0002
# For epoch: 43, Average train loss: -0.88231 !
# For epoch: 43, Average train DSC: 0.78737 !
#
# For epoch: 43, Average train DSC: -0.48931 !
# For epoch: 43, Average train MI: -0.88231 !
# For epoch: 43, Average train DDF: 0.57218 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7401 	 and 	 Current val loss: -0.8965
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 44/100
# LR is ==  0.0002
# For epoch: 44, Average train loss: -0.88293 !
# For epoch: 44, Average train DSC: 0.78751 !
#
# For epoch: 44, Average train DSC: -0.48562 !
# For epoch: 44, Average train MI: -0.88293 !
# For epoch: 44, Average train DDF: 0.57521 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7436 	 and 	 Current val loss: -0.8996
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 45/100
# LR is ==  0.0002
# For epoch: 45, Average train loss: -0.88643 !
# For epoch: 45, Average train DSC: 0.78778 !
#
# For epoch: 45, Average train DSC: -0.48752 !
# For epoch: 45, Average train MI: -0.88643 !
# For epoch: 45, Average train DDF: 0.59337 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7443 	 and 	 Current val loss: -0.9033
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 46/100
# LR is ==  0.0002
# For epoch: 46, Average train loss: -0.88796 !
# For epoch: 46, Average train DSC: 0.78815 !
#
# For epoch: 46, Average train DSC: -0.49040 !
# For epoch: 46, Average train MI: -0.88796 !
# For epoch: 46, Average train DDF: 0.61505 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7445 	 and 	 Current val loss: -0.8975
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 47/100
# LR is ==  0.0002
# For epoch: 47, Average train loss: -0.88784 !
# For epoch: 47, Average train DSC: 0.78883 !
#
# For epoch: 47, Average train DSC: -0.48797 !
# For epoch: 47, Average train MI: -0.88784 !
# For epoch: 47, Average train DDF: 0.59777 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7441 	 and 	 Current val loss: -0.8941
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 48/100
# LR is ==  0.0002
# For epoch: 48, Average train loss: -0.88971 !
# For epoch: 48, Average train DSC: 0.78815 !
#
# For epoch: 48, Average train DSC: -0.48878 !
# For epoch: 48, Average train MI: -0.88971 !
# For epoch: 48, Average train DDF: 0.62287 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7471 	 and 	 Current val loss: -0.9040
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 49/100
# LR is ==  0.0002
# For epoch: 49, Average train loss: -0.89252 !
# For epoch: 49, Average train DSC: 0.78767 !
#
# For epoch: 49, Average train DSC: -0.48824 !
# For epoch: 49, Average train MI: -0.89252 !
# For epoch: 49, Average train DDF: 0.62590 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7446 	 and 	 Current val loss: -0.9003
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 50/100
# LR is ==  0.0002
# For epoch: 50, Average train loss: -0.89517 !
# For epoch: 50, Average train DSC: 0.78687 !
#
# For epoch: 50, Average train DSC: -0.48709 !
# For epoch: 50, Average train MI: -0.89517 !
# For epoch: 50, Average train DDF: 0.65558 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7485 	 and 	 Current val loss: -0.9148
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 51/100
# LR is ==  0.0002
# For epoch: 51, Average train loss: -0.89880 !
# For epoch: 51, Average train DSC: 0.78823 !
#
# For epoch: 51, Average train DSC: -0.48850 !
# For epoch: 51, Average train MI: -0.89880 !
# For epoch: 51, Average train DDF: 0.64442 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7508 	 and 	 Current val loss: -0.9047
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 52/100
# LR is ==  0.0002
# For epoch: 52, Average train loss: -0.89792 !
# For epoch: 52, Average train DSC: 0.78880 !
#
# For epoch: 52, Average train DSC: -0.48932 !
# For epoch: 52, Average train MI: -0.89792 !
# For epoch: 52, Average train DDF: 0.65605 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7442 	 and 	 Current val loss: -0.8900
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 53/100
# LR is ==  0.0002
# For epoch: 53, Average train loss: -0.90008 !
# For epoch: 53, Average train DSC: 0.78832 !
#
# For epoch: 53, Average train DSC: -0.49031 !
# For epoch: 53, Average train MI: -0.90008 !
# For epoch: 53, Average train DDF: 0.67758 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7429 	 and 	 Current val loss: -0.8913
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 54/100
# LR is ==  0.0002
# For epoch: 54, Average train loss: -0.89974 !
# For epoch: 54, Average train DSC: 0.78780 !
#
# For epoch: 54, Average train DSC: -0.49041 !
# For epoch: 54, Average train MI: -0.89974 !
# For epoch: 54, Average train DDF: 0.67713 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7465 	 and 	 Current val loss: -0.9108
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 55/100
# LR is ==  0.0002
# For epoch: 55, Average train loss: -0.90070 !
# For epoch: 55, Average train DSC: 0.78706 !
#
# For epoch: 55, Average train DSC: -0.48968 !
# For epoch: 55, Average train MI: -0.90070 !
# For epoch: 55, Average train DDF: 0.69892 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7456 	 and 	 Current val loss: -0.8981
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 56/100
# LR is ==  0.0002
# For epoch: 56, Average train loss: -0.90116 !
# For epoch: 56, Average train DSC: 0.78937 !
#
# For epoch: 56, Average train DSC: -0.48985 !
# For epoch: 56, Average train MI: -0.90116 !
# For epoch: 56, Average train DDF: 0.68655 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7483 	 and 	 Current val loss: -0.9063
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 57/100
# LR is ==  0.0002
# For epoch: 57, Average train loss: -0.90490 !
# For epoch: 57, Average train DSC: 0.78817 !
#
# For epoch: 57, Average train DSC: -0.48738 !
# For epoch: 57, Average train MI: -0.90490 !
# For epoch: 57, Average train DDF: 0.70777 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7455 	 and 	 Current val loss: -0.9035
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 58/100
# LR is ==  0.0002
# For epoch: 58, Average train loss: -0.90050 !
# For epoch: 58, Average train DSC: 0.78762 !
#
# For epoch: 58, Average train DSC: -0.48586 !
# For epoch: 58, Average train MI: -0.90050 !
# For epoch: 58, Average train DDF: 0.71852 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7506 	 and 	 Current val loss: -0.9131
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 59/100
# LR is ==  0.0002
# For epoch: 59, Average train loss: -0.89903 !
# For epoch: 59, Average train DSC: 0.78711 !
#
# For epoch: 59, Average train DSC: -0.48703 !
# For epoch: 59, Average train MI: -0.89903 !
# For epoch: 59, Average train DDF: 0.70366 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7504 	 and 	 Current val loss: -0.9208
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 60/100
# LR is ==  0.0002
# For epoch: 60, Average train loss: -0.90663 !
# For epoch: 60, Average train DSC: 0.78734 !
#
# For epoch: 60, Average train DSC: -0.48817 !
# For epoch: 60, Average train MI: -0.90663 !
# For epoch: 60, Average train DDF: 0.73831 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7398 	 and 	 Current val loss: -0.8891
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 61/100
# LR is ==  0.0002
# For epoch: 61, Average train loss: -0.90787 !
# For epoch: 61, Average train DSC: 0.78792 !
#
# For epoch: 61, Average train DSC: -0.48837 !
# For epoch: 61, Average train MI: -0.90787 !
# For epoch: 61, Average train DDF: 0.74201 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7427 	 and 	 Current val loss: -0.9148
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 62/100
# LR is ==  0.0002
# For epoch: 62, Average train loss: -0.91018 !
# For epoch: 62, Average train DSC: 0.78835 !
#
# For epoch: 62, Average train DSC: -0.48740 !
# For epoch: 62, Average train MI: -0.91018 !
# For epoch: 62, Average train DDF: 0.76735 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7441 	 and 	 Current val loss: -0.9196
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 63/100
# LR is ==  0.0002
# For epoch: 63, Average train loss: -0.90656 !
# For epoch: 63, Average train DSC: 0.78723 !
#
# For epoch: 63, Average train DSC: -0.48444 !
# For epoch: 63, Average train MI: -0.90656 !
# For epoch: 63, Average train DDF: 0.75074 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7418 	 and 	 Current val loss: -0.9099
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 64/100
# LR is ==  0.0002
# For epoch: 64, Average train loss: -0.90706 !
# For epoch: 64, Average train DSC: 0.78509 !
#
# For epoch: 64, Average train DSC: -0.48126 !
# For epoch: 64, Average train MI: -0.90706 !
# For epoch: 64, Average train DDF: 0.76993 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7426 	 and 	 Current val loss: -0.9107
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 65/100
# LR is ==  0.0002
# For epoch: 65, Average train loss: -0.90558 !
# For epoch: 65, Average train DSC: 0.78473 !
#
# For epoch: 65, Average train DSC: -0.47767 !
# For epoch: 65, Average train MI: -0.90558 !
# For epoch: 65, Average train DDF: 0.76794 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7398 	 and 	 Current val loss: -0.9115
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 66/100
# LR is ==  0.0002
# For epoch: 66, Average train loss: -0.90513 !
# For epoch: 66, Average train DSC: 0.78458 !
#
# For epoch: 66, Average train DSC: -0.47921 !
# For epoch: 66, Average train MI: -0.90513 !
# For epoch: 66, Average train DDF: 0.79128 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7429 	 and 	 Current val loss: -0.9203
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 67/100
# LR is ==  0.0002
# For epoch: 67, Average train loss: -0.90164 !
# For epoch: 67, Average train DSC: 0.78571 !
#
# For epoch: 67, Average train DSC: -0.48062 !
# For epoch: 67, Average train MI: -0.90164 !
# For epoch: 67, Average train DDF: 0.77215 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7439 	 and 	 Current val loss: -0.9122
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 68/100
# LR is ==  0.0002
# For epoch: 68, Average train loss: -0.90479 !
# For epoch: 68, Average train DSC: 0.78546 !
#
# For epoch: 68, Average train DSC: -0.48067 !
# For epoch: 68, Average train MI: -0.90479 !
# For epoch: 68, Average train DDF: 0.79441 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7411 	 and 	 Current val loss: -0.9002
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 69/100
# LR is ==  0.0002
# For epoch: 69, Average train loss: -0.90740 !
# For epoch: 69, Average train DSC: 0.78568 !
#
# For epoch: 69, Average train DSC: -0.48555 !
# For epoch: 69, Average train MI: -0.90740 !
# For epoch: 69, Average train DDF: 0.81515 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7485 	 and 	 Current val loss: -0.9130
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 70/100
# LR is ==  0.0002
# For epoch: 70, Average train loss: -0.91132 !
# For epoch: 70, Average train DSC: 0.78662 !
#
# For epoch: 70, Average train DSC: -0.48475 !
# For epoch: 70, Average train MI: -0.91132 !
# For epoch: 70, Average train DDF: 0.81851 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7464 	 and 	 Current val loss: -0.9155
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 71/100
# LR is ==  0.0002
# For epoch: 71, Average train loss: -0.91579 !
# For epoch: 71, Average train DSC: 0.78792 !
#
# For epoch: 71, Average train DSC: -0.48670 !
# For epoch: 71, Average train MI: -0.91579 !
# For epoch: 71, Average train DDF: 0.78614 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7404 	 and 	 Current val loss: -0.8947
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 72/100
# LR is ==  0.0002
# For epoch: 72, Average train loss: -0.91567 !
# For epoch: 72, Average train DSC: 0.78725 !
#
# For epoch: 72, Average train DSC: -0.48488 !
# For epoch: 72, Average train MI: -0.91567 !
# For epoch: 72, Average train DDF: 0.83024 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7491 	 and 	 Current val loss: -0.9145
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 73/100
# LR is ==  0.0002
# For epoch: 73, Average train loss: -0.91432 !
# For epoch: 73, Average train DSC: 0.78733 !
#
# For epoch: 73, Average train DSC: -0.48453 !
# For epoch: 73, Average train MI: -0.91432 !
# For epoch: 73, Average train DDF: 0.85767 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7437 	 and 	 Current val loss: -0.9125
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 74/100
# LR is ==  0.0002
# For epoch: 74, Average train loss: -0.91682 !
# For epoch: 74, Average train DSC: 0.78531 !
#
# For epoch: 74, Average train DSC: -0.48242 !
# For epoch: 74, Average train MI: -0.91682 !
# For epoch: 74, Average train DDF: 0.85482 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7457 	 and 	 Current val loss: -0.9096
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 75/100
# LR is ==  0.0002
# For epoch: 75, Average train loss: -0.91701 !
# For epoch: 75, Average train DSC: 0.78593 !
#
# For epoch: 75, Average train DSC: -0.47916 !
# For epoch: 75, Average train MI: -0.91701 !
# For epoch: 75, Average train DDF: 0.84524 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7474 	 and 	 Current val loss: -0.9103
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 76/100
# LR is ==  0.0002
# For epoch: 76, Average train loss: -0.92087 !
# For epoch: 76, Average train DSC: 0.78645 !
#
# For epoch: 76, Average train DSC: -0.48283 !
# For epoch: 76, Average train MI: -0.92087 !
# For epoch: 76, Average train DDF: 0.86902 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7549 	 and 	 Current val loss: -0.9300
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 77/100
# LR is ==  0.0002
# For epoch: 77, Average train loss: -0.92082 !
# For epoch: 77, Average train DSC: 0.78692 !
#
# For epoch: 77, Average train DSC: -0.48330 !
# For epoch: 77, Average train MI: -0.92082 !
# For epoch: 77, Average train DDF: 0.84907 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7446 	 and 	 Current val loss: -0.9250
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 78/100
# LR is ==  0.0002
# For epoch: 78, Average train loss: -0.92273 !
# For epoch: 78, Average train DSC: 0.78653 !
#
# For epoch: 78, Average train DSC: -0.48150 !
# For epoch: 78, Average train MI: -0.92273 !
# For epoch: 78, Average train DDF: 0.88216 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7431 	 and 	 Current val loss: -0.9186
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 79/100
# LR is ==  0.0002
# For epoch: 79, Average train loss: -0.92086 !
# For epoch: 79, Average train DSC: 0.78614 !
#
# For epoch: 79, Average train DSC: -0.48384 !
# For epoch: 79, Average train MI: -0.92086 !
# For epoch: 79, Average train DDF: 0.89887 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7484 	 and 	 Current val loss: -0.9233
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 80/100
# LR is ==  0.0002
# For epoch: 80, Average train loss: -0.91980 !
# For epoch: 80, Average train DSC: 0.78584 !
#
# For epoch: 80, Average train DSC: -0.48163 !
# For epoch: 80, Average train MI: -0.91980 !
# For epoch: 80, Average train DDF: 0.87923 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7449 	 and 	 Current val loss: -0.9285
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 81/100
# LR is ==  0.0002
# For epoch: 81, Average train loss: -0.91795 !
# For epoch: 81, Average train DSC: 0.78679 !
#
# For epoch: 81, Average train DSC: -0.47865 !
# For epoch: 81, Average train MI: -0.91795 !
# For epoch: 81, Average train DDF: 0.86485 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7469 	 and 	 Current val loss: -0.8780
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 82/100
# LR is ==  0.0002
# For epoch: 82, Average train loss: -0.91437 !
# For epoch: 82, Average train DSC: 0.78517 !
#
# For epoch: 82, Average train DSC: -0.47620 !
# For epoch: 82, Average train MI: -0.91437 !
# For epoch: 82, Average train DDF: 0.85893 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7448 	 and 	 Current val loss: -0.8958
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 83/100
# LR is ==  0.0002
# For epoch: 83, Average train loss: -0.91794 !
# For epoch: 83, Average train DSC: 0.78412 !
#
# For epoch: 83, Average train DSC: -0.47888 !
# For epoch: 83, Average train MI: -0.91794 !
# For epoch: 83, Average train DDF: 0.89545 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7451 	 and 	 Current val loss: -0.9184
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 84/100
# LR is ==  0.0002
# For epoch: 84, Average train loss: -0.92117 !
# For epoch: 84, Average train DSC: 0.78540 !
#
# For epoch: 84, Average train DSC: -0.48206 !
# For epoch: 84, Average train MI: -0.92117 !
# For epoch: 84, Average train DDF: 0.89274 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7464 	 and 	 Current val loss: -0.9091
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 85/100
# LR is ==  0.0002
# For epoch: 85, Average train loss: -0.92119 !
# For epoch: 85, Average train DSC: 0.78455 !
#
# For epoch: 85, Average train DSC: -0.48100 !
# For epoch: 85, Average train MI: -0.92119 !
# For epoch: 85, Average train DDF: 0.88258 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7418 	 and 	 Current val loss: -0.8979
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 86/100
# LR is ==  0.0002
# For epoch: 86, Average train loss: -0.91856 !
# For epoch: 86, Average train DSC: 0.78387 !
#
# For epoch: 86, Average train DSC: -0.47504 !
# For epoch: 86, Average train MI: -0.91856 !
# For epoch: 86, Average train DDF: 0.90562 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7507 	 and 	 Current val loss: -0.9147
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 87/100
# LR is ==  0.0002
# For epoch: 87, Average train loss: -0.91621 !
# For epoch: 87, Average train DSC: 0.78472 !
#
# For epoch: 87, Average train DSC: -0.47708 !
# For epoch: 87, Average train MI: -0.91621 !
# For epoch: 87, Average train DDF: 0.90423 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7543 	 and 	 Current val loss: -0.9169
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 88/100
# LR is ==  0.0002
# For epoch: 88, Average train loss: -0.91337 !
# For epoch: 88, Average train DSC: 0.78374 !
#
# For epoch: 88, Average train DSC: -0.48023 !
# For epoch: 88, Average train MI: -0.91337 !
# For epoch: 88, Average train DDF: 0.86996 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7551 	 and 	 Current val loss: -0.9101
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 89/100
# LR is ==  0.0002
# For epoch: 89, Average train loss: -0.90835 !
# For epoch: 89, Average train DSC: 0.78502 !
#
# For epoch: 89, Average train DSC: -0.47901 !
# For epoch: 89, Average train MI: -0.90835 !
# For epoch: 89, Average train DDF: 0.85859 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7542 	 and 	 Current val loss: -0.9149
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 90/100
# LR is ==  0.0002
# For epoch: 90, Average train loss: -0.91150 !
# For epoch: 90, Average train DSC: 0.78532 !
#
# For epoch: 90, Average train DSC: -0.48120 !
# For epoch: 90, Average train MI: -0.91150 !
# For epoch: 90, Average train DDF: 0.86468 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7453 	 and 	 Current val loss: -0.8974
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 91/100
# LR is ==  0.0002
# For epoch: 91, Average train loss: -0.91031 !
# For epoch: 91, Average train DSC: 0.78585 !
#
# For epoch: 91, Average train DSC: -0.48161 !
# For epoch: 91, Average train MI: -0.91031 !
# For epoch: 91, Average train DDF: 0.86319 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7411 	 and 	 Current val loss: -0.8888
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 92/100
# LR is ==  0.0002
# For epoch: 92, Average train loss: -0.91320 !
# For epoch: 92, Average train DSC: 0.78619 !
#
# For epoch: 92, Average train DSC: -0.48162 !
# For epoch: 92, Average train MI: -0.91320 !
# For epoch: 92, Average train DDF: 0.85898 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7580 	 and 	 Current val loss: -0.9184
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 93/100
# LR is ==  0.0002
# For epoch: 93, Average train loss: -0.92095 !
# For epoch: 93, Average train DSC: 0.78663 !
#
# For epoch: 93, Average train DSC: -0.48113 !
# For epoch: 93, Average train MI: -0.92095 !
# For epoch: 93, Average train DDF: 0.90249 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7563 	 and 	 Current val loss: -0.9099
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 94/100
# LR is ==  0.0002
# For epoch: 94, Average train loss: -0.92453 !
# For epoch: 94, Average train DSC: 0.78713 !
#
# For epoch: 94, Average train DSC: -0.48102 !
# For epoch: 94, Average train MI: -0.92453 !
# For epoch: 94, Average train DDF: 0.95857 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7490 	 and 	 Current val loss: -0.9110
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 95/100
# LR is ==  0.0002
# For epoch: 95, Average train loss: -0.92750 !
# For epoch: 95, Average train DSC: 0.78495 !
#
# For epoch: 95, Average train DSC: -0.48062 !
# For epoch: 95, Average train MI: -0.92750 !
# For epoch: 95, Average train DDF: 0.93201 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7467 	 and 	 Current val loss: -0.9179
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 96/100
# LR is ==  0.0002
# For epoch: 96, Average train loss: -0.92766 !
# For epoch: 96, Average train DSC: 0.78507 !
#
# For epoch: 96, Average train DSC: -0.48119 !
# For epoch: 96, Average train MI: -0.92766 !
# For epoch: 96, Average train DDF: 0.94366 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7429 	 and 	 Current val loss: -0.9152
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 97/100
# LR is ==  0.0002
# For epoch: 97, Average train loss: -0.92948 !
# For epoch: 97, Average train DSC: 0.78418 !
#
# For epoch: 97, Average train DSC: -0.48047 !
# For epoch: 97, Average train MI: -0.92948 !
# For epoch: 97, Average train DDF: 0.96915 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7528 	 and 	 Current val loss: -0.9256
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 98/100
# LR is ==  0.0002
# For epoch: 98, Average train loss: -0.93060 !
# For epoch: 98, Average train DSC: 0.78587 !
#
# For epoch: 98, Average train DSC: -0.48248 !
# For epoch: 98, Average train MI: -0.93060 !
# For epoch: 98, Average train DDF: 0.98296 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7528 	 and 	 Current val loss: -0.9243
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 99/100
# LR is ==  0.0002
# For epoch: 99, Average train loss: -0.92886 !
# For epoch: 99, Average train DSC: 0.78522 !
#
# For epoch: 99, Average train DSC: -0.48083 !
# For epoch: 99, Average train MI: -0.92886 !
# For epoch: 99, Average train DDF: 0.94767 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7531 	 and 	 Current val loss: -0.9255
#
# Best val DSC: 0.7585 at epoch number of 12
# ----------------------------------------------------------------------------------------------------
# Epoch 100/100
# LR is ==  0.0002
# For epoch: 100, Average train loss: -0.92821 !
# For epoch: 100, Average train DSC: 0.78522 !
#
# For epoch: 100, Average train DSC: -0.48164 !
# For epoch: 100, Average train MI: -0.92821 !
# For epoch: 100, Average train DDF: 0.93068 !
# ------------------------------------------------------------
#
# Current mean dice: 0.7515 	 and 	 Current val loss: -0.9242
#
# Best val DSC: 0.7585 at epoch number of 12

# %%
# %matplotlib inline
plt.figure("train", (20, 4))
plt.subplot(1, 2, 1)
plt.plot(epoch_loss_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.plot(epoch_val_loss_values, label = 'val', color='b', lw=2, linestyle='-', marker = 'x')
plt.legend(fontsize=20, loc='upper right', ncol=1)
plt.xticks(range(0, max_epochs , 10))
plt.ylabel('Losses', fontsize=20)
plt.xlabel('Epochs', fontsize=20)

plt.subplot(1, 2, 2)
plt.plot(metric_values, label = 'training', color='k', lw=2, linestyle='-', marker = 'o')
plt.ylabel('DSC', fontsize=20)
plt.xlabel('Epochs', fontsize=20)
# Out:
# Text(0.5, 0, 'Epochs')

# %%
def hausdorff (mask1, mask2):
    mask1_class_LV = mask1.copy()
    mask1_class_Myo = mask1.copy()
    
    mask1_class_LV[mask1_class_LV==1] = 0
    mask1_class_Myo[mask1_class_Myo==2] = 0
    
    mask2_class_LV = mask2.copy()
    mask2_class_Myo = mask2.copy()
    
    mask2_class_LV[mask2_class_LV==1] = 0
    mask2_class_Myo[mask2_class_Myo==2] = 0
    
    hausdorff_Myo = (directed_hausdorff(mask1_class_Myo, mask2_class_Myo)[0]+directed_hausdorff(mask2_class_Myo, mask1_class_Myo)[0])/2

    hausdorff_LV = (directed_hausdorff(mask1_class_LV, mask2_class_LV)[0]+directed_hausdorff(mask2_class_LV, mask1_class_LV)[0])/2
    
    return [hausdorff_Myo, hausdorff_LV]

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()

metric = monai.metrics.MSEMetric()

before_MSEMetric = []
after_MSEMetric = []

before_compute_meandice = []
after_compute_meandice = []

before_compute_hausdorff_distance = []
after_compute_hausdorff_distance = []
                                                                         

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    before_MSEMetric.extend(metric(moving_val_img_,fixed_val_img_).detach().cpu().numpy())
    
    after_MSEMetric.extend(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())
    
#     print(metric(pred_image_val,fixed_val_img_).detach().cpu().numpy())

    before_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy())
    after_compute_hausdorff_distance.extend((compute_hausdorff_distance(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3), directed=True)).detach().cpu().numpy()) 
    
    
    before_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(moving_val_msk_, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy())
    after_compute_meandice.extend((compute_meandice(y_pred = make_one_hot(pred_mask_val, C=3), y=make_one_hot(fixed_val_msk_, C=3))).detach().cpu().numpy()) 
    
    
#     break

print(np.array(before_MSEMetric).shape)
print(np.array(after_MSEMetric).shape)

print(np.array(before_compute_meandice).shape)
print(np.array(after_compute_meandice).shape)

print()

print(f'MSEMetric W/O registration {np.mean(np.array(before_MSEMetric))}')
print(f'MSEMetric W/ registration = {np.mean(np.array(after_MSEMetric))}')

print(f'Mean dice W/O registration = {np.mean(np.array(before_compute_meandice), axis=0)}')
print(f'Mean dice W/ registration = {np.mean(np.array(after_compute_meandice), axis=0)}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.array(before_compute_hausdorff_distance), axis=0)}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.array(after_compute_hausdorff_distance), axis=0)}')

print()

print('----------------For Report Metric +/- Std-----------------------')
print(f'Mean dice W/O registration = {np.mean(np.mean(np.array(before_compute_meandice), axis=0))} + {np.mean(np.std(np.array(before_compute_meandice), axis=0))}')
print(f'Mean dice W/ registration = {np.mean(np.mean(np.array(after_compute_meandice), axis=0))} + {np.mean(np.std(np.array(after_compute_meandice), axis=0))}')

print(f'Hausdorff_distance W/O registration = {np.mean(np.mean(np.array(before_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(before_compute_hausdorff_distance), axis=0))}')
print(f'Hausdorff_distance W/ registration = {np.mean(np.mean(np.array(after_compute_hausdorff_distance), axis=0))} + {np.mean(np.std(np.array(after_compute_hausdorff_distance), axis=0))}')

df = ({
     'before_compute_hausdorff_distance':np.mean(np.array(before_compute_hausdorff_distance), axis=1),
     'after_compute_hausdorff_distance'   : np.mean(np.array(after_compute_hausdorff_distance), axis=1),
     'before_compute_meandice':np.mean(np.array(before_compute_meandice), axis=1),
     'after_compute_meandice':np.mean(np.array(after_compute_meandice), axis=1),
     'before_MSEMetric': np.mean(np.array(before_MSEMetric), axis=1),
     'after_MSEMetric':np.mean(np.array(after_MSEMetric), axis=1)
})

pd.DataFrame(df).to_csv(fileNames+'.csv')
# Out:
# <function compute_meandice at 0x7ff095f471f0>: Function `compute_meandice` has been deprecated since version 1.0.0. use `compute_dice` instead.
# (20, 1)
# (20, 1)
# (20, 3)
# (20, 3)
#
# MSEMetric W/O registration 0.0037914433050900698
# MSEMetric W/ registration = 0.0032817113678902388
# Mean dice W/O registration = [0.99137247 0.8077254  0.7419963 ]
# Mean dice W/ registration = [0.9877888  0.68632334 0.60133445]
# Hausdorff_distance W/O registration = [5.79930922 6.06233479]
# Hausdorff_distance W/ registration = [20.86653829  6.84991817]
#
# ----------------For Report Metric +/- Std-----------------------
# Mean dice W/O registration = 0.8470314145088196 + 0.12218629568815231
# Mean dice W/ registration = 0.7584821581840515 + 0.09043965488672256
# Hausdorff_distance W/O registration = 5.930822006719249 + 2.0668776584082336
# Hausdorff_distance W/ registration = 13.858228234640656 + 3.7723098253487652

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, fileNames+'.pth')))
model.eval()
                                          

for fixed_val_img_, fixed_val_msk_, moving_val_img_, moving_val_msk_ in zip(fixed_val_img, fixed_val_msk,
                                                                                        moving_val_img, moving_val_msk): 
    
    fixed_val_img_ = fixed_val_img_.to(device)
    fixed_val_msk_ = fixed_val_msk_.to(device)

    moving_val_img_ = moving_val_img_.to(device)
    moving_val_msk_ = moving_val_msk_.to(device)


    ddf_val = model(torch.cat((moving_val_img_, fixed_val_img_), dim=1))

    pred_image_val = warp_layer(moving_val_img_, ddf_val)
    pred_mask_val = warp_layer(moving_val_msk_, ddf_val)
    
    
    break

fixed_val_img_ = fixed_val_img_.detach().cpu().numpy()[:, 0]
fixed_val_msk_ = fixed_val_msk_.detach().cpu().numpy()[:, 0]

moving_val_img_ = moving_val_img_.detach().cpu().numpy()[:, 0]
moving_val_msk_ = moving_val_msk_.detach().cpu().numpy()[:, 0]

pred_image_val = pred_image_val.detach().cpu().numpy()[:, 0]
pred_mask_val = pred_mask_val.detach().cpu().numpy()[:, 0]

# %%
def colored (pred_img, true_img): 
    bitwise_and = cv2.bitwise_and(pred_img, true_img)
    
    TP = np.stack((np.zeros_like(bitwise_and), bitwise_and, np.zeros_like(bitwise_and)), axis=-1)
    
    FN = np.stack((true_img-bitwise_and,
                   true_img-bitwise_and,
                   np.zeros_like(true_img-bitwise_and)), axis=-1)
    
    FP = np.stack((pred_img-bitwise_and,
                   pred_img-bitwise_and,
                  np.zeros_like(pred_img-bitwise_and)), axis=-1)
    
    return (255*(TP+FN+FP)).astype('uint8')

# %%
slice_no = 15
# %matplotlib inline
slice_num = 8
plt.subplots(slice_num, 7, figsize=(12, 15))

for b in range(slice_num):
    # moving image
    plt.subplot(slice_num, 7, b * 7 + 1)
    plt.axis('off')
    plt.title("moving img")
    plt.imshow(moving_val_img_[0, :, :, slice_no], cmap="gray")
    
    # moving label
    plt.subplot(slice_num, 7, b * 7 + 2)
    plt.axis('off')
    plt.title("moving lab")
    plt.imshow(moving_val_msk_[0, :, :, slice_no], cmap="gray")
    
    
    # fixed image
    plt.subplot(slice_num, 7, b * 7 + 3)
    plt.axis('off')
    plt.title("fixed img")
    plt.imshow(fixed_val_img_[0, :, :, slice_no], cmap="gray")
    
    # fixed label
    plt.subplot(slice_num, 7, b * 7 + 4)
    plt.axis('off')
    plt.title("fixed lab")
    plt.imshow(fixed_val_msk_[0, :, :, slice_no], cmap="gray")
    
    
    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 5)
    plt.axis('off')
    plt.title("Pred Img")
    plt.imshow(pred_image_val[0, :, :, slice_no], cmap="gray")


    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 6)
    plt.axis('off')
    plt.title("Before Reg")
    plt.imshow(colored(moving_val_msk_[0, :, :, slice_no], fixed_val_msk_[0, :, :, slice_no]))
    
    
    # warped moving
    plt.subplot(slice_num, 7, b * 7 + 7)
    plt.axis('off')
    plt.title("After Reg")
    plt.imshow(colored(pred_mask_val[0, :, :, slice_no], fixed_val_msk_[0, :, :, slice_no]))

    slice_no = slice_no + 1
    
plt.axis('off')
plt.show()
